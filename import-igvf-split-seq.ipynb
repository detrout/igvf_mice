# %% [markdown]
# # Introduction

# %% [markdown]
# UCI has a complex google doc they've been using to track their samples so far.
#
# https://docs.google.com/spreadsheets/d/13M6-Ry6oXgkx94BHZOGioYPI6F_hWDqjGgcaNu2JNYs/edit#gid=1838362486
#
# Also there's a metadata spreadsheet for IGVF at
# https://docs.google.com/spreadsheets/d/1BLMledzmqOqXnJHzpijgw91IOs-9tSlVeZDG_MtXddk/edit#gid=1284120531

# %%
import bz2
from collections import Counter, namedtuple
import datetime
import numpy
import os
import pandas
from pathlib import Path
import re
from subprocess import run, PIPE
import sys
import zoneinfo
from tqdm import tqdm

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'mousedemo.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

import django
from django.contrib.auth import get_user_model
from django.db import DEFAULT_DB_ALIAS

MOUSEDEMO = str(Path("mousedemo").absolute())
if MOUSEDEMO not in sys.path:
    sys.path.append(MOUSEDEMO)

# %% [markdown]
# # Pre-initialization setup

# %% [markdown]
# Backup the old ones and make a new database file before we initialize the database.

# %%
# Create a new database
result = run(["python3", "manage.py", "check"], capture_output=True)

if len(result.stderr) > 0:
    print(result.stderr.decode("utf-8"))
    
result.check_returncode()

# %%
initial = Path("igvf_mice/migrations/0001_initial.py")
if initial.exists():
    initial.unlink()
    
result = run(["python3", "manage.py", "makemigrations", "igvf_mice"], capture_output=True)

if len(result.stderr) > 0:
    print(result.stderr.decode("utf-8"))
    
result.check_returncode()

# %%
# Backup several old sqlite database files

db_name = Path("db.sqlite3")

backup_names = []
for i in range(0, 4):
    backup_names.append(Path("db{}.sqlite3".format(i+1)))

if backup_names[-1].exists():
    backup_names[-1].unlink()

if db_name.exists():    
    for i in reversed(range(0, 3)):
        if backup_names[i].exists():
            print("renaming {} to {}".format(backup_names[i], backup_names[i+1]))
            backup_names[i].rename(backup_names[i+1])

    db_name.rename(backup_names[0])
    print("renaming {} to {}".format(db_name, backup_names[0]))
# Out:
# renaming db3.sqlite3 to db4.sqlite3
# renaming db2.sqlite3 to db3.sqlite3
# renaming db1.sqlite3 to db2.sqlite3
# renaming db.sqlite3 to db1.sqlite3

# %%
# Create a new database
result = run(["python3", "manage.py", "migrate"], capture_output=True)

if len(result.stderr) > 0:
    print(result.stderr.decode("utf-8"))
    
result.check_returncode()
    
assert Path("db.sqlite3").exists()

# %% [markdown]
# # Setup users

# %% [markdown]
# Now that we have a fresh clean database, lets create user accounts

# %%
django.setup()

from mousedemo import settings
from igvf_mice import models

# %%
# Create accounts.
with open("pw", "rt") as instream:
    pw = instream.read().strip()

user_model = get_user_model()
user_model._default_manager.db_manager(DEFAULT_DB_ALIAS).create_superuser(
    username="diane",
    password=pw,   
)
pw = None

# %% [markdown]
# # Load data

# %%
#spreadsheet_name = "IGVF_Split-seq_20230118.xlsx"
lizs_sheet_name = "https://woldlab.caltech.edu/nextcloud/index.php/s/eEtjBfDqQFnLpSS/download"

book = pandas.ExcelFile(lizs_sheet_name)
for name in book.sheet_names:
    print(name)
# Out:
# Planning
# Counting
# mice - 8 founders
# Line information
# schedule - all
# Sheet40
# Nuclei isolation Schedule with
# Samples - 8 founders
# tissue weights
# gonads plots
# Bridge Samples
# Samples into experiment
# Gastroc_numbers
# Gastroc_testing
# Gastroc_all_reps
# Bridge samples into experiment
# Plate setups
# Failed_samples
# Experiment
# Recount for gene capture
# DCC
# PBMCs
# Recount_TA
# practice mice
# IGVF002 Pilot Samples
# IGVF002 Pulverized Samples
# IGVF002 Plate Setup
# IGVF002 Metadata
# Cerebellum testing

# %%
submitted_book_names = {
    "IGVF_003": "https://woldlab.caltech.edu/nextcloud/index.php/s/nBnE6j2RBMkpM9i/download",
    "IGVF_b01": "https://woldlab.caltech.edu/nextcloud/index.php/s/5cJteSWgitN5BDM/download",
}
submitted_sheets = {}
for book_name in submitted_book_names:
    book = pandas.ExcelFile(submitted_book_names[book_name])
    
    for sheet_name in book.sheet_names:
        if sheet_name not in submitted_sheets:
            submitted_sheets[sheet_name] = book.parse(sheet_name)
        else:
            submitted_sheets[sheet_name] = pandas.concat([submitted_sheets[sheet_name], book.parse(sheet_name)])

# %% [markdown]
# Converters

# %%
def truncate(model):
    table_name = model._meta.db_table
    assert "\\" not in table_name
    with django.db.connection.cursor() as cursor:
        # I don't know why the sql params didn't work. this is a sql vulnerability waiting to happen
        cursor.execute("delete from \"{}\"".format(table_name))
        cursor.execute("DELETE FROM SQLITE_SEQUENCE WHERE name=\"{}\"".format(table_name))
        cursor.fetchone()

# %%
def int_or_none(x):
    if x in ("N/A", '#DIV/0!', '-'):
        return None
    elif pandas.isnull(x):
        return None
    else:
        return int(x)
    
def int_or_0(x):
    if pandas.isnull(x):
        return 0
    else:
        return int(x)

def float_or_none(x):
    if pandas.isnull(x):
        return None
    else:
        return float(x)
    
def str_or_empty(x):
    if pandas.isnull(x):
        return ""
    else:
        return x

def str_or_none(x):
    if pandas.isnull(x):
        return None
    else:
        return x
    
def date_or_none(x):
    if pandas.isnull(x):
        return None
    elif isinstance(x, datetime.datetime):
        return x.date()
    elif x in ("-"):
        return None
    else:
        return x

def datetime_or_none(x):
    if pandas.isnull(x):
        return None
    else:
        return x

# %% [markdown]
# # initialize general use tables

# %%
accession_namespaces = [
    {"name": "ENCODE", "homepage": "https://www.encodeproject.org", "accession_prefix": "encode"},
    {"name": "ENCODE test", "homepage": "https://test.encodedcc.org", "accession_prefix": "encodetst"},
    {"name": "IGVF", "homepage": "https://data.igvf.org", "accession_prefix": "igvf"},
    {"name": "IGVF test", "homepage": "https://sandbox.igvf.org", "accession_prefix": "igvftst"},
]

if models.AccessionNamespace.objects.count() > 0:
    truncate(models.AccessionNamespace)

for row in accession_namespaces:
    record = models.AccessionNamespace(
        name=row["name"],
        homepage=row["homepage"],
        accession_prefix=row["accession_prefix"],
    )
    record.save()

igvf_namespace = models.AccessionNamespace.objects.get(name="IGVF")
igvf_test_namespace = models.AccessionNamespace.objects.get(name="IGVF test")

# %%
source = [
    {
        "name": "The Jackson Laboratory", 
        "homepage": "http://www.jax.org/index.html", 
        "igvf_id": "/sources/jackson-labs/",
    },
    {
        "name": "Parse Bioscience", 
        "homepage": "https://www.parsebiosciences.com/",
        "igvf_id": "/sources/parse-biosciences/",
    },
    {
        "name": "Illumina", 
        "homepage": "https://www.illumina.com", 
        "igvf_id": "/sources/illumina/",
    },
]

if models.Source.objects.count() > 0:
    truncate(models.Source)

for row in source:
    record = models.Source(
        name=row["name"],
        homepage=row["homepage"],
        igvf_id=row["igvf_id"])
    record.save()

jax_source = models.Source.objects.get(name="The Jackson Laboratory")

# %%
# Should this include machine model?
illumina_source = models.Source.objects.get(name="Illumina")
platforms = [
    {"display_name": "Nextseq 2000", "name": "nextseq2000", "family": "illumina", "igvf_id": "/platform-terms/EFO_0010963/", "source": illumina_source},
    {"display_name": "Novaseq 6000", "name": "novaseq6000", "family": "illumina", "igvf_id": "/platform-terms/EFO_0008637/", "source": illumina_source},
    {"display_name": "Oxford Nanopore", "name": "nanopore", "family": "nanopore",},
    {"display_name": "Pac Bio", "name": "pacbio", "family": "pacbio",},
]

for row in platforms:
    record = models.Platform(
        name=row["name"],
        display_name=row["display_name"],
        family=row["family"],
        igvf_id=row.get("igvf_id"),
        source=row.get("source"),
    )
    record.save()

# %% [markdown]
# # Library kit type & version

# %%
library_construction_kit = [
    {"name": "WT Mega", "version": "v2", "source": "Parse Bioscience"},
]

if models.LibraryConstructionKit.objects.count() > 0:
    truncate(models.LibraryConstructionKit)

for row in library_construction_kit:
    try:
        source = models.Source.objects.get(name=row["source"])
        
        record = models.LibraryConstructionKit(
            name=row["name"],
            version=row["version"],
            source=source,
        )
        record.save()        
    except models.Source.DoesNotExist:
        print(f"Couldn't find {row['source']}")

# %% [markdown]
# # Load LibraryBarcodes

# %%
models.LibraryConstructionKit.objects.get(name="WT Mega")
# Out:
# <LibraryConstructionKit: WT Mega v2>

# %%
if models.LibraryBarcode.objects.count() > 0:
    truncate(models.LibraryBarcode)


# Load WT Mega v2 first barcode
bc1 = pandas.read_csv("bc_data_n192_v4.csv")

kit = models.LibraryConstructionKit.objects.get(name="WT Mega", version="v2")

for i, row in bc1.iterrows():
    record = models.LibraryBarcode(
        kit=kit,
        name=row["uid"],
        code=row["well"],
        sequence=row["sequence"],
        barcode_type=row["type"], # TODO what do the codes mean again T,R?
    )
    record.save()

subpool = [
    ("1", "CAGATC"),
    ("2", "ACTTGA"),
    ("3", "GATCAG"),
    ("4", "TAGCTT"),
    ("5", "ATGTCA"),
    ("6", "CTTGTA"),
    ("7", "AGTCAA"),
    ("8", "AGTTCC"),
    ("9", "GAGTGG"),
    ("10", "CCGTCC"),
    ("11", "GTAGAG"),
    ("12", "GTCCGC"),
    ("13", "GTGAAA"),
    ("14", "GTGGCC"),
    ("15", "GTTTCG"),
    ("16", "CGTACG"),
]
subpool = pandas.DataFrame(subpool, columns=["code","sequence"])

for i, row in subpool.iterrows():
    record = models.LibraryBarcode(
        kit=kit,
        code=row["code"],
        sequence=row["sequence"],
    )
    record.save()

# %% [markdown]
# # Initialize TissueOntology

# %%
seen_tissues = Counter()
for sample_sheet_name in ["Samples - 8 founders", "Bridge Samples"]:
    tissue_sheet = pandas.read_excel(
        lizs_sheet_name, 
        sample_sheet_name,
        usecols=["Tissue"]).dropna(axis=0, how='all')

    for i, row in tissue_sheet.iterrows():
        if not pandas.isnull(row["Tissue"]):
            seen_tissues[row["Tissue"]] += 1
    print(sample_sheet_name, tissue_sheet.shape, len(seen_tissues))

seen_tissues
# Out:
# Samples - 8 founders (1621, 1) 22
# Bridge Samples (144, 1) 26
# Counter({'Hypothalamus/Pituitary': 81,
#          'Cerebellum': 81,
#          'Cortex/Hippocampus left': 81,
#          'Cortex/Hippocampus right': 81,
#          'Liver': 81,
#          'Heart': 81,
#          'Lung': 81,
#          'Adrenal': 81,
#          'Kidney': 81,
#          'Gonads -1 Ovary': 41,
#          'Gonads -2 Oviduct': 41,
#          'Perigonadal fat': 81,
#          'Brown fat': 81,
#          'Soleus': 81,
#          'Plantaris': 81,
#          'Gastrocnemius': 82,
#          'TA': 81,
#          'EDL': 81,
#          'Tail': 105,
#          'PBMC - WBC': 105,
#          'Gonads -1 Testis': 40,
#          'Gonads -2 Epididymis': 40,
#          'Left cortex': 24,
#          'Right cortex': 24,
#          'Left hippocampus': 24,
#          'Right hippocampus': 24})

# %%
tissue_dissection_to_ontology_map = {
    'Hypothalamus/Pituitary': [("UBERON:0001898","hypothalamus"), ("UBERON:0000007","pituitary gland")],
    'Cerebellum': [("UBERON:0002037","cerebellum")],
    # Hippocampus might be:
    #   Hippocampal formation UBERON:0002421 https://www.ebi.ac.uk/ols/ontologies/uberon/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FUBERON_0002421
    #   Layer of hippocampus UBERON:0002305 https://www.ebi.ac.uk/ols/ontologies/uberon/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FUBERON_0002305
    'Cortex/Hippocampus left': [("NTR:0000646","left cerebral cortex"), ("NTR:0000750", "Hippocampal formation left")],
    'Cortex/Hippocampus right': [("NTR:0000647","right cerebral cortex"), ("NTR:0000751", "Hippocampal formation right")],
    'Liver': [("UBERON:0002107", "liver")],
    'Heart': [("UBERON:0000948","heart")],
    'Lung': [("UBERON:0002048","lung")],
    'Adrenal': [("UBERON:0002369","adrenal gland")],
    'Kidney': [("UBERON:0002113","kidney")],
    'Gonads -1 Ovary': [("UBERON:0000992","ovary")],
    'Gonads -2 Oviduct': [("UBERON:0000993","oviduct")],
    'Perigonadal fat': [("UBERON:0003428", "gonadal fat pad")], #"is closer" to dissection
    'Brown fat': [("UBERON:0001348","brown adipose tissue")], 
    'Soleus': [("UBERON:0001389","soleus muscle")],
    'Plantaris': [("UBERON:0011905","plantaris")],
    'Gastrocnemius': [("UBERON:0001388","gastrocnemius")],
    'TA': [("UBERON:0001385","tibialis anterior")],
    'EDL': [("UBERON:0001386","extensor digitorum longus")],
    'Tail': [("UBERON:0002415","tail")],
    'PBMC - WBC': [("CL:2000001", "peripheral blood mononuclear cell")],
    'Gonads -1 Testis': [("UBERON:0000473","testis")],
    'Gonads -2 Epididymis': [("UBERON:0001301","epididymis")],
    "Left cortex": [("NTR:0000646","left cerebral cortex"),],
    "Right cortex": [("NTR:0000647","right cerebral cortex"),],
    "Left hippocampus": [("NTR:0000750", "Hippocampal formation left")],
    "Right hippocampus": [("NTR:0000751", "Hippocampal formation right")],
}

print(set(seen_tissues).difference(tissue_dissection_to_ontology_map.keys()))
# Out:
# set()

# %%
term_details = pandas.read_csv("obo.tsv.bz2", compression="bz2", sep="\t", index_col="term_id")

if models.OntologyTerm.objects.count() > 0:
    truncate(models.OntologyTerm)
    
for key in tissue_dissection_to_ontology_map:
    for term_curie, term_name in tissue_dissection_to_ontology_map[key]:
        if term_curie.startswith("NTR:"):
            description=None
        else:
            details = term_details.loc[term_curie]
            description = details.description

        record = models.OntologyTerm(
            curie=term_curie,
            name=term_name,
            description=description
        )
        record.save()

# %%
strain_urls = {
    "AJ": "https://www.jax.org/strain/000646",
    "B6J": "https://www.jax.org/strain/000664",
    "129S1J": "https://www.jax.org/strain/002448",
    "NODJ": "https://www.jax.org/strain/001976",
    "NZOJ": "https://www.jax.org/strain/002105",
    "CASTJ": "https://www.jax.org/strain/000928",
    "PWKJ": "https://www.jax.org/strain/003715",
    "WSBJ": "https://www.jax.org/strain/001145"
}

strain_name = {
    "AJ": "A/J (AJ)",
    "B6J": "C57BL/6J (B6)",
    "129S1J": "129S1/SvImJ (129)",
    "NODJ": "NOD/ShiLtJ (NOD)",
    "NZOJ": "NZO/HlLtJ (NZO)",
    "CASTJ": "CAST/EiJ (CAST)",
    "PWKJ": "PWK/PhJ (PWK)",
    "WSBJ": "WSB/EiJ (WSB)",
    #"CAST (M. m. castaneus)",
    #"WSB (M. m. domesticus)",
    #"PWK (M. m. musculus)",
}
strain_background = {k: strain_name[k].split(" ")[0] for k in strain_name}

# %%
def int_csv_to_hex(x):
    r, g, b = x.split(",")
    
    return "#{:02x}{:02x}{:02x}".format(int(r), int(g), int(b))

def remove_citation(x):
    return x.split(" ")[0]

strains = pandas.read_excel(
    lizs_sheet_name, 
    sheet_name="Line information", 
    usecols=[
        "Designation",
        "Strain",
        "Note",
        "Jax Catalog No",
        "Sample CODE",
        "Strain notes",
    ],
    converters={
        "Strain": remove_citation,
        "Jax Catalog No": str,
        "Strain notes": str_or_empty,
    }
)

# Remove the extra lines with the bridge samples for now. I don't want to track thta level of detail
bridge = strains[strains["Designation"] == "Bridge sample"].first_valid_index() - 1
strains = strains.iloc[0:bridge]

# Add in Strain URL
strains["url"] = strains["Sample CODE"].apply(lambda x: strain_urls[x])
strains
# Out:
#   Designation       Strain        Note Jax Catalog No Sample CODE  \
# 0           A          A/J  CC founder         000646          AJ
# 1           B     C57BL/6J  CC founder         000664         B6J
# 2           C  129S1/SvImJ  CC founder         002448      129S1J
# 3           D   NOD/ShiLtJ  CC founder         001976        NODJ
# 4           E    NZO/HlLtJ  CC founder         002105        NZOJ
# 5           F     CAST/EiJ  CC founder         000928       CASTJ
# 6           G      PWK/PhJ  CC founder         003715        PWKJ
# 7           H      WSB/EiJ  CC founder         001145        WSBJ
#
#                                         Strain notes  \
# 0                            Yellower adrenal gland.
# 1                                                NaN
# 2  Male skin is tougher than female skin. Gallbla...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#                                  url
# 0  https://www.jax.org/strain/000646
# 1  https://www.jax.org/strain/000664
# 2  https://www.jax.org/strain/002448
# 3  https://www.jax.org/strain/001976
# 4  https://www.jax.org/strain/002105
# 5  https://www.jax.org/strain/000928
# 6  https://www.jax.org/strain/003715
# 7  https://www.jax.org/strain/001145

# %%
strain_background
# Out:
# {'AJ': 'A/J',
#  'B6J': 'C57BL/6J',
#  '129S1J': '129S1/SvImJ',
#  'NODJ': 'NOD/ShiLtJ',
#  'NZOJ': 'NZO/HlLtJ',
#  'CASTJ': 'CAST/EiJ',
#  'PWKJ': 'PWK/PhJ',
#  'WSBJ': 'WSB/EiJ'}

# %%
strain_type_lookup = {
    "CC founder": models.StrainType.CC_FOUNDER,
    "CC Cross": models.StrainType.CC_CROSS,
}

if models.MouseStrain.objects.count() > 0:
    truncate(models.MouseStrain)

for i, row in strains.iterrows():
    record = models.MouseStrain(
        name=strain_name[row["Sample CODE"]],
        code=strain_background[row["Sample CODE"]],
        strain_type=strain_type_lookup[row["Note"]],
        jax_catalog_number=row["Jax Catalog No"],
        notes=str_or_empty(row["Strain notes"]),
        url=row["url"],
        source=jax_source,
    )
    record.save()

# %% [markdown]
# This is closest to the Mouse table

# %%
submitted_mice = {
}

for i, row in submitted_sheets["rodent_donor"].iterrows():
    if not pandas.isnull(row["accession"]):
        rodent_identifier = row["rodent_identifier"]
        submitted_mice[rodent_identifier] = {
            "namespace": igvf_test_namespace,
            "name": row["accession"],
            "uuid": row["uuid"],
            "url": "https://api.sandbox.igvf.org/rodent-donors/{}/".format(row["accession"]),
        }
        
print(len(submitted_mice))
# Out:
# 72

# %%
def estrus_cycle(x):
    if pandas.isnull(x):
        return "NA"
    else:
        return x

sex_lookup = {
    numpy.nan: models.SexEnum.UNKNOWN,
    "Female": models.SexEnum.FEMALE,
    "Male": models.SexEnum.MALE,
}

estrus_stage = {
    "Unknown": models.EstrusCycle.UNKNOWN,
    "Anestrus": models.EstrusCycle.ANESTRUS,
    "Anestrus>Proestrus": models.EstrusCycle.ANESTRUS_PROESTRUS,
    "Proestrus": models.EstrusCycle.PROESTRUS,
    "Proestrus>Estrus": models.EstrusCycle.PROESTRUS_ESTRUS,
    "Estrus": models.EstrusCycle.ESTRUS,
    "Estrus>Metestrus": models.EstrusCycle.ESTRUS_METESTRUS,
    "Metestrus": models.EstrusCycle.METESTRUS,
    "Metestrus>Diestrus": models.EstrusCycle.METESTRUS_DIESTRUS,
    "Diestrus": models.EstrusCycle.DIESTRUS,
    "Diestrus>Proestrus": models.EstrusCycle.DIESTRUS_PROESTRUS,
}

mice = pandas.read_excel(
    lizs_sheet_name, 
    sheet_name="mice - 8 founders", 
    usecols=range(0,16),
    converters={
        "Estres cycle stage": estrus_cycle,
        "Dissection ID": int,
        "RMS number": int_or_none,
        "Housing number": int_or_none,
    }
)

if models.Mouse.objects.count() > 0:
    truncate(models.Mouse)

los_angeles_tz = zoneinfo.ZoneInfo("America/Los_Angeles")



failed = False
for i, row in mice.iterrows():
    if not pandas.isnull(row["Mouse Name"]):
        name = row["Mouse Name"]
        strain_code = row["Strain"]
        
        if name == "056_WSBJ_10F->PWKJ_9F":
            name = "056_PWKJ_9F"

        try:
            strain = models.MouseStrain.objects.get(code=strain_code)
        except models.MouseStrain.DoesNotExist as e:
            print(f"Unable to find {row['Strain']} for row {i+2}")
            failed = True
            continue

        if not name[-1] in ("M", "F"):
            raise ValueError(f"Unrecognized sex field {mouse_name}")
            
        name_fields = name.split("_")
        
        if len(name_fields) != 3:
            raise ValueError(f"Wrong number of attributes in {name} line {i+1}")
            
        if not name_fields[1] in strain_background:
            raise ValueError(f"strain background in {name} not recognized line {i+1}")
        
        sample_box = "" if pandas.isnull(row["Sample box"]) else row["Sample box"]
        
        record = models.Mouse(
            # should i use liz's disection id?
            name=name,
            strain=strain,
            sex=sex_lookup[row["Sex"]],
            weight_g=row["Weight (g)"],
            date_of_birth=row["DOB"].date(),
            harvest_date=row["Harvest Date"].date(),
            operator=row["Operator"],
            notes=str_or_empty(row["Comments"]),
            sample_box=sample_box,
        )
        
        if not pandas.isnull(row["Estres cycle stage"]):
            # Ignore those transitions.
            stage = row["Estres cycle stage"]
            if stage.endswith("?"):
                stage = stage[:-1]
            record.estrus_cycle=estrus_stage[stage]
       
        record.save()
        
        if name in submitted_mice:
            accession = models.Accession(
                namespace=submitted_mice[name]["namespace"],
                name=submitted_mice[name]["name"],
                uuid=submitted_mice[name]["uuid"],
                url=submitted_mice[name]["url"],
            )
            accession.save()
            record.accession.set([accession])
            record.save()
        
        
        
assert not failed, "Check warning messages"

# %%
submitted_mice
# Out:
# {'016_B6J_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO32293389',
#   'uuid': '5adf9704-60ab-41da-bdb6-ac8a3b156fb3',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO32293389/'},
#  '017_B6J_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO90675659',
#   'uuid': '171702c9-bf6f-4759-839b-4a7946146837',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO90675659/'},
#  '018_B6J_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO01760234',
#   'uuid': 'f60da031-f24c-4baf-b001-898724466c91',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO01760234/'},
#  '019_B6J_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO83719175',
#   'uuid': 'd17f4e1b-ac5b-434a-be0b-fead09279d88',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO83719175/'},
#  '020_B6J_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO52284503',
#   'uuid': 'b006f822-9a39-424a-a2a7-8e7d2e2f1936',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO52284503/'},
#  '021_B6J_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO46924710',
#   'uuid': 'cdfbbed6-f466-4bdb-b2bd-531c5e94b13f',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO46924710/'},
#  '024_B6J_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO89093339',
#   'uuid': '35b4899d-69bc-451e-90b8-df9a78d5969d',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO89093339/'},
#  '025_B6J_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO29771657',
#   'uuid': '95e1cf00-0d36-4073-824b-995b8e323a01',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO29771657/'},
#  '026_AJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO94208104',
#   'uuid': 'effe348f-ea31-4c75-a987-6f0279d978a7',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO94208104/'},
#  '028_AJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO91714400',
#   'uuid': 'ff073641-5d3f-48b9-bf16-cd7d909f0a15',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO91714400/'},
#  '029_AJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO41491740',
#   'uuid': '194391ed-d287-4c8a-8a86-e61ef864cb76',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO41491740/'},
#  '030_AJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO86946008',
#   'uuid': '4feda215-69fe-4012-ab58-b708c554cfa3',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO86946008/'},
#  '031_AJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO43152139',
#   'uuid': '2951ca50-5074-49ab-8126-89f4d3463bae',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO43152139/'},
#  '032_AJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO00761787',
#   'uuid': '0bdaa947-9039-4c10-8ca9-f6de74c1aa21',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO00761787/'},
#  '033_AJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO80530242',
#   'uuid': '3df174fc-3b8e-4d45-8baa-678f62780340',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO80530242/'},
#  '035_AJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO38679396',
#   'uuid': 'f01857e6-c666-40a6-8166-c01b1498689c',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO38679396/'},
#  '036_129S1J_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO24931131',
#   'uuid': '91a043af-624a-4f97-8247-9d20a8420fdb',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO24931131/'},
#  '037_129S1J_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO12941763',
#   'uuid': '371c9315-de9a-4c9d-b4ff-5f7f6de8466e',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO12941763/'},
#  '038_129S1J_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO36528785',
#   'uuid': '49c3b628-4076-499f-9a81-57c497ddd443',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO36528785/'},
#  '040_129S1J_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO69479022',
#   'uuid': 'fda3b2db-d7ba-40d4-a75c-9ea4a8d08fcb',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO69479022/'},
#  '041_129S1J_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO85973629',
#   'uuid': '497e3dfe-6c56-408d-99a8-2832a8b4d896',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO85973629/'},
#  '043_129S1J_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO98710265',
#   'uuid': '58cf6e82-ebc2-4def-9a36-d57d0e7f60ab',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO98710265/'},
#  '044_129S1J_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO50102840',
#   'uuid': 'c62b902e-2d3b-40e9-8322-ad7499186e32',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO50102840/'},
#  '045_129S1J_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO92303956',
#   'uuid': '357c4a94-a447-4463-bf32-3801357a809f',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO92303956/'},
#  '046_NZOJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO38202788',
#   'uuid': '58d2c52b-839c-4afb-97c3-520b839d5869',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO38202788/'},
#  '047_NZOJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO64676241',
#   'uuid': '2c5e1cb0-3e59-410e-9b73-62107e1942bb',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO64676241/'},
#  '048_NZOJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO45656391',
#   'uuid': 'f13e9959-7cb1-4360-a32f-29d0627020ff',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO45656391/'},
#  '049_NZOJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO68840786',
#   'uuid': '9b0cea63-65ec-467d-a627-7c1f6f2c8857',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO68840786/'},
#  '050_NZOJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO62926149',
#   'uuid': '70337d0a-3c05-4855-9d58-e52b4c7dec1c',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO62926149/'},
#  '051_NZOJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO63535889',
#   'uuid': '7f3890bb-e4c3-4db8-bcbf-e7041c10f660',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO63535889/'},
#  '052_NZOJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO99451541',
#   'uuid': 'dec2121d-1c68-4d1a-aaf2-242a3a1a01f8',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO99451541/'},
#  '053_NZOJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO26972281',
#   'uuid': '668f320d-a2fa-4b2d-9a6f-87683e072299',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO26972281/'},
#  '057_WSBJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO03113260',
#   'uuid': 'b13a3c91-47e2-49f5-92fe-793c0e0fa66f',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO03113260/'},
#  '058_WSBJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO50709299',
#   'uuid': '49a338a5-d387-49f3-9958-e2826e34826d',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO50709299/'},
#  '059_WSBJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO33072093',
#   'uuid': '64c16d83-0103-4a69-bc93-00b5b3457a73',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO33072093/'},
#  '060_WSBJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO94485067',
#   'uuid': '1f7f110e-19a9-4493-b1f2-eef4228cde7d',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO94485067/'},
#  '061_WSBJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO73673021',
#   'uuid': '54b4d27b-b60f-4f83-a0b9-bbb2c8420b75',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO73673021/'},
#  '062_WSBJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO50952270',
#   'uuid': '87b47bfd-73e8-4c0d-97c2-eda6f9f28ee9',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO50952270/'},
#  '063_WSBJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO26939083',
#   'uuid': 'b23e5d2a-8055-4fa9-abfa-acd8ec7af714',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO26939083/'},
#  '066_NODJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO32028783',
#   'uuid': '23c6a218-7635-4e42-bf2b-d89c3484e70a',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO32028783/'},
#  '067_NODJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO58645928',
#   'uuid': '1b030e75-7903-4f0d-8769-4d21aed44666',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO58645928/'},
#  '068_NODJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO45253174',
#   'uuid': '57aab386-8712-45d3-8900-94adac9db0f0',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO45253174/'},
#  '069_NODJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO01181719',
#   'uuid': 'c73e6c01-1592-42ea-bca9-28012fec1b9c',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO01181719/'},
#  '070_NODJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO47750034',
#   'uuid': '07d56886-f206-485e-9e23-f01fac1d673d',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO47750034/'},
#  '071_NODJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO21887615',
#   'uuid': '84be0923-1042-47f6-a1b9-fca71fad45bb',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO21887615/'},
#  '072_NODJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO77277137',
#   'uuid': '45169eee-6121-4631-80a1-b2894f8692c6',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO77277137/'},
#  '073_NODJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO07183952',
#   'uuid': '75f2a287-4562-45c0-912e-7b6e5c250a29',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO07183952/'},
#  '076_PWKJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO07955113',
#   'uuid': '332cbbd4-0547-4ec7-990e-f87f1e8fe3fa',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO07955113/'},
#  '077_PWKJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO33656155',
#   'uuid': 'd402772d-610d-42f8-8561-12e4d1a10a3c',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO33656155/'},
#  '078_PWKJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO14034975',
#   'uuid': '3b900c90-c54f-4020-9037-aabbe560cb72',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO14034975/'},
#  '079_PWKJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO22244365',
#   'uuid': 'cd1fe40e-848d-4469-a21a-1fc49a6832d9',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO22244365/'},
#  '080_PWKJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO62994979',
#   'uuid': 'ca4b14cb-d663-4e07-af5c-178cd0785dd5',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO62994979/'},
#  '081_PWKJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO29678506',
#   'uuid': 'd6127558-a238-4f37-b2e0-3d484c4b4d32',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO29678506/'},
#  '084_PWKJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO51598158',
#   'uuid': 'fa10521b-df3a-44b3-bc8d-403f244599ee',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO51598158/'},
#  '085_PWKJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO11462810',
#   'uuid': '91a2183f-6c0f-4b63-8976-9170ba8944ed',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO11462810/'},
#  '086_CASTJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO12540543',
#   'uuid': '2b45f5f6-c236-414d-b236-bb88cb9943f4',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO12540543/'},
#  '087_CASTJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO32517230',
#   'uuid': '076f4e93-0639-405d-b325-6dd05e12bc2a',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO32517230/'},
#  '088_CASTJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO23401556',
#   'uuid': 'd46b8cba-84b7-4b9c-8da2-3bda165d4329',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO23401556/'},
#  '089_CASTJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO89564798',
#   'uuid': '4ed52a3f-0231-4b4f-be23-7f19857afb50',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO89564798/'},
#  '090_CASTJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO70628089',
#   'uuid': 'c612b3e4-8b25-44a0-92b4-545a1cc835fb',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO70628089/'},
#  '091_CASTJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO41429670',
#   'uuid': 'e9e761f8-2b58-41e5-b087-38eb4d129dd0',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO41429670/'},
#  '093_CASTJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO84986960',
#   'uuid': '9285186e-8ba4-4c03-8eb8-45844157f6c2',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO84986960/'},
#  '094_CASTJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO59020001',
#   'uuid': '880aa0ba-8af9-4804-a9ec-e848d9cf2042',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO59020001/'},
#  '096_WSBJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO49696857',
#   'uuid': '2859f493-3683-481e-bbb7-f60f0a26279e',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO49696857/'},
#  '105_CASTJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO49460733',
#   'uuid': '1d2a58e0-9f0b-45c2-a9cb-a2a66193d616',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO49460733/'},
#  '106_CASTJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO78829713',
#   'uuid': '5a0fde8b-9d8a-4be5-97c4-507f3b85babb',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO78829713/'},
#  '107_CASTJ_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO92049597',
#   'uuid': 'd9ae241a-cd2f-4c35-b515-8273c9891ab3',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO92049597/'},
#  '108_CASTJ_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO31719222',
#   'uuid': 'baebb5c6-bff2-4a63-9bbb-118b26c80390',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO31719222/'},
#  '117_B6J_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO02830801',
#   'uuid': '0885025d-bc54-4151-aacb-2e3866e9e18d',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO02830801/'},
#  '118_B6J_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO75684586',
#   'uuid': 'b41f3c2c-f15b-4973-9271-d6309ea2d325',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO75684586/'},
#  '119_B6J_10M': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO85621848',
#   'uuid': 'b9a48ed0-468c-4660-94df-b331dcad8dc4',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO85621848/'},
#  '120_B6J_10F': {'namespace': <AccessionNamespace: IGVF test>,
#   'name': 'TSTDO94777016',
#   'uuid': '3e862973-5993-431f-a2c6-a8656cb9a2aa',
#   'url': 'https://api.sandbox.igvf.org/rodent-donors/TSTDO94777016/'}}

# %% [markdown]
# # Tissues

# %%
#if models.Tissue.objects.count() > 0:
#    truncate(models.Tissue)

tissues_8cube = pandas.read_excel(
    lizs_sheet_name, 
    sheet_name="Samples - 8 founders",
    header=0,
).dropna(axis=0, how="all")
tissues_8cube
# Out:
#         IGVF Sample BOX  Mouse_Tissue ID Unnamed: 2                    Tissue  \
# 0       IGVF_Sample_5&6   016_B6J_10F_01        NaN    Hypothalamus/Pituitary
# 1       IGVF_Sample_5&6   016_B6J_10F_02        NaN                Cerebellum
# 2       IGVF_Sample_5&6   016_B6J_10F_03        NaN   Cortex/Hippocampus left
# 3       IGVF_Sample_5&6   016_B6J_10F_04        NaN  Cortex/Hippocampus right
# 4       IGVF_Sample_5&6   016_B6J_10F_05        NaN                     Liver
# ...                 ...              ...        ...                       ...
# 1616  IGVF_sample_17&18  096_WSBJ_10F_17        NaN                        TA
# 1617  IGVF_sample_17&18  096_WSBJ_10F_18        NaN                       EDL
# 1618  IGVF_sample_17&18  096_WSBJ_10F_19        NaN                      Tail
# 1619  IGVF_sample_17&18  096_WSBJ_10F_20        NaN                PBMC - WBC
# 1621    IGVF_Sample_5&6   122_B6J_10F_16        NaN             Gastrocnemius
#
#      Sex Timepoint Genotype Tube label  tube weight (g)  \
# 0      F  10 weeks      B6J     016-01            1.046
# 1      F  10 weeks      B6J     016-02            1.046
# 2      F  10 weeks      B6J     016-03            1.040
# 3      F  10 weeks      B6J     016-04            1.048
# 4      F  10 weeks      B6J     016-05            1.133
# ...   ..       ...      ...        ...              ...
# 1616   F  10 weeks     WSBJ     096-17            1.030
# 1617   F  10 weeks     WSBJ     096-18            1.030
# 1618   F  10 weeks     WSBJ     096-19            1.047
# 1619   F  10 weeks     WSBJ     096-20              NaN
# 1621   F  10 weeks      B6J     022-16            1.035
#
#       tube+tissue wight (g)  tissue weight (mg) or blood volume (ul)  \
# 0                     1.118                                     72.0
# 1                       NaN                                  -1046.0
# 2                     1.181                                    141.0
# 3                       NaN                                  -1048.0
# 4                     2.099                                    966.0
# ...                     ...                                      ...
# 1616                  1.089                                     59.0
# 1617                    NaN                                  -1030.0
# 1618                    NaN                                  -1047.0
# 1619                    NaN                                      NaN
# 1621                    NaN                                  -1035.0
#
#      cryopreserved blood location Dissection date Approx. sac time  \
# 0                             NaN      2022-10-27         09:01:00
# 1                             NaN      2022-10-27         09:01:00
# 2                             NaN      2022-10-27         09:01:00
# 3                             NaN      2022-10-27         09:01:00
# 4                             NaN      2022-10-27         09:01:00
# ...                           ...             ...              ...
# 1616                          NaN      2022-10-31         10:35:00
# 1617                          NaN      2022-10-31         10:35:00
# 1618                          NaN      2022-10-31         10:35:00
# 1619                          NaN      2022-10-31         10:35:00
# 1621                          NaN      2023-05-31         10:43:00
#
#       Body weight (g) Dissector Comment
# 0                21.1        SK     NaN
# 1                21.1        SK     NaN
# 2                21.1        SK     NaN
# 3                21.1        SK     NaN
# 4                21.1        GM     NaN
# ...               ...       ...     ...
# 1616             12.2        SK     NaN
# 1617             12.2        SK     NaN
# 1618             12.2        GM     NaN
# 1619             12.2       NaN     NaN
# 1621              NaN        SK     NaN
#
# [1621 rows x 17 columns]

# %%
#if models.Tissue.objects.count() > 0:
#    truncate(models.Tissue)

tissues_bridge = pandas.read_excel(
    lizs_sheet_name, 
    sheet_name="Bridge Samples",
    header=0,
).dropna(axis=0, how="all")
tissues_bridge
# Out:
#          IGVF Sample BOX   Mouse_Tissue ID Unnamed: 2             Tissue Sex  \
# 0    IGVF_BridgeSample_1  097_CASTJ_10M_19        NaN               Tail   M
# 1    IGVF_BridgeSample_1  097_CASTJ_10M_20        NaN         PBMC - WBC   M
# 2    IGVF_BridgeSample_1  097_CASTJ_10M_21        NaN        Left cortex   M
# 3    IGVF_BridgeSample_1  097_CASTJ_10M_22        NaN       Right cortex   M
# 4    IGVF_BridgeSample_1  097_CASTJ_10M_23        NaN   Left hippocampus   M
# ..                   ...               ...        ...                ...  ..
# 139  IGVF_BridgeSample_2    120_B6J_10F_20        NaN         PBMC - WBC   F
# 140  IGVF_BridgeSample_2    120_B6J_10F_21        NaN        Left cortex   F
# 141  IGVF_BridgeSample_2    120_B6J_10F_22        NaN       Right cortex   F
# 142  IGVF_BridgeSample_2    120_B6J_10F_23        NaN   Left hippocampus   F
# 143  IGVF_BridgeSample_2    120_B6J_10F_24        NaN  Right hippocampus   F
#
#     Timepoint Genotype Tube label  tube weight (g)  tube+tissue wight (g)  \
# 0    10 weeks    CASTJ     097-19              NaN                  1.094
# 1    10 weeks    CASTJ     097-20              NaN                    NaN
# 2    10 weeks    CASTJ     097-21            2.332                  2.492
# 3    10 weeks    CASTJ     097-22            1.043                  1.156
# 4    10 weeks    CASTJ     097-23            1.038                  1.063
# ..        ...      ...        ...              ...                    ...
# 139  10 weeks      B6J     120-20              NaN                    NaN
# 140  10 weeks      B6J     120-21            2.332                  2.465
# 141  10 weeks      B6J     120-22            1.041                  1.154
# 142  10 weeks      B6J     120-23            1.042                  1.063
# 143  10 weeks      B6J     120-24            1.040                  1.069
#
#      ...  PBMC count 1  PBMC count 2  PBMC RSB after RBC lysis  Total # PBMCs  \
# 0    ...           NaN           NaN                       NaN            NaN
# 1    ...         125.0         103.0                     300.0       684000.0
# 2    ...           NaN           NaN                       NaN            NaN
# 3    ...           NaN           NaN                       NaN            NaN
# 4    ...           NaN           NaN                       NaN            NaN
# ..   ...           ...           ...                       ...            ...
# 139  ...          79.0         110.0                     300.0       567000.0
# 140  ...           NaN           NaN                       NaN            NaN
# 141  ...           NaN           NaN                       NaN            NaN
# 142  ...           NaN           NaN                       NaN            NaN
# 143  ...           NaN           NaN                       NaN            NaN
#
#      cryopreserved PBMC location  Dissection date Approx. sac time  \
# 0                            NaN       2023-01-19         11:38:00
# 1             Canister 5, Cane 1       2023-01-19         11:38:00
# 2                            NaN       2023-01-19         11:38:00
# 3                            NaN       2023-01-19         11:38:00
# 4                            NaN       2023-01-19         11:38:00
# ..                           ...              ...              ...
# 139           Canister 5, Cane 5       2023-02-02         10:16:00
# 140                          NaN       2023-02-02         10:16:00
# 141                          NaN       2023-02-02         10:16:00
# 142                          NaN       2023-02-02         10:16:00
# 143                          NaN       2023-02-02         10:16:00
#
#     Mouse_Tissue ID.1 Dissector  \
# 0    097_CASTJ_10M_19        SK
# 1    097_CASTJ_10M_20        SK
# 2    097_CASTJ_10M_21        SK
# 3    097_CASTJ_10M_22        SK
# 4    097_CASTJ_10M_23        SK
# ..                ...       ...
# 139    120_B6J_10F_20        SK
# 140    120_B6J_10F_21        SK
# 141    120_B6J_10F_22        SK
# 142    120_B6J_10F_23        SK
# 143    120_B6J_10F_24        SK
#
#                                                Comment
# 0                                                  NaN
# 1                                                  NaN
# 2    Tube wasn't weighed before tissue was added, s...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
#
# [144 rows x 22 columns]

# %%
tissues = pandas.concat([tissues_8cube, tissues_bridge])

# %%
def parse_timepoint(value):
    value, units = value.split(" ")
    value = float(value)
    
    unit_map = {
        "day": models.AgeUnitsEnum.DAY,
        "days": models.AgeUnitsEnum.DAY,
        "week": models.AgeUnitsEnum.WEEK,
        "weeks": models.AgeUnitsEnum.WEEK,
        "month": models.AgeUnitsEnum.MONTH,
        "months": models.AgeUnitsEnum.MONTH,
    }
    return (value, unit_map[units])

# %%
ontology_map = {}
for record in models.OntologyTerm.objects.all():
    ontology_map[record.curie] = record

# %%
submitted_tissues = {}

for i, row in submitted_sheets["tissue"].iterrows():
    if not pandas.isnull(row["accession"]):
        aliases = row["aliases:array"].split(",")
        assert len(aliases) == 1
        alias_fields = aliases[0][len("ali-mortazavi:"):].split("_")
        tissue_id = "_".join(alias_fields[0:4])
        submitted_tissues.setdefault(tissue_id, []).append({
            "namespace": igvf_test_namespace,
            "name": row["accession"],
            "uuid": row["uuid"],
            "url": "https://ap.sndbox.igvf.org/tissues/{}/".format(row["accession"]),
        })

print(len(submitted_tissues))
# Out:
# 136

# %%
if models.Tissue.objects.count() > 0:
    truncate(models.Tissue)


failed = False
for i, row in tqdm(tissues.iterrows(), total=tissues.shape[0]):
    if not pandas.isnull(row["Tissue"]):
        mouse_tissue_id_label = "Mouse_Tissue ID"
        mouse_tissue_name_fields = row[mouse_tissue_id_label].split("_")
        
        # some validation on tissue name
        if len(mouse_tissue_name_fields) != 4:
            raise ValueError(f"Not enough elements in mouse tissue id {row[mouse_tissue_id_label]}")
            
        if not mouse_tissue_name_fields[1] in strain_background:
            raise ValueError(f"tissue strain field in {row[mouse_tissue_id_label]} not recognized")
        
        mouse_name = "_".join(mouse_tissue_name_fields[0:3])
        try:
            mouse = models.Mouse.objects.get(name=mouse_name)
        except models.Mouse.DoesNotExist:
            print("row {}, {} was not found".format(i+2, mouse_name))
            failed = True
            continue

        genotype = strain_background[row["Genotype"]]
        
        # this is the "label swap" on spreadsheet rows 602-605.
        if mouse_name == "092_CASTJ_10F":
            genotype = "CAST/EiJ"
        # this is the other half the swap on spreadsheet rows 1522-1525
        elif mouse_name == "046_NZOJ_10F":
            genotype = 'NZO/HlLtJ'

        assert mouse.strain.code == genotype, f"{mouse.strain.code} != {genotype}"
        tissue_terms = []
        for term_curie, term_name in tissue_dissection_to_ontology_map[row["Tissue"]]:
            tissue_terms.append(ontology_map[term_curie])
        
        #age, age_units = parse_timepoint(row["Timepoint"])
        
        if pandas.isnull(row["Approx. sac time"]):
            sac_time = datetime.time(0,0,0)
        else:
            sac_time = datetime.time(
                row["Approx. sac time"].hour,
                row["Approx. sac time"].minute,
                row["Approx. sac time"].second,    
            )
        dissection = datetime.datetime(
            row["Dissection date"].year,
            row["Dissection date"].month,
            row["Dissection date"].day,
            sac_time.hour,
            sac_time.minute,
            sac_time.second,
            tzinfo=los_angeles_tz,
        )
        
        record = models.Tissue(
            mouse=mouse,
            name = row[mouse_tissue_id_label],
            description = row["Tissue"],
            dissection_time=dissection,
            #age=age,
            #age_units=age_units,
            tube_label=row["Tube label"],
            timepoint_description=row["Timepoint"],
            life_stage=models.LifeStageEnum.ADULT,
            dissector=str_or_empty(row["Dissector"]),
            dissection_notes=str_or_empty(row["Comment"]),
        )

        tube_weight_label = "tube weight (g)"
        if not pandas.isnull(row[tube_weight_label]):
            record.tube_weight_g = float(row[tube_weight_label])

        total_weight_label = "tube+tissue wight (g)"
        if not pandas.isnull(row[total_weight_label]):
            record.total_weight_g = float(row[total_weight_label])
        
        record.save()
        record.ontology_term.set(tissue_terms)
        
        if row[mouse_tissue_id_label] in submitted_tissues:
            accessions = []
            for accession_row in submitted_tissues[row[mouse_tissue_id_label]]:
                accession = models.Accession(
                    namespace=accession_row["namespace"],
                    name=accession_row["name"],
                    uuid=accession_row["uuid"],
                    url=accession_row["url"],
                )
                accession.save()
                accessions.append(accession)
            record.accession.set(accessions)
        record.save()

assert not failed, "Check warning messages."
# Out:
# 100%|██████████| 1765/1765 [01:20<00:00, 22.01it/s]

# %% [markdown]
# # Information from Samples into experiment
#
# - Total barcoded nuclei (Samples into experiment)
#
# Is this FixedTissue, FixedSample, FixedBiosample?

# %%
if models.FixedSample.objects.count() > 0:
    truncate(models.FixedSample)

# %%
def load_samples_into_experiment(book_name, sheet_name, header=0):

    samples_into_experiment = pandas.read_excel(
        book_name, 
        sheet_name=sheet_name,
        header=header,
        index_col=None,
    )

    # was trying to normalize two row hierarchical headers, 
    #level0 = []
    #level1 = []
    #for header in samples_into_experiment.columns:
    #    level0.append("" if header[0].startswith("Unnamed: ") else header[0])
    #    level1.append(header[1])
    #samples_into_experiment.columns = pandas.MultiIndex.from_arrays([level0, level1], names=["phase", "name"])

    one_based = 1
    header_lines = 2
    failed = False
    for i, row in tqdm(samples_into_experiment.iterrows(), total=samples_into_experiment.shape[0]):
        line_no = i + one_based + header_lines
        box_name = row["IGVF Fixation BOX"]
        if isinstance(box_name, str):
            box_name = box_name.strip()

        if box_name in ["IGVF_FIX_001", "IGVF_FIX_002"]:
            continue

        tissue_id = row["Mouse_Tissue ID"]
        pooled_from = row.get("pooled_from")

        if pandas.isnull(tissue_id):
            continue

        #if (tissue_id.endswith("_25") or tissue_id.endswith("_26")) and pandas.isnull(pooled_from):
        #    print(f"How are we going to merge these samples? {tissue_id}")
        #    continue

        if pandas.isnull(pooled_from):
            pooled_from = [tissue_id]
        else:
            pooled_from = pooled_from.split(",")

        tissues = []
        for pooled_id in pooled_from:
            try:
                tissues.append(models.Tissue.objects.get(name=pooled_id))
            except models.Tissue.DoesNotExist:
                print(f"Tissue {pooled_id} not found in tissue table on {line_no}")
                failed = True

        weight = row["weight (mg)"]
        fixation_date = row["Fixation date"]
        notes = row["Notes"]

        if weight == "#VALUE!":
            pass
        elif weight < 0:
            pass
        elif pandas.isnull(weight):
            pass
        else:
            total_weight = 0
            for tissue in tissues:
                if not pandas.isnull(tissue.weight_mg):
                    total_weight += tissue.weight_mg

            if not numpy.isclose(total_weight, weight):
                print(f"Sum of tissue weights from {pooled_from} {total_weight} doesn't match {weight}. {line_no}")

        sample_id = row["Sample ID"]
        if not (pandas.isnull(sample_id) or pandas.isnull(tissue_id)):
            if tissue_id != sample_id:
                print(f"If defined, {tissue_id} should equal {sample_id} line {line_no}")
                failed = True

        cap_label = row["Cap label"]
        if not (pandas.isnull(cap_label) or pandas.isnull(sample_id)):
            sample_fields = sample_id.split("_")
            predicted_label = "_".join([sample_fields[0], sample_fields[-1]])
            if predicted_label != cap_label:
                print(f"{cap_label} should equal {predicted_label} line {line_no}")
                failed = True

        well_id = row["wells in Barcoding plate"]

        record = models.FixedSample(
            name=tissue_id,
            tube_label=cap_label,
            fixation_name=box_name,
            fixation_date=date_or_none(row["Fixation date"]),
            starting_nuclei=int_or_none(row["Total nuclei (x10^6)"]),
            nuclei_into_fixation=int_or_none(row["Nuclei into fixation (x10^6)"]),
            fixed_nuclei=int_or_none(row["Total fixed nuclei (x10^6)"]),
            aliquots_made=int_or_none(row["# aliquots"]),
            aliquot_volume_ul=float_or_none(row["uL per aliquot"]),
        )
        record.save()
        record.tissue.set(tissues)
        record.save()

    assert not failed, "Check warning messages"

# %%
load_samples_into_experiment(lizs_sheet_name, "Samples into experiment", header=1)
# Out:
#  56%|█████▌    | 553/994 [00:11<00:16, 27.00it/s]
# Sum of tissue weights from ['046_NZOJ_10F_17'] 116.0 doesn't match 190.0. 556
#  75%|███████▍  | 744/994 [00:16<00:07, 31.83it/s]
# Sum of tissue weights from ['095_CASTJ_10M_08'] 11.0 doesn't match 15.0000000000001. 747
# 100%|██████████| 994/994 [00:22<00:00, 44.60it/s]

# %%
load_samples_into_experiment(lizs_sheet_name, "Bridge samples into experiment", header=0)
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 25.14it/s]

# %% [markdown]
# # Plate layout
#
# (the hard thing)

# %%
WellContent = namedtuple("well_content", ["genotype", "tissue_id"])

def validate_tissue_ids(contents, expected_genotypes):
    for expected, (row_index, row) in zip(expected_genotypes, contents.iterrows()):
        for cell in row:
            fields = cell.split("_")
            assert len(fields) == 4, f"Field label validation fail {cell}"
            # there's a few sample swaps, don't validate them.
            if fields[1] not in ("092_CASTJ_10F_03"):
                assert fields[1] == expected, f"{fields[1]} failed to match {expected}"

def is_plate_name(name):
    return not pandas.isnull(name) and name.startswith("IGVF_")

def find_plate_start(sheet, offsets):
    for plate_id_row in sheet[sheet[offsets["plate_label"]].apply(is_plate_name)].index:
        plate_name = sheet.loc[plate_id_row, offsets["plate_label"]]
        for i in range(plate_id_row, plate_id_row + 4):
            cell = sheet.loc[i, offsets["well_start"]]
            if isinstance(cell, str) and (cell.startswith("Tissue") or cell in ("M", "F")):
                yield (plate_name, i)
                
def get_plate_genotype(sheet, start, offsets):
    plate_tissues = []
    for cell in sheet.loc[start+2:start+9, offsets["tissue_label"]].tolist():
        if not pandas.isnull(cell):
            match = re.match("(B6J|NODJ|AJ|PWKJ|129S1J|CASTJ|WSBJ|NZOJ)", cell)
            if match is not None:
                plate_tissues.append(match.group(0))
            else:
                print("Diffculty matching {} in {} {}".format(cell, start+2, start+9))
    
    return plate_tissues

def parse_single_well_block(sheet, plate_start, offsets):
    # column ids
    simple_plate_column_ids = sheet.loc[plate_start+1, offsets["well_range"]].tolist()

    plate_row_labels = sheet.loc[plate_start+2:plate_start+9, offsets["well_row_label"]].tolist()

    contents = sheet.loc[plate_start+2:plate_start+9, offsets["well_range"]].copy()
    contents.index = plate_row_labels
    contents.columns = simple_plate_column_ids

    genotypes = get_plate_genotype(sheet, plate_start, offsets)
    validate_tissue_ids(contents, genotypes)

    well_contents = {}
    for genotype, (well_row, row) in zip(genotypes, contents.iterrows()):
        for well_column, cell in zip(simple_plate_column_ids, row):
            well_contents[(well_row, str(well_column))] = [WellContent(genotype, cell)]
    return well_contents

def parse_multiplexed_well_block(sheet, start, expected_genotypes, offsets):
    well_re = re.compile("^[A-H]1?[\d]$")
    wells = sheet.loc[start+3, offsets["well_range"]].tolist()
    for cell in wells:
        if pandas.isnull(cell) or well_re.match(cell) is None:
            raise ValueError(f"well value {cell} in row {start+3} does not look correct")

    contents = sheet.loc[start+0:start+1, offsets["well_range"]]
    contents.columns = [(x[0], x[1:]) for x in wells]
    validate_tissue_ids(contents, expected_genotypes)
    contents.index = expected_genotypes

    well_contents = {}
    for genotype, row in contents.iterrows():
        for well, tissue_id in row.iteritems():
            well_contents.setdefault(well, []).append(WellContent(genotype, tissue_id))

    return well_contents

def parse_plate(sheet):
    max_rows_from_plate_name_to_well_names = 4

    offsets = {
        "plate_label": 1,
        "tissue_label": 1,
        "well_row_label": 2,
        "well_start": 3,
        "well_range": slice(3, 10),
    }
    offsets_simple = offsets.copy()
    offsets_simple["well_range"] = slice(3, 14)

    for plate_name, plate_start in find_plate_start(sheet, offsets):
        well_contents = {}
        genotypes = get_plate_genotype(sheet, plate_start, offsets)
        
        
        if plate_name == "IGVF_B01":
            well_contents.update(parse_single_well_block(sheet, plate_start, offsets_simple))
            complex_blocks = []        
        else:
            well_contents.update(parse_single_well_block(sheet, plate_start, offsets))

            complex_blocks = [
                (plate_start + 12, slice(0, 2)),
                (plate_start + 12 + 5, slice(2, 4)),
                (plate_start + 12 + 10, slice(4, 6)),
                (plate_start + 12 + 15, slice(6, 8)),
            ]

            for complex_start, genotype_slice in complex_blocks:
                expected_genotypes = genotypes[genotype_slice]
                well_contents.update(parse_multiplexed_well_block(sheet, complex_start, expected_genotypes, offsets))
        
        yield (plate_name, well_contents)
        
plate_layout = pandas.read_excel(
    lizs_sheet_name, 
    sheet_name="Plate setups",
    header=None,
)

# %%
#for plate_name, plate_contents in parse_plate(plate_layout):
#    for well_id in plate_contents:
#        barcodes = models.LibraryBarcode.objects.filter(
#            kit=wt_mega_2_kit,
#            code="{}{}".format(well_id[0], well_id[1]),
#        )        
#        
#        print(plate_name, well_id, barcodes.count())

# %%
# Validate tissue references:
failed = False
for plate_name, plate_contents in parse_plate(plate_layout):
    for well_id in plate_contents:
        well_contents = plate_contents[well_id]
        
        for well_fraction in well_contents:
            try:
                biosample = models.FixedSample.objects.get(name=well_fraction.tissue_id)
            except models.FixedSample.DoesNotExist:
                print(f"Unable to find {well_fraction.tissue_id} on plate {plate_name}")
                failed = True
                
#assert not failed, "Resolve tissues"

# populate database
if models.SplitSeqWell.biosample.through.objects.count() > 0:
    truncate(models.SplitSeqWell.biosample.through)

if models.SplitSeqWell.objects.count() > 0:
    truncate(models.SplitSeqWell)
    
if models.SplitSeqPlate.objects.count() > 0:
    truncate(models.SplitSeqPlate)

wt_mega_2_kit = models.LibraryConstructionKit.objects.get(name="WT Mega", version="v2")

errors = 0
for plate_name, plate_contents in parse_plate(plate_layout):
    plate_record = models.SplitSeqPlate(
        name=plate_name,
        size=models.PlateSizeEnum.size_96,
        pool_location=None,
        date_performed=None,
    )
    plate_record.save()

    for well_id in plate_contents:
        well_contents = plate_contents[well_id]
        
        biosamples = []
        for well_content in well_contents:
            try:
                biosamples.append(models.FixedSample.objects.get(name=well_content.tissue_id))
            except models.FixedSample.DoesNotExist:
                print(f"unable to find tissue {well_content.tissue_id} for {plate_name} {well_id}")
                errors += 1
        
        barcodes = models.LibraryBarcode.objects.filter(
            kit=wt_mega_2_kit,
            code="{}{}".format(well_id[0], well_id[1]),
        )
        
        well_record = models.SplitSeqWell(
            plate=plate_record,
            row=well_id[0],
            column=well_id[1],
        )
        well_record.save()
        well_record.biosample.set(biosamples)
        well_record.barcode.set(barcodes)
        well_record.save()
        
assert not errors, "Check error messages"

# %% [markdown]
# # Submitted measurement sets

# %%
measurement_sets = {}

for i, row in submitted_sheets["measurement_set"].iterrows():
    if not pandas.isnull(row["accession"]):
        aliases = row["aliases:array"].split(',')
        name = aliases[0].replace("ali-mortazavi:", "")
        
        try:
            record = models.MeasurementSet.objects.get(name=name)
        except models.MeasurementSet.DoesNotExist:
            record = models.MeasurementSet(
                name=name,
            )
            record.save()

            accession = models.Accession(
                namespace=igvf_test_namespace,
                name=row["accession"],
                uuid=row["uuid"],
                url="https://api.sandbox.igvf.org/measurement-sets/{}/".format(row["accession"]),
            )
            accession.save()
            record.accession.set([accession])
            record.save()
        measurement_sets[name] = record
print(len(measurement_sets))
# Out:
# 25

# %% [markdown]
# # Subpool
#
# ## Extract meaning from the Experiments tab

# %% [markdown]
# - number of nuclei per subpool (Experiment)
# - cDNA amp # PCR cycles (Experiment)
# - cDNA ng/ul in 25ul (experiment)
# - total cDNA ng (experiment)
# - Bioanalyzer cDNA ave bp length (expierment)
# - Sub library Index PCR # (experiment)
# - Sublibrary Index (experiment)
# - Sequence for SampleSheet (experiment)
# - library ng/ul (experiment)
# - Bioanalyzer library ave bp length (experiment)
# - Nextseq run number (experiment)
#
# - number of 67k aliquots  (experiment)
# - number of 8k aliquots (experiment)
#
# - QC # raw reads (1 mismatch) (experiment)

# %%
experiment = pandas.read_excel(
    lizs_sheet_name, 
    sheet_name="Experiment",
    header=0,
    index_col=None,
    #usecols=range(0, 49)
)
experiment
# Out:
#             Experiment          mice     Sample Box  Fixation Box  \
# 0    IGVF_Splitseq_002    B6 (2F+2M)  IGVF_Sample_3  IGVF_FIX_001
# 1                  NaN  CAST (2F+2M)  IGVF_Sample_4  IGVF_FIX_002
# 2          Fixation V1           NaN            NaN           NaN
# 3                1M V1           NaN            NaN           NaN
# 4                  NaN           NaN            NaN           NaN
# ..                 ...           ...            ...           ...
# 209                NaN           NaN            NaN  IGVF_FIX_007
# 210                NaN           NaN            NaN           NaN
# 211                NaN           NaN            NaN           NaN
# 212                NaN           NaN            NaN           NaN
# 213                NaN           NaN            NaN           NaN
#
#     Split-seq prep start date  barcoded [nuclei/ul] cell counter  \
# 0                  2022-08-24                             4540.0
# 1                         NaT                                NaN
# 2                         NaT                                NaN
# 3                         NaT                                NaN
# 4                         NaT                                NaN
# ..                        ...                                ...
# 209                       NaT                                NaN
# 210                       NaT                                NaN
# 211                       NaT                                NaN
# 212                       NaT                                NaN
# 213                       NaT                                NaN
#
#      Volume of barcoded nuclei  Total barcoded nuclei (1st 3 rounds)  \
# 0                        240.0                             1089600.0
# 1                          NaN                                   NaN
# 2                          NaN                                   NaN
# 3                          NaN                                   NaN
# 4                          NaN                                   NaN
# ..                         ...                                   ...
# 209                        NaN                                   NaN
# 210                        NaN                                   NaN
# 211                        NaN                                   NaN
# 212                        NaN                                   NaN
# 213                        NaN                                   NaN
#
#      # of backup aliquots size of backup aliquot  ...  Unnamed: 44  \
# 0                     3.0                    67k  ...          NaN
# 1                     NaN                    NaN  ...          NaN
# 2                     NaN                    NaN  ...          NaN
# 3                     NaN                    NaN  ...          NaN
# 4                     NaN                    NaN  ...          NaN
# ..                    ...                    ...  ...          ...
# 209                   2.0                    13k  ...          NaN
# 210                   NaN                    NaN  ...          NaN
# 211                   NaN                    NaN  ...          NaN
# 212                   NaN                    NaN  ...          NaN
# 213                   NaN                    NaN  ...          NaN
#
#      Unnamed: 45  Unnamed: 46 Unnamed: 47 Unnamed: 48 Unnamed: 49  \
# 0            NaN          NaN         NaN         NaN         NaN
# 1            NaN          NaN         NaN         NaN         NaN
# 2            NaN          NaN         NaN         NaN         NaN
# 3            NaN          NaN         NaN         NaN         NaN
# 4            NaN          NaN         NaN         NaN         NaN
# ..           ...          ...         ...         ...         ...
# 209          NaN          NaN         NaN         NaN         NaN
# 210          NaN          NaN         NaN         NaN         NaN
# 211          NaN          NaN         NaN         NaN         NaN
# 212          NaN          NaN         NaN         NaN         NaN
# 213          NaN          NaN         NaN         NaN         NaN
#
#      Unnamed: 50  Unnamed: 51 Unnamed: 52  Unnamed: 53
# 0            NaN          NaN         NaN          NaN
# 1            NaN          NaN         NaN          NaN
# 2            NaN          NaN         NaN          NaN
# 3            NaN          NaN         NaN          NaN
# 4            NaN          NaN         NaN          NaN
# ..           ...          ...         ...          ...
# 209          NaN          NaN         NaN          NaN
# 210          NaN          NaN         NaN          NaN
# 211          NaN          NaN         NaN          NaN
# 212          NaN          NaN         NaN          NaN
# 213          NaN          NaN         NaN          NaN
#
# [214 rows x 54 columns]

# %%
experiment = pandas.read_excel(
    lizs_sheet_name, 
    sheet_name="Experiment",
    header=0,
    index_col=None,
    #usecols=range(0, 49)
).rename(columns={
    # Unnamed: 42 seems like an index or reference to the sample sheet?
    "Unnamed: 43": "Novaseq raw reads",
    "Unnamed: 44": "Novaseq1 L001",
    "Unnamed: 45": "Novaseq1 L002",
    "Unnamed: 46": "Novaseq1 L003",
    "Unnamed: 47": "Novaseq1 L004",
    "Unnamed: 48": "Novaseq2 L001",
    "Unnamed: 49": "Novaseq2 L002",
    "Unnamed: 50": "Novaseq2 L003",
    "Unnamed: 51": "Novaseq2 L004",
})

experiment
# Out:
#             Experiment          mice     Sample Box  Fixation Box  \
# 0    IGVF_Splitseq_002    B6 (2F+2M)  IGVF_Sample_3  IGVF_FIX_001
# 1                  NaN  CAST (2F+2M)  IGVF_Sample_4  IGVF_FIX_002
# 2          Fixation V1           NaN            NaN           NaN
# 3                1M V1           NaN            NaN           NaN
# 4                  NaN           NaN            NaN           NaN
# ..                 ...           ...            ...           ...
# 209                NaN           NaN            NaN  IGVF_FIX_007
# 210                NaN           NaN            NaN           NaN
# 211                NaN           NaN            NaN           NaN
# 212                NaN           NaN            NaN           NaN
# 213                NaN           NaN            NaN           NaN
#
#     Split-seq prep start date  barcoded [nuclei/ul] cell counter  \
# 0                  2022-08-24                             4540.0
# 1                         NaT                                NaN
# 2                         NaT                                NaN
# 3                         NaT                                NaN
# 4                         NaT                                NaN
# ..                        ...                                ...
# 209                       NaT                                NaN
# 210                       NaT                                NaN
# 211                       NaT                                NaN
# 212                       NaT                                NaN
# 213                       NaT                                NaN
#
#      Volume of barcoded nuclei  Total barcoded nuclei (1st 3 rounds)  \
# 0                        240.0                             1089600.0
# 1                          NaN                                   NaN
# 2                          NaN                                   NaN
# 3                          NaN                                   NaN
# 4                          NaN                                   NaN
# ..                         ...                                   ...
# 209                        NaN                                   NaN
# 210                        NaN                                   NaN
# 211                        NaN                                   NaN
# 212                        NaN                                   NaN
# 213                        NaN                                   NaN
#
#      # of backup aliquots size of backup aliquot  ...  Novaseq1 L001  \
# 0                     3.0                    67k  ...            NaN
# 1                     NaN                    NaN  ...            NaN
# 2                     NaN                    NaN  ...            NaN
# 3                     NaN                    NaN  ...            NaN
# 4                     NaN                    NaN  ...            NaN
# ..                    ...                    ...  ...            ...
# 209                   2.0                    13k  ...            NaN
# 210                   NaN                    NaN  ...            NaN
# 211                   NaN                    NaN  ...            NaN
# 212                   NaN                    NaN  ...            NaN
# 213                   NaN                    NaN  ...            NaN
#
#      Novaseq1 L002  Novaseq1 L003 Novaseq1 L004 Novaseq2 L001 Novaseq2 L002  \
# 0              NaN            NaN           NaN           NaN           NaN
# 1              NaN            NaN           NaN           NaN           NaN
# 2              NaN            NaN           NaN           NaN           NaN
# 3              NaN            NaN           NaN           NaN           NaN
# 4              NaN            NaN           NaN           NaN           NaN
# ..             ...            ...           ...           ...           ...
# 209            NaN            NaN           NaN           NaN           NaN
# 210            NaN            NaN           NaN           NaN           NaN
# 211            NaN            NaN           NaN           NaN           NaN
# 212            NaN            NaN           NaN           NaN           NaN
# 213            NaN            NaN           NaN           NaN           NaN
#
#      Novaseq2 L003  Novaseq2 L004 Unnamed: 52  Unnamed: 53
# 0              NaN            NaN         NaN          NaN
# 1              NaN            NaN         NaN          NaN
# 2              NaN            NaN         NaN          NaN
# 3              NaN            NaN         NaN          NaN
# 4              NaN            NaN         NaN          NaN
# ..             ...            ...         ...          ...
# 209            NaN            NaN         NaN          NaN
# 210            NaN            NaN         NaN          NaN
# 211            NaN            NaN         NaN          NaN
# 212            NaN            NaN         NaN          NaN
# 213            NaN            NaN         NaN          NaN
#
# [214 rows x 54 columns]

# %%
def find_fixation_start(sheet):
    def is_experiment_name(name):
        return not pandas.isnull(name) and name.startswith("IGVF_Splitseq")

    for fixation_id_row in sheet[sheet["Experiment"].apply(is_experiment_name)].index:
        name = sheet.loc[fixation_id_row, "Experiment"]
        start = fixation_id_row

        stop = sheet.shape[0]
        for i, value in sheet.iloc[start:]["sublibrary"].iteritems():
            if pandas.isnull(value):
                stop = i - 1
                break
        
        
        yield (name, start, stop)

for name, start, stop in find_fixation_start(experiment):
    print(name, start, stop)
# Out:
# IGVF_Splitseq_002 0 15
# IGVF_Splitseq_003 17 33
# IGVF_Splitseq_004 36 52
# IGVF_Splitseq_005 55 71
# IGVF_Splitseq_006 74 91
# IGVF_Splitseq_007 93 109
# IGVF_Splitseq_008 112 121
# IGVF_Splitseq_B01 124 131
# IGVF_Splitseq_008B 133 143
# IGVF_Splitseq_009 146 161
# IGVF_Splitseq_010 163 178
# IGVF_Splitseq_011 180 195
# IGVF_Splitseq_3,4,5,7 206 214

# %%
def parse_selection_type(value):
    if value is None:
        return None
    elif value.lower() in ("normal", "no"):
        return models.SublibrarySelectionType.no_selection
    elif value in ("capture", "EX"):
        return models.SublibrarySelectionType.exome_capture
    else:
        raise ValueError(f"Unrecognized capture type {value}")


def parse_fixation(sheet, experiment_name, start, stop):
    block = sheet.loc[start:stop]

    experiment_name_fields = experiment_name.split("_")
    plate_name = f"{experiment_name_fields[0]}_{experiment_name_fields[-1]}"
    
    aliquots = {}
    for i, row in block.iterrows():
        count = row["# of backup aliquots"]
        size = row["size of backup aliquot"]
        if not (pandas.isnull(count) or pandas.isnull(size)):
            if isinstance(size, str) and size.endswith("k"):
                size = size[:-1]
            size = int(size) * 1000
            aliquots[size] = int(count)
    
    experiment = {
        "experiment_name": experiment_name,
        "plate_name": plate_name,
        "prep_date": block.loc[start, "Split-seq prep start date"],
        "unused_aliquots": aliquots,
        "subpool": [],
    }

    for i, row in block.iterrows():
        if not pandas.isnull(row["sublibrary"]):
            if pandas.isnull(row["NovaSeq Sequencing date"]):
                novaseq_run_id = None
            else:
                novaseq_run_id = row["NovaSeq Sequencing date"].isoformat().split("T")[0]

            if pandas.isnull(row.get("Novaseq raw reads")):
                novaseq_raw_reads = None
                novaseq1_raw_reads = None
                novaseq2_raw_reads = None
            elif row["Novaseq raw reads"] == "Total":
                novaseq_raw_reads = None
                novaseq1_raw_reads = None
                novaseq2_raw_reads = None
            else:
                novaseq_raw_reads = int_or_none(row.get("Novaseq raw reads"))
                novaseq1_raw_reads = sum([int_or_none(row.get(x)) for x in["Novaseq1 L001", "Novaseq1 L002", "Novaseq1 L003", "Novaseq1 L004"]])
                novaseq2_raw_reads = sum([int_or_none(row.get(x)) for x in["Novaseq2 L001", "Novaseq2 L002", "Novaseq2 L003", "Novaseq2 L004"]])

            print(row["sublibrary_selection_type"], row["sublibrary"])
            subpool = {
                "name": row["sublibrary"],
                "subpool_subname": row["sublibrary"].split("_")[1],
                "nuclei": int_or_none(row["# of nuclei per sublibrary"]),
                "selection_type": parse_selection_type(row["sublibrary_selection_type"]),
                "cdna_pcr_rounds": row["cDNA amp # PCR cycles"],
                "cdna_ng_per_ul_in_25ul": row["[cDNA] ng/ul     in 25ul"],
                #total_cdna = cdna_ng_per_ul_in_25ul * 25
                "bioanalyzer_date": row["BA date"],
                "cdna_average_bp_length": int_or_none(row["Bioanalyzer cDNA ave bp length"]),
                "index_pcr_no": int_or_none(row["Sub library Index PCR #"]),
                "index": int_or_none(row["Sublibrary Index"]),
                "barcode": row["Sequence for SampleSheet"],
                "library_ng_per_ul": float_or_none(row["[library] ng/ul"]),
                "library_average_bp_length": float_or_none(row["Bioanalyzer library ave bp length"]),
                "nextseq_run_date": date_or_none(row["QC Sequencing date"]),
                "nextseq_run_id": str_or_none(int_or_none(row["Nextseq run #"])),
                "nextseq_run_raw_reads": int_or_none(row["QC # raw reads  (1 mismatch)"]),
                "novaseq_run_date": date_or_none(row["NovaSeq Sequencing date"]),
                "novaseq_run_id": novaseq_run_id,
                "novaseq_run_raw_reads": novaseq_raw_reads,
                "novaseq1_raw_reads": novaseq1_raw_reads,
                "novaseq2_raw_reads": novaseq2_raw_reads,
            }
            experiment["subpool"].append(subpool)
            #if not pandas.isnull(subpool["nuclei"]):
            #    nuclei = subpool["nuclei"]
            #    aliquots[nuclei] = aliquots.get(nuclei) + 1

    return experiment

#parse_fixation(experiment, "IGVF_Splitseq_003", 17, 32)
#parse_fixation(experiment, "IGVF_Splitseq_008", 108, 117)
parse_fixation(experiment, "IGVF_Splitseq_B01", 124, 131)
#parse_fixation(experiment, "IGVF_Splitseq_008B", 133, 143)
# Out:
# NO B01_13A
# NO B01_13B
# NO B01_13C
# NO B01_13D
# NO B01_13E
# NO B01_13F
# EX B01_13G
# NO B01_13H
# {'experiment_name': 'IGVF_Splitseq_B01',
#  'plate_name': 'IGVF_B01',
#  'prep_date': Timestamp('2023-04-03 00:00:00'),
#  'unused_aliquots': {13000: 10},
#  'subpool': [{'name': 'B01_13A',
#    'subpool_subname': '13A',
#    'nuclei': 13000,
#    'selection_type': <SublibrarySelectionType.no_selection: 'NO'>,
#    'cdna_pcr_rounds': '5 + 7',
#    'cdna_ng_per_ul_in_25ul': 40,
#    'bioanalyzer_date': datetime.datetime(2023, 4, 5, 0, 0),
#    'cdna_average_bp_length': 1413,
#    'index_pcr_no': 11,
#    'index': 1,
#    'barcode': 'CAGATC',
#    'library_ng_per_ul': 25.2,
#    'library_average_bp_length': 437.0,
#    'nextseq_run_date': None,
#    'nextseq_run_id': None,
#    'nextseq_run_raw_reads': None,
#    'novaseq_run_date': None,
#    'novaseq_run_id': None,
#    'novaseq_run_raw_reads': None,
#    'novaseq1_raw_reads': None,
#    'novaseq2_raw_reads': None},
#   {'name': 'B01_13B',
#    'subpool_subname': '13B',
#    'nuclei': 13000,
#    'selection_type': <SublibrarySelectionType.no_selection: 'NO'>,
#    'cdna_pcr_rounds': '5 + 7',
#    'cdna_ng_per_ul_in_25ul': 34.9,
#    'bioanalyzer_date': datetime.datetime(2023, 4, 5, 0, 0),
#    'cdna_average_bp_length': 1469,
#    'index_pcr_no': 11,
#    'index': 2,
#    'barcode': 'ACTTGA',
#    'library_ng_per_ul': 24.4,
#    'library_average_bp_length': 447.0,
#    'nextseq_run_date': None,
#    'nextseq_run_id': None,
#    'nextseq_run_raw_reads': None,
#    'novaseq_run_date': None,
#    'novaseq_run_id': None,
#    'novaseq_run_raw_reads': None,
#    'novaseq1_raw_reads': None,
#    'novaseq2_raw_reads': None},
#   {'name': 'B01_13C',
#    'subpool_subname': '13C',
#    'nuclei': 13000,
#    'selection_type': <SublibrarySelectionType.no_selection: 'NO'>,
#    'cdna_pcr_rounds': '5 + 7',
#    'cdna_ng_per_ul_in_25ul': 41.4,
#    'bioanalyzer_date': datetime.datetime(2023, 4, 5, 0, 0),
#    'cdna_average_bp_length': 1424,
#    'index_pcr_no': 11,
#    'index': 3,
#    'barcode': 'GATCAG',
#    'library_ng_per_ul': 24.2,
#    'library_average_bp_length': 451.0,
#    'nextseq_run_date': None,
#    'nextseq_run_id': None,
#    'nextseq_run_raw_reads': None,
#    'novaseq_run_date': None,
#    'novaseq_run_id': None,
#    'novaseq_run_raw_reads': None,
#    'novaseq1_raw_reads': None,
#    'novaseq2_raw_reads': None},
#   {'name': 'B01_13D',
#    'subpool_subname': '13D',
#    'nuclei': 13000,
#    'selection_type': <SublibrarySelectionType.no_selection: 'NO'>,
#    'cdna_pcr_rounds': '5 + 7',
#    'cdna_ng_per_ul_in_25ul': 43.8,
#    'bioanalyzer_date': datetime.datetime(2023, 4, 5, 0, 0),
#    'cdna_average_bp_length': 1352,
#    'index_pcr_no': 11,
#    'index': 4,
#    'barcode': 'TAGCTT',
#    'library_ng_per_ul': 27.2,
#    'library_average_bp_length': 449.0,
#    'nextseq_run_date': None,
#    'nextseq_run_id': None,
#    'nextseq_run_raw_reads': None,
#    'novaseq_run_date': None,
#    'novaseq_run_id': None,
#    'novaseq_run_raw_reads': None,
#    'novaseq1_raw_reads': None,
#    'novaseq2_raw_reads': None},
#   {'name': 'B01_13E',
#    'subpool_subname': '13E',
#    'nuclei': 13000,
#    'selection_type': <SublibrarySelectionType.no_selection: 'NO'>,
#    'cdna_pcr_rounds': '5 + 7',
#    'cdna_ng_per_ul_in_25ul': 36,
#    'bioanalyzer_date': datetime.datetime(2023, 4, 5, 0, 0),
#    'cdna_average_bp_length': 1347,
#    'index_pcr_no': 11,
#    'index': 5,
#    'barcode': 'ATGTCA',
#    'library_ng_per_ul': 26.4,
#    'library_average_bp_length': 433.0,
#    'nextseq_run_date': None,
#    'nextseq_run_id': None,
#    'nextseq_run_raw_reads': None,
#    'novaseq_run_date': None,
#    'novaseq_run_id': None,
#    'novaseq_run_raw_reads': None,
#    'novaseq1_raw_reads': None,
#    'novaseq2_raw_reads': None},
#   {'name': 'B01_13F',
#    'subpool_subname': '13F',
#    'nuclei': 13000,
#    'selection_type': <SublibrarySelectionType.no_selection: 'NO'>,
#    'cdna_pcr_rounds': '5 + 7',
#    'cdna_ng_per_ul_in_25ul': 44.5,
#    'bioanalyzer_date': datetime.datetime(2023, 4, 5, 0, 0),
#    'cdna_average_bp_length': 1388,
#    'index_pcr_no': 11,
#    'index': 6,
#    'barcode': 'CTTGTA',
#    'library_ng_per_ul': 28.2,
#    'library_average_bp_length': 457.0,
#    'nextseq_run_date': None,
#    'nextseq_run_id': None,
#    'nextseq_run_raw_reads': None,
#    'novaseq_run_date': None,
#    'novaseq_run_id': None,
#    'novaseq_run_raw_reads': None,
#    'novaseq1_raw_reads': None,
#    'novaseq2_raw_reads': None},
#   {'name': 'B01_13G',
#    'subpool_subname': '13G',
#    'nuclei': 13000,
#    'selection_type': <SublibrarySelectionType.exome_capture: 'EX'>,
#    'cdna_pcr_rounds': '5 + 8',
#    'cdna_ng_per_ul_in_25ul': 48,
#    'bioanalyzer_date': datetime.datetime(2023, 4, 5, 0, 0),
#    'cdna_average_bp_length': 1473,
#    'index_pcr_no': 11,
#    'index': 7,
#    'barcode': 'AGTCAA',
#    'library_ng_per_ul': 31.2,
#    'library_average_bp_length': 444.0,
#    'nextseq_run_date': None,
#    'nextseq_run_id': None,
#    'nextseq_run_raw_reads': None,
#    'novaseq_run_date': None,
#    'novaseq_run_id': None,
#    'novaseq_run_raw_reads': None,
#    'novaseq1_raw_reads': None,
#    'novaseq2_raw_reads': None},
#   {'name': 'B01_13H',
#    'subpool_subname': '13H',
#    'nuclei': 13000,
#    'selection_type': <SublibrarySelectionType.no_selection: 'NO'>,
#    'cdna_pcr_rounds': '5 + 8',
#    'cdna_ng_per_ul_in_25ul': 41.3,
#    'bioanalyzer_date': datetime.datetime(2023, 4, 5, 0, 0),
#    'cdna_average_bp_length': 1447,
#    'index_pcr_no': 11,
#    'index': 8,
#    'barcode': 'AGTTCC',
#    'library_ng_per_ul': 22.6,
#    'library_average_bp_length': 534.0,
#    'nextseq_run_date': None,
#    'nextseq_run_id': None,
#    'nextseq_run_raw_reads': None,
#    'novaseq_run_date': None,
#    'novaseq_run_id': None,
#    'novaseq_run_raw_reads': None,
#    'novaseq1_raw_reads': None,
#    'novaseq2_raw_reads': None}]}

# %%
platforms = {x.name: x for x in models.Platform.objects.all()}
platforms
# Out:
# {'nextseq2000': <Platform: Nextseq 2000>,
#  'novaseq6000': <Platform: Novaseq 6000>,
#  'nanopore': <Platform: Oxford Nanopore>,
#  'pacbio': <Platform: Pac Bio>}

# %%
class SubpoolName:
    def __init__(self, name=None):
        if isinstance(name, str):
            self._normalized = SubpoolName.subpool_name_to_numbers(name)
        elif isinstance(name, list):
            self._normalized = name
        elif name is None:
            self._normalized = None
        else:
            raise ValueError("Unrecognized type {} for {}".format(type(name), name))

    def __str__(self):
        if self._normalized is None:
            return "None"
        else:
            return SubpoolName.numbers_to_subpool_name(self._normalized)
        
    def __repr__(self):
        if self._normalized is None:
            return str("{}()".format(self.__class__.__name__))
        else:
            return str("{}('{}')".format(self.__class__.__name__, str(self)))
        
    def __eq__(self, cmp):
        if self._normalized is None and cmp is None:
            return True
        elif self._normalized is None and cmp._normalized is None:
            return True
        elif self._normalized is None or cmp._normalized is None:
            return False
        elif len(self._normalized) != len(cmp._normalized):
            return False
        else:
            for left, right in zip(self._normalized, cmp._normalized):
                if left != right:
                    return False
                
        return True
    
    def __lt__(self, cmp):
        if self._normalized is None and cmp is None:
            return False
        elif self._normalized is None and cmp._normalized is None:
            return False
        elif self._normalized is None:
            return True
        elif cmp is None or cmp._normalized is None:
            return False
        elif self._normalized[0] < cmp._normalized[0]:
            return True
        elif len(self._normalized) < len(cmp._normalized):
            return True
        elif len(self._normalized) > len(cmp._normalized):
            return False
        else:
            for left, right in zip(self._normalized, cmp._normalized):
                if left == right:
                    continue
                elif left < right:
                    return True
                else:
                    return False
                
        return False
                
    def __gt__(self, cmp):
        if self._normalized is None and cmp is None:
            return False
        elif self._normalized is None and cmp._normalized is None:
            return False
        elif cmp is None or cmp._normalized is None:
            return True
        elif self._normalized[0] > cmp._normalized[0]:
            return True
        elif len(self._normalized) < len(cmp._normalized):
            return False
        elif len(self._normalized) > len(cmp._normalized):
            return True
        else:
            for left, right in zip(self._normalized, cmp._normalized):
                if left == right:
                    continue
                elif left < right:
                    return False
                else:
                    return True
            
        return False
        
    @classmethod
    def subpool_name_to_numbers(cls, name):
        STATE_DIGITS = 1
        STATE_LETTERS = 2
        STATE_ERROR = -1

        digits = []
        letters = []
        state = STATE_DIGITS
        for char in name:
            if state == STATE_DIGITS:
                if char.isdigit():
                    digits.append(char)
                elif char.isalpha():
                    state = STATE_LETTERS
                    letters.append(char)
                else:
                    raise ValueError("Unrecognized symbol {} in {}".format(char, name))
            elif state == STATE_LETTERS:
                if char.isdigit():
                    raise ValueError("Unexpected digit {} in {}".format(char, name))
                elif char.isalpha():
                    letters.append(char)
                else:
                    raise ValueError("Unrecognized symbol {} in {}".format(char, name))

        result = [int("".join(digits))]
        for number in letters:
            if number < "A" or number > "Z":
                raise ValueError("out of bounds letter code in {}".format(name))
            else:
                result.append(ord(number) - ord("A"))

        return result

    @classmethod
    def numbers_to_subpool_name(cls, subpool_list):

        result = [str(subpool_list[0])]
        for char in subpool_list[1:]:
            result.append(chr(char + ord("A")))

        return "".join(result)

    def next_code(self):
        if self._normalized is None:
            return None

        carry = 0
        advancable = []
        for i, place in enumerate(reversed(self._normalized[1:])):
            if i == 0:
                place += 1
            else:
                place += carry
                carry = 0

            if place > 25:
                carry = 1
                place = 0

            advancable.append(place)

        if carry > 0:
            advancable.append(0)

        result = [self._normalized[0]]
        result.extend(reversed(advancable))
        
        return SubpoolName(result)

s = SubpoolName("8ACZ")
print(s)

decoded = SubpoolName.subpool_name_to_numbers("8ACZ") 
print("decoded", decoded)
encoded = SubpoolName.numbers_to_subpool_name(decoded)
print("encoded", encoded)

print(SubpoolName("8ACZ").next_code())



for pairs in [("8A", "8B"), ("8AA", "8Z"), ("8B", "8E"), ("8B", "8A"), ("8Z", "8AA"), ("67A", "67A"), ("8AA", "8AB")]:
    left = SubpoolName(pairs[0])
    right = SubpoolName(pairs[1])
    print(left, right, left < right, left == right, left > right)
    
print(max(SubpoolName("8A"), SubpoolName("8B")))
print(max(None, SubpoolName("8B")))
print(max(SubpoolName("8A"), None))
# Out:
# 8ACZ
# decoded [8, 0, 2, 25]
# encoded 8ACZ
# 8ADA
# 8A 8B True False False
# 8AA 8Z False False True
# 8B 8E True False False
# 8B 8A False False True
# 8Z 8AA True False False
# 67A 67A False True False
# 8AA 8AB True False False
# 8B
# 8B
# 8A

# %% [markdown]
# # load subpools, sequencing runs and subpools in sequencing run

# %%
multiplexed_samples = {}

for i, row in submitted_sheets["multiplexed_sample"].iterrows():
    if not pandas.isnull(row["accession"]):
        aliases = row["aliases:array"].split(',')
        name = aliases[0].replace("ali-mortazavi:", "")

        multiplexed_samples[name] = {
            "namespace": igvf_test_namespace,
            "name": row["accession"],
            "uuid": row["uuid"],
            "url": "https://api.sandbox.igvf.org/multiplexed-samples/{}/".format(row["accession"]),
        }
print(len(multiplexed_samples))
# Out:
# 8

# %%
compression=r"(?<compression>gz|bz2|xz|zstd)"
nanopore_library_name_re_template = r"igvf(?P<run>[\d]+)_(?P<library_id>{library_name})_.*_(?P<fragment>[\d]+)\.fastq\.{compression}"
nextseq_library_name_re_template = r"(?P<run>[\d]+)_(?P<library_id>{library_name})_(?P<read_id>[RI][\d])\.fastq\.{compression}"
nextseq_library_index_re_template = r"Sublibrary_(?P<library_id>{library_index})_S(?P<sample_id>[\d]+)_(?P<lane_id>L[\d]+)_(?P<read_id>[RI][\d])_(?P<fragment>[\d]+)\.fastq\.{compression}"
novaseq_library_index_re_template = r"Sublibrary_(?P<library_id>{library_index})_S(?P<sample_id>[\d]+)_(?P<lane_id>L[\d]+)_(?P<read_id>[RI][\d])_(?P<fragment>[\d]+)\.fastq\.{compression}"

expected_names = {
    "IGVF_Splitseq_003": {
        "nanopore": nanopore_library_name_re_template,
        "nextseq": nextseq_library_name_re_template,
        "novaseq": novaseq_library_index_re_template,
    },
    "IGVF_Splitseq_004": {
        "nanopore": nanopore_library_name_re_template,
        "nextseq": nextseq_library_name_re_template,
        "novaseq": novaseq_library_index_re_template,
    },
    "IGVF_Splitseq_005": {
        "nanopore": nanopore_library_name_re_template,
        "nextseq": nextseq_library_index_re_template,
        "novaseq": novaseq_library_index_re_template,
    },
    "IGVF_Splitseq_006": {
        "nanopore": nanopore_library_name_re_template,
        "nextseq": nextseq_library_index_re_template,
        "novaseq": novaseq_library_index_re_template,
    },
    
}

nanopore_runs = {
    "IGVF_Splitseq_003": {
        "name": "2023-01-03-8A",
        "run_date": datetime.datetime(2023,1,3),
        "raw_reads": 87784162,
    }
}



failed_plates = {"IGVF_006",}
failed = False
for experiment_name, experiment_start, experiment_stop in find_fixation_start(experiment):
    fixation = parse_fixation(experiment, experiment_name, experiment_start, experiment_stop)
    
    try:
        plate = models.SplitSeqPlate.objects.get(name=fixation["plate_name"])
    except models.SplitSeqPlate.DoesNotExist:
        print(f"Unable to find plate {fixation['plate_name']}")
        continue
        
    if fixation["plate_name"] in failed_plates:
        print(f"Skipping failed plate {fixation['plate_name']}")
        continue
        
    last_subpools = {}
    
    wt_mega_2_kit = models.LibraryConstructionKit.objects.get(name="WT Mega", version="v2")
    for line_offset, subpool in enumerate(fixation["subpool"]):
        try:
            barcodes = models.LibraryBarcode.objects.filter(
                kit=wt_mega_2_kit, 
                barcode_type=None, 
                code=subpool["index"])
        except models.LibraryBarcode.DoesNotExist:
            print(f"Unable to find barcode {subpool['index']}")

        # validate barcodes
        library_barcodes_sequence = {b.sequence for b in barcodes}
        if not pandas.isnull(subpool["barcode"]):
            expected_sequence = set(subpool["barcode"].split(","))
        else:
            expected_sequence = set()
        if library_barcodes_sequence != expected_sequence:
            print(f"{subpool['name']} Database lookup of barcodes {library_barcodes_sequence} doesn't match human entry {expected_sequence}")
            failed = True
            continue
        
        subpool_prefix = subpool["name"].split("_")[0]
        last_subpools[subpool["nuclei"]] = max(
            last_subpools.get(subpool["nuclei"]), 
            SubpoolName(subpool["subpool_subname"]))

        record = models.Subpool(
            name=subpool["name"],
            plate=plate,
            nuclei=subpool["nuclei"],
            selection_type=subpool["selection_type"],
            cdna_pcr_rounds=subpool["cdna_pcr_rounds"],
            cdna_ng_per_ul_in_25ul=float_or_none(subpool["cdna_ng_per_ul_in_25ul"]),
            bioanalyzer_date=date_or_none(subpool["bioanalyzer_date"]),
            cdna_average_bp_length=int_or_none(subpool["cdna_average_bp_length"]),
            index_pcr_number=int_or_none(subpool["index_pcr_no"]),
            index=int_or_none(subpool["index"]),
            library_ng_per_ul=float_or_none(subpool["library_ng_per_ul"]),
            library_average_bp_length=int_or_none(subpool["library_average_bp_length"]),
        )
        record.save()
        record.barcode.set(barcodes)
        record.save()
        
        name = "subpool_{}".format(subpool["name"].lower())
        if name in multiplexed_samples:
            print(name, record.name, multiplexed_samples[name])
            accession = models.Accession(**multiplexed_samples[name])
            accession.save()
            record.accession.set([accession])
            record.save()            
        
    for nuclei in fixation["unused_aliquots"]:
        subpool_name = last_subpools[nuclei]
        for i in range(fixation["unused_aliquots"][nuclei]):
            subpool_name = subpool_name.next_code()

            record = models.Subpool(
                name="{}_{}".format(subpool_prefix, subpool_name),
                plate=plate,
                nuclei=nuclei,
            )
            print(record.name)
            record.save()

assert not failed
# Out:
# NO 002_4A
# NO 002_4B
# NO 002_64A
# NO 002_64B
# NO 002_64C
# NO 002_64D
# NO 002_64E
# NO 002_64F
# NO 002_64G
# NO 002_64H
# NO 002_64I
# NO 002_64J
# NO 002_64K
# NO 002_64L
# NO 002_64M
# NO 002_64N
# Unable to find plate IGVF_002
# NO 003_8A
# NO 003_13A
# NO 003_67A
# NO 003_67B
# NO 003_67C
# NO 003_67D
# NO 003_67E
# NO 003_67F
# NO 003_67G
# NO 003_67H
# NO 003_67I
# NO 003_67J
# NO 003_67K
# NO 003_67L
# NO 003_67M
# NO 003_67N
# NO 003_67O
# 003_67P
# 003_67Q
# 003_67R
# 003_67S
# 003_67T
# 003_67U
# 003_67V
# 003_13B
# 003_8B
# 003_8C
# NO 004_8A
# NO 004_13A
# NO 004_67A
# NO 004_67B
# NO 004_67C
# NO 004_67D
# NO 004_67E
# NO 004_67F
# NO 004_67G
# NO 004_67H
# NO 004_67I
# NO 004_67J
# NO 004_67K
# NO 004_67L
# NO 004_67M
# NO 004_67N
# NO 004_67O
# 004_67P
# 004_67Q
# 004_67R
# 004_67S
# 004_67T
# 004_13B
# 004_13C
# 004_8B
# 004_8C
# NO 005_8A
# NO 005_13A
# NO 005_67A
# NO 005_67B
# NO 005_67C
# NO 005_67D
# NO 005_67E
# NO 005_67F
# NO 005_67G
# NO 005_67H
# NO 005_67I
# NO 005_67J
# NO 005_67K
# NO 005_67L
# NO 005_67M
# NO 005_67N
# NO 005_67O
# 005_67P
# 005_67Q
# 005_67R
# 005_67S
# 005_67T
# 005_67U
# 005_13B
# 005_13C
# 005_8B
# 005_8C
# 005_8D
# 005_8E
# 005_8F
# 005_8G
# 005_8H
# NO 006_8A
# NO 006_67A
# NO 006_67B
# NO 006_67C
# NO 006_67D
# NO 006_67E
# NO 006_67F
# NO 006_67G
# NO 006_67H
# NO 006_67I
# NO 006_67J
# NO 006_67K
# NO 006_67L
# NO 006_67M
# NO 006_67N
# NO 006_67O
# NO 006_67P
# NO 006_67Q
# Skipping failed plate IGVF_006
# NO 007_8A
# NO 007_13A
# NO 007_67A
# NO 007_67B
# NO 007_67C
# NO 007_67D
# NO 007_67E
# NO 007_67F
# NO 007_67G
# NO 007_67H
# NO 007_67I
# NO 007_67J
# NO 007_67K
# NO 007_67L
# NO 007_67M
# NO 007_67N
# NO 007_67O
# 007_67P
# 007_67Q
# 007_67R
# 007_67S
# 007_67T
# 007_67U
# 007_67V
# 007_67W
# 007_13B
# 007_13C
# 007_8B
# 007_8C
# 007_8D
# 007_8E
# 007_8F
# 007_8G
# 007_8H
# 007_8I
# NO 008_8A
# NO 008_67A
# NO 008_67B
# NO 008_67C
# NO 008_67D
# NO 008_67E
# NO 008_67F
# NO 008_67G
# NO 008_67H
# NO 008_67I
# NO B01_13A
# NO B01_13B
# NO B01_13C
# NO B01_13D
# NO B01_13E
# NO B01_13F
# EX B01_13G
# NO B01_13H
# subpool_b01_13a B01_13A {'namespace': <AccessionNamespace: IGVF test>, 'name': 'TSTSM35366348', 'uuid': '77a93b75-f44a-4aa5-937b-a6788051bc18', 'url': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM35366348/'}
# subpool_b01_13b B01_13B {'namespace': <AccessionNamespace: IGVF test>, 'name': 'TSTSM99018100', 'uuid': '6cac6a8b-7750-4df6-92cf-fae41082813d', 'url': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM99018100/'}
# subpool_b01_13c B01_13C {'namespace': <AccessionNamespace: IGVF test>, 'name': 'TSTSM36900951', 'uuid': '01858fa2-3c3d-476a-8d81-e82a0612c0e8', 'url': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM36900951/'}
# subpool_b01_13d B01_13D {'namespace': <AccessionNamespace: IGVF test>, 'name': 'TSTSM27245068', 'uuid': 'b69b021b-aa90-41cf-8d1f-cfc59c726b20', 'url': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM27245068/'}
# subpool_b01_13e B01_13E {'namespace': <AccessionNamespace: IGVF test>, 'name': 'TSTSM90710268', 'uuid': '8d44590d-bcb5-46f9-8c87-ea375db12ea9', 'url': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM90710268/'}
# subpool_b01_13f B01_13F {'namespace': <AccessionNamespace: IGVF test>, 'name': 'TSTSM57985101', 'uuid': '2f34272a-6603-41e0-9820-cf2dd432244b', 'url': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM57985101/'}
# subpool_b01_13g B01_13G {'namespace': <AccessionNamespace: IGVF test>, 'name': 'TSTSM10953505', 'uuid': 'b0e63479-2caf-4aac-9c98-2ff823f92c74', 'url': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM10953505/'}
# subpool_b01_13h B01_13H {'namespace': <AccessionNamespace: IGVF test>, 'name': 'TSTSM89995437', 'uuid': '5484bec6-4b0e-4488-b3b1-fd4def0022df', 'url': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM89995437/'}
# B01_13I
# B01_13J
# B01_13K
# B01_13L
# B01_13M
# B01_13N
# B01_13O
# B01_13P
# B01_13Q
# B01_13R
# EX 008B_13A
# NO 008B_67A
# NO 008B_67B
# NO 008B_67C
# NO 008B_67D
# NO 008B_67E
# NO 008B_67F
# NO 008B_67G
# NO 008B_67H
# NO 008B_67I
# NO 008B_67J
# Unable to find plate IGVF_008B
# EX 009_13A
# NO 009_67A
# NO 009_67B
# NO 009_67C
# NO 009_67D
# NO 009_67E
# NO 009_67F
# NO 009_67G
# NO 009_67H
# NO 009_67I
# NO 009_67J
# NO 009_67K
# NO 009_67L
# NO 009_67M
# NO 009_67N
# NO 009_67O
# EX 010_13A
# NO 010_67A
# NO 010_67B
# NO 010_67C
# NO 010_67D
# NO 010_67E
# NO 010_67F
# NO 010_67G
# NO 010_67H
# NO 010_67I
# NO 010_67J
# NO 010_67K
# NO 010_67L
# NO 010_67M
# NO 010_67N
# NO 010_67O
# 010_67P
# 010_67Q
# 010_67R
# 010_13B
# 010_13C
# 010_13D
# 010_13E
# EX 011_13A
# NO 011_67A
# NO 011_67B
# NO 011_67C
# NO 011_67D
# NO 011_67E
# NO 011_67F
# NO 011_67G
# NO 011_67H
# NO 011_67I
# NO 011_67J
# NO 011_67K
# NO 011_67L
# NO 011_67M
# NO 011_67N
# NO 011_67O
# 011_67P
# 011_67Q
# 011_67R
# 011_67S
# 011_67T
# 011_67U
# 011_67V
# 011_13B
# 011_13C
# 011_13D
# 011_13E
# 011_13F
# 011_13G
# 011_13H
# EX 003_13A
# EX 004_13A
# EX 005_13A
# EX 007_13A
# EX 008B_13A
# EX 009_13A
# EX 010_13A
# EX 011_13A
# Unable to find plate IGVF_3,4,5,7

# %%
# Old creating runs from the sample sheet

#        if experiment_name in nanopore_runs and subpool["nuclei"] == 8000:
#            measurement = get_or_create_sequencing_run(
#                # nanopore_runs[experiment_name]["name"]
#                name="{}/{}".format(plate.name.lower(), "nanopore"),
#                run_date=nanopore_runs[experiment_name]["run_date"],
#                platform=platforms["nanopore"],
#                plate=plate,
#            )
#            
#            pattern = expected_names[experiment_name]["nanopore"].format(
#                library_name=subpool["subpool_subname"],
#                library_index=line_offset+1,
#                compression=compression,
#            )
#            
#            run = models.SubpoolInRun(
#                subpool=record,
#                sequencing_run=measurement,
#                raw_reads=nanopore_runs[experiment_name]["raw_reads"],
#                status=models.RunStatus.PASS,
#            )
#            run.save()            
#
#        if subpool["nextseq_run_date"] is not None:
#            measurement = get_or_create_sequencing_run(
#                #sublibrary["nextseq_run_id"]
#                name="{}/{}".format(plate.name.lower(), "nextseq"),
#                run_date=subpool["nextseq_run_date"],
#                platform=platforms["nextseq"],
#                plate=plate,
#            )
#
#            pattern = expected_names[experiment_name]["nextseq"].format(
#                library_name=subpool["subpool_subname"],
#                library_index=line_offset+1,
#                compression=compression,
#            )            
#            
#            run = models.SubpoolInRun(
#                subpool=record,
#                sequencing_run=measurement,
#                raw_reads=subpool["nextseq_run_raw_reads"],
#                status=models.RunStatus.PASS,
#            )
#            run.save()
#            
#        if subpool["novaseq_run_date"] is not None:
#            for i, nova_raw_reads in enumerate([subpool["novaseq1_raw_reads"], subpool["novaseq2_raw_reads"]]):
#                #nova_run_name = "{}-{}".format(sublibrary["novaseq_run_id"], i+1)
#                nova_run_name = "{}/{}".format(plate.name.lower(), "nova{}".format(i+1))
#                measurement = get_or_create_sequencing_run(
#                    name=nova_run_name,
#                    run_date=subpool["novaseq_run_date"],
#                    platform=platforms["novaseq"],
#                    plate=plate,
#                )
#
#                pattern = expected_names[experiment_name]["novaseq"].format(
#                    library_name=subpool["subpool_subname"],
#                    library_index=line_offset+1,
#                    compression=compression,
#                )
#
#                run = models.SubpoolInRun(
#                    subpool=record,
#                    sequencing_run=measurement,
#                    raw_reads=nova_raw_reads,
#                    status=models.RunStatus.PASS,                    
#                )
#                run.save()

# %%
fastqs = pandas.read_csv(
    "fastq_metadata.tsv", sep="\t",
    dtype={
        "sample_id": str,
        "read_id": str,
        "fragment": str,
        "sequencer_run": str,
        "lane": str,
    }).sort_values(["experiment", "library_id", "lane_id", "read_id"])
fastqs.head()
# Out:
#    experiment                                         filename  \
# 15   igvf_003              igvf_003/nextseq/003_8A_R1.fastq.gz
# 16   igvf_003              igvf_003/nextseq/003_8A_R2.fastq.gz
# 0    igvf_003   igvf_003/nanopore/igvf003_8A_lig-ss_1.fastq.gz
# 1    igvf_003  igvf_003/nanopore/igvf003_8A_lig-ss_10.fastq.gz
# 2    igvf_003  igvf_003/nanopore/igvf003_8A_lig-ss_11.fastq.gz
#
#                               md5sum        size       ctime  library_id  \
# 15  bb696e63b6a8710ec8435b60ef6c81f8  8886302014  2023-02-07           1
# 16  21967ba1a5a3218508961fac482a2952  5866415324  2023-02-07           1
# 0   3cc7eaba69775ece39914a7b4e58de8d  5479439080  2022-12-06           1
# 1   f637c61c5c3df12dc946d2d32c0bdace  7997759697  2022-12-13           1
# 2   494bd18e8eb9bcef5b79f18f8f21d569  7241241549  2022-12-13           1
#
#    sample_id lane_id read_id fragment compression sequencer  \
# 15       NaN     NaN      R1      NaN          gz   VH00582
# 16       NaN     NaN      R2      NaN          gz   VH00582
# 0        NaN     NaN     NaN        1          gz  nanopore
# 1        NaN     NaN     NaN       10          gz  nanopore
# 2        NaN     NaN     NaN       11          gz  nanopore
#
#                                sequencer_run flowcell_id lane barcode
# 15                                         1   AAATMGFHV    1  CAGATC
# 16                                         1   AAATMGFHV    1  CAGATC
# 0   ffc0d811f8ac1aafcd29643e65cf87acf848891f    FAU11962  NaN     NaN
# 1   7d6a038266e5875db51e462422179436e6c44b3a    FAV21462  NaN     NaN
# 2   e0fe4672609d60d67277a22973f5c8534df5fc4c    FAU06484  NaN     NaN

# %%
models.SplitSeqPlate.objects.get(name="IGVF_003")
# Out:
# <SplitSeqPlate: IGVF_003>

# %%
models.Subpool.objects.get(plate__name="IGVF_003", index=10).barcode.get().sequence
# Out:
# 'CCGTCC'

# %%
models.Subpool.objects.filter(plate__name="IGVF_B01")
# Out:
# <QuerySet [<Subpool: B01_13A>, <Subpool: B01_13B>, <Subpool: B01_13C>, <Subpool: B01_13D>, <Subpool: B01_13E>, <Subpool: B01_13F>, <Subpool: B01_13G>, <Subpool: B01_13H>, <Subpool: B01_13I>, <Subpool: B01_13J>, <Subpool: B01_13K>, <Subpool: B01_13L>, <Subpool: B01_13M>, <Subpool: B01_13N>, <Subpool: B01_13O>, <Subpool: B01_13P>, <Subpool: B01_13Q>, <Subpool: B01_13R>]>

# %%
for i, row in fastqs.iterrows():
    plate_name = row.experiment.upper()
    library_id = int(row.library_id)

    subpool = models.Subpool.objects.get(plate__name=plate_name, index=library_id)
    assert subpool.barcode.count() == 1, "{} {}".format(subpool, library_id)

    barcode = subpool.barcode.get()

    if barcode.sequence != row.barcode:
        print(f"Barcode mismatch {plate_name} {library_id} {barcode.sequence} {row.barcode} {row.filename}")
# Out:
# Barcode mismatch IGVF_003 1 CAGATC nan igvf_003/nanopore/igvf003_8A_lig-ss_1.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC nan igvf_003/nanopore/igvf003_8A_lig-ss_10.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC nan igvf_003/nanopore/igvf003_8A_lig-ss_11.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC nan igvf_003/nanopore/igvf003_8A_lig-ss_2.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC nan igvf_003/nanopore/igvf003_8A_lig-ss_3.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC nan igvf_003/nanopore/igvf003_8A_lig-ss_4.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC nan igvf_003/nanopore/igvf003_8A_lig-ss_5.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC nan igvf_003/nanopore/igvf003_8A_lig-ss_6.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC nan igvf_003/nanopore/igvf003_8A_lig-ss_7.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC nan igvf_003/nanopore/igvf003_8A_lig-ss_8.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC nan igvf_003/nanopore/igvf003_8A_lig-ss_9.fastq.gz

# %%
plate_name, library_id
# Out:
# ('IGVF_B01', 8)

# %% [markdown]
# Load information about previously submitted records

# %%
submitted_sequence_file = {}

for i, row in submitted_sheets["sequence_file"].iterrows():
    if not pandas.isnull(row["accession"]):
        submitted_sequence_file[row["submitted_file_name"]] = {
            "namespace": igvf_test_namespace,
            "name": row["accession"],
            "uuid": row["uuid"],
            "url": "https://api.sandbox.igvf.org/rodent-donors/{}/".format(row["accession"]),
        }
        
print("loaded {} submitted sequence_file records".format(len(submitted_sequence_file)))
# Out:
# loaded 278 submitted sequence_file records

# %%
submitted_sheets.keys()
# Out:
# dict_keys(['rodent_donor', 'tissue', 'measurement_set', 'sequence_file', 'multiplexed_sample'])

# %%
def built_in_cache(a, b, cache={}):
    cache.setdefault(a, b)
    print(cache)
    
built_in_cache('a', 1)
built_in_cache('b', 3)
built_in_cache('c', 4)
built_in_cache('a', 2)
# Out:
# {'a': 1}
# {'a': 1, 'b': 3}
# {'a': 1, 'b': 3, 'c': 4}
# {'a': 1, 'b': 3, 'c': 4}

# %%
sequencing_experiments = {}
sequencing_subpools = {}

# %%
def get_or_create_sequencing_run(name, run_date, platform, plate, accessions=None):
    if name in sequencing_experiments:
        return sequencing_experiments[name]
    
    try:
        sequencing_run = models.SequencingRun.objects.get(name=name)
    except models.SequencingRun.DoesNotExist:
        sequencing_run = models.SequencingRun(
            name=name,
            run_date=run_date,
            platform=platform,
            plate=plate,
            stranded=models.Stranded.REVERSE,
        )
        sequencing_run.save()
        if accessions is not None:
            sequencing_run.accession.set(accessions)
            sequencing_run.save
        
    sequencing_experiments[name] = sequencing_run
    return sequencing_run

def get_or_create_subpool_in_run(subpool, sequencing_run, raw_reads=None, measurement_set=None):
    try:
        subpool_in_run = models.SubpoolInRun.objects.get(subpool=subpool, sequencing_run=sequencing_run)
    except models.SubpoolInRun.DoesNotExist:
        subpool_in_run = models.SubpoolInRun(
            subpool=subpool, 
            sequencing_run=sequencing_run,
            raw_reads=None,
            status=models.RunStatus.PASS,
            measurement_set=measurement_set,
        )
        subpool_in_run.save()
        
    sequencing_subpools[name] = subpool_in_run
    return subpool_in_run


def lane_or_none(value):
    if pandas.isnull(value):
        return None
    elif isinstance(value, float):
        return int(value)
    elif value.startswith("L"):
        return int(value[1:])
    else:
        return int(value)


fastqs = pandas.read_csv(
    "fastq_metadata.tsv", sep="\t",
    dtype={
        "sample_id": str,
        "read_id": str,
        "fragment": str,
        "sequencer_run": str,
        "lane": str,
    }).sort_values(["experiment", "library_id", "lane_id", "read_id"])
fastqs.head()

for i, row in fastqs.iterrows():
    plate_name = row.experiment.upper()
    library_id = int(row.library_id)
    fastq_relative = Path(row.filename)
    sequencing_run_name = str(Path(fastq_relative.parts[0])/fastq_relative.parts[1])
    sequencer = row.get("sequencer")
    run_date = row["ctime"]
    md5sum = row["md5sum"]

    if row["read_id"] in ('I1',):
        continue

    subpool = models.Subpool.objects.get(plate__name=plate_name, index=library_id)
    plate = subpool.plate

    platform = {
        "A00850": models.Platform.objects.get(display_name="Novaseq 6000"),
        "VH00582": models.Platform.objects.get(display_name="Nextseq 2000"),
        "nanopore": models.Platform.objects.get(display_name="Oxford Nanopore"),  # TODO: figure out a machine id
    }[sequencer]

    sequencing_run = get_or_create_sequencing_run(sequencing_run_name, run_date, platform, plate, accessions=None)
    subpool_run = get_or_create_subpool_in_run(subpool=subpool, sequencing_run=sequencing_run)
    
    file_set_name = None
    try:
        file_set_alias = submitted_sheets["sequence_file"].set_index("md5sum").loc[row.md5sum, "file_set"]
        file_set_name = file_set_alias.split(":")[1]
    except KeyError:
        
        print(f"Unable to find {row.md5sum}")

    if file_set_name is None:
        pass
    elif subpool_run.measurement_set is None:
        subpool_run.measurement_set = measurement_sets[file_set_name]
        subpool_run.save()
        print(f"updating {subpool_run} measurement set to {measurement_sets[file_set_name]}")
    else:
        assert subpool_run.measurement_set.name == file_set_name, f"SubpoolInRun measurement_set mismatch {subpool_run.measurement_set.name} {file_set_name}"
        

    accession_info = submitted_sequence_file.get(str(fastq_relative))
    subpool_file = models.SubpoolInRunFile(
        subpool_run=subpool_run,
        md5sum=md5sum,
        filename=str(fastq_relative),
        flowcell_id=row["flowcell_id"],
        lane=lane_or_none(row["lane"]),
        fragment=int_or_none(row["fragment"]),
        read=row["read_id"],
    )
    subpool_file.save()

    if accession_info is not None:
        accession = models.Accession(
            namespace=accession_info["namespace"],
            name=accession_info["name"],
            uuid=accession_info["uuid"],
            url=accession_info["url"],
        )
        accession.save()                
        subpool_file.accession.set([accession])
        subpool_file.save()


        
print("total plates", models.SplitSeqPlate.objects.count())
print("total sequencing runs", models.SequencingRun.objects.count())
print("total subpools", models.Subpool.objects.count())
print("total subpool in run", models.SubpoolInRun.objects.count())
print("total subpool in run files", models.SubpoolInRunFile.objects.count())
# Out:
# updating 003_8A igvf_003/nextseq measurement set to 003_8A_illumina
# Unable to find 3cc7eaba69775ece39914a7b4e58de8d
# Unable to find f637c61c5c3df12dc946d2d32c0bdace
# Unable to find 494bd18e8eb9bcef5b79f18f8f21d569
# Unable to find 52ddf98b481bb1f5fa7e0f705a09625a
# Unable to find 83fe8790d4a03f082b2b042719302fcb
# Unable to find af524063452a305fa81585f760ad0cd4
# Unable to find 82e30f39ad4bf46b3dc4e341c891e08f
# Unable to find 747ed12f09ae3b9cf85c4ea32807c972
# Unable to find 0dbdc8a7fe445f8a9e6bbbd7a7d42cfd
# Unable to find a263e940bd4e732193b7615fc142b054
# Unable to find 968a3e1b887b164eef30f7a443d984be
# updating 003_67A igvf_003/nova1 measurement set to 003_67A_illumina
# updating 003_67A igvf_003/nova2 measurement set to 003_67A_illumina
# updating 003_67A igvf_003/nextseq measurement set to 003_67A_illumina
# updating 003_67B igvf_003/nova1 measurement set to 003_67B_illumina
# updating 003_67B igvf_003/nova2 measurement set to 003_67B_illumina
# updating 003_67B igvf_003/nextseq measurement set to 003_67B_illumina
# updating 003_67C igvf_003/nova1 measurement set to 003_67C_illumina
# updating 003_67C igvf_003/nova2 measurement set to 003_67C_illumina
# updating 003_67D igvf_003/nova1 measurement set to 003_67D_illumina
# updating 003_67D igvf_003/nova2 measurement set to 003_67D_illumina
# updating 003_67E igvf_003/nova1 measurement set to 003_67E_illumina
# updating 003_67E igvf_003/nova2 measurement set to 003_67E_illumina
# updating 003_67F igvf_003/nova1 measurement set to 003_67F_illumina
# updating 003_67F igvf_003/nova2 measurement set to 003_67F_illumina
# updating 003_67G igvf_003/nova1 measurement set to 003_67G_illumina
# updating 003_67G igvf_003/nova2 measurement set to 003_67G_illumina
# updating 003_67H igvf_003/nova1 measurement set to 003_67H_illumina
# updating 003_67H igvf_003/nova2 measurement set to 003_67H_illumina
# updating 003_67I igvf_003/nova1 measurement set to 003_67I_illumina
# updating 003_67I igvf_003/nova2 measurement set to 003_67I_illumina
# updating 003_67J igvf_003/nova1 measurement set to 003_67J_illumina
# updating 003_67J igvf_003/nova2 measurement set to 003_67J_illumina
# updating 003_67K igvf_003/nova1 measurement set to 003_67K_illumina
# updating 003_67K igvf_003/nova2 measurement set to 003_67K_illumina
# updating 003_67L igvf_003/nova1 measurement set to 003_67L_illumina
# updating 003_67L igvf_003/nova2 measurement set to 003_67L_illumina
# updating 003_67M igvf_003/nova1 measurement set to 003_67M_illumina
# updating 003_67M igvf_003/nova2 measurement set to 003_67M_illumina
# updating 003_67N igvf_003/nova1 measurement set to 003_67N_illumina
# updating 003_67N igvf_003/nova2 measurement set to 003_67N_illumina
# updating 003_67O igvf_003/nova1 measurement set to 003_67O_illumina
# updating 003_67O igvf_003/nova2 measurement set to 003_67O_illumina
# Unable to find 7c2e696b3ef32c93df6b60904e944206
# Unable to find 35a5f174f5092c77a9b49abb6e760162
# Unable to find 091ce70e2a81a67cab829a8ad950a05c
# Unable to find 8bd57a0ee351c5b6c4b75241e27841fb
# Unable to find 9fc966f9a65017ed8d08253358f9838a
# Unable to find 9f619b9573bceee16a101e896603a04b
# Unable to find a71346fbebadc9cd919371c635fbc4a7
# Unable to find be7f202f30967334d5a0c9efb1beb586
# Unable to find b7d9ee19e2e3d326d806185d309bd751
# Unable to find 70086765aaf2678119bb04b488aa9416
# Unable to find 42fc16a794c9f570eca9eca1393672a2
# Unable to find 429e388d61addcd0b0c8f97458b9cdfc
# Unable to find a898c9dbb5173d72304dcdda3e693d71
# Unable to find 9fef40606119b48ae90ecad0976c7363
# Unable to find 32113bed6290500ee58281936ebadc0a
# Unable to find 4b64f562917fd3ee2dcf40a18f525dda
# Unable to find de9bc2b72383f85a2779c6f90fc1ff96
# Unable to find 310343ca4eeaee652e4b23b1a4d117cf
# Unable to find b37eb5352cdc612eaa64099ff61fb255
# Unable to find 06eb1b5adbec7243160c976f0c27f06c
# Unable to find be0419eb87c252b1b35f7f62a23d0476
# Unable to find 595fa38ab2b447550c6e526e042b41af
# Unable to find 2219b962c5c81feddc0b63bb38605728
# Unable to find 56b640e9df1c43334458708fb9fea31d
# Unable to find 096237a6e997f226244978eb1d908a93
# Unable to find 981506bcdeb1d8821042ea38a69e6d1a
# Unable to find 9d0708779041d8315ac46b8534f2b15c
# Unable to find 8d669de24ff2ca0d34544f4153db0c4a
# Unable to find 63d8f3ec621aecf7569cf8eeb2b94ab9
# Unable to find e987b7a5dfe3cfc1c0ff7ca74ba41a44
# Unable to find 399c2a49c7ff22d3e494924371d6b4a7
# Unable to find 369f4852a1465b4f4462d118e15ee417
# Unable to find b159a646077c4ebe60baba76e03e9a30
# Unable to find efd713aeee526624b5b728e0be860729
# Unable to find 831b4c80b3855f671072e2fa9a4aa401
# Unable to find 011f1d710e047550a85b8318e9bf8c80
# Unable to find 43ca31d3604111e80572ebce19bf89e7
# Unable to find b35de1a33e6653fb87227fb3ac1af723
# Unable to find 1ae43c9897223dbb15ff3e2b0fa53008
# Unable to find 82d02585700f5ed73a176e5191148cd0
# Unable to find f01181fa31093a024ad42e6237babe8d
# Unable to find 8dc6232b46d8fbe744956bd83c1c631c
# Unable to find e4ba135dba9d7e7cd5f8f73bd0bbfd25
# Unable to find 99a51eabb1235e0f9aee6c600e71f56a
# Unable to find 67a28c6b7eee5dd5355317995eff23ca
# Unable to find 0a2b70b7943256441a6a5be216a601e3
# Unable to find ba8f751700841d0e5e35e7192aeef8b4
# Unable to find c3b2ea8f0975233864a5a88932c767b2
# Unable to find fae45bef661ebdaffc8bd988ad973bb7
# Unable to find 1379b8e9ff539751c253a374debcc7a9
# Unable to find 58b5ad20d04cca18a4f9b90e1445c1b4
# Unable to find 4cb815d97063042b17db20485580409c
# Unable to find 793ace3aab7fde1ead9d2cd803d960ce
# Unable to find 04d1c0ae847002c8242887a41549a435
# Unable to find dbde1caebe27de7d9fc029f787078559
# Unable to find 889da42024507f9928225f7251208f89
# Unable to find 11665291c0200154ce4970a564b0eebd
# Unable to find 032cf45ef0c66d69af3ec76bcb85d14a
# Unable to find c3ead83fa41c61c7543f0edad22e1795
# Unable to find 96cb83b941da4100a97684f596d743fa
# Unable to find f996476af14ef27280793059f19ce129
# Unable to find e71d9b35a78605cf9db9e2e3ee29dda8
# Unable to find a52ffd9922caa7a148f56e0ae66039da
# Unable to find 697ffaa53bb44eaec0aea4e80b6a0d90
# Unable to find 94f59a944c03d87e8d58f49032dc2ea2
# Unable to find ec86deab0b5d2a08f112a27a83eae6fe
# Unable to find 48879d0646b604ce71263578dbe97a13
# Unable to find 375d363560ff354bfdd526c223375fd9
# Unable to find 44f25854a197af581e1cb292e3480ebe
# Unable to find 07ade726d3652dfa30a9c5f4906ce76a
# Unable to find 35804dc97353ae3809b40c8ed5e3bebf
# Unable to find c1908ed5443510b0a4338d4acf8e6624
# Unable to find b49aa80b860b63c28641cd50565d131d
# Unable to find b43aaede8a66467fe1f5b521b9c131e3
# Unable to find a4d7df1b3ead6a237bbbcfc759fb9823
# Unable to find a5946ccd3e3cf64ec8b775bb80de5e90
# Unable to find bee8dbb991a30c2c578bd9c4f4f7d6bc
# Unable to find 1fb7aa2e302287a27b9f89d91818a050
# Unable to find 0dc9e3530c41962f2a8cf1ff0a2427d4
# Unable to find 56f6fb0f91ab0d3a0a3724fba9764758
# Unable to find 12f48ccc04ba566fe38d55a4721e8ad1
# Unable to find 747cff8bab00af77df2f66c488d3f30c
# Unable to find 2fe55b07c2adc4a95e34ea816d01ab46
# Unable to find f379f9a4cf81e7f545ac7786ab21fac6
# Unable to find 3c5ec1d2ff110fea05908f32c2b8ba1e
# Unable to find 608113c0adc39d432fbf35df11b0ddf2
# Unable to find c065a72bafd89e2845f8fe9a6a67cdc4
# Unable to find 1064be35e0fb959b2f2d36fe1132fcb8
# Unable to find 011eabe8b6f6643aec26ac85b8daece3
# Unable to find 6b6301c1553156da8fafaffb4ab4c48e
# Unable to find 6c830cd71124a46945223fb20546d3be
# Unable to find 8fa2c945d92794b5f9a5530039b734d1
# Unable to find 9e51fabea038a41d3515129c1f82988e
# Unable to find faa6da753981777453cf49bcf300f4af
# Unable to find 20e14ba5f06f8ad2598017c5845c9ef6
# Unable to find f287f5ef2229d0bedf071d507cf876b2
# Unable to find 8f0c9a83ada11bc987c24fbb2816b0bf
# Unable to find bea731854b76d462c18e1724c9e6832a
# Unable to find 88073e9c877089b1023835f0fb026859
# Unable to find 454ba90d4def82c9244c46b9c2243778
# Unable to find 438a06e46611f08e587cc426765528eb
# Unable to find 4a1071c08f9da3d30cea4e480ba6569e
# Unable to find b2396764f4b88372ab8ad6e05f0c534e
# Unable to find 96564eba8baf86caeaac67f20f4ee7b2
# Unable to find b3373ad49dd8ebf5819eb313a1dee17f
# Unable to find 1c5e4b02cf682ae861b7de37bcb2cbc6
# Unable to find 58305d984ccc92badc0442cfbabe085e
# Unable to find cde566cb42ac11ec97df64fa3d7c9783
# Unable to find a7a57cbc1e68ad2433f262708aae9b75
# Unable to find 0a906b1cf529ffefd696956c8dd58ea8
# Unable to find 41f73c808ff036aa602aa5074581778f
# Unable to find 533d7b784e0099e2b69f88ed0f637676
# Unable to find 90073f04a446e525832b34ce26a53469
# Unable to find 0f531209b365677881ddebb0e9ba9908
# Unable to find 1d24b88b0894bb7c05caa0a330402953
# Unable to find 21e061d7d62b4a8e8257f552ab84d6f5
# Unable to find 4b2312b7762997fe621b0b708c791759
# Unable to find 2b5557cd84259124cadadd5676940e28
# Unable to find 945986935d0c8fd5886fe08086f66fd9
# Unable to find 706031683f8dc23754437d07cc454367
# Unable to find 0cf96234ee7e754e23b6cbb06db7aaf3
# Unable to find f841723261808e4d27f9325bf8593d4a
# Unable to find 0ae7e5cca34c0c15298693680a7a407a
# Unable to find 5c368497efadcfa4d9f3cf628121d199
# Unable to find f7029d4e44bda89abb221985448a2a32
# Unable to find 6db8062c9b25a7a3fd8d352347c18eed
# Unable to find ae9fd97e7fec715d455c3e190921ddaf
# Unable to find 42a13a6b9a1931d50c7507e482183957
# Unable to find 2a4d540927cf8742694b19d551907ff6
# Unable to find 2b184742a7396f596f2509daa3bcdd9c
# Unable to find 4f6afc7542acb3c613ecaf718f8b11d9
# Unable to find 20934a1f874f029d9caa3ab629fec9f3
# Unable to find 7a422ab13a08e253928acf01e119109a
# Unable to find b6abb56b5961f16d84080ce1cf974f44
# Unable to find 0833907c6c7e9fa67f31e923f8cb4dae
# Unable to find 575e0e545e413362c272546a70238bb0
# Unable to find 3301aa432c98b3a648f17ff607eca27c
# Unable to find 30f978330bcc5f8b2621ab2c7076fcbf
# Unable to find b96504a45d92491129b45b9f4e1a4ffd
# Unable to find 841f1b74af136d8c082dd9835e695096
# Unable to find 60357b65c5897d02e2539f6ace783f13
# Unable to find 6b8105a1aac2754828a77006eb4e7600
# Unable to find 1acb26ac9f3b4ef1abbcfcb5cda062e3
# Unable to find 44bd94287405d48620e81bea80077584
# Unable to find e9b292eb885ca4d43245463588db1f88
# Unable to find 500d6463a8aba1ea8d26ede99a09f9c1
# Unable to find 071ef7e8d1cd7dec921f333f72cd7b30
# Unable to find cbba592ce23b31c19baa203b3fd7246a
# Unable to find 5d18cc29ea5853f2d2e0c3d6d8756fb3
# Unable to find a2e9743d2dcd9c5b95958ab380c3b04e
# Unable to find 82bdc4a9183a88c5eb566d7cccb7e417
# Unable to find e2ad221c32ecb538062d52a3fb4daac2
# Unable to find b56f58a3ffc6d5917faacd8058a41253
# Unable to find fb8c31249fd951f8bf853f77bfd5a4d1
# Unable to find 58b7bbda0521471889206ca4cb844c41
# Unable to find 74ac26ad186c0d9ce5c697f4c1a986db
# Unable to find c8a2bdb7f8f9b225ce8f297991f7a7ce
# Unable to find a4d70856bf6c82cc2ea1d3edbb709937
# Unable to find f83fe37e564ccbfb23a24b38f4d3359f
# Unable to find c1ff99fe573397dfc8e30120b45cd6d8
# Unable to find 25941a5bb973f9648c6603941296d6d5
# Unable to find dae43810f5f12b8ea2f2ad4be28eaa5c
# Unable to find 5bd4c964df0b1edb59a02592e80c2298
# Unable to find 3199abb6ab7a74021e68ff8d82c55339
# Unable to find 3ee71f65efd4ca7a55d45608ca37d9cc
# Unable to find ca95ea918554339ee2639933db68489a
# Unable to find a355e2eda77543b1446c55569e84f082
# Unable to find b0ca0f5f3d43fd21fba8ff01405b1174
# Unable to find dc80f2b4b2a4eaaeec93528edd97e902
# Unable to find 3463674f95d7ff25cb0b90d0cb2d0ebb
# Unable to find 1bdd813ee656c008a1e67e460ca3bf48
# Unable to find 5af31b96f642918c20ae7bae95141868
# Unable to find 833f7751cccce848423a966040c962c7
# Unable to find 3c0c50d0112dfd67cc5516baf0d01e6b
# Unable to find 71f0b220f5923f3e22a3fd21e2e2be70
# Unable to find b950cc47e7b2d4767efb6dbb09f1c0a4
# Unable to find d4fa690460de2d6da24d4049dddecb7f
# Unable to find f2c6d5f0bc43a9b3c08b8dd4c39fb9b2
# Unable to find 7c4eb82b8520fdb1ccc87408d4f819f6
# Unable to find d337de8cf9dc9191277270e1dd0f63b1
# Unable to find d61f88556bce54e4eef42864f745b3fa
# Unable to find 639215b918d6dbfd8d04f0659b45832a
# Unable to find c458912637161c38ded725eb6a55ffc1
# Unable to find 98b0e1297ea681dc213b383444429545
# Unable to find 95f6616d7e397af8bdfd5705756f3a52
# Unable to find de45fa735389a21539e77bc661dfb560
# Unable to find f37a20e2ac3e8cfae798ae096c0f32f9
# Unable to find a60bb302f2ba56592f6126d4fcfdc610
# Unable to find 097e0d31ca2b61a1ccacbb0791496fb4
# Unable to find bed02a9d001781013b380bab3ff49e37
# Unable to find fa9d19728c2ffbd0bf2469147dc37923
# Unable to find 6e5db08e7c3dc2c055d3dcc8ee462ab3
# Unable to find c7684d783a2e6961f1571dea736b05c9
# Unable to find 975b136e76ff587cce6cf4d90ac42575
# Unable to find 13dbd506207489e1bfb7fb90e649a584
# Unable to find b0e62637889d5ffbc69c4c9af31ad0c3
# Unable to find 26bf10852d89435075c836c5e023deb0
# Unable to find b086714d3949ac0c869204b53cb59c7c
# Unable to find f20d4009fcad973ce697a0442eac9bab
# Unable to find 693c3223fefb1e9357a7904e9013c9e6
# Unable to find 1ab10a8ada340e5fc6fa3ab0f1872fd7
# Unable to find e95d8664a056058e24691be75cec698c
# Unable to find 94ffc3f5237a5f1a6b7def58ef902ed3
# Unable to find 8e174005925ea8007d9749b4f34daaea
# Unable to find 7ec50b47ae513298a78d69d9eb1d5327
# Unable to find abb0052faf9233ee809f42fed0227092
# Unable to find 35e2b5686a2949193a0ed1cdb7c04a76
# Unable to find d978bfe7b2bcd912b19db5a8b90ed94a
# Unable to find a6e803195c78882074158d68ae5576f3
# Unable to find cfa626ff7870403a35669d68db02b540
# Unable to find 90340f0f7f754d7340b47c61580c6bc7
# Unable to find ffbcfd49209211569a1b6754fa4ebde3
# Unable to find e7fd2d4ea79dc75023e98c870cc43f61
# Unable to find bbbfdd2696b1527c6fdc0ec1e35f8933
# Unable to find 6c7ac6397613436ba4195472273c49d2
# Unable to find 40c28dcc856213ba1144603e7f243caf
# Unable to find 72478d810741c82e8b00685bc0a6f770
# Unable to find 19d94cf2040d89ac14562e373ebaa226
# Unable to find 18d5c41cf55d35a46538c1db30fbff6d
# Unable to find 42de699134e0954ee2aef39f81db3a70
# Unable to find 346f1a54be26735545ff691037fc385d
# Unable to find 4b71d2439ac24617d9ef0d47bcc30ed0
# Unable to find a25eb265531fac082de597c20106b568
# Unable to find bc1726e8b61d5ab1b6ed56c99d21d87c
# Unable to find b2e9d73cb56073ef8a24b157f8aa5b80
# Unable to find c22a34eae50cd28e319d00a70435dc97
# Unable to find 7583b04d4ec7cdeec06e270b61219a8a
# Unable to find 955815f212e9389c30883d501e60d345
# Unable to find f4fd6f1dc375d214bde6361ef2d4eed4
# Unable to find 1cc03429039a277e5e92bd8ea44e9809
# Unable to find 0a47fd72289f4c7bdf55bdeac44d3c09
# Unable to find 1a127b65a4e6ca6ad7cdd2de9a344e32
# Unable to find 028c6220881164fc5e2a8a6ad8e974ed
# Unable to find 4a7363079ec871e27c9fd9d298016480
# Unable to find 093e74e1d2d09818b8b45041ac3122ff
# Unable to find 7ef4c6109f23f01ae2b6629bbfffc228
# Unable to find e87b44e2dbbf5e589afd971ba7469173
# Unable to find 652e77e5267544e129bc6f240aa00e64
# Unable to find 3936dee09b0f4809821f639f80e89b19
# Unable to find f13efbea063fd2809c3fbafee8ab21ce
# Unable to find 23a6ed489fe53accba6db235f307d79f
# Unable to find df9647df8d73cd2f0457f977ecd2959f
# Unable to find f851ea47ed44bfefec97ff9822c363fe
# Unable to find 2a90de5626a71e0b8f451eb13cc4cb99
# Unable to find 5d26d55eff99cda323f784b782481f6b
# Unable to find 40fc5d5db869c3b0daf2a462d1b195b5
# Unable to find 0c48d3c086d609816eaad49c6902ef60
# Unable to find 9c4888ea4dc074491340a569d99937df
# Unable to find 705f90c13dea6fead5fb0526d3f7aa9a
# Unable to find 61088283336d77046ac49db8599d0026
# Unable to find 286c2fe70cda13ec3138b7a6fd0da36b
# Unable to find 76831c060e1886edf90e2ee158ad79a4
# Unable to find b02ed3a97d1ef9c51194c2b7987de1d5
# Unable to find 00d05a91aae90cbcfcd27e7c5339ba61
# Unable to find e6fb6bf1823711d23be03e1449e6747d
# Unable to find 79a9ff5ada609cfdee87296b2fa8f5cc
# Unable to find e7525667052d4b8049269f00eb460952
# Unable to find 0d35e56ceb47313957d3161f115b0fc6
# Unable to find 702e24ab8f2fed9abf868e94a52f2b08
# Unable to find 0a19b2067d693d18078907dca5f7b564
# Unable to find e4df8cc0b1f6462d2ed662b8d98c145c
# Unable to find 7565549a49e57257ebc0cbcabd82c626
# Unable to find 7142e878729bdc333fd6fcd455658024
# Unable to find becaa28c7b9694ff4e0779f7c0c17447
# Unable to find ca739778141f70555b04a3efa596d7c9
# Unable to find 6f6afb9e6d4ea5b6ef9120deb14cce47
# Unable to find b22089272fcaa00468cc88e093f2ca08
# Unable to find 9c0707c63936b1826eb0caf519efcfb2
# Unable to find 0b5dea2906ae9ec30faadc759fb47b5c
# Unable to find d371d9731167550f3de38b800ceb6609
# Unable to find b0513ef377d413e61f1bcfaec72d7f93
# Unable to find f900d75b9c4f5352f2379bd023698c49
# Unable to find c0c00a40287045605243a403c7217593
# Unable to find 70b3d3233278e3b068b3c59fbec46b4d
# Unable to find c853bf6eeac42fd5f3bf7f9e996a064a
# Unable to find 7acc52845d9a27f64727828b31f384fc
# Unable to find a1c7dcf9302caa2b99eb481f4ae3b6de
# Unable to find 16cfc025ba266f3212088a7730ea54a6
# Unable to find 0e04e656db239dd609a1f370c680029b
# Unable to find fcbae83c93935997d31cee3a8c315418
# Unable to find 259be10bf9ce46d080525902185c00d9
# Unable to find 6728c2594b91a43a3ce08a20def15b0e
# Unable to find b1288b020c222401c9672d8be4390165
# Unable to find 5651aef2d8cddb9539e370aba6d0b2d3
# Unable to find 82a02c994d0dcd4be4598756dd1b9200
# Unable to find 59040625cd953b0ff722ee21bfeac2ba
# Unable to find 9be86c7d9a3f51207afc8f6dacf213a7
# Unable to find 9031ecc1d6d2cdf1d3b90fce7fd99e7c
# Unable to find 9b80d956aa20a7215b60a235a143af5e
# Unable to find 3072a2b5c5272724d482d9c27837795b
# Unable to find 579e1e61623dea1636c2fb6ceb8a3562
# Unable to find af4a5ec5c75ec9b9a1f5059a9171c85a
# Unable to find 17cfd4e95d5a8dc1a1162b3f3e2b7c87
# Unable to find c2dc3603fe1696c2d50be06f349e4591
# Unable to find 48293a211a24dee992d8a9d6e5438dc4
# Unable to find 61ef5ea008e3b87fb68f7238baba050b
# Unable to find 492a2f6ab9f6c72d8ea1586f2cb8aeb3
# Unable to find 3aaa276c0aa30a7220c1fb53c7eaefa0
# Unable to find aefee63a46a79d03928fa05061b037dd
# Unable to find 21b38ef192a7131f3a38364700867dd9
# Unable to find e2470bd494bfdd3639a571aa836b99bc
# Unable to find 918cb4e67b394af3c356f16d1ed1296f
# Unable to find 87a8aad0f3504e8c2092d7cf3d5c0393
# Unable to find 42f0d54a72dc1754d7859e4e335fdda4
# Unable to find 1bd6a287176307c8c63e5c0c46a1abd0
# Unable to find 5d6683abaddd7d1896686ee7063394f8
# Unable to find 8196b64bbe621181a99331a040920af6
# Unable to find 8afb4ec8bfdcb32651dc4d8e62a8b73d
# Unable to find 99fb0cc82b25527a317b358d76c8bb75
# Unable to find 8c075873585461d69d9ee89906acf326
# Unable to find df9ed97ff3aad25f259206e87450678a
# Unable to find b3324ec1d011b2984e47ce18f42d11b5
# Unable to find 9d21ee483a0483c5523a545b308c15d3
# Unable to find 2cf0b4e244e8a4aa06145e0a197ee2a6
# Unable to find f07a8e61c1b2495e6dcb31bd0e1462eb
# Unable to find e10a4883d09b86890789bce0d1cb59fc
# Unable to find 411b7523cfc016d7a4fa44f178037538
# Unable to find 0eb8304cbf8ea1f51e8612c2dbd6417c
# Unable to find 01a94637eb0e0cf47e4b0da5ea5244e7
# Unable to find 190314c4f57b3309d2b3b06f01cd2b22
# Unable to find 7da447b043f8b5bf09a057a528d61e5a
# Unable to find c85a037ba327626ed656b33d8d73f39a
# Unable to find 9634ab8c8d3da3fec5941d513623a938
# Unable to find 833dfe286ca153e989cbcd547a736868
# Unable to find 5fb544386a0bab6ae7f630db313043ac
# Unable to find 3d319340255a02781a026e329ea344e5
# Unable to find 8f947dcc0ed0bafda54343ba697bae78
# Unable to find 29581adc5275742fefbaf8b81107a6b0
# Unable to find fa5cc54d55647c4ecb10526f43339f96
# Unable to find eff8415c2cd80793d251a184921b7071
# Unable to find 2141ff31d3124d55f43361e0bf541430
# Unable to find 216c5549b8e69f17f7378b4d9e3c6965
# Unable to find ab6f286b88669e2209b38a1655e52d1e
# Unable to find 720a062413dc8d0e78b5765aac8f8073
# Unable to find efe3057072170569a853310b20c7ce93
# Unable to find b6123bc64638db028684f8b8d38c6b58
# Unable to find f2f56485c8867565a5cf6c4d623ede69
# Unable to find 7427059121ebb51ec7ba85a206778147
# Unable to find ac1d30fb5d3a10343859de254463373a
# Unable to find 2b6a73404c5fe64a1026b863412825da
# Unable to find 0c0e9808989b0d894597e0980b5b1f07
# Unable to find 7223b227f25d343b30f18eb223718732
# Unable to find 561346e58b8257b3e588c159909755af
# Unable to find 9e923368e0eabdfee44cf28f862c7b2a
# Unable to find 25fb1af8540109d997dda7b6bdbaca83
# Unable to find e43f978317365eea653e92ae66cf5572
# Unable to find 88e2f7b21437945a59d902b5989d520c
# Unable to find 9b4904065c8457534b3c0020cf7d5e83
# Unable to find e099451db469777cd12a9c5eaa2d393e
# Unable to find 80d0d25eb8072c59e8e74be511a8dab2
# Unable to find 174fa4104c605eca8a9205ee9619f078
# Unable to find 25cb767ddb1c956b90c0dc4e63f50a5d
# Unable to find fb97266acd289e295a7838d7e0e60693
# Unable to find 954c6e936695636161d1d9d657ae1e2e
# Unable to find 7ca6c548e5f34ca8a49a5fd309445de0
# Unable to find 0f39ed01b8ad3750c512354d2f961c60
# Unable to find 7460852cb11f1e2f890efc06a4a1d972
# Unable to find 4c1c287aea22c5413e8bc005d5fc3f28
# Unable to find ded679536c9d783080cf9ed4ca1a02c2
# Unable to find fc6fbbdcc2efef5cef6b8a679f0a3a3d
# Unable to find 78fa59a04d383414f59e9cfda98d8871
# Unable to find 461be29d93743c729ee27b50d9ff0147
# Unable to find f9e2517986a13791880e33e02e779e42
# Unable to find f5c449c0ade8ae417875d9249e298d73
# Unable to find 9de765b8ac18784b6c872bf8ec67a907
# Unable to find 51042adf5fc8930b0043e399c0c580bf
# Unable to find 1fddd12449e1b417535d785f9da605f0
# Unable to find 340a4d74b2c78593282ba340a3bc6294
# Unable to find a99fe6bf431dbd0503d1c03fb7213ac8
# Unable to find 00733641a74a1d17de4a8092ebd977a1
# Unable to find b1f955838354e26dea5215ec589d9cd4
# Unable to find 504d6ed91812b5b931c89cd0fbbd8077
# Unable to find 3274cc512b7d083423eca10c93f5a071
# Unable to find 6dc4d90b73c2cfeeb53888fc5442d211
# Unable to find 2f2be48603af4a18389d0655a6a30d96
# Unable to find 1b9332a5df8d33784786251ccbba2a92
# Unable to find 154e0ce9d800cc83816bc494c4a35cea
# Unable to find 6a6e7a0d5d6f60c8ff6582869b936c3d
# Unable to find e84bd1ed5b025ace3d8b0d25f7f0ca0d
# Unable to find 34c351656326d57970725d5eb6276819
# Unable to find f43ca2540cfa36fe6799660fd619e4ba
# Unable to find 9031130d19aef77ac51e7967d1fd226e
# Unable to find bfb3209d4dcd131c2f64408fbf6335cb
# Unable to find 7026b3367658f48469c03ab782c16305
# Unable to find d4236a9133a6efbf939aaa75c5c03fec
# Unable to find 556bb27944c65ae940fc41971e1d8c31
# Unable to find a2e77dc109231f8a6c20a29cf84c75e6
# Unable to find 01d72d748a3ebece737d7d9036688945
# Unable to find e02991f9ccdbe1d1111b093cd4da6579
# Unable to find 7b696f1b2c55ba5b0605047ca6d212df
# Unable to find 271b2b099a3e42687a92a2e6fdc973c8
# Unable to find 1a4cc8ec4147d41e5b11396a9cf44098
# Unable to find ebbac613a886bb0963e72fde6288594c
# Unable to find 9b692d76442e0935f95f2255630ca7ca
# Unable to find cf7fb39cd888617e2571003d99101e10
# Unable to find 955143a8c2327ac492c366c5eecff1ab
# Unable to find 4dde592fbe08e7243a020df359f324c1
# Unable to find 975c34734f74b8774f08564642c0b52f
# Unable to find 8034d45902ca502b587b32dc7fcc8ddf
# Unable to find 8cda10b36f05edd117afcc7a79c423ed
# Unable to find 14430ae552dc1ddf3d02d1aa82beb4ad
# Unable to find fc9e44b1e2195416e3bada4662372847
# Unable to find e0bf0e4635367eda1b8dc679b30ad4c2
# Unable to find bf57823f6b067b31e46888d18c6d6569
# Unable to find 6371c31156ebfcdf9f45b8d524b476ab
# Unable to find f8dfb37904355508398ec1f6cbeaeb73
# Unable to find c2fd180b43fce4087bdd20f335e668ee
# Unable to find 9ed7561106f42d0af5efbee69c1da8b0
# Unable to find acea3c14b50fb3e747d3ab937510222a
# Unable to find 21e611873c273154e14d4cf8c7143ca3
# Unable to find 55eef058445869564d23709a8db7ba4d
# Unable to find 5edcccf9da8978669c049576db7d4016
# Unable to find 4378dc8c9b2ddab55020af9a4adcc61e
# Unable to find 1480eb5b91fe36a80043047674a5af03
# Unable to find 9e38f17d7d198749db579baa767add4e
# Unable to find 114497c1d87ea020a3292f33e3c861dc
# Unable to find f40d82a8d49e606e523c607edcf61010
# Unable to find 7e06b2b7fea52931e21a325205e4916e
# Unable to find 7aa0af27f8b103c9ca37b78592232afc
# Unable to find d595c37f2a889bb128279cdfea67635a
# Unable to find 090f1749037a59443d39dfd514b725be
# Unable to find 7b44b8a9229d208753c36dd6463a04e5
# Unable to find dff7b5b4ccdec762f518a0f886b186c9
# Unable to find 016a94820d0a2f2e6317e6958d5ee9c6
# Unable to find aebd701aaa4a204443bda7d82d1f0540
# Unable to find 7b7d7d9c5989b395cb897a47af285546
# Unable to find 6761810d322e1edf22402b8d2b636cd1
# Unable to find 144911cb3f9e2c24b8d70538768c2502
# Unable to find bcfe1a1176952408e6b6531941de40ab
# Unable to find f7a0562085fbf37e2d3c94106ec84190
# Unable to find 0c7441bf17e0d6c446058bba5bdb8bed
# Unable to find 3bedf329ba14a748a0035bab170c7ed0
# Unable to find 0b868cbf46df17a6ab9efdc2e3783e46
# Unable to find 23f012599dc4aa33689b400fcc2a845d
# Unable to find cb94089b8924ed72050f30029c62def3
# Unable to find 11b29e96b0f228995accd89721f4e0a0
# Unable to find 6afc8c48fab3226bb018fe05866987b9
# Unable to find b63c2f0d6f7c27a1765c8c3ed193a681
# Unable to find dee91189dc4a79ecb33da87ff22f0e64
# Unable to find d940ce954a0ef71bd8d1a97aa4da8d2f
# Unable to find 4a3c2ee8227098a755e40adf9e76c6b6
# Unable to find 3d45e5aad4123bf7ab9d981fd9c65c9c
# Unable to find 9f95377855e493f3bc078512e603272e
# Unable to find 81554a419906ef6ebf4b30d60a74f8b0
# Unable to find 67163ef42eb5e4c2611a439bab97f114
# Unable to find a017ddb6668d9f36dec1078a57a5fd7a
# Unable to find e1b7d2c326d3cd08409e74a377902721
# Unable to find bfe4d1f60936b8bfda2f695d9223cd4d
# Unable to find 558863fdbefb0abbacec51f91e44ac01
# Unable to find bff9c3e33c792c5b54791610307cd887
# Unable to find 938bb4bc738450902a293e6e5e750994
# Unable to find cad8e744cd257077972fee1942e6cbdc
# Unable to find 5147aac6add5cd589d71cd5c47ddc450
# Unable to find 58190e86412f359e4a19557e1bc99af9
# Unable to find feee95654d5b45ed0475f915f6d278dc
# Unable to find 6f16af1530b4d561e876384eb9ea249d
# Unable to find 49b1497b21ebea35021c16f353aa904f
# Unable to find d954313605a35e192950bc4bf8cc90f7
# Unable to find 3a1a0792a3356e45a8bf7af45d364c15
# Unable to find a581386c2e0db4322348cae3da90b079
# Unable to find 943d6f74fe60ee4392d9c27edcef5ff8
# Unable to find b8560133ed3d9aa66662a1703d353a06
# Unable to find 7c10e7b3d3db717e48b15390f1ca6613
# Unable to find 079758e2a1b69969bc0b69ef971b22b4
# Unable to find c298ae91715ad8daa42b43a33e702452
# Unable to find 788b8f969f1fc9a6262e53341e64c42d
# Unable to find ccb9e24b351a1083cff1da116adbe767
# Unable to find 7f0e3f2138dc72f0efcdf315f7b3d6de
# Unable to find 88a6714afb2b92a587886c18c00fa330
# Unable to find b88f96ffd653d73ed4fdc0d19eae4c05
# Unable to find ead5d24cb2c6fbf7f7beaea0fbc8aba5
# Unable to find 389ecf2fafcdcf8fc1a4052433b14636
# Unable to find ca8929c9c88c56939f5caa9401c6421a
# Unable to find 0d8774b2c388fb63a1d4431c51dee59f
# Unable to find 7c5c46ed2756add5839b1bd9a745b356
# Unable to find b22c5de90e4db5924bbc360906eb81ee
# Unable to find 7b0a2df1713211ddbec2a2bd5c125695
# Unable to find bec5783cda545b96a6387469895d2a5b
# Unable to find 8008301ce64b72bf60e92a87c8b8319a
# Unable to find 21e41bb405172d11148dc40079b8a7e1
# Unable to find 04d42ccfe8d7bed0303b9db293f674b5
# Unable to find 834b995756fa7132758430ce33b32ad0
# Unable to find 001b020a22ff492c2a3e072e77ac9efa
# Unable to find 5d8c319b485b1bea5f80cf5b49726409
# Unable to find ab31cab21a5a9e117e8e914ff2134bcb
# Unable to find 682a74a22574ee1b95c407d284af2fa0
# Unable to find e3c1555f25a1b95cdd6349ffddf84862
# Unable to find ee28e2c0003466391055e848ca16da54
# Unable to find 46e6cff130137971da02f3e25334388c
# Unable to find fa9766938ac11fbffbf20366e6f3e2f4
# Unable to find e341997a36b73d7f500ef48bcf048570
# Unable to find 9b31b23a0dea52d9961ba6f8a2c84c82
# Unable to find 9acc7a9f8d1c62b7b7d504080ff6e4d9
# Unable to find 0d31c6628e9c0439a4e2301203e156bd
# Unable to find 460a9e7d05c8718723a7fb16bc1ae8fd
# Unable to find 150b69d1a185bba90d6972b39e0a1a52
# Unable to find 96e22aef2bb35de59f0a1d7981112ae6
# Unable to find b18e09fd9d874563295707ea0d190e78
# Unable to find 3799795af8c4e30073a277ba16ac704d
# Unable to find 0d86fc00bda1f7dd140bb7cbc64a3db9
# Unable to find 9c7ffb753183d74241091921bf833b77
# Unable to find b28d12a867fa621f6285781a36aa699f
# Unable to find da1e3960e6595d47558ec744431b4d69
# Unable to find 0101694eba2057221337028045aa0672
# Unable to find f02b5c5517243ed981b5e82d795e4121
# Unable to find 97de238c9c86119ce023c867e5676fe6
# Unable to find 682cc0f9f49992a85cd311df37531925
# Unable to find 39a47476cc0eeb0d88584b7889206c88
# Unable to find 884697756fa470e7110a32ee9d3d92f7
# Unable to find 5f74a16a683081419a4f29596b314d49
# Unable to find 20562b1be3d2e1858e52d79d703ae41b
# Unable to find e55501e9d6d6dfae11c623d3f642a91f
# Unable to find fa07484bb1d54c840a2ceb9e1f661511
# Unable to find ad8763ebd425c0ce25fe79bf270490f1
# Unable to find 7d1fc07641d0cf6eda68437f993a857c
# Unable to find 53f21d0f1d8d6f73e7ccb7c234e758ab
# Unable to find 0e258873566d1a84d6dc72ff948bd80d
# Unable to find 6c43c7d71123b1ec6fb8194f351a8f7d
# Unable to find e8bcdbb6d6e07725a209330cadd32b9d
# Unable to find 22ebbac2ec53810fdaf3e33430838011
# Unable to find dc82343f9c9e3f94d62a1adea6850040
# Unable to find 00bf76b18f85c7c15a2219293d3a72b2
# Unable to find af66f7b80740b2d6e624f76deb7f7960
# Unable to find e8ffa2d7b60559d896066fba93b28b22
# Unable to find 67c462afc50d9fd3eee7c8cb4121d26b
# Unable to find 10cf7b00b03677d97b0bcde9aa14ab05
# Unable to find 87a3836365215932ab60b01a1b45a3d9
# Unable to find 5fc5b2596bdb92531af0bdc3375680f4
# Unable to find cea2744fdbe97af693099a9fc844c299
# Unable to find e1d879ceb8967d0ecb8eb88992935371
# Unable to find 5a0f65b93cf5302105b29ff17f02f043
# Unable to find b05f79b00af82dfffa86211985630dbe
# Unable to find 80af6a4f3e499ff0f3af3d487d7e027b
# Unable to find 890a65a38ca6cae76a764495f7995a7a
# Unable to find c098895e19d457697cfea78430983687
# Unable to find de3ff3881c0e8dd7bd34fa834eac61cc
# Unable to find 744c6b0f3f9846be495a61e085ab40af
# Unable to find 31a28b970b606c531691eaf8ae10583c
# Unable to find 1bce5f3d7624eedcdc0ff4cee2942ba6
# Unable to find df7578afb85f52ef0d4f7dd2d6772100
# Unable to find b802cc448fdb3730e1b8f1f1720f3507
# Unable to find e3df7bafd8c16cb85476e860b9f8832e
# Unable to find 8c14036e33214a1197244b745307e7d9
# Unable to find 1fc8ec3dc112e8f5ba6a7c69b0e37e03
# Unable to find 0195f9d709e07e01523e359baa71a0fd
# Unable to find 6ea20ae3c85f43596b1dcc01bfd3a8ac
# Unable to find 51193373e4ddafa399305ba48ce70929
# Unable to find 4919baeff5b1e9e26a25054d508bebb8
# Unable to find 707a9eebcd8455036793a9e7dbfc1cc9
# Unable to find 282dfa6434f87380826e6ee099d6c670
# Unable to find 32462eca85529e540b1c4471677e7a89
# Unable to find 52e7806393ef2f52c9c6ee5cecbf0081
# Unable to find 0de7973d87c40d1a36840bb0c062c930
# Unable to find fbe19808faea2082bb08bb59b912a83c
# Unable to find 9e2d1db3970e75683953367254d2d964
# Unable to find e1211ff13ee8492222ca2093cd6195d4
# Unable to find 73b9a51b39442520327786e2506bbd0d
# Unable to find acf61a2a3940c0192526e949c7f7cdc8
# Unable to find 44fd8ed818020fb60f3800543b276465
# Unable to find 2b385af7a7ce5a9ddb1a111bd189407c
# Unable to find cfd0fb7a88f7f428cb992b8204edf5e6
# Unable to find 20b30c077ed02e043a6e4336eeeb0758
# Unable to find c29751a4bcbc4f720fd9e8123e2bbef0
# Unable to find bc3ab6a9b5a2af9b6bd0053a29fcc2af
# Unable to find a42057f8deebaca7815b42c192988e10
# Unable to find aa8d8c80aef8b67c3f40ff2344624508
# Unable to find 3688823f1e3143fdbe162d413a199d6b
# Unable to find e6f4da2063686034b290c9812d446712
# Unable to find 9ea0e3cb5bb754039a230878b156d74c
# Unable to find ae8bc33f23d665e219f96c3446ba46f4
# Unable to find 0468b4fea19bc90c8689e29f3e3ca593
# Unable to find ce7b93a768c758236c7aa78255550234
# Unable to find d5d494a650ae9c4f1f61a0a3742837bd
# Unable to find 0d893beaf788d3b48b4be413fe503075
# Unable to find 52f3c97e6ea5d472ee174cd28cc350c9
# Unable to find 600363446be3a5625bf265f153a5a25b
# Unable to find f6309ab9cd1fa5c4faa36206e3d84f03
# Unable to find 31fb566283b7200fb12014cc769d5a53
# Unable to find f730d80e1c44aa1ce80009c2187bb93f
# Unable to find abd5b66dd200e4adc31056889ef776da
# Unable to find 7e0a25fafe04a42099135132c007aed0
# Unable to find a0af8f24a69add465f439dd8542276fa
# Unable to find f98564b13df2bd544a54b5995d464e10
# Unable to find 9ce4632c75629e496cb2765c9a131e9a
# Unable to find 8bb354d41575daed8fe2186a2c68cffb
# Unable to find 0ea744abb347704ced80d9eec9540e4d
# Unable to find 2ee4ecd7434786fd80f1fa3e8f7b34b5
# Unable to find a58a059ba3ea1d1ec56057a430a5b193
# Unable to find 38acff41ba6d53aa2656b18014f26e58
# Unable to find 0bf3859b42eb6a2122dff92adb8308e8
# Unable to find 1222e3e69d8cf5b5e8c63f0393e98517
# Unable to find 59b22364e9582881ad9348ef54ec6e6a
# Unable to find 27b1cf8e0819ce0f9ae1a82c719556ef
# Unable to find 8987eba3f60c4a28aa8334ce532b3f6c
# Unable to find 0950db74808d08e98c66104359d356ab
# Unable to find 6de8b5b96bccb0d67891745bd927c1a5
# Unable to find 70a2acf5766712986dfd2205f1deec03
# Unable to find bb46d568c756b482be7edf3afdaad9c6
# Unable to find a744ec4c6c44df29f20aa3adfd6bda34
# Unable to find e1ec4e9fd174f17ca09dd970aeb25ff2
# Unable to find 44b390c51d96bd87be9ce9da991d0ddc
# Unable to find a64bee8ecb928434eeb2511ee96fad2d
# Unable to find 37070c25399637d91f9ed9eaab0b59ab
# Unable to find 1e2384c03017590494af709745f8dfd4
# Unable to find 623423cee4d6429ccb4f38a1107a5857
# Unable to find f29107159ee017ee25840cd35e33844e
# Unable to find 5a69f2682944669eba13eb324cdf490f
# Unable to find 6bac41f59051d32c6730687d8c47e9d8
# Unable to find 33665f7c9346b7e884eefa212efb801e
# Unable to find 43f1cb3996ff6d4622154bd01b26ed6a
# Unable to find 498493909f62e9af57d62604a009c0b0
# Unable to find b45926bbeb77de6ddcd8265ff39a887b
# Unable to find 8da7e1922cda57984cf38dd3c4b4d2bc
# Unable to find b546f2d1240a8556962c5d2adaa37d6f
# Unable to find ee3d4293b25a0c6dfed811d772685438
# Unable to find 1f82bfa25e1f9cccf793e7562011d435
# Unable to find 0b36ade568a183f5d20d30baf297325f
# Unable to find 4b90682e8e171cc8623523048874fff5
# Unable to find 190c87d79a127a491743b8d40a82cc4d
# Unable to find 9bc50935c1ebce2f825813732a03dab6
# Unable to find fa1ae7b0b49d85be3c446b39b2a4462f
# Unable to find fc4cd440da8c12e0ced22832d1d29cc0
# Unable to find c7d347791e3e9e838286cee9c06b0be9
# Unable to find 10e6f4ff20856cc58db83a1e5955b18d
# Unable to find b3c615945cfed4ac23a17d475bef4b88
# Unable to find c98c6992ba44b353b7e6add49c9b7c91
# Unable to find e769a4a7d543eaf40f151fe523f2e2bf
# Unable to find 3b8ddefdeec330acef07deb33c11f16c
# Unable to find b9cd3541618e307af55eb63eb32b54a0
# Unable to find 60c07ab18f31f2b47f999414a2efb768
# Unable to find eebb1672f5fb3a8ebeb8c3efa0e9a8be
# Unable to find a59d4a101e0cfe7ff08abfd1eb452a2f
# Unable to find 95d40e46cccfe85f43519ae8e809369d
# Unable to find df16065efa9e0fb2d36471d42d256f99
# Unable to find d4556acc09303b2b4da8cc38a7c412e9
# Unable to find a2dd7d0d880f12d6fa73eb1b5e6d612a
# Unable to find 618433ae0610a73a7e305a044b41fc87
# Unable to find c73b65be8f9949c103f89c66b5f78555
# Unable to find e1dedd342815ac3900ca23e8751f10a4
# Unable to find 77411e68d437d568a3c88fca2b7afac5
# Unable to find 2a70d91a76ebd032f126a77bc3c83c6b
# Unable to find 8a5a31db2494a44d703c4fab6ad09ded
# Unable to find faae8305d2b9ea77608e6e0a5a93887c
# Unable to find 08ce43758b54b873d59904bc5f11a93e
# Unable to find 59603efe38ce533bcee9a2f6858dc76f
# Unable to find ee412dc5c05a547684f460d03eba698f
# Unable to find 996b0bdbbe8c269d44675dbafc4ea763
# Unable to find 4eadc5cd108c6690a6c4b064bf85197d
# Unable to find c2a5bb7f64343f3bc920fd3a3847fe05
# Unable to find 3221440bf0b6398c5514a2ba28650597
# Unable to find 04528b4bacb04d3a1fb5aff8d3baa32e
# Unable to find 087ac1a049a9050525e4c7179700b02c
# Unable to find 7b2dea4aab87cf0509cb5a244415c182
# Unable to find 0d56580f132cc6510f6cf4dd89ec246e
# Unable to find 9b06f1ac27b2cb7fc8a3ae423d707bf6
# Unable to find 7ce555945181e088179898334c54f175
# Unable to find c7fb68242eebb0c7414863cd9f631f08
# Unable to find bb8c670ae2a6c23d8fdcce8cf0cdc9f2
# Unable to find 9b956be86b0528252f334249ce02cd6f
# Unable to find e35c07bb6be131fd736d56a946ae96e5
# Unable to find f735902688eeb51d7776a0356b521e82
# Unable to find 15d305a9359dc6b237962e432bf8d8a5
# Unable to find 90fcbddb0b5f1e5b19b70d4f08a6de89
# Unable to find bc98d77c98007a2a0a6f1a87c6c26ec9
# Unable to find ab521a7b7284eb22a4cc7171d281ceaa
# Unable to find 0c48928f7c37dc4e8655d17571ef230f
# Unable to find f0cc9693f09b754c639f2247677439cc
# Unable to find 6fa0147489fa12206e52e39559ea4eb2
# Unable to find 4546aa80a4dfc028eba79231ae923a1a
# Unable to find 4d2dcff1f654596199b43001505eed43
# Unable to find 605ed840eff406f1144f9155a7bbb8b7
# Unable to find 2a65a02e9bdb236f726185b06a8be2c3
# Unable to find 7608372ea4319e47aca9e40cab8fb82d
# Unable to find 4ff2d64bebbca8f945d4e454c07e1459
# Unable to find 41963a3299a192dfaeb1bbd6001b8a3e
# Unable to find 2d8118c924665b37be85ff65843a63b1
# Unable to find d9a08760a1fb633c25f1e842ebc34065
# Unable to find 9fce639669cc3e0a38f827df5c5563e6
# Unable to find 4ae1ea09c1aac49974eef578b594a2d7
# Unable to find 40ddce88bb8dc3104c02f6f3d6c0e3bc
# Unable to find d1b85aa6aefe4fc1e340f3febb0b9712
# Unable to find 6524015bde1de724e975ca06e15e4559
# Unable to find 4d5009c12b569ae6f6e8318b214c3f6b
# Unable to find 9a5cfe3e651680f1010417554c352e5b
# Unable to find 9178597fc4d88fedf497accbefb4e0c2
# Unable to find 1e56b8124128a4c72887443f91017279
# Unable to find df8025e1f6f6999740442e15e16004db
# Unable to find 9bc00e52a7af5a5d36be54340a352772
# Unable to find e8c27323a057504496c9c44bfe2ae177
# Unable to find e083772373e5fc23456ba13150880b86
# Unable to find 3c4099ffef968c7e65fe0c1bd474fe79
# Unable to find 31ee6e640df306a9520ac39e04ba7394
# Unable to find 4a411d860d19e5a71320a06d188e5fae
# Unable to find d9ea1c552cbf1f73cd123644a059a020
# Unable to find d3f419e604603b344536961e44380de2
# Unable to find a6787d60098baa2f41141c0d53e01e1c
# Unable to find 27d2a35d0e500cb7bd6af04049498a01
# Unable to find 1e592a959761c66873065cbfa44c7141
# Unable to find d51eedac57c9837d388864cb35b8af55
# Unable to find 845f48c45db6f2e57bb4563b66016ad0
# Unable to find 5b947ccd5e1671507dd40abc81a3a61e
# Unable to find dc410b4341e40b341d761a57045f8935
# Unable to find beb4a87a1279c6911a0a5476f3760134
# Unable to find cee1716266454aa94e84702a6506020a
# Unable to find 95dc28d09491d2f90e5540cc8649bb20
# Unable to find 97d574d770989db27907b10a7dffd1c6
# Unable to find 2de11259d425bcf4bbd07e5dc1148140
# Unable to find 59e0f5968672644a0876ae304390801f
# Unable to find 3ca5b2fab2e2e7001a4b45b95f9d705e
# Unable to find 7562bd1e8810b346c40127edbd3e400c
# Unable to find c23ff3785e8a9b84f923d5df9e7db25d
# Unable to find 08c8307565cf34d0a15738dcc98a1aad
# Unable to find f17fa461f3cc920672b930556fbd2156
# Unable to find f8dd3d3fd2d3faf0137bdf18be753207
# Unable to find d7160b846a2f2a768df534cba6e913e4
# Unable to find a628c353db8ae530a729a814b974f90f
# Unable to find 7e8f88267286bc33d7bcbe48ca1fcb5d
# Unable to find a4d244bef56624d1f2b624585b3a2887
# Unable to find d60372da2ca617dcdadcc908bdff2bc6
# Unable to find 3cd9ff6f326c0645ab5178a6a35d1402
# Unable to find d5fbedba3da9f02d41d72d83b1cf4f14
# Unable to find 4302b3cffa905bffb54437d830e789fa
# Unable to find 185a4323152897bdbfe621f6db467ea6
# Unable to find 30b6f51be3d409e281b534bb292b3bd0
# Unable to find d4ecd203ca465e835f5e6c48238f3dc2
# Unable to find b5adef44c28d504ee0753492d086a248
# Unable to find d9f29534e8b8d8ec9fd9d594ca5facde
# Unable to find 294d46ecf3f1cd22b18be6b0290c4819
# Unable to find 2814853e0e0c7a2ba980dc69eacab182
# Unable to find 03a11532f44e9d0a1a198e37ae8dedcd
# Unable to find b122ee2fa3a43f43d02069ed4ce5df27
# Unable to find d5ef349d096b6a84e651362da570d200
# Unable to find a4ddac1ad00557a58ae42d6c5164129c
# Unable to find 5711bfde6b1e1607cf07073c8ec076e2
# Unable to find 839bae71df01a0c2dfad6335bb724591
# Unable to find 023339f689dad564ac4ebf5d0b13cbff
# Unable to find f4a4e94e70262cde4044d8d6b5fe9021
# Unable to find 56aced50c5671e3124bd7de72148b771
# Unable to find f48ab5b40cc1e9a5ca98205e846d5f9f
# Unable to find 158a1b80cf98c78da8312e73cae08047
# Unable to find c223340f2cda7060eb3add4ef1e99095
# Unable to find cc2bc28ccabbf200b374ffe51ba13f41
# Unable to find c0f66bbe93cdc0f7050a2c747c11a606
# Unable to find 613a55e69a8be2e8410135f806cbc04c
# Unable to find f26cbeac92af39ac5f54e7a4ee7ed213
# Unable to find 4158f9cd913f88e8956457d11d0ce64d
# Unable to find d1c63e73cd04db3eb0154121f1488194
# Unable to find 4cdbf6893df3ced1ca75d6613ee20106
# Unable to find f0807d691e47c8a1c453c03b6e492b4a
# Unable to find 60c8d754363278bbf9021336430c52e9
# Unable to find b108c32341d1d3402d33f40722815386
# Unable to find 4dbb080642735267343968c6ab5751f3
# Unable to find bc832096099192422d6677db25240182
# Unable to find 69fbda9adb5157062241d2285026feec
# Unable to find 9f29559dad160cd59505405d2002bcee
# Unable to find 5d6829b17f9166d4a2a74930c4cef17d
# Unable to find 0969758250d4b33df9da2a569bd6957f
# Unable to find b383d83f113ffcdc7befa23296c4a1d8
# Unable to find 97b7dda0f41968b4a187927b2f338250
# Unable to find 4f8a8629ccd1be620ce00fac1a93bf4e
# Unable to find 6e31e7b26b008fe9cba3d3dfc189043c
# Unable to find a1e4b32c8131e24cfcecb965601953a8
# Unable to find d8acda19ef8e4cd297bb68bc6113b8fe
# Unable to find e8d9b655f2191b2af13fb8e675a9a47d
# Unable to find 1d7f99d7475bb7ae637960f9dd8a5635
# Unable to find c21f1d201f41600c2f4bd168cc30fce0
# Unable to find a1210e702ec6de976051f9008986c651
# Unable to find 754b4716cdc4c1ecfda4ba51ddae4e96
# Unable to find a6ae06a9c5e5794cb48486ec573953d3
# Unable to find 2f6276aa3c10fe85bab89a35b5a56985
# Unable to find b1d9ed298383ed1f66e49b3ec5c61e20
# Unable to find a291e51de3496ad88af5ab37c37cba24
# Unable to find 12706c7487d038a3a1a0c4fdb9b99747
# Unable to find 23136bcff2e7b56d46f0800cd2f31aa0
# Unable to find 1cf530ff35d14d2ec550e9b906a86200
# Unable to find 4e046f84676b7b06f9dd1b3ca17a1b85
# Unable to find 7f1d2573e543026d1728b2cdb71e2105
# Unable to find 60a2e9e2c4d5a96e1e8ef0a08eb65567
# Unable to find 2965746fe7d94889d742943dd97236af
# Unable to find fca3ec2c04c89e6f67e70abba264812e
# Unable to find a03429c921ea7d1a64826258187538f6
# Unable to find e6f11a4d50c5014c1ed1411ebc0fae58
# Unable to find 902c4c03b497f59e5b32323fa1b4f136
# Unable to find e496b1cd0ca221857a900d92429e5da0
# Unable to find 9b4e8481f1ac750d9af8391a9e726bc7
# Unable to find 2a75ec16e83c135c835dbadef48e05fa
# Unable to find 3e4b6a6494aeb0419d598911a351d205
# Unable to find 07cef61f688bbe64b02170191275b393
# Unable to find face672009915e31bf568203ce0fe31e
# Unable to find e29be705467c52ffc5941aed6b5a406a
# Unable to find b237afa07d6d792b9af6677e57fee811
# Unable to find c4700bfd375a5b31e85f2851b1446970
# Unable to find ac6e141c11eec7f4c208fb1be83fbb38
# Unable to find 91073f62281850475f0366c8fe4ca86b
# Unable to find d1f33f3acb20b61d9e945f1a5d0cd38d
# Unable to find e69e4f765b87df6a3ce43c6461b6bd9b
# Unable to find 55b9084194ac9e77c85ed20c6a641483
# Unable to find ab9eada92e8e89dabaf4c1345d4f9c93
# Unable to find 7a9f34946e3ce06bedb3757a2e4b08f2
# Unable to find 7d2494233f0d9b04d47e6a84502a5310
# Unable to find 8b6dfb3cfcc4711a41de28ff4f5fd300
# Unable to find 30650b930fb4166d245279139ac5c4af
# Unable to find 9736c9e307040a26253b798f1b7aa441
# Unable to find 29619aa46e4701e9ff303834ada4a85e
# Unable to find eb104a248f69c8a12c0526cf5c06d38d
# Unable to find 8a2d9954deab336fa560f81f3199e88e
# Unable to find afcb29186003d50c8a62a7799641dacc
# Unable to find 56309ce7da06adfc847b0e5d3f94f1e3
# Unable to find 2bfba4c8be677dd06e8b8a9a350ae7a2
# Unable to find ea45861904f761415af6ae6c2c9a9a98
# Unable to find 363ab4f319bb4a26fe5c0d067714a672
# Unable to find b6489c3bb49b107f0ec11e8b8585e05c
# Unable to find b153c436b8ff1aeefde8874f17f85e3d
# Unable to find b2a5735603c36caa8574d2d9b0d35573
# Unable to find 7efa9dcf86dc8179eea6f79f21e9099e
# Unable to find d417a13741a6f0aad2d767062734d070
# updating B01_13A igvf_b01/next1 measurement set to B01_13A_illumina
# updating B01_13A igvf_b01/next2 measurement set to B01_13A_illumina
# updating B01_13B igvf_b01/next1 measurement set to B01_13B_illumina
# updating B01_13B igvf_b01/next2 measurement set to B01_13B_illumina
# updating B01_13C igvf_b01/next1 measurement set to B01_13C_illumina
# updating B01_13C igvf_b01/next2 measurement set to B01_13C_illumina
# updating B01_13D igvf_b01/next1 measurement set to B01_13D_illumina
# updating B01_13D igvf_b01/next2 measurement set to B01_13D_illumina
# updating B01_13E igvf_b01/next1 measurement set to B01_13E_illumina
# updating B01_13E igvf_b01/next2 measurement set to B01_13E_illumina
# updating B01_13F igvf_b01/next1 measurement set to B01_13F_illumina
# updating B01_13F igvf_b01/next2 measurement set to B01_13F_illumina
# updating B01_13G igvf_b01/next1 measurement set to B01_13G_illumina
# updating B01_13G igvf_b01/next2 measurement set to B01_13G_illumina
# updating B01_13H igvf_b01/next1 measurement set to B01_13H_illumina
# updating B01_13H igvf_b01/next2 measurement set to B01_13H_illumina
# total plates 10
# total sequencing runs 16
# total subpools 217
# total subpool in run 158
# total subpool in run files 1105
