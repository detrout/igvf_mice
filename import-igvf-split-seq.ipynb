# %% [markdown]
# # Introduction

# %% [markdown]
# UCI has a complex google doc they've been using to track their samples so far.
#
# https://docs.google.com/spreadsheets/d/13M6-Ry6oXgkx94BHZOGioYPI6F_hWDqjGgcaNu2JNYs/edit#gid=1838362486
#
# Also there's a metadata spreadsheet for IGVF at
# https://docs.google.com/spreadsheets/d/1BLMledzmqOqXnJHzpijgw91IOs-9tSlVeZDG_MtXddk/edit#gid=1284120531

# %%
import bz2
from collections import Counter, namedtuple
import datetime
from io import StringIO
import numpy
import os
import pandas
from pathlib import Path
import re
from subprocess import run, PIPE
import sys
import zoneinfo

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'mousedemo.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

import django
from django.contrib.auth import get_user_model
from django.db import DEFAULT_DB_ALIAS

MOUSEDEMO = str(Path("mousedemo").absolute())
if MOUSEDEMO not in sys.path:
    sys.path.append(MOUSEDEMO)

# %% [markdown]
# # Pre-initialization setup

# %% [markdown]
# Backup the old ones and make a new database file before we initialize the database.

# %%
# Create a new database
result = run(["python3", "manage.py", "check"], capture_output=True)

if len(result.stderr) > 0:
    print(result.stderr.decode("utf-8"))
    
result.check_returncode()

# %%
initial = Path("igvf_mice/migrations/0001_initial.py")
if initial.exists():
    initial.unlink()
    
result = run(["python3", "manage.py", "makemigrations", "igvf_mice"], capture_output=True)

if len(result.stderr) > 0:
    print(result.stderr.decode("utf-8"))
    
result.check_returncode()

# %%
# Backup several old sqlite database files

db_name = Path("db.sqlite3")

backup_names = []
for i in range(0, 4):
    backup_names.append(Path("db{}.sqlite3".format(i+1)))

if backup_names[-1].exists():
    backup_names[-1].unlink()

if db_name.exists():    
    for i in reversed(range(0, 3)):
        if backup_names[i].exists():
            print("renaming {} to {}".format(backup_names[i], backup_names[i+1]))
            backup_names[i].rename(backup_names[i+1])

    db_name.rename(backup_names[0])
    print("renaming {} to {}".format(db_name, backup_names[0]))
# Out:
# renaming db3.sqlite3 to db4.sqlite3
# renaming db2.sqlite3 to db3.sqlite3
# renaming db1.sqlite3 to db2.sqlite3
# renaming db.sqlite3 to db1.sqlite3

# %%
# Create a new database
result = run(["python3", "manage.py", "migrate"], capture_output=True)

if len(result.stderr) > 0:
    print(result.stderr.decode("utf-8"))
    
result.check_returncode()
    
assert Path("db.sqlite3").exists()

# %% [markdown]
# # Setup users

# %% [markdown]
# Now that we have a fresh clean database, lets create user accounts

# %%
django.setup()

from django.contrib.auth.models import ContentType
from mousedemo import settings
from igvf_mice import models

# %%
# Create accounts.
with open("pw", "rt") as instream:
    pw = instream.read().strip()

user_model = get_user_model()
user_model._default_manager.db_manager(DEFAULT_DB_ALIAS).create_superuser(
    username="diane",
    password=pw,   
)

# load igvf_mice permissions    
permissions = set()
for ct in ContentType.objects.filter(app_label="igvf_mice"):
    permissions.update(ct.permission_set.all())

with open("guest.pw", "rt") as instream:
    pw = instream.read().strip()

user_model = get_user_model()
guest = user_model._default_manager.db_manager(DEFAULT_DB_ALIAS).create_user(
    username="guest",
    password=pw,
    is_staff=True,
)
guest.user_permissions.set(permissions)
print(guest)
# Out:
# guest

# %%
guest = user_model._default_manager.db_manager(DEFAULT_DB_ALIAS).get(username="guest")
diane = guest = user_model._default_manager.db_manager(DEFAULT_DB_ALIAS).get(username="diane")

# %%
assert guest.is_staff

# %%
guest.user_permissions.all()
# Out:
# <QuerySet []>

# %%
def validate_alias(alias):
    alias_pattern = re.compile("^(?:j-michael-cherry|ali-mortazavi|barbara-wold|lior-pachter|grant-macgregor|kim-green|mark-craven|qiongshi-lu|audrey-gasch|robert-steiner|jesse-engreitz|thomas-quertermous|anshul-kundaje|michael-bassik|will-greenleaf|marlene-rabinovitch|lars-steinmetz|jay-shendure|nadav-ahituv|martin-kircher|danwei-huangfu|michael-beer|anna-katerina-hadjantonakis|christina-leslie|alexander-rudensky|laura-donlin|hannah-carter|bing-ren|kyle-gaulton|maike-sander|charles-gersbach|gregory-crawford|tim-reddy|ansuman-satpathy|andrew-allen|gary-hon|nikhil-munshi|w-lee-kraus|lea-starita|doug-fowler|luca-pinello|guillaume-lettre|benhur-lee|daniel-bauer|richard-sherwood|benjamin-kleinstiver|marc-vidal|david-hill|frederick-roth|mikko-taipale|anne-carpenter|hyejung-won|karen-mohlke|michael-love|jason-buenrostro|bradley-bernstein|hilary-finucane|chongyuan-luo|noah-zaitlen|kathrin-plath|roy-wollman|jason-ernst|zhiping-weng|manuel-garber|xihong-lin|alan-boyle|ryan-mills|jie-liu|maureen-sartor|joshua-welch|stephen-montgomery|alexis-battle|livnat-jerby|jonathan-pritchard|predrag-radivojac|sean-mooney|harinder-singh|nidhi-sahni|jishnu-das|hao-wu|sreeram-kannan|hongjun-song|alkes-price|soumya-raychaudhuri|shamil-sunyaev|len-pennacchio|axel-visel|jill-moore|ting-wang|feng-yue|igvf|igvf-dacc):[a-zA-Z\\d_$.+!*,()'-]+(?:\\s[a-zA-Z\\d_$.+!*,()'-]+)*$")
    
    if alias_pattern.match(alias) is None:
        raise ValueError("Invalid alias")
    else:
        return True


try:
    validate_alias("ali-mortazavi:194_B6CASTF1/J_10F_20")
    assert False, "This should fail"
except ValueError:
    pass

# %% [markdown]
# # Load data

# %%
#spreadsheet_name = "IGVF_Split-seq_20230118.xlsx"
lizs_sheet_name = "https://woldlab.caltech.edu/nextcloud/index.php/s/eEtjBfDqQFnLpSS/download"

book = pandas.ExcelFile(lizs_sheet_name)
for name in book.sheet_names:
    print(name)
# Out:
# schedule - all
# Line information
# mice
# Planning
# DissectionSorting
# Counting
# Sample Tissue IDs
# Samples - 8 founders
# Samples - F1s
# Samples - F1s_6mo
# Samples - CClines
# Samples - Bridge
# Founder Samples into experiment
# F1 Samples into experiment
# CC Samples into experiment
# Bridge samples into experiment
# PBMCs
# Founder Nuclei isolation Sample
# F1 Nuclei isolation SampleID
# Plate setups
# Experiment
# nreads_per_sublibrary_novaseq
# nreads_per_sublibrary_nextseq
# ONT Sequencing
# DCC
# Tissue_body_weight_metadata
# Failed_samples
# Sheet40
# tissue weights
# practice mice
# CellDrop_Demo
# Gastroc_numbers
# Gastroc_all_reps
# Recount for gene capture
# Gastroc_testing
# Cerebellum testing
# IGVF002 Pilot Samples
# IGVF002 Pulverized Samples
# IGVF002 Plate Setup
# IGVF002 Metadata

# %%
def load_submitted_sheets():
    submitted_book_names = {
        # Sheets on sandbox
        "igvftst": {
            "IGVF_003": "https://woldlab.caltech.edu/nextcloud/index.php/s/nBnE6j2RBMkpM9i/download",
            "IGVF_b01": "https://woldlab.caltech.edu/nextcloud/index.php/s/5cJteSWgitN5BDM/download",
        },
        # Sheets on data. (production)
        "igvf": {
            "IGVF_b01": "https://woldlab.caltech.edu/nextcloud/index.php/s/HTbfN6btm3kqJXb/download",
            "IGVF_003": "https://woldlab.caltech.edu/nextcloud/index.php/s/wRFxdcknisFfM2t/download",
            "IGVF_004": "https://woldlab.caltech.edu/nextcloud/index.php/s/8ygLzeyjAQ9CxXn/download",
            "IGVF_005": "https://woldlab.caltech.edu/nextcloud/index.php/s/2Pba74eLFwmFfgS/download",
            # IGVF_006 failed.
            "IGVF_007": "https://woldlab.caltech.edu/nextcloud/index.php/s/7rQKGSTS7937kTW/download",
            "IGVF_008": "https://woldlab.caltech.edu/nextcloud/index.php/s/iECMTJF2iPMy3kT/download",
            "IGVF_008B": "https://woldlab.caltech.edu/nextcloud/index.php/s/YF46eNqSASJC8fr/download",
            "IGVF_009": "https://woldlab.caltech.edu/nextcloud/index.php/s/PtNn96zR9XbybFZ/download",
            "IGVF_010": "https://woldlab.caltech.edu/nextcloud/index.php/s/CocTP9pePJobyPs/download",
            "IGVF_011": "https://woldlab.caltech.edu/nextcloud/index.php/s/Sm72GtmdN4QsXJr/download",
            "IGVF_012": "https://woldlab.caltech.edu/nextcloud/index.php/s/MmatjmzQgofeM2Y/download",
            "IGVF_013": "https://woldlab.caltech.edu/nextcloud/index.php/s/EHret5a6Sjiro4q/download",
            "IGVF_014": "https://woldlab.caltech.edu/nextcloud/index.php/s/GRQCaSZ3WgeonzK/download",
        }
    }
    submitted_sheets = {}
    for accession_prefix in submitted_book_names:
        for book_name in submitted_book_names[accession_prefix]:
            print("reading {} {} {}".format(accession_prefix, book_name, submitted_book_names[accession_prefix][book_name]))
            book = pandas.ExcelFile(submitted_book_names[accession_prefix][book_name])

            for sheet_name in book.sheet_names:
                if sheet_name not in submitted_sheets.get(accession_prefix, {}):
                    submitted_sheets.setdefault(accession_prefix, {})[sheet_name] = book.parse(sheet_name)
                else:
                    previous_sheet = submitted_sheets[accession_prefix][sheet_name]
                    next_sheet = book.parse(sheet_name)
                    print("next_sheet {} {}".format(sheet_name, next_sheet.shape))
                    
                    already_seen = set(previous_sheet["accession"])
                    need_to_add = set(next_sheet["accession"]).difference(already_seen)
                    next_sheet = next_sheet[next_sheet["accession"].isin(need_to_add)]
                    print("next_sheet after duplicate filter {}".format(next_sheet.shape))
                    
                    submitted_sheets.setdefault(accession_prefix, {})[sheet_name] = pandas.concat([previous_sheet, next_sheet])
                print(accession_prefix, sheet_name, submitted_sheets[accession_prefix][sheet_name].shape)

    return submitted_sheets

submitted_sheets = load_submitted_sheets()
# Out:
# reading igvftst IGVF_003 https://woldlab.caltech.edu/nextcloud/index.php/s/nBnE6j2RBMkpM9i/download
# igvftst rodent_donor (64, 25)
# igvftst tissue (192, 9)
# igvftst measurement_set (17, 12)
# igvftst sequence_file (246, 14)
# reading igvftst IGVF_b01 https://woldlab.caltech.edu/nextcloud/index.php/s/5cJteSWgitN5BDM/download
# next_sheet rodent_donor (8, 25)
# next_sheet after duplicate filter (8, 25)
# igvftst rodent_donor (72, 25)
# next_sheet tissue (8, 9)
# next_sheet after duplicate filter (8, 9)
# igvftst tissue (200, 9)
# igvftst multiplexed_sample (8, 8)
# next_sheet measurement_set (8, 13)
# next_sheet after duplicate filter (8, 13)
# igvftst measurement_set (25, 13)
# next_sheet sequence_file (32, 14)
# next_sheet after duplicate filter (32, 14)
# igvftst sequence_file (278, 14)
# igvftst configuration_file (16, 8)
# reading igvf IGVF_b01 https://woldlab.caltech.edu/nextcloud/index.php/s/HTbfN6btm3kqJXb/download
# igvf rodent_donor (8, 25)
# igvf tissue (8, 9)
# igvf multiplexed_sample (8, 7)
# igvf measurement_set (8, 12)
# igvf sequence_file (32, 20)
# reading igvf IGVF_003 https://woldlab.caltech.edu/nextcloud/index.php/s/wRFxdcknisFfM2t/download
# next_sheet rodent_donor (65, 25)
# next_sheet after duplicate filter (65, 25)
# igvf rodent_donor (73, 25)
# next_sheet tissue (192, 9)
# next_sheet after duplicate filter (192, 9)
# igvf tissue (200, 9)
# next_sheet multiplexed_sample (16, 7)
# next_sheet after duplicate filter (16, 7)
# igvf multiplexed_sample (24, 7)
# next_sheet measurement_set (16, 13)
# next_sheet after duplicate filter (16, 13)
# igvf measurement_set (24, 13)
# next_sheet sequence_file (246, 20)
# next_sheet after duplicate filter (246, 20)
# igvf sequence_file (278, 20)
# reading igvf IGVF_004 https://woldlab.caltech.edu/nextcloud/index.php/s/8ygLzeyjAQ9CxXn/download
# next_sheet rodent_donor (64, 25)
# next_sheet after duplicate filter (0, 25)
# igvf rodent_donor (73, 25)
# next_sheet tissue (128, 9)
# next_sheet after duplicate filter (64, 9)
# igvf tissue (264, 9)
# next_sheet multiplexed_sample (16, 7)
# next_sheet after duplicate filter (16, 7)
# igvf multiplexed_sample (40, 7)
# next_sheet measurement_set (16, 13)
# next_sheet after duplicate filter (16, 13)
# igvf measurement_set (40, 13)
# next_sheet sequence_file (246, 20)
# next_sheet after duplicate filter (246, 20)
# igvf sequence_file (524, 20)
# reading igvf IGVF_005 https://woldlab.caltech.edu/nextcloud/index.php/s/2Pba74eLFwmFfgS/download
# next_sheet rodent_donor (65, 25)
# next_sheet after duplicate filter (0, 25)
# igvf rodent_donor (73, 25)
# next_sheet tissue (192, 9)
# next_sheet after duplicate filter (128, 9)
# igvf tissue (392, 9)
# next_sheet multiplexed_sample (16, 7)
# next_sheet after duplicate filter (16, 7)
# igvf multiplexed_sample (56, 7)
# next_sheet measurement_set (16, 13)
# next_sheet after duplicate filter (16, 13)
# igvf measurement_set (56, 13)
# next_sheet sequence_file (242, 20)
# next_sheet after duplicate filter (242, 20)
# igvf sequence_file (766, 20)
# reading igvf IGVF_007 https://woldlab.caltech.edu/nextcloud/index.php/s/7rQKGSTS7937kTW/download
# next_sheet rodent_donor (65, 25)
# next_sheet after duplicate filter (0, 25)
# igvf rodent_donor (73, 25)
# next_sheet tissue (256, 9)
# next_sheet after duplicate filter (128, 9)
# igvf tissue (520, 9)
# next_sheet multiplexed_sample (16, 7)
# next_sheet after duplicate filter (16, 7)
# igvf multiplexed_sample (72, 7)
# next_sheet measurement_set (16, 13)
# next_sheet after duplicate filter (16, 13)
# igvf measurement_set (72, 13)
# next_sheet sequence_file (242, 20)
# next_sheet after duplicate filter (242, 20)
# igvf sequence_file (1008, 20)
# reading igvf IGVF_008 https://woldlab.caltech.edu/nextcloud/index.php/s/iECMTJF2iPMy3kT/download
# next_sheet rodent_donor (65, 25)
# next_sheet after duplicate filter (1, 25)
# igvf rodent_donor (74, 25)
# next_sheet tissue (192, 9)
# next_sheet after duplicate filter (64, 9)
# igvf tissue (584, 9)
# next_sheet multiplexed_sample (9, 7)
# next_sheet after duplicate filter (9, 7)
# igvf multiplexed_sample (81, 7)
# next_sheet measurement_set (9, 13)
# next_sheet after duplicate filter (9, 13)
# igvf measurement_set (81, 13)
# next_sheet sequence_file (76, 20)
# next_sheet after duplicate filter (76, 20)
# igvf sequence_file (1084, 20)
# reading igvf IGVF_008B https://woldlab.caltech.edu/nextcloud/index.php/s/YF46eNqSASJC8fr/download
# next_sheet rodent_donor (65, 25)
# next_sheet after duplicate filter (0, 25)
# igvf rodent_donor (74, 25)
# next_sheet tissue (192, 9)
# next_sheet after duplicate filter (0, 9)
# igvf tissue (584, 9)
# next_sheet multiplexed_sample (11, 7)
# next_sheet after duplicate filter (11, 7)
# igvf multiplexed_sample (92, 7)
# next_sheet measurement_set (11, 13)
# next_sheet after duplicate filter (11, 13)
# igvf measurement_set (92, 13)
# next_sheet sequence_file (86, 20)
# next_sheet after duplicate filter (86, 20)
# igvf sequence_file (1170, 20)
# reading igvf IGVF_009 https://woldlab.caltech.edu/nextcloud/index.php/s/PtNn96zR9XbybFZ/download
# next_sheet rodent_donor (65, 25)
# next_sheet after duplicate filter (0, 25)
# igvf rodent_donor (74, 25)
# next_sheet tissue (128, 9)
# next_sheet after duplicate filter (64, 9)
# igvf tissue (648, 9)
# next_sheet multiplexed_sample (16, 7)
# next_sheet after duplicate filter (16, 7)
# igvf multiplexed_sample (108, 7)
# next_sheet measurement_set (16, 13)
# next_sheet after duplicate filter (16, 13)
# igvf measurement_set (108, 13)
# next_sheet sequence_file (246, 20)
# next_sheet after duplicate filter (246, 20)
# igvf sequence_file (1416, 20)
# reading igvf IGVF_010 https://woldlab.caltech.edu/nextcloud/index.php/s/CocTP9pePJobyPs/download
# next_sheet rodent_donor (70, 25)
# next_sheet after duplicate filter (5, 25)
# igvf rodent_donor (79, 25)
# next_sheet tissue (128, 9)
# next_sheet after duplicate filter (64, 9)
# igvf tissue (712, 9)
# next_sheet multiplexed_sample (16, 7)
# next_sheet after duplicate filter (16, 7)
# igvf multiplexed_sample (124, 7)
# next_sheet measurement_set (16, 13)
# next_sheet after duplicate filter (16, 13)
# igvf measurement_set (124, 13)
# next_sheet sequence_file (246, 20)
# next_sheet after duplicate filter (246, 20)
# igvf sequence_file (1662, 20)
# reading igvf IGVF_011 https://woldlab.caltech.edu/nextcloud/index.php/s/Sm72GtmdN4QsXJr/download
# next_sheet rodent_donor (70, 25)
# next_sheet after duplicate filter (0, 25)
# igvf rodent_donor (79, 25)
# next_sheet tissue (192, 9)
# next_sheet after duplicate filter (0, 9)
# igvf tissue (712, 9)
# next_sheet multiplexed_sample (16, 7)
# next_sheet after duplicate filter (16, 7)
# igvf multiplexed_sample (140, 7)
# next_sheet measurement_set (16, 13)
# next_sheet after duplicate filter (16, 13)
# igvf measurement_set (140, 13)
# next_sheet sequence_file (246, 20)
# next_sheet after duplicate filter (246, 20)
# igvf sequence_file (1908, 20)
# reading igvf IGVF_012 https://woldlab.caltech.edu/nextcloud/index.php/s/MmatjmzQgofeM2Y/download
# next_sheet rodent_donor (11, 25)
# next_sheet after duplicate filter (2, 25)
# igvf rodent_donor (81, 25)
# next_sheet tissue (14, 9)
# next_sheet after duplicate filter (6, 9)
# igvf tissue (718, 9)
# next_sheet multiplexed_sample (8, 7)
# next_sheet after duplicate filter (8, 7)
# igvf multiplexed_sample (148, 7)
# next_sheet measurement_set (8, 14)
# next_sheet after duplicate filter (8, 14)
# igvf measurement_set (148, 14)
# next_sheet sequence_file (32, 20)
# next_sheet after duplicate filter (32, 20)
# igvf sequence_file (1940, 20)
# reading igvf IGVF_013 https://woldlab.caltech.edu/nextcloud/index.php/s/EHret5a6Sjiro4q/download
# next_sheet rodent_donor (96, 25)
# next_sheet after duplicate filter (32, 25)
# igvf rodent_donor (113, 25)
# next_sheet tissue (96, 9)
# next_sheet after duplicate filter (96, 9)
# igvf tissue (814, 9)
# next_sheet multiplexed_sample (15, 7)
# next_sheet after duplicate filter (15, 7)
# igvf multiplexed_sample (163, 7)
# next_sheet measurement_set (15, 14)
# next_sheet after duplicate filter (15, 14)
# igvf measurement_set (163, 15)
# next_sheet sequence_file (174, 20)
# next_sheet after duplicate filter (174, 20)
# igvf sequence_file (2114, 20)
# reading igvf IGVF_014 https://woldlab.caltech.edu/nextcloud/index.php/s/GRQCaSZ3WgeonzK/download
# next_sheet rodent_donor (8, 25)
# next_sheet after duplicate filter (8, 25)
# igvf rodent_donor (121, 25)
# next_sheet tissue (8, 9)
# next_sheet after duplicate filter (8, 9)
# igvf tissue (822, 9)
# next_sheet multiplexed_sample (8, 7)
# next_sheet after duplicate filter (8, 7)
# igvf multiplexed_sample (171, 7)
# next_sheet measurement_set (8, 14)
# next_sheet after duplicate filter (8, 14)
# igvf measurement_set (171, 15)
# next_sheet sequence_file (16, 20)
# next_sheet after duplicate filter (16, 20)
# igvf sequence_file (2130, 20)

# %% [markdown]
# Converters

# %%
def truncate(model):
    table_name = model._meta.db_table
    assert "\\" not in table_name
    with django.db.connection.cursor() as cursor:
        # I don't know why the sql params didn't work. this is a sql vulnerability waiting to happen
        cursor.execute("delete from \"{}\"".format(table_name))
        cursor.execute("DELETE FROM SQLITE_SEQUENCE WHERE name=\"{}\"".format(table_name))
        cursor.fetchone()

# %%
def int_or_none(x):
    if x in ("N/A", '#DIV/0!', '-'):
        return None
    elif pandas.isnull(x):
        return None
    else:
        return int(x)
    
def int_or_0(x):
    if pandas.isnull(x):
        return 0
    else:
        return int(x)

def float_or_none(x):
    if pandas.isnull(x):
        return None
    else:
        return float(x)
    
def str_or_empty(x):
    if pandas.isnull(x):
        return ""
    else:
        return x

def str_or_none(x):
    if pandas.isnull(x):
        return None
    else:
        return x
    
def date_or_none(x):
    if pandas.isnull(x):
        return None
    elif isinstance(x, datetime.datetime):
        return x.date()
    elif x in ("-"):
        return None
    else:
        return x

def datetime_or_none(x):
    if pandas.isnull(x):
        return None
    else:
        return x

# %%
def normalize_strain(strain):
    strain = strain.replace("F1/J", "F1J")
    return strain
    
assert normalize_strain("B6WSBF1/J") == "B6WSBF1J"
assert normalize_strain("195_B6CASTF1/J_10M_20") == "195_B6CASTF1J_10M_20"

def validate_mouse_age_sex(value):
    sex = value[-1]
    age = value[0:-1]
    
    assert sex in ("M", "F")
    assert isinstance(int(age), int)
    
validate_mouse_age_sex("10F")

mouse_name_tuple = namedtuple("mouse_name_tuple", ["mouse_id", "mouse_strain", "mouse_age_sex"])
def parse_mouse_name(mouse_name):    
    mouse_id_end = mouse_name.find("_")
    mouse_age_sex_start = mouse_name.rfind("_") + 1
    
    mouse_id = mouse_name[0:mouse_id_end]
    mouse_strain = normalize_strain(mouse_name[mouse_id_end+1:mouse_age_sex_start-1])
    mouse_age_sex = mouse_name[mouse_age_sex_start:]
    validate_mouse_age_sex(mouse_age_sex)
    return mouse_name_tuple(mouse_id, mouse_strain, mouse_age_sex)

assert parse_mouse_name("477_CC030_10M") == ("477", "CC030", "10M")
assert parse_mouse_name("239_TREM2R47HNSS_HO_10M") == ("239", "TREM2R47HNSS_HO", "10M")
assert parse_mouse_name("238_B6WSBF1/J_10F") == ("238", "B6WSBF1J", "10F")

mouse_tissue_tuple = namedtuple("mouse_tissue_tuple", ["mouse_id", "mouse_strain", "mouse_age_sex", "tissue_id"])
def parse_mouse_tissue(mouse_tissue):
    fields = mouse_tissue.split("_")
    
    mouse_id = fields.pop(0)
    mouse_strain = fields.pop(0)
    if mouse_strain in ("TREM2R47HNSS",):
        mouse_strain = "_".join([mouse_strain, fields.pop(0)])
    mouse_strain = normalize_strain(mouse_strain)
    mouse_age_sex = fields.pop(0)
    validate_mouse_age_sex(mouse_age_sex)
    tissue_id = fields.pop(0)
    assert len(fields) == 0
    
    return mouse_tissue_tuple(mouse_id, mouse_strain, mouse_age_sex, tissue_id)
    
assert parse_mouse_tissue("096_WSBJ_10F_15") == ("096", "WSBJ", "10F", "15")
assert parse_mouse_tissue("239_TREM2R47HNSS_HO_10M_01") == ("239", "TREM2R47HNSS_HO", "10M", "01")

def normalize_plate_name(name):
    name = name.upper()

    return name

assert normalize_plate_name("igvf_003") == "IGVF_003"
assert normalize_plate_name("IGVF_008B") == "IGVF_008B"

# %%
normalize_strain("B6WSBF1/J")
# Out:
# 'B6WSBF1J'

# %% [markdown]
# # initialize general use tables

# %%
# Delete later: switch to just using an enum for the accessions.
#
#accession_namespaces = [
#    {"name": "ENCODE", "homepage": "https://www.encodeproject.org", "accession_prefix": "encode"},
#    {"name": "ENCODE test", "homepage": "https://test.encodedcc.org", "accession_prefix": "encodetst"},
#    {"name": "IGVF", "homepage": "https://data.igvf.org", "accession_prefix": "igvf"},
#    {"name": "IGVF test", "homepage": "https://sandbox.igvf.org", "accession_prefix": "igvftst"},
#]
#
#if models.AccessionNamespace.objects.count() > 0:
#    truncate(models.AccessionNamespace)
#
#for row in accession_namespaces:
#    record = models.AccessionNamespace(
#        name=row["name"],
#        homepage=row["homepage"],
#        accession_prefix=row["accession_prefix"],
#    )
#    record.save()
#
#igvf_namespace = models.AccessionNamespace.objects.get(name="IGVF")
#igvf_test_namespace = models.AccessionNamespace.objects.get(name="IGVF test")

# %%
def load_sources():
    source = [
        {
            "name": "jackson-labs",
            "display_name": "The Jackson Laboratory", 
            "homepage": "http://www.jax.org/index.html", 
            "igvf_id": "/sources/jackson-labs/",
        },
        {
            "name": "parse-biosciences",
            "display_name": "Parse Bioscience", 
            "homepage": "https://www.parsebiosciences.com/",
            "igvf_id": "/sources/parse-biosciences/",
        },
        {
            "name": "illumina",
            "display_name": "Illumina", 
            "homepage": "https://www.illumina.com", 
            "igvf_id": "/sources/illumina/",
        },
        {
            "name": "unc-csbio",
            "display_name": "UNC Systems Genetics",
            "homepage": "https://csbio.unc.edu",
            "igvf_id": "/sources/unc-csbio/",
        }
    ]

    if models.Source.objects.count() > 0:
        truncate(models.Source)

    for row in source:
        record = models.Source(
            name=row["name"],
            homepage=row["homepage"],
            igvf_id=row["igvf_id"])
        record.save()

load_sources()
jax_source = models.Source.objects.get(name="jackson-labs")
unc_csbio_source = models.Source.objects.get(name="unc-csbio")

# %%
# Should this include machine model?

def load_platforms():
    platforms = [
        {"display_name": "Nextseq 2000", "name": "nextseq2000", "family": "illumina", "igvf_id": "/platform-terms/EFO_0010963/"},
        {"display_name": "Novaseq 6000", "name": "novaseq6000", "family": "illumina", "igvf_id": "/platform-terms/EFO_0008637/"},
        {"display_name": "Oxford Nanopore MinION", "name": "minion", "family": "nanopore", "igvf_id": "/platform-terms/EFO_0008632/"},
        {"display_name": "Oxford Nanopore PromethION", "name": "promethion", "family": "nanopore", "igvf_id": "/platform-terms/EFO_0008634/"},
        {"display_name": "Pac Bio", "name": "pacbio", "family": "pacbio",},
    ]

    for row in platforms:
        record = models.Platform(
            name=row["name"],
            display_name=row["display_name"],
            family=row["family"],
            igvf_id=row.get("igvf_id"),
            #source=row.get("source"),
        )
        record.save()
        
load_platforms()

# %% [markdown]
# # Library kit type & version

# %%
def load_library_reagents():
    library_construction_reagent = [
        {"name": "wt-mega", "display_name": "Parse WT Mega", "version": "v2", "source": "parse-biosciences"},
        {"name": "wt", "display_name": "Parse WT", "version": "v2", "source": "parse-biosciences"},
    ]

    if models.LibraryConstructionReagent.objects.count() > 0:
        truncate(models.LibraryConstructionReagent)

    for row in library_construction_reagent:
        try:
            source = models.Source.objects.get(name=row["source"])

            record = models.LibraryConstructionReagent(
                name=row["name"],
                display_name=row["display_name"],
                version=row["version"],
                source=source,
            )
            record.save()        
        except models.Source.DoesNotExist:
            print(f"Couldn't find {row['source']}")

load_library_reagents()

# %% [markdown]
# # Load LibraryBarcodes

# %%
models.LibraryConstructionReagent.objects.get(name="wt-mega")
# Out:
# <LibraryConstructionReagent: Parse WT Mega v2>

# %%
def normalize_udi_to_code(value):
    prefix = "UDI_Plate_WT_"
    assert value.startswith(prefix)
    barcode_number = int(value[len(prefix):])
    return "UDI{:02}".format(barcode_number)

assert normalize_udi_to_code("UDI_Plate_WT_1") == "UDI01"
assert normalize_udi_to_code("UDI_Plate_WT_45") == "UDI45"

# %%
def load_barcodes():
    if models.LibraryBarcode.objects.count() > 0:
        truncate(models.LibraryBarcode)

    # Load WT Mega v2 first barcode
    bc1 = pandas.read_csv("bc_data_n192_v4.csv")

    mega_reagent = models.LibraryConstructionReagent.objects.get(name="wt-mega", version="v2")

    for i, row in bc1.iterrows():
        record = models.LibraryBarcode(
            reagent=mega_reagent,
            name=row["uid"],
            code=row["well"],
            i7_sequence=row["sequence"],
            barcode_type=row["type"], # TODO what do the codes mean again T,R?
            well_position=row["well"],
        )
        record.save()

    mega_subpool = [
        ("1", "CAGATC"),
        ("2", "ACTTGA"),
        ("3", "GATCAG"),
        ("4", "TAGCTT"),
        ("5", "ATGTCA"),
        ("6", "CTTGTA"),
        ("7", "AGTCAA"),
        ("8", "AGTTCC"),
        ("9", "GAGTGG"),
        ("10", "CCGTCC"),
        ("11", "GTAGAG"),
        ("12", "GTCCGC"),
        ("13", "GTGAAA"),
        ("14", "GTGGCC"),
        ("15", "GTTTCG"),
        ("16", "CGTACG"),
    ]
    subpool = pandas.DataFrame(mega_subpool, columns=["code", "i7_sequence"])

    for i, row in subpool.iterrows():
        record = models.LibraryBarcode(
            reagent=mega_reagent,
            name=row["code"],
            code=row["code"],
            i7_sequence=row["i7_sequence"],
        )
        record.save()

    regular_reagent = models.LibraryConstructionReagent.objects.get(name="wt", version="v2")    
    regular_subpool = [
        ("1", "CAGATC"),
        ("2", "ACTTGA"),
        ("3", "GATCAG"),
        ("4", "TAGCTT"),
        ("5", "ATGTCA"),
        ("6", "CTTGTA"),
        ("7", "AGTCAA"),
        ("8", "AGTTCC"),
    ]
    subpool = pandas.DataFrame(regular_subpool, columns=["code","i7_sequence"])
    for i, row in subpool.iterrows():
        record = models.LibraryBarcode(
            reagent=regular_reagent,
            name=row["code"],
            code=row["code"],
            i7_sequence=row["i7_sequence"],
        )
        record.save()


    udi_wt_reagent = models.LibraryConstructionReagent.objects.get(name="wt-mega", version="v2")
    udi_wt_barcodes = pandas.read_excel("https://support.parsebiosciences.com/hc/en-us/article_attachments/12988277964436")
    for i, row in udi_wt_barcodes.iterrows():
        record = models.LibraryBarcode(
            reagent=udi_wt_reagent,
            name=row["Index name"],
            code=normalize_udi_to_code(row["Index name"]),
            i7_sequence=row["i7_index"],
            i5_sequence=row["i5_index"],
            well_position=row["well_position"],
        )
        record.save()
        
load_barcodes()

# %% [markdown]
# # Initialize TissueOntology

# %%
def count_seen_tissues():
    seen_tissues = Counter()
    for sample_sheet_name in ["Samples - 8 founders", "Samples - Bridge"]:
        tissue_sheet = pandas.read_excel(
            lizs_sheet_name, 
            sample_sheet_name,
            usecols=["Tissue"]).dropna(axis=0, how='all')

        for i, row in tissue_sheet.iterrows():
            if not pandas.isnull(row["Tissue"]):
                seen_tissues[row["Tissue"]] += 1
        print(sample_sheet_name, tissue_sheet.shape, len(seen_tissues))
        
    return seen_tissues

seen_tissues = count_seen_tissues()
seen_tissues
# Out:
# Samples - 8 founders (1621, 1) 22
# Samples - Bridge (416, 1) 44
# Counter({'Hypothalamus/Pituitary': 97,
#          'Cerebellum': 81,
#          'Cortex/Hippocampus left': 85,
#          'Cortex/Hippocampus right': 85,
#          'Liver': 97,
#          'Heart': 97,
#          'Lung': 81,
#          'Adrenal': 97,
#          'Kidney': 81,
#          'Gonads -1 Ovary': 41,
#          'Gonads -2 Oviduct': 41,
#          'Perigonadal fat': 81,
#          'Brown fat': 81,
#          'Soleus': 81,
#          'Plantaris': 81,
#          'Gastrocnemius': 82,
#          'TA': 81,
#          'EDL': 81,
#          'Tail': 121,
#          'PBMC - WBC': 121,
#          'Gonads -1 Testis': 40,
#          'Gonads -2 Epididymis': 40,
#          'Left cortex': 24,
#          'Right cortex': 24,
#          'Left hippocampus': 24,
#          'Right hippocampus': 24,
#          'Testis left': 8,
#          'Testis right': 8,
#          'Epididymis left': 8,
#          'Epididymis right': 8,
#          'Kidney left': 16,
#          'Kidney right': 16,
#          'Gastrocnemius left': 16,
#          'Gastrocnemius right': 16,
#          'TA left': 4,
#          'TA right': 4,
#          'Ovary': 1,
#          'Oviduct': 1,
#          'Gonads -1 (Ovary)': 7,
#          'Gonads - 2 (Oviduct)': 7,
#          'Cortex left': 12,
#          'Cortex right': 12,
#          'Hippocampus left': 12,
#          'Hippocampus right': 12})

# %%
tissue_dissection_to_ontology_map = {
    'Hypothalamus/Pituitary': [("UBERON:0001898","hypothalamus"), ("UBERON:0000007","pituitary gland")],
    'Cerebellum': [("UBERON:0002037","cerebellum")],
    # Hippocampus might be:
    #   Hippocampal formation UBERON:0002421 https://www.ebi.ac.uk/ols/ontologies/uberon/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FUBERON_0002421
    #   Layer of hippocampus UBERON:0002305 https://www.ebi.ac.uk/ols/ontologies/uberon/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FUBERON_0002305
    'Cortex/Hippocampus left': [("NTR:0000646","left cerebral cortex"), ("NTR:0000750", "Hippocampal formation left")],
    'Cortex/Hippocampus right': [("NTR:0000647","right cerebral cortex"), ("NTR:0000751", "Hippocampal formation right")],
    'Liver': [("UBERON:0002107", "liver")],
    'Heart': [("UBERON:0000948","heart")],
    'Lung': [("UBERON:0002048","lung")],
    'Adrenal': [("UBERON:0002369","adrenal gland")],
    'Kidney': [("UBERON:0002113","kidney")],
    'Kidney left': [("UBERON:0002113","kidney")],
    'Kidney right': [("UBERON:0002113","kidney")],
    "Ovary": [("UBERON:0000992", "ovary")],    
    'Gonads -1 Ovary': [("UBERON:0000992", "ovary")],
    'Gonads -1 (Ovary)': [("UBERON:0000992", "ovary")],
    'Oviduct': [("UBERON:0000993","oviduct")],
    'Gonads -2 Oviduct': [("UBERON:0000993","oviduct")],
    'Gonads -2 (Oviduct)': [("UBERON:0000993","oviduct")],
    'Gonads - 2 (Oviduct)': [("UBERON:0000993","oviduct")],
    'Perigonadal fat': [("UBERON:0003428", "gonadal fat pad")], #"is closer" to dissection
    'Brown fat': [("UBERON:0001348","brown adipose tissue")], 
    'Soleus': [("UBERON:0001389","soleus muscle")],
    'Plantaris': [("UBERON:0011905","plantaris")],
    'Gastrocnemius': [("UBERON:0001388","gastrocnemius")],
    'Gastrocnemius left': [("UBERON:0001388","gastrocnemius")],
    'Gastrocnemius right': [("UBERON:0001388","gastrocnemius")],
    'TA': [("UBERON:0001385","tibialis anterior")],
    'TA left': [("UBERON:0001385","tibialis anterior")],
    'TA right': [("UBERON:0001385","tibialis anterior")],
    'EDL': [("UBERON:0001386","extensor digitorum longus")],
    'Tail': [("UBERON:0002415","tail")],
    'PBMC - WBC': [("CL:2000001", "peripheral blood mononuclear cell")],
    'Gonads -1 Testis': [("UBERON:0000473","testis")],
    'Gonads -2 Epididymis': [("UBERON:0001301","epididymis")],
    "Left cortex": [("NTR:0000646","left cerebral cortex"),],
    "Cortex left": [("NTR:0000646","left cerebral cortex"),],
    "Right cortex": [("NTR:0000647","right cerebral cortex"),],
    "Cortex right": [("NTR:0000647","right cerebral cortex"),],
    "Left hippocampus": [("NTR:0000750", "Hippocampal formation left")],
    "Hippocampus left": [("NTR:0000750", "Hippocampal formation left")],
    "Right hippocampus": [("NTR:0000751", "Hippocampal formation right")],
    "Hippocampus right": [("NTR:0000751", "Hippocampal formation right")],
    # does left & right matter?
    "Testis left": [("UBERON:0000473", "Testis")],
    "Testis right": [("UBERON:0000473", "Testis")],
    "Epididymis left": [("UBERON:0001301", "Epididymis")],
    "Epididymis right": [("UBERON:0001301", "Epididymis")],
    "Pancreas": [("UBERON:0001264", "Pancreas")],
    "Lungs": [("UBERON:0002048", "Lung")],
}

print(set(seen_tissues).difference(tissue_dissection_to_ontology_map.keys()))

assert len(set(seen_tissues).difference(tissue_dissection_to_ontology_map.keys())) == 0, "Add in more names to term ids"
# Out:
# set()

# %%
def load_ontology_terms():
    term_details = pandas.read_csv("obo.tsv.bz2", compression="bz2", sep="\t", index_col="term_id")

    if models.OntologyTerm.objects.count() > 0:
        truncate(models.OntologyTerm)

    for key in tissue_dissection_to_ontology_map:
        for term_curie, term_name in tissue_dissection_to_ontology_map[key]:
            if term_curie.startswith("NTR:"):
                description=None
            else:
                details = term_details.loc[term_curie]
                description = details.description

            record = models.OntologyTerm(
                curie=term_curie,
                name=term_name,
                description=description
            )
            record.save()

load_ontology_terms()

# %%
strain_urls = {
    "AJ": "https://www.jax.org/strain/000646",
    "B6J": "https://www.jax.org/strain/000664",
    "129S1J": "https://www.jax.org/strain/002448",
    "NODJ": "https://www.jax.org/strain/001976",
    "NZOJ": "https://www.jax.org/strain/002105",
    "CASTJ": "https://www.jax.org/strain/000928",
    "PWKJ": "https://www.jax.org/strain/003715",
    "WSBJ": "https://www.jax.org/strain/001145",
    'B6129SF1J': "https://www.jax.org/strain/101043",
    'B6AF1J': "https://www.jax.org/strain/100002",
    'B6CASTF1J': None,
    'B6NODF1J': None,
    'B6NZOF1J': None,
    'B6PWKF1J': None,
    'B6WSBF1J': "https://www.jax.org/strain/019019",
    'TREM2R47HNSS_HO': 'https://www.jax.org/strain/034036',
    'CC001': "https://www.jax.org/strain/021238",
    'CC002': "https://www.jax.org/strain/021236",
    'CC003': "https://www.jax.org/strain/021237",
    'CC004': "https://www.jax.org/strain/020944",
    'CC005': "https://www.jax.org/strain/020945",
    'CC006': "https://www.jax.org/strain/022869",
    'CC007': "https://www.jax.org/strain/029625",
    'CC008': "https://www.jax.org/strain/026971",
    'CC009': "https://www.jax.org/strain/018856",
    'CC010': "https://www.jax.org/strain/021889",
    'CC011': "https://www.jax.org/strain/018854",
    'CC012': "https://www.jax.org/strain/028409",
    'CC013': "https://www.jax.org/strain/021892",
    'CC015': "https://www.jax.org/strain/018859",
    'CC017': "https://www.jax.org/strain/022870",
    'CC018': "https://www.jax.org/strain/021890",
    'CC024': "https://www.jax.org/strain/021891",
    'CC025': "https://www.jax.org/strain/018857",
    'CC028': "https://www.jax.org/strain/025126",
    'CC029': "https://www.jax.org/strain/026972",
    'CC030': "https://www.jax.org/strain/025426",
    'CC032': "https://www.jax.org/strain/020946",
    'CC036': "https://www.jax.org/strain/025127",
    'CC037': "https://www.jax.org/strain/025423",
    'CC038': None,
    'CC041': "https://www.jax.org/strain/021893",
    'CC055': None,
    'CC057': "https://www.jax.org/strain/024683",
    'CC060': "https://www.jax.org/strain/026427",
    'CC062': None,
    'CC065': None,
    'CC071': None,
    'CC074': "https://www.jax.org/strain/018855",
}

# used as name. Should this be 
strain_igvf_id = {
    "AJ": "A/J (AJ)",
    "B6J": "C57BL/6J (B6)",
    "129S1J": "129S1/SvImJ (129)",
    "NODJ": "NOD/ShiLtJ (NOD)",
    "NZOJ": "NZO/HlLtJ (NZO)",
    "CASTJ": "CAST/EiJ (CAST)",
    "PWKJ": "PWK/PhJ (PWK)",
    "WSBJ": "WSB/EiJ (WSB)",
    'B6129SF1J': None, #"B6129SF1/J (B6 female x 129S male F1)"
    'B6AF1J':    None, #"B6AF1/J (B6 female x AJ male F1)"
    'B6CASTF1J': None, #"B6CASTF1/J (B6 female x CAST male F1)"
    'B6NODF1J':  None, #"B6NODF1/J (B6 female x NOD male F1)"
    'B6NZOF1J':  None, #"B6NZOF1/J (B6 female x NZO male F1)"
    'B6PWKF1J':  None, #"B6PWKF1/J (B6 female x PWK male F1)"
    'B6WSBF1J':  None, #"B6WSBF1/J (B6 female x WSB male F1)"
    "TREM2R47HNSS_HO": "B6(SJL)-Trem2<em1Aduci>/J", #"B6(SJL)-Tre2ᵉᵐ¹ᴬᵈᵘᶜⁱ/J",
    # commented out CC lines are ones we're not currently using.
    'CC001': 'CC001/Unc',
    'CC002': 'CC002/Unc',
    'CC003': 'CC003/Unc',
    'CC004': 'CC004/TauUnc',
    'CC005': 'CC005/TauUnc',
    'CC006': 'CC006/TauUnc',
    'CC007': 'CC007/Unc',
    'CC008': 'CC008/GeniUnc',
    'CC009': 'CC009/Unc',
    'CC010': 'CC010/GeniUnc',
    'CC011': 'CC011/Unc',
    'CC012': 'CC012/GeniUnc',
    'CC013': 'CC013/GeniUnc',
    'CC015': 'CC015/Unc',
    #'CC016': 'CC016/GeniUnc',
    'CC017': 'CC017/Unc',
    'CC018': 'CC018/Unc',
    #'CC019': 'CC019/TauUnc',
    #'CC020': 'CC020/GeniUnc',
    #'CC021': 'CC021/Unc',
    #'CC022': 'CC022/GeniUnc',
    #'CC023': 'CC023/GeniUnc',
    'CC024': 'CC024/GeniUnc',
    'CC025': 'CC025/GeniUnc',
    #'CC026': 'CC026/GeniUnc',
    #'CC027': 'CC027/GeniUnc',
    'CC028': 'CC028/GeniUnc',
    'CC029': 'CC029/Unc',
    'CC030': 'CC030/GeniUnc',
    #'CC031': 'CC031/GeniUnc',
    'CC032': 'CC032/GeniUnc',
    #'CC033': 'CC033/GeniUnc',
    #'CC034': 'CC034/Unc',
    #'CC035': 'CC035/Unc',
    'CC036': 'CC036/Unc',
    'CC037': 'CC037/TauUnc',
    'CC038': 'CC038/GeniUnc',
    #'CC039': 'CC039/Unc',
    #'CC040': 'CC040/TauUnc',
    'CC041': 'CC041/TauUnc',
    #'CC042': 'CC042/GeniUnc',
    'CC043': 'CC043/GeniUnc',
    #'CC044': 'CC044/Unc',
    #'CC045': 'CC045/GeniUnc',
    #'CC046': 'CC046/Unc',
    #'CC047': 'CC047/Unc',
    #'CC048': 'CC048/Unc',
    #'CC049': 'CC049/TauUnc',
    #'CC050': 'CC050/Unc',
    #'CC051': 'CC051/TauUnc',
    #'CC052': 'CC052/GeniUnc',
    #'CC053': 'CC053/Unc',
    #'CC054': 'CC054/GeniUnc',
    'CC055': 'CC055/TauUnc',
    #'CC056': 'CC056/GeniUnc',
    'CC057': 'CC057/Unc',
    #'CC058': 'CC058/Unc',
    #'CC059': 'CC059/TauUnc',
    'CC060': 'CC060/Unc',
    #'CC061': 'CC061/GeniUnc',
    'CC062': 'CC062/Unc',
    #'CC063': 'CC063/Unc',
    'CC065': 'CC065/Unc',
    #'CC068': 'CC068/TauUnc',
    #'CC070': 'CC070/TauUnc',
    'CC071': 'CC071/TauUnc',
    #'CC072': 'CC072/TauUnc',
    #'CC073': 'CC073/Unc',
    'CC074': 'CC074/Unc',
    #'CC075': 'CC075/Unc',
    #'CC076': 'CC076/Unc',
    #'CC078': 'CC078/TauUnc',
    #'CC079': 'CC079/TauUnc',
    #'CC080': 'CC080/TauUnc',
    #'CC081': 'CC081/Unc',
}

# %%
def int_csv_to_hex(x):
    r, g, b = x.split(",")
    
    return "#{:02x}{:02x}{:02x}".format(int(r), int(g), int(b))

def remove_citation(x):
    return x.split(" ")[0]

#strains = pandas.read_excel(
#    lizs_sheet_name, 
#    sheet_name="Line information", 
#    usecols=[
#        "Designation",
#        "Strain",
#        "Note",
#        "Jax Catalog No",
#        "Sample CODE",
#        "Strain notes",
#    ],
#    converters={
#        "Strain": remove_citation,
#        "Jax Catalog No": str,
#        "Strain notes": str_or_empty,
#    }
#).dropna(how="all")
# Remove the extra lines with the bridge samples for now. I don't want to track thta level of detail
#bridge = strains[strains["Designation"] == "Bridge sample"].first_valid_index() - 1
#strains = strains.iloc[0:bridge]

# Add in Strain URL
#strains["see_also"] = strains["Sample CODE"].apply(lambda x: strain_urls.get(x, x))
#strains

#print(strains.to_csv(index=False))

strains_csv = StringIO("""Designation,Strain,Note,Jax Catalog No,Sample CODE,Strain notes,see_also,Source
A,A/J,CC founder,000646,AJ,Yellower adrenal gland.,https://www.jax.org/strain/000646,jackson-labs
B,C57BL/6J,CC founder,000664,B6J,,https://www.jax.org/strain/000664,jackson-labs
C,129S1/SvImJ,CC founder,002448,129S1J,Male skin is tougher than female skin. Gallbladder is more filled in this strain. Adrenals are pale and smaller than A6J.,https://www.jax.org/strain/002448,jackson-labs
D,NOD/ShiLtJ,CC founder,001976,NODJ,,https://www.jax.org/strain/001976,jackson-labs
E,NZO/HlLtJ,CC founder,002105,NZOJ,,https://www.jax.org/strain/002105,jackson-labs
F,CAST/EiJ,CC founder,000928,CASTJ,,https://www.jax.org/strain/000928,jackson-labs
G,PWK/PhJ,CC founder,003715,PWKJ,,https://www.jax.org/strain/003715,jackson-labs
H,WSB/EiJ,CC founder,001145,WSBJ,,https://www.jax.org/strain/001145,jackson-labs
,B6129SF1/J,CC F1,101043,B6129SF1J,,https://www.jax.org/strain/101043,jackson-labs
,B6AF1/J,CC F1,101043,B6AF1J,,https://www.jax.org/strain/100002,jackson-labs
,B6CASTF1/J,CC F1,Custom C56BL/6J crossed CAST/EiJ,B6CASTF1J,,,jackson-labs
,B6NODF1/J,CC F1,Custom C56BL/6J crossed NOD/ShiLtJ,B6NODF1J,,,jackson-labs
,B6NZOF1/J,CC F1,Custom C56BL/6J crossed NZO/HlLtJ,B6NZOF1J,,,jackson-labs
,B6PWKF1/J,CC F1,Custom C56BL/6J crossed PWK/PhJ,B6PWKF1J,,,jackson-labs
,B6WSBF1/J,CC F1,019019,B6WSBF1J,,https://www.jax.org/strain/019019,jackson-labs
,TREM2R47HNSS_HO,CC Mutant,033781,TREM2R47HNSS_HO,,https://www.jax.org/strain/033781,jackson-labs
,CC001,CC Cross,021238,CC001,,https://www.jax.org/strain/021238,unc-csbio
,CC002,CC Cross,021236,CC002,,https://www.jax.org/strain/021236,unc-csbio
,CC003,CC Cross,021237,CC003,,https://www.jax.org/strain/021237,unc-csbio
,CC004,CC Cross,020944,CC004,,https://www.jax.org/strain/020944,unc-csbio
,CC005,CC Cross,020945,CC005,,https://www.jax.org/strain/020945,unc-csbio
,CC006,CC Cross,022869,CC006,,https://www.jax.org/strain/022869,unc-csbio
,CC007,CC Cross,029625,CC007,,https://www.jax.org/strain/029625,unc-csbio
,CC008,CC Cross,026971,CC008,,https://www.jax.org/strain/026971,unc-csbio
,CC009,CC Cross,018856,CC009,,https://www.jax.org/strain/018856,unc-csbio
,CC010,CC Cross,021889,CC010,,https://www.jax.org/strain/021889,unc-csbio
,CC011,CC Cross,018854,CC011,,https://www.jax.org/strain/018854,unc-csbio
,CC012,CC Cross,028409,CC012,,https://www.jax.org/strain/028409,unc-csbio
,CC013,CC Cross,021892,CC013,,https://www.jax.org/strain/021892,unc-csbio
,CC015,CC Cross,018859,CC015,,https://www.jax.org/strain/018859,unc-csbio
,CC017,CC Cross,022870,CC017,,https://www.jax.org/strain/022870,unc-csbio
,CC018,CC Cross,021890,CC018,,https://www.jax.org/strain/021890,unc-csbio
,CC024,CC Cross,021891,CC024,,https://www.jax.org/strain/021891,unc-csbio
,CC025,CC Cross,018857,CC025,,https://www.jax.org/strain/018857,unc-csbio
,CC028,CC Cross,025126,CC028,,https://www.jax.org/strain/025126,unc-csbio
,CC029,CC Cross,026972,CC029,,https://www.jax.org/strain/026972,unc-csbio
,CC030,CC Cross,025426,CC030,,https://www.jax.org/strain/025426,unc-csbio
,CC032,CC Cross,020946,CC032,,https://www.jax.org/strain/020946,unc-csbio
,CC036,CC Cross,025127,CC036,,https://www.jax.org/strain/025127,unc-csbio
,CC037,CC Cross,025423,CC037,,https://www.jax.org/strain/025423,unc-csbio
,CC038,CC Cross,,CC038,,,unc-csbio
,CC041,CC Cross,021893,CC041,,https://www.jax.org/strain/021893,unc-csbio
,CC043,CC Cross,023828,CC043,,https://www.jax.org/strain/023828,unc-csbio
,CC055,CC Cross,,CC055,,,unc-csbio
,CC057,CC Cross,024683,CC057,,https://www.jax.org/strain/024683,unc-csbio
,CC060,CC Cross,026427,CC060,,https://www.jax.org/strain/026427,unc-csbio
,CC062,CC Cross,,CC062,,,unc-csbio
,CC065,CC Cross,,CC065,,,unc-csbio
,CC071,CC Cross,,CC071,,,unc-csbio
,CC074,CC Cross,018855,CC074,,https://www.jax.org/strain/018855,unc-csbio""")

strains = pandas.read_csv(
    strains_csv,
    converters={"Jax Catalog No": str_or_none}
)

for i, row in strains.iterrows():
    assert pandas.notnull(row["Strain"]), f"{row['Strain']} was null {i} {row}"
    assert pandas.notnull(row["Sample CODE"]), f"{row['Sample CODE']} was null {i} {row}"
    assert pandas.notnull(row["Source"]), f"{row['Source']} was null {i} {row}"

strains
# Out:
#    Designation           Strain        Note  \
# 0            A              A/J  CC founder
# 1            B         C57BL/6J  CC founder
# 2            C      129S1/SvImJ  CC founder
# 3            D       NOD/ShiLtJ  CC founder
# 4            E        NZO/HlLtJ  CC founder
# 5            F         CAST/EiJ  CC founder
# 6            G          PWK/PhJ  CC founder
# 7            H          WSB/EiJ  CC founder
# 8          NaN       B6129SF1/J       CC F1
# 9          NaN          B6AF1/J       CC F1
# 10         NaN       B6CASTF1/J       CC F1
# 11         NaN        B6NODF1/J       CC F1
# 12         NaN        B6NZOF1/J       CC F1
# 13         NaN        B6PWKF1/J       CC F1
# 14         NaN        B6WSBF1/J       CC F1
# 15         NaN  TREM2R47HNSS_HO   CC Mutant
# 16         NaN            CC001    CC Cross
# 17         NaN            CC002    CC Cross
# 18         NaN            CC003    CC Cross
# 19         NaN            CC004    CC Cross
# 20         NaN            CC005    CC Cross
# 21         NaN            CC006    CC Cross
# 22         NaN            CC007    CC Cross
# 23         NaN            CC008    CC Cross
# 24         NaN            CC009    CC Cross
# 25         NaN            CC010    CC Cross
# 26         NaN            CC011    CC Cross
# 27         NaN            CC012    CC Cross
# 28         NaN            CC013    CC Cross
# 29         NaN            CC015    CC Cross
# 30         NaN            CC017    CC Cross
# 31         NaN            CC018    CC Cross
# 32         NaN            CC024    CC Cross
# 33         NaN            CC025    CC Cross
# 34         NaN            CC028    CC Cross
# 35         NaN            CC029    CC Cross
# 36         NaN            CC030    CC Cross
# 37         NaN            CC032    CC Cross
# 38         NaN            CC036    CC Cross
# 39         NaN            CC037    CC Cross
# 40         NaN            CC038    CC Cross
# 41         NaN            CC041    CC Cross
# 42         NaN            CC043    CC Cross
# 43         NaN            CC055    CC Cross
# 44         NaN            CC057    CC Cross
# 45         NaN            CC060    CC Cross
# 46         NaN            CC062    CC Cross
# 47         NaN            CC065    CC Cross
# 48         NaN            CC071    CC Cross
# 49         NaN            CC074    CC Cross
#
#                         Jax Catalog No      Sample CODE  \
# 0                               000646               AJ
# 1                               000664              B6J
# 2                               002448           129S1J
# 3                               001976             NODJ
# 4                               002105             NZOJ
# 5                               000928            CASTJ
# 6                               003715             PWKJ
# 7                               001145             WSBJ
# 8                               101043        B6129SF1J
# 9                               101043           B6AF1J
# 10    Custom C56BL/6J crossed CAST/EiJ        B6CASTF1J
# 11  Custom C56BL/6J crossed NOD/ShiLtJ         B6NODF1J
# 12   Custom C56BL/6J crossed NZO/HlLtJ         B6NZOF1J
# 13     Custom C56BL/6J crossed PWK/PhJ         B6PWKF1J
# 14                              019019         B6WSBF1J
# 15                              033781  TREM2R47HNSS_HO
# 16                              021238            CC001
# 17                              021236            CC002
# 18                              021237            CC003
# 19                              020944            CC004
# 20                              020945            CC005
# 21                              022869            CC006
# 22                              029625            CC007
# 23                              026971            CC008
# 24                              018856            CC009
# 25                              021889            CC010
# 26                              018854            CC011
# 27                              028409            CC012
# 28                              021892            CC013
# 29                              018859            CC015
# 30                              022870            CC017
# 31                              021890            CC018
# 32                              021891            CC024
# 33                              018857            CC025
# 34                              025126            CC028
# 35                              026972            CC029
# 36                              025426            CC030
# 37                              020946            CC032
# 38                              025127            CC036
# 39                              025423            CC037
# 40                                                CC038
# 41                              021893            CC041
# 42                              023828            CC043
# 43                                                CC055
# 44                              024683            CC057
# 45                              026427            CC060
# 46                                                CC062
# 47                                                CC065
# 48                                                CC071
# 49                              018855            CC074
#
#                                          Strain notes  \
# 0                             Yellower adrenal gland.
# 1                                                 NaN
# 2   Male skin is tougher than female skin. Gallbla...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                              see_also        Source
# 0   https://www.jax.org/strain/000646  jackson-labs
# 1   https://www.jax.org/strain/000664  jackson-labs
# 2   https://www.jax.org/strain/002448  jackson-labs
# 3   https://www.jax.org/strain/001976  jackson-labs
# 4   https://www.jax.org/strain/002105  jackson-labs
# 5   https://www.jax.org/strain/000928  jackson-labs
# 6   https://www.jax.org/strain/003715  jackson-labs
# 7   https://www.jax.org/strain/001145  jackson-labs
# 8   https://www.jax.org/strain/101043  jackson-labs
# 9   https://www.jax.org/strain/100002  jackson-labs
# 10                                NaN  jackson-labs
# 11                                NaN  jackson-labs
# 12                                NaN  jackson-labs
# 13                                NaN  jackson-labs
# 14  https://www.jax.org/strain/019019  jackson-labs
# 15  https://www.jax.org/strain/033781  jackson-labs
# 16  https://www.jax.org/strain/021238     unc-csbio
# 17  https://www.jax.org/strain/021236     unc-csbio
# 18  https://www.jax.org/strain/021237     unc-csbio
# 19  https://www.jax.org/strain/020944     unc-csbio
# 20  https://www.jax.org/strain/020945     unc-csbio
# 21  https://www.jax.org/strain/022869     unc-csbio
# 22  https://www.jax.org/strain/029625     unc-csbio
# 23  https://www.jax.org/strain/026971     unc-csbio
# 24  https://www.jax.org/strain/018856     unc-csbio
# 25  https://www.jax.org/strain/021889     unc-csbio
# 26  https://www.jax.org/strain/018854     unc-csbio
# 27  https://www.jax.org/strain/028409     unc-csbio
# 28  https://www.jax.org/strain/021892     unc-csbio
# 29  https://www.jax.org/strain/018859     unc-csbio
# 30  https://www.jax.org/strain/022870     unc-csbio
# 31  https://www.jax.org/strain/021890     unc-csbio
# 32  https://www.jax.org/strain/021891     unc-csbio
# 33  https://www.jax.org/strain/018857     unc-csbio
# 34  https://www.jax.org/strain/025126     unc-csbio
# 35  https://www.jax.org/strain/026972     unc-csbio
# 36  https://www.jax.org/strain/025426     unc-csbio
# 37  https://www.jax.org/strain/020946     unc-csbio
# 38  https://www.jax.org/strain/025127     unc-csbio
# 39  https://www.jax.org/strain/025423     unc-csbio
# 40                                NaN     unc-csbio
# 41  https://www.jax.org/strain/021893     unc-csbio
# 42  https://www.jax.org/strain/023828     unc-csbio
# 43                                NaN     unc-csbio
# 44  https://www.jax.org/strain/024683     unc-csbio
# 45  https://www.jax.org/strain/026427     unc-csbio
# 46                                NaN     unc-csbio
# 47                                NaN     unc-csbio
# 48                                NaN     unc-csbio
# 49  https://www.jax.org/strain/018855     unc-csbio

# %%
strain_code_to_name = strains[["Strain", "Sample CODE"]].set_index("Sample CODE")["Strain"].to_dict()
strain_name_to_code = strains[["Strain", "Sample CODE"]].set_index("Strain")["Sample CODE"].to_dict()

# %%
#strain_name_to_code
strain_code_to_name
# Out:
# {'AJ': 'A/J',
#  'B6J': 'C57BL/6J',
#  '129S1J': '129S1/SvImJ',
#  'NODJ': 'NOD/ShiLtJ',
#  'NZOJ': 'NZO/HlLtJ',
#  'CASTJ': 'CAST/EiJ',
#  'PWKJ': 'PWK/PhJ',
#  'WSBJ': 'WSB/EiJ',
#  'B6129SF1J': 'B6129SF1/J',
#  'B6AF1J': 'B6AF1/J',
#  'B6CASTF1J': 'B6CASTF1/J',
#  'B6NODF1J': 'B6NODF1/J',
#  'B6NZOF1J': 'B6NZOF1/J',
#  'B6PWKF1J': 'B6PWKF1/J',
#  'B6WSBF1J': 'B6WSBF1/J',
#  'TREM2R47HNSS_HO': 'TREM2R47HNSS_HO',
#  'CC001': 'CC001',
#  'CC002': 'CC002',
#  'CC003': 'CC003',
#  'CC004': 'CC004',
#  'CC005': 'CC005',
#  'CC006': 'CC006',
#  'CC007': 'CC007',
#  'CC008': 'CC008',
#  'CC009': 'CC009',
#  'CC010': 'CC010',
#  'CC011': 'CC011',
#  'CC012': 'CC012',
#  'CC013': 'CC013',
#  'CC015': 'CC015',
#  'CC017': 'CC017',
#  'CC018': 'CC018',
#  'CC024': 'CC024',
#  'CC025': 'CC025',
#  'CC028': 'CC028',
#  'CC029': 'CC029',
#  'CC030': 'CC030',
#  'CC032': 'CC032',
#  'CC036': 'CC036',
#  'CC037': 'CC037',
#  'CC038': 'CC038',
#  'CC041': 'CC041',
#  'CC043': 'CC043',
#  'CC055': 'CC055',
#  'CC057': 'CC057',
#  'CC060': 'CC060',
#  'CC062': 'CC062',
#  'CC065': 'CC065',
#  'CC071': 'CC071',
#  'CC074': 'CC074'}

# %%
print(strains.to_csv(index=False))
# Out:
# Designation,Strain,Note,Jax Catalog No,Sample CODE,Strain notes,see_also,Source
# A,A/J,CC founder,000646,AJ,Yellower adrenal gland.,https://www.jax.org/strain/000646,jackson-labs
# B,C57BL/6J,CC founder,000664,B6J,,https://www.jax.org/strain/000664,jackson-labs
# C,129S1/SvImJ,CC founder,002448,129S1J,Male skin is tougher than female skin. Gallbladder is more filled in this strain. Adrenals are pale and smaller than A6J.,https://www.jax.org/strain/002448,jackson-labs
# D,NOD/ShiLtJ,CC founder,001976,NODJ,,https://www.jax.org/strain/001976,jackson-labs
# E,NZO/HlLtJ,CC founder,002105,NZOJ,,https://www.jax.org/strain/002105,jackson-labs
# F,CAST/EiJ,CC founder,000928,CASTJ,,https://www.jax.org/strain/000928,jackson-labs
# G,PWK/PhJ,CC founder,003715,PWKJ,,https://www.jax.org/strain/003715,jackson-labs
# H,WSB/EiJ,CC founder,001145,WSBJ,,https://www.jax.org/strain/001145,jackson-labs
# ,B6129SF1/J,CC F1,101043,B6129SF1J,,https://www.jax.org/strain/101043,jackson-labs
# ,B6AF1/J,CC F1,101043,B6AF1J,,https://www.jax.org/strain/100002,jackson-labs
# ,B6CASTF1/J,CC F1,Custom C56BL/6J crossed CAST/EiJ,B6CASTF1J,,,jackson-labs
# ,B6NODF1/J,CC F1,Custom C56BL/6J crossed NOD/ShiLtJ,B6NODF1J,,,jackson-labs
# ,B6NZOF1/J,CC F1,Custom C56BL/6J crossed NZO/HlLtJ,B6NZOF1J,,,jackson-labs
# ,B6PWKF1/J,CC F1,Custom C56BL/6J crossed PWK/PhJ,B6PWKF1J,,,jackson-labs
# ,B6WSBF1/J,CC F1,019019,B6WSBF1J,,https://www.jax.org/strain/019019,jackson-labs
# ,TREM2R47HNSS_HO,CC Mutant,033781,TREM2R47HNSS_HO,,https://www.jax.org/strain/033781,jackson-labs
# ,CC001,CC Cross,021238,CC001,,https://www.jax.org/strain/021238,unc-csbio
# ,CC002,CC Cross,021236,CC002,,https://www.jax.org/strain/021236,unc-csbio
# ,CC003,CC Cross,021237,CC003,,https://www.jax.org/strain/021237,unc-csbio
# ,CC004,CC Cross,020944,CC004,,https://www.jax.org/strain/020944,unc-csbio
# ,CC005,CC Cross,020945,CC005,,https://www.jax.org/strain/020945,unc-csbio
# ,CC006,CC Cross,022869,CC006,,https://www.jax.org/strain/022869,unc-csbio
# ,CC007,CC Cross,029625,CC007,,https://www.jax.org/strain/029625,unc-csbio
# ,CC008,CC Cross,026971,CC008,,https://www.jax.org/strain/026971,unc-csbio
# ,CC009,CC Cross,018856,CC009,,https://www.jax.org/strain/018856,unc-csbio
# ,CC010,CC Cross,021889,CC010,,https://www.jax.org/strain/021889,unc-csbio
# ,CC011,CC Cross,018854,CC011,,https://www.jax.org/strain/018854,unc-csbio
# ,CC012,CC Cross,028409,CC012,,https://www.jax.org/strain/028409,unc-csbio
# ,CC013,CC Cross,021892,CC013,,https://www.jax.org/strain/021892,unc-csbio
# ,CC015,CC Cross,018859,CC015,,https://www.jax.org/strain/018859,unc-csbio
# ,CC017,CC Cross,022870,CC017,,https://www.jax.org/strain/022870,unc-csbio
# ,CC018,CC Cross,021890,CC018,,https://www.jax.org/strain/021890,unc-csbio
# ,CC024,CC Cross,021891,CC024,,https://www.jax.org/strain/021891,unc-csbio
# ,CC025,CC Cross,018857,CC025,,https://www.jax.org/strain/018857,unc-csbio
# ,CC028,CC Cross,025126,CC028,,https://www.jax.org/strain/025126,unc-csbio
# ,CC029,CC Cross,026972,CC029,,https://www.jax.org/strain/026972,unc-csbio
# ,CC030,CC Cross,025426,CC030,,https://www.jax.org/strain/025426,unc-csbio
# ,CC032,CC Cross,020946,CC032,,https://www.jax.org/strain/020946,unc-csbio
# ,CC036,CC Cross,025127,CC036,,https://www.jax.org/strain/025127,unc-csbio
# ,CC037,CC Cross,025423,CC037,,https://www.jax.org/strain/025423,unc-csbio
# ,CC038,CC Cross,,CC038,,,unc-csbio
# ,CC041,CC Cross,021893,CC041,,https://www.jax.org/strain/021893,unc-csbio
# ,CC043,CC Cross,023828,CC043,,https://www.jax.org/strain/023828,unc-csbio
# ,CC055,CC Cross,,CC055,,,unc-csbio
# ,CC057,CC Cross,024683,CC057,,https://www.jax.org/strain/024683,unc-csbio
# ,CC060,CC Cross,026427,CC060,,https://www.jax.org/strain/026427,unc-csbio
# ,CC062,CC Cross,,CC062,,,unc-csbio
# ,CC065,CC Cross,,CC065,,,unc-csbio
# ,CC071,CC Cross,,CC071,,,unc-csbio
# ,CC074,CC Cross,018855,CC074,,https://www.jax.org/strain/018855,unc-csbio

# %%
strain_type_lookup = {
    "CC founder": models.StrainType.FOUNDER,
    "CC F1": models.StrainType.F1,
    "CC Cross": models.StrainType.CROSS,
    "CC Mutant": models.StrainType.MUTANT,
}

if models.MouseStrain.objects.count() > 0:
    truncate(models.MouseStrain)

# This is the version where I was pulling from Liz's spreadsheet
#for i, row in strains.iterrows():
#    record = models.MouseStrain(
#        name=row["Sample CODE"],
#        display_name=strain_name[row["Sample CODE"]],
#        igvf_id=strain_igvf_id[row["Sample CODE"]],
#        strain_type=strain_type_lookup[row["Note"]],
#        jax_catalog_number=row["Jax Catalog No"],
#        notes=str_or_empty(row["Strain notes"]),
#        see_also=row["see_also"],
#        source=jax_source,
#    )
#    record.save()

sources = {
    "jackson-labs": jax_source,
    "unc-csbio": unc_csbio_source,
}

# this version is from my embedded csv file, so less adjusting needed
for i, row in strains.iterrows():
    record = models.MouseStrain(
        name=row["Sample CODE"],
        display_name=row["Strain"],
        igvf_id=strain_igvf_id[row["Sample CODE"]] if pandas.notnull(row["Sample CODE"]) else None,
        strain_type=strain_type_lookup[row["Note"]],
        jax_catalog_number=str_or_none(row["Jax Catalog No"]),
        notes=str_or_empty(row["Strain notes"]),
        see_also=str_or_none(row["see_also"]),
        source=sources[row["Source"]],
    )
    record.save()

# %%
row
# Out:
# Designation                                     NaN
# Strain                                        CC074
# Note                                       CC Cross
# Jax Catalog No                               018855
# Sample CODE                                   CC074
# Strain notes                                    NaN
# see_also          https://www.jax.org/strain/018855
# Source                                    unc-csbio
# Name: 49, dtype: object

# %% [markdown]
# This is closest to the Mouse table

# %%
def load_submitted_mice():
    submitted_mice = {
    }

    for accession_prefix in submitted_sheets:
        for i, row in submitted_sheets[accession_prefix]["rodent_donor"].iterrows():
            if not pandas.isnull(row["accession"]):
                rodent_identifier = row["rodent_identifier"]
                if accession_prefix == "igvftst":
                    see_also_template = "https://api.sandbox.igvf.org/rodent-donors/{}/"
                elif accession_prefix == "igvf":
                    see_also_template = "https://api.data.igvf.org/rodent-donors/{}/"
                if pandas.notnull(row["accession"]):
                    submitted_mice.setdefault(rodent_identifier, []).append({
                        "accession_prefix": accession_prefix,
                        "name": row["accession"],
                        "uuid": row["uuid"],
                        "see_also": see_also_template.format(row["accession"]),
                    })

    print(len(submitted_mice))
    return submitted_mice

# %%
def estrus_cycle(x):
    if pandas.isnull(x):
        return "NA"
    else:
        return x

    
def load_mouse_tables():
    submitted_mice = load_submitted_mice()
    
    sex_lookup = {
        numpy.nan: models.SexEnum.UNKNOWN,
        "Female": models.SexEnum.FEMALE,
        "Male": models.SexEnum.MALE,
    }

    estrus_stage = {
        "Unknown": models.EstrusCycle.UNKNOWN,
        "Anestrus": models.EstrusCycle.ANESTRUS,
        "Anestrus>Proestrus": models.EstrusCycle.ANESTRUS_PROESTRUS,
        "Proestrus": models.EstrusCycle.PROESTRUS,
        "Proestrus>Estrus": models.EstrusCycle.PROESTRUS_ESTRUS,
        "Estrus": models.EstrusCycle.ESTRUS,
        "Estrus>Metestrus": models.EstrusCycle.ESTRUS_METESTRUS,
        "Metestrus": models.EstrusCycle.METESTRUS,
        "Metestrus>Diestrus": models.EstrusCycle.METESTRUS_DIESTRUS,
        "Diestrus": models.EstrusCycle.DIESTRUS,
        "Diestrus>Proestrus": models.EstrusCycle.DIESTRUS_PROESTRUS,
    }

    mice = pandas.read_excel(
        lizs_sheet_name, 
        sheet_name="mice", 
        usecols=range(0,16),
        converters={
            "Estres cycle stage": estrus_cycle,
            "Dissection ID": int,
            "RMS number": int_or_none,
            "Housing number": int_or_none,
        }
    )

    if models.Mouse.objects.count() > 0:
        truncate(models.Mouse)

    los_angeles_tz = zoneinfo.ZoneInfo("America/Los_Angeles")


    failed = False
    for i, row in mice.iterrows():
        if not (pandas.isnull(row["Mouse Name"]) or pandas.isnull(row["Dissection ID"])):
            name = normalize_strain(row["Mouse Name"])
            strain_code = strain_name_to_code[row["Strain"]]

            if name == "056_WSBJ_10F->PWKJ_9F":
                name = "056_PWKJ_9F"

            try:
                strain = models.MouseStrain.objects.get(name=strain_code)
            except models.MouseStrain.DoesNotExist as e:
                print(f"Unable to find {row['Strain']} for row {i+2} with code {strain_code}")
                failed = True
                continue

            if not name[-1] in ("M", "F"):
                raise ValueError(f"Unrecognized sex field {mouse_name}")

            name_fields = name.split("_")

            # deal with TERM2R47HNSS_HO
            if len(name_fields) > 3:
                name_fields = [name_fields[0], "_".join(name_fields[1:-1]), name_fields[-1]]
            #if len(name_fields) != 3:
            #    raise ValueError(f"Wrong number of attributes in {name} line {i+1}")

            if not name_fields[1] in strain_igvf_id:
                raise ValueError(f"strain background in {name} not recognized line {i+1}")

            housing_number = None if pandas.isnull(row["Housing number"]) else row["Housing number"]

            record = models.Mouse(
                # should i use liz's disection id?
                name=name,
                strain=strain,
                sex=sex_lookup[row["Sex"]],
                weight_g=row["Weight (g)"],
                date_of_birth=row["DOB"].date() if not pandas.isnull(row["DOB"]) else None,
                harvest_date=row["Harvest Date"].date() if not pandas.isnull(row["Harvest Date"]) else None,
                timepoint_description=row["Timepoint"],
                life_stage=models.LifeStageEnum.ADULT,                
                operator=str_or_empty(row["Operator"]),
                notes=str_or_empty(row["Comments"]),
                housing_number=housing_number,
            )

            if not pandas.isnull(row["Estres cycle stage"]):
                # Ignore those transitions.
                stage = row["Estres cycle stage"]
                if stage.endswith("?"):
                    stage = stage[:-1]
                record.estrus_cycle=estrus_stage[stage]

            record.save()

            if name in submitted_mice:
                accessions = []
                for accession_record in submitted_mice[name]:
                    accession = models.Accession(
                        accession_prefix=accession_record["accession_prefix"],
                        name=accession_record["name"],
                        uuid=accession_record["uuid"],
                        see_also=accession_record["see_also"],
                    )
                    accession.save()
                    accessions.append(accession)
                record.accession.set(accessions)
                record.save()

    assert not failed, "Check warning messages"
    
load_mouse_tables()
# Out:
# 121

# %%
# %debug
# Out:
# ERROR:root:No traceback has been produced, nothing to debug.

# %% [markdown]
# # Tissues

# %%
def load_tissue_sheets():
    tissue_sheets = [
        "Samples - 8 founders", 
        "Samples - Bridge", 
        "Samples - F1s",
        "Samples - CClines",
    ]
    tissues = []
    for tissue_sheet in tissue_sheets:
        tissue = pandas.read_excel(
            lizs_sheet_name, 
            sheet_name=tissue_sheet,
            header=0,
        ).dropna(axis=0, how="all")
        if "tube+tissue wight (g)" in tissue.columns:
            print(f"{tissue_sheet} has typoed wight column, renaming to weight")
            tissue = tissue.rename(columns={
                "tube+tissue wight (g)": "tube+tissue weight (g)"
            })
        print(tissue_sheet, tissue.shape)
        tissues.append(tissue)

    combined = pandas.concat(tissues)
    assert "tube+tissue wight (g)" not in combined.columns
    return combined

_ = load_tissue_sheets()
# Out:
# Samples - 8 founders (1621, 16)
# Samples - Bridge (416, 23)
# Samples - F1s (1920, 18)
# Samples - CClines (5720, 18)

# %%
def parse_timepoint(value):
    value, units = value.split(" ")
    value = float(value)
    
    unit_map = {
        "day": models.AgeUnitsEnum.DAY,
        "days": models.AgeUnitsEnum.DAY,
        "week": models.AgeUnitsEnum.WEEK,
        "weeks": models.AgeUnitsEnum.WEEK,
        "month": models.AgeUnitsEnum.MONTH,
        "months": models.AgeUnitsEnum.MONTH,
    }
    return (value, unit_map[units])

# %%
ontology_map = {}
for record in models.OntologyTerm.objects.all():
    ontology_map[record.curie] = record

# %%
def load_submitted_tissues():
    submitted_tissues = {}

    for accession_prefix in submitted_sheets:
        for i, row in submitted_sheets[accession_prefix]["tissue"].iterrows():
            if not pandas.isnull(row["accession"]):
                if accession_prefix == "igvftst":
                    see_also_template = "https://api.sandbox.igvf.org/tissues/{}/"
                elif accession_prefix == "igvf":
                    see_also_template = "https://api.data.igvf.org/tissues/{}/"

                aliases = row["aliases:array"].split(",")
                assert len(aliases) == 1
                alias_fields = aliases[0][len("ali-mortazavi:"):].split("_")
                tissue_id = "_".join(alias_fields[0:4])
                if pandas.notnull(row["accession"]):
                    submitted_tissues.setdefault(tissue_id, []).append({
                        "accession_prefix": accession_prefix,
                        "name": row["accession"],
                        "uuid": row["uuid"],
                        "see_also": see_also_template.format(row["accession"]),
                    })

    print(len(submitted_tissues))
    return submitted_tissues

submitted_tissues = load_submitted_tissues()
#len(submitted_tissues)
# Out:
# 692

# %%
for key in submitted_tissues:
    value = submitted_tissues[key]
    if len(value) != 1:
        print(key, value)
# Out:
# 016_B6J_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM21751020', 'uuid': '5093a872-bf44-42c5-abfd-a99dd3d6df2c', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM21751020/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM20935867', 'uuid': '8ac461bf-8d25-4f0e-bd17-f5043cb96ce5', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM20935867/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2747ZOJJ', 'uuid': '12089b43-dc3c-40cd-b7b7-de5934949a94', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2747ZOJJ/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9909OKAR', 'uuid': '3ecee650-301b-481f-bc5e-1a46dafd4542', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9909OKAR/'}]
# 017_B6J_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM58133825', 'uuid': '56f28252-6e1a-4367-bd0d-3bdd75abb6f2', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM58133825/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM51811428', 'uuid': 'ce1bfdf4-cacb-4859-a79f-5da312178a27', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM51811428/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM5751LMFR', 'uuid': '489b79b4-c432-4f92-b1ae-9e3b765b8dbf', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM5751LMFR/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9616JAGA', 'uuid': '74a4f3c4-5173-4a0f-b684-1cf988a49c7a', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9616JAGA/'}]
# 018_B6J_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM10325421', 'uuid': 'db754d0d-e36b-49b6-b0fa-53eaf25fd744', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM10325421/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM33316466', 'uuid': 'e9114d98-ffe6-447a-9f6f-9a6c4bb8ddd6', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM33316466/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM4584AIMA', 'uuid': '13650fd4-0573-4e27-92d2-c42c7b5eaaf6', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4584AIMA/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6999WOUL', 'uuid': 'a71cb08f-2788-461d-9c5c-079ed8b1e4a7', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6999WOUL/'}]
# 019_B6J_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM26473010', 'uuid': '8863dd4f-198b-4d15-9067-d0561c39734b', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM26473010/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM18283790', 'uuid': '83cee65e-441a-4703-8a05-68a89b7499ee', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM18283790/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM3502KEWR', 'uuid': 'e48b8327-9d8d-41d9-8735-b924df3bfaf1', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3502KEWR/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9565QVTN', 'uuid': '552b6e0a-454f-4900-87b0-e7405e6a494b', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9565QVTN/'}]
# 020_B6J_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM01160367', 'uuid': '3e69fe23-5e69-4b91-973e-2728f79d718e', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM01160367/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM33524527', 'uuid': '99b62f36-444b-4649-9e4e-26a663a7c252', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM33524527/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6578SAUC', 'uuid': 'c170a792-994e-4c37-bc3b-ef49897c5de4', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6578SAUC/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9764WOWB', 'uuid': 'd861a51f-57ff-4222-820a-b46a4f9907d4', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9764WOWB/'}]
# 021_B6J_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM42088479', 'uuid': '9ab88858-088f-4095-8651-5cc42419a0dd', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM42088479/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM99278471', 'uuid': '924e79ca-d960-42ab-acde-1a9d85fdbb78', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM99278471/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2795QIAK', 'uuid': '164c4760-ba0e-4424-9ab6-0f37bda42607', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2795QIAK/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM3360ORUF', 'uuid': 'cf407c40-57a8-4ee4-b7a3-15be85574c60', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3360ORUF/'}]
# 024_B6J_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM41442798', 'uuid': 'c06d0f9d-6fee-4b01-8401-14c26f84c1af', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM41442798/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM92339352', 'uuid': '71a9c6e3-4013-456f-b1cd-f547ef8caf95', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM92339352/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM7596ZIPA', 'uuid': '8654187a-0b2a-4326-b464-09fb102bddd2', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7596ZIPA/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0587AFGX', 'uuid': 'c4e66921-3298-4ffc-9a43-f6ce8698ae7e', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0587AFGX/'}]
# 025_B6J_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM53700181', 'uuid': 'b779a774-03fd-4495-9e11-43d1b886816e', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM53700181/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM24966581', 'uuid': '4191c958-5276-480b-8242-b11faae829d6', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM24966581/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM4108RLII', 'uuid': 'f814d7f1-3bfc-448a-853a-b4b0e9ecd877', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4108RLII/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1457MNSR', 'uuid': 'f1f113d7-662a-43d9-aef2-e9b508aaeef0', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1457MNSR/'}]
# 066_NODJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM00342720', 'uuid': '5a77d96b-0dbf-4f69-882c-405bc8c5fa46', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM00342720/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM62163894', 'uuid': '2fb0690b-46dd-4370-bc3c-0f0591bc3316', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM62163894/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1810KYOB', 'uuid': 'c221bf2e-917b-46b2-88e1-a2cb67ba636d', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1810KYOB/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM5439QLWY', 'uuid': '14ed6824-2dd2-42b5-9ea5-68eed279b527', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM5439QLWY/'}]
# 067_NODJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM05994267', 'uuid': 'dac6d232-6f33-48d0-81d7-dea1ee5b6204', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM05994267/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM96811554', 'uuid': '1629913b-4e9c-4032-a115-98757739d445', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM96811554/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6514BRQT', 'uuid': '2821b73b-5d02-4ef6-ac0d-badd69b82778', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6514BRQT/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM3477RPDP', 'uuid': 'aa241577-33cb-48c6-bac9-221cda21cbde', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3477RPDP/'}]
# 068_NODJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM72460407', 'uuid': '6012f47d-d05c-41f1-b154-3130845e9979', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM72460407/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM52294448', 'uuid': '940cd826-45e8-495a-a1a2-1fec4f617810', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM52294448/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0483CXTW', 'uuid': 'ef6a8399-83b9-4160-9fbb-47e1a18b0a43', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0483CXTW/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2315DNPR', 'uuid': '6cd5eed6-35dc-46e7-9dba-5f566f014066', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2315DNPR/'}]
# 069_NODJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM70776988', 'uuid': '64c37487-bc8c-4fbf-a70d-4815014ee4e3', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM70776988/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM04240735', 'uuid': 'b54afd50-51d6-4b6f-b4ae-41e5fb04a26c', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM04240735/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2210CUOC', 'uuid': '3237d42d-9f30-412c-be67-97f43cd605bb', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2210CUOC/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM3655BTER', 'uuid': '2b03b94c-c611-44c1-98c6-7aa18f1641c3', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3655BTER/'}]
# 070_NODJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM16736591', 'uuid': '7f713377-43fd-4ea7-901c-35c3e50e8a77', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM16736591/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM83682213', 'uuid': '7f390718-5684-4145-b3b5-85284e482727', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM83682213/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM4132TDOU', 'uuid': '8293abba-add2-4a82-affb-d0af66f38a2e', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4132TDOU/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1916FXAR', 'uuid': '269c39b2-e726-4fe5-851b-5b175979b936', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1916FXAR/'}]
# 071_NODJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM76160667', 'uuid': '8736e722-d0be-49cc-acb9-db2e38629d4c', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM76160667/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM28533810', 'uuid': '6e39b3b2-a5ea-47b2-81af-4dc0fcec779a', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM28533810/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9423CHGE', 'uuid': '2a2997b4-56ee-4217-ae0d-a8268af47355', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9423CHGE/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2219SJUB', 'uuid': '6eaec560-1fcf-4769-a9e9-9c060f2af1a6', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2219SJUB/'}]
# 072_NODJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM79168608', 'uuid': 'd4df962c-c9b9-47a7-adf5-6f622e84f7bb', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM79168608/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM85453964', 'uuid': '0c60d4a3-dbbb-4750-853e-fabe199470b8', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM85453964/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0749UUSU', 'uuid': 'ad59bbd5-96bf-4aa0-873a-543c3ce74588', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0749UUSU/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1724CQMW', 'uuid': '23e32920-8fa8-4b7d-af9b-6b5676edc4b8', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1724CQMW/'}]
# 073_NODJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM45296598', 'uuid': '35b4d0f5-213c-4c5d-8c9c-40d66423b038', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM45296598/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM90705852', 'uuid': '00f594bc-3ed3-4072-a22c-2ed304759f85', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM90705852/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9890CMQT', 'uuid': '11041153-5c6f-48c0-976a-f4926a829f3b', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9890CMQT/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM5506IVPG', 'uuid': 'b285ef2b-32dd-4c44-864f-8b9537d0c231', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM5506IVPG/'}]
# 026_AJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM12615846', 'uuid': '7e5de2b8-9185-4700-a665-548914c62015', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM12615846/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM92907388', 'uuid': 'a58fe6cd-8956-4170-8e2d-350485ac1e7b', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM92907388/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM4370URZQ', 'uuid': '7e2f83bb-686d-4cdf-ad60-06a415149844', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4370URZQ/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2423BNZZ', 'uuid': '3a8b2024-b8da-46db-954d-4551c348f9c3', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2423BNZZ/'}]
# 029_AJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM38994111', 'uuid': '3b680c8b-146b-4310-8f08-94bd2dee5119', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM38994111/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM47454871', 'uuid': 'f857066f-cf89-45a9-a653-7795e030373c', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM47454871/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM7221OIET', 'uuid': 'a56ecec3-101a-42cc-8007-4ba96b3b2e6d', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7221OIET/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2957XPNR', 'uuid': 'fb7f4566-4a49-4a1e-9ff7-eac9d16e5f97', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2957XPNR/'}]
# 028_AJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM30161161', 'uuid': 'a8e03d55-deaf-413f-b933-c93e793d0732', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM30161161/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM51463318', 'uuid': '76ebeea1-04a3-40f0-a7a6-9c821f2d8959', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM51463318/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM7981HLTV', 'uuid': 'caff5d29-ca29-4fe8-a5db-35bff6384de2', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7981HLTV/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8529NIEC', 'uuid': '74efe2ba-adde-4ceb-ab49-0d88526b8648', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8529NIEC/'}]
# 031_AJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM02881437', 'uuid': 'ffea0493-9cbc-4ac0-a6c4-3a2fe4a486b4', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM02881437/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM84736502', 'uuid': '3f29043c-477a-4e5e-a777-7cea6f1ea34a', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM84736502/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6144DRYM', 'uuid': 'c75fc1e6-69fd-4b8f-9081-ca906ede0630', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6144DRYM/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8120ZQGC', 'uuid': '15ff0666-156d-47a7-8b25-9e64067a5d2e', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8120ZQGC/'}]
# 030_AJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM83815196', 'uuid': '9bcf7b19-cc01-4089-b0f1-e5bd7927f864', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM83815196/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM03250341', 'uuid': '0ede3985-50d8-4b16-89e8-ccf024fc756d', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM03250341/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9442VMKA', 'uuid': '355d36a6-82db-4e97-96b2-64f56363f4c9', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9442VMKA/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0425PEQP', 'uuid': 'ac533e1f-824f-4852-81a3-38c47b9b9cfc', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0425PEQP/'}]
# 033_AJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM66295363', 'uuid': '9074c218-f526-44f4-86e7-e2a5cf2ee7eb', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM66295363/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM89879775', 'uuid': '91defe4a-7bb6-49af-8dc8-32043ab5ce1c', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM89879775/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9867TADD', 'uuid': '29ae3b1b-7632-4146-a2af-5dfdf9eeca62', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9867TADD/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0406DUWH', 'uuid': 'ff71c9ee-8f76-42e6-9768-9bfa1f33ff04', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0406DUWH/'}]
# 032_AJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM80577942', 'uuid': '6d8e091d-a63e-4464-b944-2785039b98a6', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM80577942/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM57113277', 'uuid': '26bdccbd-1bba-4691-aab9-8e6228442673', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM57113277/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM3195CJCF', 'uuid': 'cf59909d-c385-4e5c-a1c7-10dcdc2661f2', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3195CJCF/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6726YGIG', 'uuid': '18411a3d-e5dc-40bd-afe5-fcc9d0009ea4', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6726YGIG/'}]
# 035_AJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM59466810', 'uuid': 'de3f2622-b21c-4521-9496-04c96805f19f', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM59466810/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM93284518', 'uuid': '2eda64f7-e9e3-42fe-a6a7-c68fa659e718', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM93284518/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM4131CTSJ', 'uuid': '9ba11cdd-82ff-4407-aab5-f168da714c97', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4131CTSJ/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM4651QBMQ', 'uuid': 'fe1f3ec4-8eab-442c-816d-0efd1897ecce', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4651QBMQ/'}]
# 076_PWKJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM52954034', 'uuid': '88e8d180-0338-4f12-b49a-6a7ad3e0e549', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM52954034/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM15705729', 'uuid': 'e7356ef8-de67-4d6e-b725-58038bd875b4', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM15705729/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0918MYKM', 'uuid': 'd325cdfe-00a6-4f23-aa04-774de52ada7d', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0918MYKM/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM7550NDQP', 'uuid': '480e10d4-1d83-4bd6-ae69-5ec584ea6ded', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7550NDQP/'}]
# 077_PWKJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM83815676', 'uuid': 'aac6da89-ae7f-4eb5-9f65-0da6d1b2bc66', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM83815676/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM04954230', 'uuid': '0320b949-703d-40bf-a9f2-bf15e61ca548', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM04954230/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6013VRIK', 'uuid': '270b496d-e5d7-4b81-893e-bdd40fa7971a', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6013VRIK/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0563DEOO', 'uuid': '7fc28775-ddf6-4c14-9793-312b4d48932f', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0563DEOO/'}]
# 078_PWKJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM03938139', 'uuid': '007e2129-8560-49e8-b925-07f2697c961a', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM03938139/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM20539280', 'uuid': '7c485858-6b2a-4a8b-86de-da2885b89f33', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM20539280/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6356IYPX', 'uuid': '3c9c357e-4e8d-4e28-b027-9b31a21fde39', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6356IYPX/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0623LMKH', 'uuid': '6333e18a-0755-4f18-a887-070ae5f5270e', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0623LMKH/'}]
# 079_PWKJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM22223422', 'uuid': '8d7f1305-4634-4489-aef7-4f79cea13d1a', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM22223422/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM12427616', 'uuid': '08e893c3-e408-4f54-a1a7-9c76bafa848f', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM12427616/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM4224SVKL', 'uuid': '5e631ee5-4547-4d35-b02f-985c79180b90', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4224SVKL/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2048SMTE', 'uuid': '9d37ed77-929e-4b8d-9341-ddd293311ca0', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2048SMTE/'}]
# 080_PWKJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM65126292', 'uuid': '136be24f-8e79-4884-9edc-18f66ef76790', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM65126292/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM82793177', 'uuid': '8e27cc65-2496-4be7-9b0e-d47f51139dee', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM82793177/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1463UXNU', 'uuid': '134ff3a6-3b32-4313-9874-82dd71a65433', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1463UXNU/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM3905UDST', 'uuid': '99197a01-b977-4482-8338-303fcd21b12d', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3905UDST/'}]
# 081_PWKJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM69336152', 'uuid': '46b85ce0-63ae-4c76-92e5-0e3aced3ac31', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM69336152/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM16556661', 'uuid': '3e1a251c-10a1-47bd-b9dd-21ccb493ac9c', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM16556661/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1764RZHQ', 'uuid': '4f1ac155-9874-402b-b63b-d14fd8d775ee', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1764RZHQ/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0454IWHA', 'uuid': '4f486bac-7118-422f-bdd7-026191f62168', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0454IWHA/'}]
# 084_PWKJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM60112939', 'uuid': 'b031b861-4912-4013-ab3f-6f2ae8b5893e', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM60112939/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM20313266', 'uuid': 'aa5409f3-a67d-4784-8388-6943a519043d', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM20313266/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2111IGAF', 'uuid': '21318f88-293b-47b4-b042-d1518651b155', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2111IGAF/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM7111UROK', 'uuid': 'd36d756f-c0a5-40aa-8927-c68ade6feb0c', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7111UROK/'}]
# 085_PWKJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM07209305', 'uuid': '1b973b12-10e5-4834-aaf0-f68c55199e4e', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM07209305/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM51740762', 'uuid': '8f4529af-8e03-4309-92f5-c073a259883a', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM51740762/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM5036ECAW', 'uuid': '61d1e625-09fe-427e-aa53-9036eb57f8af', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM5036ECAW/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1227KXDL', 'uuid': 'bef60b67-6f91-42a4-a157-2f12e8cfa467', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1227KXDL/'}]
# 036_129S1J_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM53940869', 'uuid': '475429e8-7e03-4377-973d-e89e2e22b86b', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM53940869/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM96114334', 'uuid': '994c3ec7-bd62-47ac-b44b-c9ec2a48e492', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM96114334/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9227EIZD', 'uuid': '5b35e6a7-6648-4c4c-b78f-3125c84efe97', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9227EIZD/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8124ZHLJ', 'uuid': 'd1d75f8f-3d4a-43d0-8654-add43f26d44f', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8124ZHLJ/'}]
# 037_129S1J_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM79359987', 'uuid': '24278b79-3600-4fd8-8ef3-55f78bbe77be', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM79359987/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM14025651', 'uuid': '2657fe8f-9409-4cdd-b8d3-522bd1135eac', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM14025651/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0860OBUU', 'uuid': '9ce6f4ec-0e70-4cce-ab32-b2fe0bc9e97b', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0860OBUU/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2419NKNV', 'uuid': '44fe44ad-3ce9-466c-97c5-8b8936d14106', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2419NKNV/'}]
# 038_129S1J_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM46396178', 'uuid': '8ef01892-7f1b-4ea2-9b50-5d827e1f1d72', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM46396178/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM52735813', 'uuid': '21859d64-6f62-4cfc-b51e-fb4280809d4a', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM52735813/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0225XPQG', 'uuid': 'b7867990-c177-4b2c-8a9f-3a405f1f442f', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0225XPQG/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1783ISPH', 'uuid': 'ee5197d5-82f3-4875-ad1a-d73a53ee3e21', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1783ISPH/'}]
# 041_129S1J_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM92914084', 'uuid': 'ede30dbb-c084-44ab-9d54-3ad6e25349c5', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM92914084/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM90714157', 'uuid': '90f34008-76b4-4f73-bb48-391c510e2f59', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM90714157/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9603NVUP', 'uuid': 'e64b3d46-b5a9-44ab-9697-b1fc4556f9a2', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9603NVUP/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM4535GZXJ', 'uuid': 'c7faf615-7151-4f54-b063-8bdf71adb031', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4535GZXJ/'}]
# 040_129S1J_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM77387655', 'uuid': '349daa31-7d4d-4a56-89e0-86085d48998e', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM77387655/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM74867542', 'uuid': '888fdbfc-bd1c-4439-b43b-f4d714acb690', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM74867542/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1865RBAP', 'uuid': '26661547-9c86-4f4e-8054-4ea59d555095', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1865RBAP/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM3592ZCYS', 'uuid': 'e54e61d7-f4ea-48ac-b5a2-cd0074470279', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3592ZCYS/'}]
# 043_129S1J_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM16786304', 'uuid': 'f42e340d-b2a6-4083-9c7c-f36f460e71c6', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM16786304/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM54542240', 'uuid': '827a41c6-c206-4325-b751-1f78666c2355', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM54542240/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2592YCXF', 'uuid': '84d33c54-3f48-4f22-9f11-574d30d2a987', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2592YCXF/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM4046THJJ', 'uuid': '162cb92b-9e88-4b16-98c5-af314807c787', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4046THJJ/'}]
# 044_129S1J_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM33999140', 'uuid': 'a53d9f0d-ad97-464e-a137-1b8364eddaf3', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM33999140/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM35170934', 'uuid': 'd6c65361-4d12-40e0-b535-4ebcc66000e8', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM35170934/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8263PWJC', 'uuid': '6ab6613c-7057-4ddc-9d18-99940dbabe51', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8263PWJC/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0923PDGB', 'uuid': '63a0fa92-389a-4b5d-b4c5-cc22fbf02c84', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0923PDGB/'}]
# 045_129S1J_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM44620762', 'uuid': '7f863cef-6c3d-4285-9de1-d35f4ba1bf04', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM44620762/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM93636128', 'uuid': '17226952-dfa8-400b-a4a2-b3e1daa18930', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM93636128/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9934DIHO', 'uuid': 'f1b33610-3df0-49f8-8990-3d90c1382fb1', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9934DIHO/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0221ZKMO', 'uuid': '2ba4661d-8e4d-451b-b69b-7bfced3c9e4e', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0221ZKMO/'}]
# 086_CASTJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM23724063', 'uuid': '463fd79b-5e4f-4012-bac2-b7ba1a3394f9', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM23724063/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM36392432', 'uuid': 'cfc0cb17-14f6-42e7-b98d-8b3dc24906bb', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM36392432/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM7195PKWY', 'uuid': 'a9637f98-9c95-4a35-9b95-c62680707a51', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7195PKWY/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM7666QOZY', 'uuid': '1e6db460-5b80-4fc5-9052-29e86eb9685c', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7666QOZY/'}]
# 087_CASTJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM32674535', 'uuid': '2e6aeee2-cb21-4df9-9bba-6afceea05c14', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM32674535/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM01448874', 'uuid': 'a3c0df52-96f5-409d-8faf-f6eda174909d', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM01448874/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM7317YYMK', 'uuid': 'a8ad5cd0-22e9-4bfb-b6d2-cee8fce9c2f5', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7317YYMK/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8253LIZU', 'uuid': '35c7329b-3ca6-4a7f-a9a2-befb336a3905', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8253LIZU/'}]
# 088_CASTJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM79946851', 'uuid': '3febf347-cd39-4718-8c5d-bae336c84849', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM79946851/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM57968715', 'uuid': '45d6a976-c79d-4462-812e-573781dda9fa', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM57968715/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8386KIXU', 'uuid': '09d4d693-82d7-4cec-8a5e-55469af01157', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8386KIXU/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM3708BQMH', 'uuid': '437f21ae-ba2a-44fb-82ef-9693b4a7058c', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3708BQMH/'}]
# 089_CASTJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM49388204', 'uuid': 'fe4a6e87-bb8c-4611-b089-23af834ff814', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM49388204/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM57395435', 'uuid': 'd9f5df98-f0bd-4c06-b486-c4d3ea8ab57b', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM57395435/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6275QJJU', 'uuid': 'd9e9bee7-7412-4a35-bf17-00054975f090', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6275QJJU/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM7470VZNE', 'uuid': '8a298c03-1cdb-4e38-aa3d-00afb7dcc00d', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7470VZNE/'}]
# 090_CASTJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM38489848', 'uuid': '5ec2ee20-ad68-4a12-ada9-ba63bd84b113', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM38489848/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM57565332', 'uuid': '03d61e1c-9c02-4669-9129-2c0c9ad0ad21', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM57565332/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9194WULA', 'uuid': 'e97872f8-da47-4980-8a75-0426a69ea189', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9194WULA/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM3391TANO', 'uuid': '4a773267-7169-43a1-9a01-67fdd84f0351', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3391TANO/'}]
# 091_CASTJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM62101456', 'uuid': 'd7a9a951-4843-4ff0-b909-26d3098c87f7', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM62101456/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM66782725', 'uuid': 'a9aa2edc-a47e-4dce-9b4e-daa393396a2d', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM66782725/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM3523HTHO', 'uuid': '47365040-d1c5-4892-8306-66647229345c', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3523HTHO/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM4618XBBU', 'uuid': 'c195863e-d49c-4347-8e62-91e9640ba62b', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4618XBBU/'}]
# 094_CASTJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM90443496', 'uuid': '6532ab58-9141-4dd0-a1a1-8c4aff5a036e', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM90443496/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM57771690', 'uuid': '764c1f5a-1e05-433d-9a66-2650db1344b5', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM57771690/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM7747QNMD', 'uuid': '277353ca-1540-4289-9140-695f62a03bf4', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7747QNMD/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8043HCTC', 'uuid': '87ac318f-a8e4-43ea-8a47-bf0c88efbf86', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8043HCTC/'}]
# 093_CASTJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM79094150', 'uuid': '6c4d166d-8657-45fa-90ab-fc11165968dd', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM79094150/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM84121976', 'uuid': '6c941741-096c-4dee-8e98-b8f10a9495e0', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM84121976/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8601VZGE', 'uuid': '5bf3801d-a019-4678-a9f6-f62356fb7054', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8601VZGE/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0611PVMT', 'uuid': '5cee9cef-0e3c-482d-a066-2d0e09d71972', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0611PVMT/'}]
# 058_WSBJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM32200435', 'uuid': '5f9db1c1-0496-43c4-a7c7-e8bbd688b306', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM32200435/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM15885234', 'uuid': '891e5899-4b30-4e71-97b4-78adb49f216c', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM15885234/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2105LIWI', 'uuid': '9862f105-760c-47ea-8ccd-8f6a39861e6c', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2105LIWI/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1395QLCT', 'uuid': '96ef3f40-91b9-4148-a466-20c5e952f03b', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1395QLCT/'}]
# 057_WSBJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM43608351', 'uuid': 'b8b00f4b-d2e7-45e9-b468-0356c2407109', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM43608351/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM11842313', 'uuid': '84725cb2-a0e8-4c20-8170-a04749b56c9a', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM11842313/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6575IFHC', 'uuid': '2eb3f073-7c09-4f5f-b23c-93e17861d5f5', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6575IFHC/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1203GHYB', 'uuid': 'd9277809-9203-4102-aea1-503ea29d675a', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1203GHYB/'}]
# 060_WSBJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM63825870', 'uuid': 'a3680081-8f54-46ef-93f9-0ecf53648ede', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM63825870/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM41460346', 'uuid': 'c06ebf0e-5ed2-4702-ae7c-990101c9cd9e', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM41460346/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1996USDH', 'uuid': '1d4ce3c7-6c99-4af8-949a-d6e64c99a2ab', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1996USDH/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9916UWTV', 'uuid': '20342be2-d3a6-4b39-9cd2-cf24dd47ed52', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9916UWTV/'}]
# 059_WSBJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM19613428', 'uuid': '769d284b-fda3-487b-a42e-bdcbdf5dafda', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM19613428/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM97826128', 'uuid': 'fb0f8bf0-fa87-4841-a460-2d098f594018', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM97826128/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1116FVJP', 'uuid': '3e5ad4a3-73a4-459b-9812-0a46b1dd4e56', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1116FVJP/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1295CUJX', 'uuid': '9389066e-f233-4503-8970-c483ab60f03d', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1295CUJX/'}]
# 062_WSBJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM60971839', 'uuid': '596e9af4-9cd9-400d-ac18-a24a3495481b', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM60971839/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM19608989', 'uuid': 'b8f87ea3-7fb2-46d1-9797-ad31db6a6a7c', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM19608989/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2903TFAJ', 'uuid': 'c640cd48-1289-4197-aa47-9e029bd9bec3', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2903TFAJ/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM5785PIAM', 'uuid': 'e1122092-0ca4-4b95-ae27-ba161a5bbb3d', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM5785PIAM/'}]
# 061_WSBJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM45945257', 'uuid': '56bf203f-9664-4f91-a207-5fb79c05fc06', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM45945257/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM00084391', 'uuid': 'de93915a-493e-4bb1-ab5f-c9253ad89da7', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM00084391/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0898KHQX', 'uuid': 'f2daad20-7004-4546-9a46-c7bfe9fa9259', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0898KHQX/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0431DSEH', 'uuid': '17a3349e-8c25-4030-ae76-3944ae5fe95c', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0431DSEH/'}]
# 096_WSBJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM60767863', 'uuid': '2cdfca7a-8472-4245-ba95-408585983f6a', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM60767863/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM64908116', 'uuid': '54b91c6d-2fb3-4a08-a3b4-e8813d254eec', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM64908116/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM7994PCAR', 'uuid': 'aa248864-199b-4f5b-b651-b6888fc80652', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7994PCAR/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1901NWCD', 'uuid': 'a9047a77-3864-4ff7-9432-45479de846b3', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1901NWCD/'}]
# 063_WSBJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM55897972', 'uuid': '1e20fa9c-ea22-4766-a1df-d8b53af753b6', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM55897972/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM15834985', 'uuid': '07bb5012-908c-416a-95ba-64010ff3cf20', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM15834985/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8727ZEXW', 'uuid': '857c0d4c-64a5-42bb-8d6f-189ce3460106', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8727ZEXW/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1039KCGC', 'uuid': 'bbc4bbb1-c7ef-4c6b-9526-ed8daae6c024', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1039KCGC/'}]
# 046_NZOJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM24255023', 'uuid': 'dfff0205-ca9b-47a5-8e77-41fc29ffecf1', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM24255023/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM72017255', 'uuid': '3adad841-b470-457f-986e-c4b150107e70', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM72017255/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1839OFVA', 'uuid': 'c429089a-98e9-4a8c-bdf6-1106fa9ea3df', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1839OFVA/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8201XPIS', 'uuid': '204cd5a3-ccfd-4103-8f93-b2da7d330414', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8201XPIS/'}]
# 047_NZOJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM33306992', 'uuid': 'e0b436be-bc8a-4a6a-bd93-8824288cf1e8', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM33306992/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM30685000', 'uuid': '93291861-0f79-4db9-a95a-dd740c8ac3cf', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM30685000/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9072COND', 'uuid': 'e07c3c4b-afb7-488c-af4a-8608fa7775ba', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9072COND/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM7371QPPK', 'uuid': '6346bcc3-f4fd-4c35-b799-40366f19d461', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7371QPPK/'}]
# 048_NZOJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM61430175', 'uuid': 'd6185f78-2e47-486e-8f94-bfd321670386', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM61430175/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM44199147', 'uuid': '03729597-907a-4e2f-87cd-767063d30158', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM44199147/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9852CDAM', 'uuid': '9472075d-4236-4d24-ad21-157d223e2924', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9852CDAM/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8490EBUM', 'uuid': '6ea0d036-6a67-4665-8bea-41e55ba98cb2', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8490EBUM/'}]
# 049_NZOJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM42091421', 'uuid': 'b86c8f2f-dc4f-47e2-8352-2b7de835a7f1', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM42091421/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM87330877', 'uuid': '422462b9-34b2-4e5f-a269-3895cbafcb1d', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM87330877/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM4528ONTR', 'uuid': '4affe146-58d4-4da6-9e4e-e17dbd25e404', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4528ONTR/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0101ITFE', 'uuid': '39b241d7-c097-44d3-9878-fa241c4caeec', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0101ITFE/'}]
# 050_NZOJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM85978816', 'uuid': 'd6101be5-d671-4afe-b71a-2f4f9f5e3d9a', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM85978816/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM80562094', 'uuid': 'a8f27223-3eef-442b-9af3-82db0350ab2e', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM80562094/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM5306QAYC', 'uuid': 'b885aaf8-f080-487c-8c13-7891bdc200ee', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM5306QAYC/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0561GQRI', 'uuid': 'df11d12b-7b4c-4733-ab6c-0920a7afb777', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0561GQRI/'}]
# 051_NZOJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM86161501', 'uuid': 'caa2889a-9757-4b18-bdbb-a57a9f02b18e', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM86161501/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM11875348', 'uuid': '1d24833e-56eb-40a0-a3e7-93ca8d398a9d', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM11875348/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1083MRIY', 'uuid': 'c1197245-2e20-4320-9328-06d734c8bd2b', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1083MRIY/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM5958RVMJ', 'uuid': 'fe1488d9-96a6-44a3-9013-84d0c07813f9', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM5958RVMJ/'}]
# 052_NZOJ_10F_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM13439390', 'uuid': '4e281e53-7fbd-4b87-aaeb-a6d108e43c83', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM13439390/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM67022673', 'uuid': '301fe56b-2bee-4940-89eb-18f578e9c717', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM67022673/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6096DCNO', 'uuid': '25e08fc5-bee5-45c7-b518-9676a9876cff', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6096DCNO/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8959FRNP', 'uuid': 'a7b92ad5-8354-4c6a-8ac7-6d72aa4ca991', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8959FRNP/'}]
# 053_NZOJ_10M_03 [{'accession_prefix': 'igvftst', 'name': 'TSTSM78719590', 'uuid': '0c77a8fa-65cf-47de-94b5-4c993e37bda8', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM78719590/'}, {'accession_prefix': 'igvftst', 'name': 'TSTSM86500952', 'uuid': 'e009dbb6-d7a5-4df1-bad3-9cb56e2119a3', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM86500952/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9234QGBN', 'uuid': '033dea5f-6701-46d3-b469-6d21f6671e61', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9234QGBN/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8856ZHGA', 'uuid': '1b0f45b7-d996-470e-940e-eb7c05b554de', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8856ZHGA/'}]
# 016_B6J_10F_06 [{'accession_prefix': 'igvftst', 'name': 'TSTSM95666276', 'uuid': '480ad476-6353-41a2-b178-0540ec4f29a8', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM95666276/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2397OXJE', 'uuid': '24774070-a134-42fa-8ac9-9f4bb6865876', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2397OXJE/'}]
# 066_NODJ_10F_06 [{'accession_prefix': 'igvftst', 'name': 'TSTSM73842863', 'uuid': '34657832-2051-4ac4-b86f-037718503bfb', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM73842863/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0400KSXT', 'uuid': '64e5242d-ceee-48dd-9bbb-d921618ea6b2', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0400KSXT/'}]
# 017_B6J_10M_06 [{'accession_prefix': 'igvftst', 'name': 'TSTSM15336485', 'uuid': 'c85ee703-cd8c-4595-9999-7916e378be5d', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM15336485/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6821QIOI', 'uuid': 'dc9711ba-0e84-43f1-b835-f1056fe91bec', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6821QIOI/'}]
# 067_NODJ_10M_06 [{'accession_prefix': 'igvftst', 'name': 'TSTSM13603592', 'uuid': 'c8b3907d-2c7e-499c-8246-bd37cccbe629', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM13603592/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8486IRSE', 'uuid': 'be507859-5265-4f59-a3f7-8b134dcecda1', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8486IRSE/'}]
# 018_B6J_10F_06 [{'accession_prefix': 'igvftst', 'name': 'TSTSM53191815', 'uuid': '8ba491dd-cd43-4768-9ed9-ff40b57eeab7', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM53191815/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9283STYP', 'uuid': '314ead3d-f3b8-4ab6-947f-e5e86a6da896', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9283STYP/'}]
# 068_NODJ_10F_06 [{'accession_prefix': 'igvftst', 'name': 'TSTSM71072025', 'uuid': '21c29c17-6f6e-47f2-a23e-430fd41d9e30', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM71072025/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6061AIFT', 'uuid': 'c8dedd9c-8424-4846-a347-fbfe73c2531a', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6061AIFT/'}]
# 019_B6J_10M_06 [{'accession_prefix': 'igvftst', 'name': 'TSTSM46884051', 'uuid': '4f8c3b79-f670-4d89-adbe-95eb3131854d', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM46884051/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM3819GVRA', 'uuid': '17a90e67-0181-48a4-ad10-b4eacd8b632d', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3819GVRA/'}]
# 069_NODJ_10M_06 [{'accession_prefix': 'igvftst', 'name': 'TSTSM04142593', 'uuid': '26ec404b-af28-46af-b84c-0300057c8a06', 'see_also': 'https://api.sandbox.igvf.org/tissues/TSTSM04142593/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9555SHCP', 'uuid': '2cd63182-4ad1-4d86-8217-4e497e3e5d0a', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9555SHCP/'}]
# ...
# 028_AJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM4796DKJO', 'uuid': 'bd5c5c6d-83ae-4993-80d9-ac43288ad9d9', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4796DKJO/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM4881USYE', 'uuid': '5f8caf9f-e6b6-4607-b59c-ee695b60e3e3', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4881USYE/'}]
# 078_PWKJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM9111MIVH', 'uuid': '09bdfe37-27e8-4e14-a8b7-d2ddd7bbc7ac', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9111MIVH/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2146SQAW', 'uuid': '2524a727-bbc3-48b8-a40f-fadf802233ad', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2146SQAW/'}]
# 031_AJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM6893IKIH', 'uuid': '61a2b143-b341-437e-8117-ea685322676d', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6893IKIH/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM3351WODP', 'uuid': '7e190df1-ae82-4925-bc22-1ec75270b252', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3351WODP/'}]
# 079_PWKJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM3536WDNR', 'uuid': 'd18320cc-ed7a-4d10-8a8f-d918b492ab8d', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3536WDNR/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM3744QPBB', 'uuid': 'eaab5bfc-ca1e-415b-b41d-c652530c842b', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3744QPBB/'}]
# 030_AJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM4955LORB', 'uuid': 'c0dcbc3b-a748-4e07-99c2-cda6cedb63a4', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4955LORB/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9545EZNW', 'uuid': 'a7a8e27d-4f85-4335-afc0-bf861208d9ba', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9545EZNW/'}]
# 080_PWKJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM0567BKYP', 'uuid': 'ec84894a-3d99-4c0c-94b8-2822cc643237', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0567BKYP/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1552JBSI', 'uuid': 'dde86bc8-bba1-41d2-97d3-970bb8128491', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1552JBSI/'}]
# 033_AJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM2119ANJP', 'uuid': '11b78286-7eae-49b9-a664-6f5d3c18e0c0', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2119ANJP/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1755SWJI', 'uuid': '692ee9c5-aad7-4df2-a223-ab3a4c910ac5', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1755SWJI/'}]
# 081_PWKJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM8490BJOU', 'uuid': '068d55a1-c4d3-4626-a515-f341b62a3feb', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8490BJOU/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6086KVUS', 'uuid': '137daebd-0599-427a-a61e-c2b0ce4451a4', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6086KVUS/'}]
# 032_AJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM3957TLDF', 'uuid': 'a4b79c62-05d8-483d-91e2-19c4fb3b8922', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3957TLDF/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6828FNBA', 'uuid': 'df65d29a-952c-49f9-8a26-9041a4b77c13', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6828FNBA/'}]
# 084_PWKJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM4249JBEE', 'uuid': '1ba4b0aa-986d-48f4-a657-0cb7b9683ac3', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4249JBEE/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM7955ABKB', 'uuid': '31586d6d-13e8-46bc-babf-5353f58cb4a1', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7955ABKB/'}]
# 035_AJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM3012KPRJ', 'uuid': 'c3c03275-a389-40be-82f5-591d3c902716', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3012KPRJ/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1951AMWE', 'uuid': '966a66ee-8fb7-43e1-a45b-87dce5031e97', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1951AMWE/'}]
# 085_PWKJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM3050OPDO', 'uuid': '96e18fd2-04a5-4e56-802f-99cf2c959b8b', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3050OPDO/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM4510XDYL', 'uuid': 'c4301ca1-fa47-4472-8f2b-28c0220995fd', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4510XDYL/'}]
# 036_129S1J_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM9398YHXY', 'uuid': '2796ef8e-c018-46e3-868a-bcf5a5e69947', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9398YHXY/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM4167SEXH', 'uuid': '47c3f193-a365-4c91-9499-514f17567b8c', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4167SEXH/'}]
# 086_CASTJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM9286SBAR', 'uuid': 'be30909f-0d2d-47b2-b3c5-058531f7b39e', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9286SBAR/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM7092FDTP', 'uuid': '46a08032-bca7-4e1f-bc6f-85a9e53da1f7', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7092FDTP/'}]
# 037_129S1J_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM3753OVHM', 'uuid': '29892f46-8636-4e08-b35e-b99160f47926', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3753OVHM/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9806TYXF', 'uuid': 'fa3e0716-0e6f-4bf2-ad13-94d94aa94018', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9806TYXF/'}]
# 087_CASTJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM5457PTKY', 'uuid': '778c18be-698e-4ff9-b328-3f4dadf18381', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM5457PTKY/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM4956HIAH', 'uuid': '5d1e9d06-169a-4804-b750-751490291cd2', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4956HIAH/'}]
# 038_129S1J_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM9530NJWB', 'uuid': 'ea7743e9-9f48-494f-94d8-2266750dec1d', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9530NJWB/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM5458IIQG', 'uuid': 'a3154a90-e6c9-4527-bda5-1e5572b001b1', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM5458IIQG/'}]
# 088_CASTJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM0690VJRZ', 'uuid': '7296f8ef-b4d3-4e7a-adbe-3302f64d8ea9', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0690VJRZ/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9111THIZ', 'uuid': 'ae9db008-41bb-47a0-bc66-a926ae61c174', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9111THIZ/'}]
# 041_129S1J_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM4269MUAL', 'uuid': '7806d098-aa8d-414f-9527-eb359ccb6128', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4269MUAL/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0340DRJV', 'uuid': 'f9a3a29d-08c5-40f3-97e0-86f7f78b20d8', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0340DRJV/'}]
# 089_CASTJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM8458TCXX', 'uuid': '8be9fbcb-ad91-48b1-b347-0a343f440317', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8458TCXX/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6740OVAR', 'uuid': '04c1fc90-89a5-4d8c-921b-026667ef8a3f', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6740OVAR/'}]
# 040_129S1J_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM7479OZRI', 'uuid': 'cd77ff2b-d024-43aa-8895-7c5ceb8bcc66', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7479OZRI/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6249RJQV', 'uuid': '69619cc3-2e7c-4c54-a5a6-77b816868c12', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6249RJQV/'}]
# 090_CASTJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM1264GFRJ', 'uuid': '8c6a0077-6ddd-4f58-b9da-f8322e48ed3e', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1264GFRJ/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM5214BQRA', 'uuid': 'b3fbbfa8-a5da-4702-a00a-05abc74a9156', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM5214BQRA/'}]
# 043_129S1J_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM6782GARZ', 'uuid': '463b6afc-3248-4592-bdfe-03a7692ed950', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6782GARZ/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8930SAOK', 'uuid': '6300e920-318f-4cbf-a6f4-6843e98fce0d', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8930SAOK/'}]
# 091_CASTJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM4321DFFH', 'uuid': '1e9ffafe-f59c-40ae-8eca-97a9b5ef57ad', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4321DFFH/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8357WYSN', 'uuid': 'c85274aa-790b-413d-b3b2-7a79329c0d32', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8357WYSN/'}]
# 044_129S1J_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM6738OHZO', 'uuid': '83e218de-7b42-426b-81be-65127043e3e0', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6738OHZO/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0539MTAN', 'uuid': 'b49b3933-3e97-4507-9a8a-c122e6a8bc06', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0539MTAN/'}]
# 094_CASTJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM0021WQYA', 'uuid': 'da950e21-1ab3-4705-9511-5dfe7dc4176f', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0021WQYA/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1257AOMZ', 'uuid': 'd959cea7-a785-401c-aa5e-89c07cdb5de7', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1257AOMZ/'}]
# 045_129S1J_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM6742HLKN', 'uuid': '649ec13f-97a1-4398-9148-f381fddd6df0', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6742HLKN/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1996CIIR', 'uuid': '9fce9d03-d51b-49cf-b8e1-da310b5fe339', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1996CIIR/'}]
# 093_CASTJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM5017BJEE', 'uuid': '42a10680-c23d-4055-a9fe-24f2b800960a', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM5017BJEE/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1436ECIH', 'uuid': 'f3bf5922-4e53-4db9-a888-1f7aecb85752', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1436ECIH/'}]
# 058_WSBJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM4130KIEV', 'uuid': '548222ac-d86c-4d6e-95ba-7b7530ab3d0c', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4130KIEV/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0966WWIZ', 'uuid': '1103358a-4d00-4b62-b064-7afa51d094a1', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0966WWIZ/'}]
# 092_CASTJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM8134HPUH', 'uuid': '4bce5bed-6719-4220-9d3f-81bfed153cf9', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8134HPUH/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1078KTYU', 'uuid': '1639516f-a979-4240-a8eb-3454a0957d3f', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1078KTYU/'}]
# 047_NZOJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM4107ZNSE', 'uuid': '986a5e15-5553-48f5-a898-643632262c44', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4107ZNSE/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6703AANL', 'uuid': '0f90a9cb-a38b-4fef-945b-ae3297b89f13', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6703AANL/'}]
# 057_WSBJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM8498UCVA', 'uuid': 'f3fefb5c-a44f-4436-acf4-b3effb637d1b', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8498UCVA/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM7450WJIV', 'uuid': 'b40b8e46-0b01-42e8-8a5e-d98a9b37bb41', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7450WJIV/'}]
# 048_NZOJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM0298LFOQ', 'uuid': '6a108204-df5b-48f3-ad48-4082ae333c0b', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0298LFOQ/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8754ELWG', 'uuid': 'c78670f9-3e00-4d19-8031-d9520b2c468f', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8754ELWG/'}]
# 060_WSBJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM3371TFMC', 'uuid': 'f97bd66c-bae5-44f4-9535-d12e4e144f62', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3371TFMC/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM0752ZRMG', 'uuid': '6856aaab-7fec-4b0d-b0db-479e1d8c20a6', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM0752ZRMG/'}]
# 049_NZOJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM9197PRMM', 'uuid': '38ea1daf-8a5a-48ea-8693-d50a47cbb0f8', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9197PRMM/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2572HXXE', 'uuid': '7ac92b44-01cb-46ac-a5ef-c0acb4ec2489', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2572HXXE/'}]
# 059_WSBJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM9356QKBM', 'uuid': '96cacd9f-2134-4ad6-8bfd-1fc3db857b77', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9356QKBM/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2287EHGA', 'uuid': 'e0d1f6d6-2e05-4b9f-880b-b9d8f55f32ee', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2287EHGA/'}]
# 050_NZOJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM2120LYVH', 'uuid': '7e5f6196-dd64-4376-947d-0709f4f5e126', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2120LYVH/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8205AVFV', 'uuid': 'e65ecb63-e05b-4de4-9a9c-dd93f621c017', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8205AVFV/'}]
# 062_WSBJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM7560RVGB', 'uuid': '75b3af62-8e22-4fef-8944-460d7fefc0d4', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7560RVGB/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2047VYYJ', 'uuid': '59cda413-8413-49d9-81f2-d23cfdf01085', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2047VYYJ/'}]
# 051_NZOJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM3556PAEN', 'uuid': 'b13f1408-ec31-4c0e-9cd7-2bc032536fc3', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3556PAEN/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9711JMMI', 'uuid': '7afe7c7a-4d03-42c3-9ef4-14246f0930df', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9711JMMI/'}]
# 061_WSBJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM3364FXFB', 'uuid': '37270f8d-8baa-4190-83d7-b5d48b971ef4', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3364FXFB/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM4632PCNC', 'uuid': 'e04ac839-27cc-45e7-8180-c01365935d41', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM4632PCNC/'}]
# 052_NZOJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM5374RXFR', 'uuid': '0fb589eb-73cf-4b62-8ef1-4e6a59a8a315', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM5374RXFR/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9813BNZU', 'uuid': '52d7ba9c-24a0-4ae1-860f-9b19c6fd3a53', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9813BNZU/'}]
# 096_WSBJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM6620ZEBK', 'uuid': '5278d9e7-f87b-4403-aacd-30133b4068d8', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM6620ZEBK/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1348QFIK', 'uuid': '30245671-8960-4ce9-b7c6-28a71f921adf', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM1348QFIK/'}]
# 053_NZOJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM9817PYLC', 'uuid': 'd9e6d3fc-d959-49aa-9e5a-b1cbbd3db4a8', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9817PYLC/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM3167TBKE', 'uuid': 'f2a79240-36bb-4126-9440-3f63fdebdacd', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM3167TBKE/'}]
# 063_WSBJ_10M_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM7877XJMN', 'uuid': 'd9becf1f-3dcb-434f-ae18-78195c9f1eba', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM7877XJMN/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9074ZTED', 'uuid': '32feebe5-5fd9-437e-8ab3-dc7e74b46720', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM9074ZTED/'}]
# 046_NZOJ_10F_01 [{'accession_prefix': 'igvf', 'name': 'IGVFSM8078MQQC', 'uuid': 'aaaa720e-a504-426b-b79d-fa8190d4523f', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM8078MQQC/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2791YRHP', 'uuid': 'aace359e-5ae0-404c-930d-1490c1196452', 'see_also': 'https://api.data.igvf.org/tissues/IGVFSM2791YRHP/'}]

# %%
def validate_tissue_genotype(tissue, genotype):
    normalized_genotype = normalize_strain(genotype)
    assert tissue == normalized_genotype, f"{tissue} != {normalized_genotype} ({genotype})"

# %%
def load_tissues(strain_code_to_name):
    if models.Tissue.objects.count() > 0:
        truncate(models.Tissue)

    tissues = load_tissue_sheets()
    submitted_tissues = load_submitted_tissues()
    los_angeles_tz = zoneinfo.ZoneInfo("America/Los_Angeles")
    
    failed = False
    for i, row in tissues.iterrows():
        if not pandas.isnull(row["Tissue"]) and row["IGVF Sample BOX"] != "DNA Extraction Optimization":
            mouse_tissue_id_label = "Mouse_Tissue ID"

            mouse_tissue_name = normalize_strain(row[mouse_tissue_id_label])
            mouse_tissue_name_fields = parse_mouse_tissue(mouse_tissue_name)

            if not mouse_tissue_name_fields.mouse_strain in strain_code_to_name:
                raise ValueError(f"tissue strain field in {mouse_tissue_name} not recognized")

            mouse_name = "_".join(mouse_tissue_name_fields[0:3])
            try:
                mouse = models.Mouse.objects.get(name=mouse_name)
            except models.Mouse.DoesNotExist:
                print("row {}, {} was not found".format(i+2, mouse_name))
                failed = True
                continue

            mouse_tissue = "_".join(mouse_tissue_name_fields)

            genotype = row["Genotype"]

            # this is the "label swap" on spreadsheet rows 602-605.
            if mouse_name == "092_CASTJ_10F":
                genotype = "CASTJ"
            # this is the other half the swap on spreadsheet rows 1522-1525
            elif mouse_name == "046_NZOJ_10F":
                genotype = 'NZOJ'

            validate_tissue_genotype(mouse.strain.name, genotype)

            tissue_terms = []
            for term_curie, term_name in tissue_dissection_to_ontology_map[row["Tissue"]]:
                tissue_terms.append(ontology_map[term_curie])

            #age, age_units = parse_timepoint(row["Timepoint"])

            if pandas.isnull(row["Approx. sac time"]):
                sac_time = datetime.time(0,0,0)
            else:
                sac_time = datetime.time(
                    row["Approx. sac time"].hour,
                    row["Approx. sac time"].minute,
                    row["Approx. sac time"].second,    
                )


            record = models.Tissue(
                mouse=mouse,
                name = mouse_tissue,
                description = row["Tissue"],
                #dissection_time=dissection,
                #age=age,
                #age_units=age_units,
                tube_label=row["Tube label"],
                dissector=str_or_empty(row["Dissector"]),
                dissection_notes=str_or_empty(row["Comment"]),
            )

            if not pandas.isnull(row["Dissection date"]):
                record.dissection = datetime.datetime(
                    row["Dissection date"].year,
                    row["Dissection date"].month,
                    row["Dissection date"].day,
                    sac_time.hour,
                    sac_time.minute,
                    sac_time.second,
                    tzinfo=los_angeles_tz,
                )

            tube_weight_label = "tube weight (g)"
            if not pandas.isnull(row[tube_weight_label]):
                record.tube_weight_g = float(row[tube_weight_label])

            total_weight_label = "tube+tissue weight (g)"
            if not pandas.isnull(row[total_weight_label]):
                record.total_weight_g = float(row[total_weight_label])

            record.save()
            record.ontology_term.set(tissue_terms)

            if row[mouse_tissue_id_label] in submitted_tissues:
                accessions = []
                for accession_row in submitted_tissues[row[mouse_tissue_id_label]]:
                    if pandas.notnull(accession_row["name"]):
                        accession = models.Accession(
                            accession_prefix=accession_row["accession_prefix"],
                            name=accession_row["name"],
                            uuid=accession_row["uuid"],
                            see_also=accession_row["see_also"],
                        )
                        accession.save()
                        accessions.append(accession)
                record.accession.set(accessions)
            record.save()

    assert not failed, "Check warning messages."
    
load_tissues(strain_code_to_name)
# Out:
# Samples - 8 founders (1621, 16)
# Samples - Bridge (416, 23)
# Samples - F1s (1920, 18)
# Samples - CClines (5720, 18)
# 692

# %%
#submitted_tissues[row[mouse_tissue_id_label]], type(submitted_tissues[row[mouse_tissue_id_label]])

# %% [markdown]
# # Information from Samples into experiment
#
# - Total barcoded nuclei (Samples into experiment)
#
# Is this FixedTissue, FixedSample, FixedBiosample?

# %%
if models.FixedSample.objects.count() > 0:
    truncate(models.FixedSample)

# %%
def load_samples_into_experiment(book_name, sheet_name, header=0):
    samples_into_experiment = pandas.read_excel(
        book_name, 
        sheet_name=sheet_name,
        header=header,
        index_col=None,
    ).dropna(how="all")

    # was trying to normalize two row hierarchical headers, 
    #level0 = []
    #level1 = []
    #for header in samples_into_experiment.columns:
    #    level0.append("" if header[0].startswith("Unnamed: ") else header[0])
    #    level1.append(header[1])
    #samples_into_experiment.columns = pandas.MultiIndex.from_arrays([level0, level1], names=["phase", "name"])

    one_based = 1
    header_lines = 2
    failed = False
    for i, row in samples_into_experiment.iterrows():
        line_no = i + one_based + header_lines
        box_name = row["IGVF Fixation BOX"]
        if isinstance(box_name, str):
            box_name = box_name.strip()

        if box_name in ["IGVF_FIX_001", "IGVF_FIX_002"]:
            continue
            
        if pandas.isnull(row["Mouse_Tissue ID"]):
            continue

        tissue_id = normalize_strain(row["Mouse_Tissue ID"])
        pooled_from = row.get("pooled_from")

        if pandas.isnull(tissue_id):
            continue

        #if (tissue_id.endswith("_25") or tissue_id.endswith("_26")) and pandas.isnull(pooled_from):
        #    print(f"How are we going to merge these samples? {tissue_id}")
        #    continue

        if pandas.isnull(pooled_from):
            pooled_from = [tissue_id]
        else:
            pooled_from = [normalize_strain(pooled_id.strip()) for pooled_id in pooled_from.split(",")]

        tissues = []
        for pooled_id in pooled_from:
            try:
                tissues.append(models.Tissue.objects.get(name=pooled_id))
            except models.Tissue.DoesNotExist:
                print(f"Tissue {pooled_id} not found in tissue table on {line_no}")
                failed = True

        weight = row["weight (mg)"]
        fixation_date = row["Fixation date"]
        notes = row["Notes"]

        if weight == "#VALUE!":
            pass
        elif weight < 0:
            pass
        elif pandas.isnull(weight):
            pass
        else:
            total_weight = 0
            for tissue in tissues:
                if not pandas.isnull(tissue.weight_mg):
                    total_weight += tissue.weight_mg

            if not numpy.isclose(total_weight, weight):
                print(f"Sum of tissue weights from {pooled_from} {total_weight} doesn't match {weight}. {line_no}")

        sample_id = normalize_strain(row["Sample ID"]) if not pandas.isnull(row["Sample ID"]) else None
        if not (pandas.isnull(sample_id) or pandas.isnull(tissue_id)):
            if tissue_id != sample_id:
                print(f"If defined, {tissue_id} should equal {sample_id} line {line_no}")
                failed = True

        cap_label = row["Cap label"]
        if not (pandas.isnull(cap_label) or pandas.isnull(sample_id)):
            sample_fields = sample_id.split("_")
            predicted_label = "_".join([sample_fields[0], sample_fields[-1]])
            if predicted_label != cap_label:
                print(f"{cap_label} should equal {predicted_label} line {line_no}")
                failed = True

        well_id = row["wells in Barcoding plate"]

        record = models.FixedSample(
            name=tissue_id,
            tube_label=cap_label,
            fixation_name=box_name,
            fixation_date=date_or_none(row["Fixation date"]),
            starting_nuclei=int_or_none(row["Total nuclei (x10^6)"]),
            nuclei_into_fixation=int_or_none(row["Nuclei into fixation (x10^6)"]),
            fixed_nuclei=int_or_none(row["Total fixed nuclei (x10^6)"]),
            aliquots_made=int_or_none(row["# aliquots"]),
            aliquot_volume_ul=float_or_none(row["uL per aliquot"]),
        )
        record.save()
        record.tissue.set(tissues)
        record.save()

    assert not failed, "Check warning messages"

# %%
load_samples_into_experiment(lizs_sheet_name, "Founder Samples into experiment", header=1)
# Out:
# Sum of tissue weights from ['046_NZOJ_10F_17'] 116.0 doesn't match 190.0. 558
# Sum of tissue weights from ['095_CASTJ_10M_08'] 11.0 doesn't match 15.0. 749

# %%
load_samples_into_experiment(lizs_sheet_name, "Bridge samples into experiment", header=0)

# %%
load_samples_into_experiment(lizs_sheet_name, "F1 Samples into experiment", header=1)
# Out:
# Sum of tissue weights from ['127_B6AF1J_10M_05'] 1075.0 doesn't match 966.0. 205
# Sum of tissue weights from ['128_B6AF1J_10F_05'] 873.0 doesn't match 1078.0. 206
# Sum of tissue weights from ['129_B6AF1J_10M_05'] 1139.0 doesn't match 946.0. 207
# Sum of tissue weights from ['130_B6AF1J_10F_05'] 66.1 doesn't match 1577.0. 208
# Sum of tissue weights from ['131_B6AF1J_10M_05'] 1525.0 doesn't match 748.0. 209
# Sum of tissue weights from ['132_B6AF1J_10F_05'] 888.0 doesn't match 1418.0. 210
# Sum of tissue weights from ['133_B6AF1J_10M_05'] 0 doesn't match 857.0. 211
# Sum of tissue weights from ['134_B6AF1J_10F_05'] 0 doesn't match 1351.0. 212
# Sum of tissue weights from ['143_B6129SF1J_10M_05'] 1288.0 doesn't match 603.0. 213
# Sum of tissue weights from ['144_B6129SF1J_10F_05'] 995.0 doesn't match 1248.0. 214
# Sum of tissue weights from ['145_B6129SF1J_10M_05'] 1259.0 doesn't match 776.0. 215
# Sum of tissue weights from ['146_B6129SF1J_10F_05'] 974.0 doesn't match 1216.0. 216
# Sum of tissue weights from ['147_B6129SF1J_10M_05'] 1368.0 doesn't match 798.0. 217
# Sum of tissue weights from ['148_B6129SF1J_10F_05'] 977.0 doesn't match 1243.0. 218
# Sum of tissue weights from ['149_B6129SF1J_10M_05'] 1385.0 doesn't match 800.0. 219
# Sum of tissue weights from ['150_B6129SF1J_10F_05'] 870.0 doesn't match 1343.0. 220
# Sum of tissue weights from ['159_B6NODF1J_10M_05'] 1343.0 doesn't match 1189.0. 221
# Sum of tissue weights from ['160_B6NODF1J_10F_05'] 1247.0 doesn't match 828.0. 222
# Sum of tissue weights from ['161_B6NODF1J_10M_05'] 1238.0 doesn't match 1071.0. 223
# Sum of tissue weights from ['164_B6NODF1J_10F_05'] 861.0 doesn't match 626.0. 224
# Sum of tissue weights from ['165_B6NODF1J_10M_05'] 1237.0 doesn't match 1039.0. 225
# Sum of tissue weights from ['166_B6NODF1J_10F_05'] 1053.0 doesn't match 1065.0. 226
# Sum of tissue weights from ['167_B6NODF1J_10M_05'] 1343.0 doesn't match 1189.0. 227
# Sum of tissue weights from ['168_B6NODF1J_10F_05'] 1033.0 doesn't match 1157.0. 228
# Sum of tissue weights from ['175_B6NZOF1J_10M_05'] 1941.0 doesn't match 721.0. 229
# Sum of tissue weights from ['176_B6NZOF1J_10F_05'] 1142.0 doesn't match 984.0. 230
# Sum of tissue weights from ['177_B6NZOF1J_10M_05'] 1861.0 doesn't match 846.0. 231
# Sum of tissue weights from ['178_B6NZOF1J_10F_05'] 1467.0 doesn't match 707.0. 232
# Sum of tissue weights from ['181_B6NZOF1J_10M_05'] 1774.0 doesn't match 702.0. 233
# Sum of tissue weights from ['180_B6NZOF1J_10F_05'] 1528.0 doesn't match 841.0. 234
# Sum of tissue weights from ['183_B6NZOF1J_10M_05'] 1545.0 doesn't match 782.0. 235
# Sum of tissue weights from ['182_B6NZOF1J_10F_05'] 1600.0 doesn't match 927.0. 236
# Sum of tissue weights from ['191_B6CASTF1J_10M_05'] 1765.0 doesn't match 610.0. 237
# Sum of tissue weights from ['192_B6CASTF1J_10F_05'] 882.0 doesn't match 1005.0. 238
# Sum of tissue weights from ['193_B6CASTF1J_10M_05'] 1214.0 doesn't match 786.0. 239
# Sum of tissue weights from ['194_B6CASTF1J_10F_05'] 816.0 doesn't match 1050.0. 240
# Sum of tissue weights from ['195_B6CASTF1J_10M_05'] 1306.0 doesn't match 836.0. 241
# Sum of tissue weights from ['196_B6CASTF1J_10F_05'] 896.0 doesn't match 1123.0. 242
# Sum of tissue weights from ['197_B6CASTF1J_10M_05'] 1615.0 doesn't match 863.0. 243
# Sum of tissue weights from ['198_B6CASTF1J_10F_05'] 887.0 doesn't match 934.0. 244
# Sum of tissue weights from ['207_B6PWKF1J_10M_05'] 0 doesn't match 439.0. 245
# Sum of tissue weights from ['208_B6PWKF1J_10F_05'] 0 doesn't match 635.0. 246
# Sum of tissue weights from ['213_B6PWKF1J_10M_05'] 1235.0 doesn't match 411.0. 247
# Sum of tissue weights from ['210_B6PWKF1J_10F_05'] 0 doesn't match 638.0. 248
# Sum of tissue weights from ['215_B6PWKF1J_10M_05'] 1094.0 doesn't match 474.0. 249
# Sum of tissue weights from ['212_B6PWKF1J_10F_05'] 0 doesn't match 691.0. 250
# Sum of tissue weights from ['217_B6PWKF1J_10M_05'] 1236.0 doesn't match 520.0. 251
# Sum of tissue weights from ['214_B6PWKF1J_10F_05'] 984.0 doesn't match 658.0. 252
# Sum of tissue weights from ['223_B6WSBF1J_10M_05'] 1141.0 doesn't match 549.0. 253
# Sum of tissue weights from ['228_B6WSBF1J_10F_05'] 1743.0 doesn't match 651.0. 254
# Sum of tissue weights from ['225_B6WSBF1J_10M_05'] 991.0 doesn't match 522.0. 255
# Sum of tissue weights from ['232_B6WSBF1J_10F_05'] 977.0 doesn't match 691.0. 256
# Sum of tissue weights from ['227_B6WSBF1J_10M_05'] 950.0 doesn't match 656.0. 257
# Sum of tissue weights from ['234_B6WSBF1J_10F_05'] 0 doesn't match 682.0. 258
# Sum of tissue weights from ['229_B6WSBF1J_10M_05'] 962.0 doesn't match 482.0. 259
# Sum of tissue weights from ['236_B6WSBF1J_10F_05'] 0 doesn't match 607.0. 260
# Sum of tissue weights from ['239_TREM2R47HNSS_HO_10M_05'] 1262.0 doesn't match 2017.0. 261
# Sum of tissue weights from ['240_TREM2R47HNSS_HO_10F_05'] 1039.0 doesn't match 2064.0. 262
# Sum of tissue weights from ['241_TREM2R47HNSS_HO_10M_05'] 1176.0 doesn't match 2032.0. 263
# Sum of tissue weights from ['242_TREM2R47HNSS_HO_10F_05'] 1134.0 doesn't match 2001.0. 264
# Sum of tissue weights from ['243_TREM2R47HNSS_HO_10M_05'] 1128.0 doesn't match 1968.0. 265
# Sum of tissue weights from ['244_TREM2R47HNSS_HO_10F_05'] 1138.0 doesn't match 2157.0. 266
# Sum of tissue weights from ['245_TREM2R47HNSS_HO_10M_05'] 1311.0 doesn't match 1810.0. 267
# Sum of tissue weights from ['248_TREM2R47HNSS_HO_10F_05'] 981.0 doesn't match 1963.0. 268
# Sum of tissue weights from ['127_B6AF1J_10M_01'] 82.0 doesn't match 72.0. 305
# Sum of tissue weights from ['128_B6AF1J_10F_01'] 81.0 doesn't match 85.0. 306
# Sum of tissue weights from ['129_B6AF1J_10M_01'] 77.0 doesn't match 63.0. 307
# Sum of tissue weights from ['130_B6AF1J_10F_01'] 79.0 doesn't match 63.0. 308
# Sum of tissue weights from ['131_B6AF1J_10M_01'] 78.0 doesn't match 71.0. 309
# Sum of tissue weights from ['132_B6AF1J_10F_01'] 76.0 doesn't match 78.0. 310
# Sum of tissue weights from ['133_B6AF1J_10M_01'] 0 doesn't match 62.0. 311
# Sum of tissue weights from ['134_B6AF1J_10F_01'] 0 doesn't match 61.0. 312
# Sum of tissue weights from ['143_B6129SF1J_10M_01'] 99.0 doesn't match 68.0. 313
# Sum of tissue weights from ['144_B6129SF1J_10F_01'] 89.0 doesn't match 57.0. 314
# Sum of tissue weights from ['145_B6129SF1J_10M_01'] 88.0 doesn't match 69.0. 315
# Sum of tissue weights from ['146_B6129SF1J_10F_01'] 89.0 doesn't match 56.0. 316
# Sum of tissue weights from ['147_B6129SF1J_10M_01'] 92.0 doesn't match 51.0. 317
# Sum of tissue weights from ['148_B6129SF1J_10F_01'] 83.0 doesn't match 72.0. 318
# Sum of tissue weights from ['149_B6129SF1J_10M_01'] 83.0 doesn't match 52.0. 319
# Sum of tissue weights from ['150_B6129SF1J_10F_01'] 84.0 doesn't match 82.0. 320
# Sum of tissue weights from ['159_B6NODF1J_10M_01'] 96.0 doesn't match 42.0. 321
# Sum of tissue weights from ['160_B6NODF1J_10F_01'] 103.0 doesn't match 73.0. 322
# Sum of tissue weights from ['161_B6NODF1J_10M_01'] 107.0 doesn't match 51.0. 323
# Sum of tissue weights from ['164_B6NODF1J_10F_01'] 93.0 doesn't match 59.0. 324
# Sum of tissue weights from ['165_B6NODF1J_10M_01'] 79.0 doesn't match 55.0. 325
# Sum of tissue weights from ['166_B6NODF1J_10F_01'] 99.0 doesn't match 57.0. 326
# Sum of tissue weights from ['167_B6NODF1J_10M_01'] 105.0 doesn't match 65.0. 327
# Sum of tissue weights from ['168_B6NODF1J_10F_01'] 93.0 doesn't match 80.0. 328
# Sum of tissue weights from ['175_B6NZOF1J_10M_01'] 108.0 doesn't match 55.0. 329
# Sum of tissue weights from ['176_B6NZOF1J_10F_01'] 101.0 doesn't match 54.0. 330
# Sum of tissue weights from ['177_B6NZOF1J_10M_01'] 101.0 doesn't match 58.0. 331
# Sum of tissue weights from ['178_B6NZOF1J_10F_01'] 99.0 doesn't match 50.0. 332
# Sum of tissue weights from ['181_B6NZOF1J_10M_01'] 92.0 doesn't match 56.0. 333
# Sum of tissue weights from ['180_B6NZOF1J_10F_01'] 99.0 doesn't match 50.0. 334
# Sum of tissue weights from ['183_B6NZOF1J_10M_01'] 103.0 doesn't match 56.0. 335
# Sum of tissue weights from ['182_B6NZOF1J_10F_01'] 103.0 doesn't match 50.0. 336
# Sum of tissue weights from ['191_B6CASTF1J_10M_01'] 130.0 doesn't match 66.0. 337
# Sum of tissue weights from ['192_B6CASTF1J_10F_01'] 72.0 doesn't match 57.0. 338
# Sum of tissue weights from ['193_B6CASTF1J_10M_01'] 116.0 doesn't match 75.0. 339
# Sum of tissue weights from ['194_B6CASTF1J_10F_01'] 90.0 doesn't match 63.0. 340
# Sum of tissue weights from ['195_B6CASTF1J_10M_01'] 87.0 doesn't match 66.0. 341
# Sum of tissue weights from ['196_B6CASTF1J_10F_01'] 86.0 doesn't match 82.0. 342
# Sum of tissue weights from ['197_B6CASTF1J_10M_01'] 98.0 doesn't match 54.0. 343
# Sum of tissue weights from ['198_B6CASTF1J_10F_01'] 84.0 doesn't match 60.0. 344
# Sum of tissue weights from ['207_B6PWKF1J_10M_01'] 0 doesn't match 47.0. 345
# Sum of tissue weights from ['208_B6PWKF1J_10F_01'] 0 doesn't match 52.0. 346
# Sum of tissue weights from ['213_B6PWKF1J_10M_01'] 93.0 doesn't match 66.0. 347
# Sum of tissue weights from ['210_B6PWKF1J_10F_01'] 0 doesn't match 57.0. 348
# Sum of tissue weights from ['215_B6PWKF1J_10M_01'] 96.0 doesn't match 53.0. 349
# Sum of tissue weights from ['212_B6PWKF1J_10F_01'] 0 doesn't match 86.0. 350
# Sum of tissue weights from ['217_B6PWKF1J_10M_01'] 107.0 doesn't match 53.0. 351
# Sum of tissue weights from ['214_B6PWKF1J_10F_01'] 109.0 doesn't match 63.0. 352
# Sum of tissue weights from ['223_B6WSBF1J_10M_01'] 119.0 doesn't match 52.0. 353
# Sum of tissue weights from ['228_B6WSBF1J_10F_01'] 122.0 doesn't match 61.0. 354
# Sum of tissue weights from ['225_B6WSBF1J_10M_01'] 118.0 doesn't match 52.0. 355
# Sum of tissue weights from ['232_B6WSBF1J_10F_01'] 118.0 doesn't match 61.0. 356
# Sum of tissue weights from ['227_B6WSBF1J_10M_01'] 115.0 doesn't match 60.0. 357
# Sum of tissue weights from ['234_B6WSBF1J_10F_01'] 0 doesn't match 54.0. 358
# Sum of tissue weights from ['229_B6WSBF1J_10M_01'] 101.0 doesn't match 49.0. 359
# Sum of tissue weights from ['236_B6WSBF1J_10F_01'] 0 doesn't match 68.0. 360
# Sum of tissue weights from ['239_TREM2R47HNSS_HO_10M_01'] 121.0 doesn't match 42.0. 361
# Sum of tissue weights from ['240_TREM2R47HNSS_HO_10F_01'] 124.0 doesn't match 58.0. 362
# Sum of tissue weights from ['241_TREM2R47HNSS_HO_10M_01'] 112.0 doesn't match 54.0. 363
# Sum of tissue weights from ['242_TREM2R47HNSS_HO_10F_01'] 107.0 doesn't match 49.0. 364
# Sum of tissue weights from ['243_TREM2R47HNSS_HO_10M_01'] 117.0 doesn't match 64.0. 365
# Sum of tissue weights from ['244_TREM2R47HNSS_HO_10F_01'] 122.0 doesn't match 48.0. 366
# Sum of tissue weights from ['245_TREM2R47HNSS_HO_10M_01'] 100.0 doesn't match 56.0. 367
# Sum of tissue weights from ['248_TREM2R47HNSS_HO_10F_01'] 111.0 doesn't match 59.0. 368
# Sum of tissue weights from ['127_B6AF1J_10M_27', '127_B6AF1J_10M_29'] 0 doesn't match 33.0. 405
# Sum of tissue weights from ['128_B6AF1J_10F_10', '128_B6AF1J_10F_11'] 0 doesn't match 263.0. 406
# Sum of tissue weights from ['129_B6AF1J_10M_27', '129_B6AF1J_10M_29'] 0 doesn't match 42.0. 407
# Sum of tissue weights from ['130_B6AF1J_10F_10', '130_B6AF1J_10F_11'] 0 doesn't match 280.0. 408
# Sum of tissue weights from ['131_B6AF1J_10M_27', '131_B6AF1J_10M_29'] 0 doesn't match 40.0. 409
# Sum of tissue weights from ['132_B6AF1J_10F_10', '132_B6AF1J_10F_11'] 0 doesn't match 334.0. 410
# Sum of tissue weights from ['133_B6AF1J_10M_27', '133_B6AF1J_10M_29'] 0 doesn't match 30.0. 411
# Sum of tissue weights from ['134_B6AF1J_10F_10', '134_B6AF1J_10F_11'] 0 doesn't match 320.0. 412
# Sum of tissue weights from ['143_B6129SF1J_10M_27', '143_B6129SF1J_10M_29'] 0 doesn't match 30.0. 413
# Sum of tissue weights from ['144_B6129SF1J_10F_10', '144_B6129SF1J_10F_11'] 0 doesn't match 336.0. 414
# Sum of tissue weights from ['145_B6129SF1J_10M_27', '145_B6129SF1J_10M_29'] 0 doesn't match 28.0. 415
# Sum of tissue weights from ['146_B6129SF1J_10F_10', '146_B6129SF1J_10F_11'] 0 doesn't match 324.0. 416
# Sum of tissue weights from ['147_B6129SF1J_10M_27', '147_B6129SF1J_10M_29'] 0 doesn't match 26.0. 417
# Sum of tissue weights from ['148_B6129SF1J_10F_10', '148_B6129SF1J_10F_11'] 0 doesn't match 342.0. 418
# Sum of tissue weights from ['149_B6129SF1J_10M_27', '149_B6129SF1J_10M_29'] 0 doesn't match 31.0. 419
# Sum of tissue weights from ['150_B6129SF1J_10F_10', '150_B6129SF1J_10F_11'] 0 doesn't match 332.0. 420
# Sum of tissue weights from ['159_B6NODF1J_10M_27', '159_B6NODF1J_10M_29'] 0 doesn't match 41.0. 421
# Sum of tissue weights from ['160_B6NODF1J_10F_10', '160_B6NODF1J_10F_11'] 0 doesn't match 231.0. 422
# Sum of tissue weights from ['161_B6NODF1J_10M_27', '161_B6NODF1J_10M_29'] 0 doesn't match 39.0. 423
# Sum of tissue weights from ['164_B6NODF1J_10F_10', '164_B6NODF1J_10F_11'] 0 doesn't match 216.0. 424
# Sum of tissue weights from ['165_B6NODF1J_10M_27', '165_B6NODF1J_10M_29'] 0 doesn't match 35.0. 425
# Sum of tissue weights from ['166_B6NODF1J_10F_10', '166_B6NODF1J_10F_11'] 0 doesn't match 218.0. 426
# Sum of tissue weights from ['167_B6NODF1J_10M_27', '167_B6NODF1J_10M_29'] 0 doesn't match 31.0. 427
# Sum of tissue weights from ['168_B6NODF1J_10F_10', '168_B6NODF1J_10F_11'] 0 doesn't match 264.0. 428
# Sum of tissue weights from ['175_B6NZOF1J_10M_27', '175_B6NZOF1J_10M_29'] 0 doesn't match 24.0. 429
# Sum of tissue weights from ['176_B6NZOF1J_10F_10', '176_B6NZOF1J_10F_11'] 0 doesn't match 249.0. 430
# Sum of tissue weights from ['177_B6NZOF1J_10M_27', '177_B6NZOF1J_10M_29'] 0 doesn't match 28.0. 431
# Sum of tissue weights from ['178_B6NZOF1J_10F_10', '178_B6NZOF1J_10F_11'] 0 doesn't match 208.0. 432
# Sum of tissue weights from ['181_B6NZOF1J_10M_27', '181_B6NZOF1J_10M_29'] 0 doesn't match 33.0. 433
# Sum of tissue weights from ['180_B6NZOF1J_10F_10', '180_B6NZOF1J_10F_11'] 0 doesn't match 242.0. 434
# Sum of tissue weights from ['183_B6NZOF1J_10M_27', '183_B6NZOF1J_10M_29'] 0 doesn't match 19.0. 435
# Sum of tissue weights from ['182_B6NZOF1J_10F_10', '182_B6NZOF1J_10F_11'] 0 doesn't match 266.0. 436
# Sum of tissue weights from ['191_B6CASTF1J_10M_27', '191_B6CASTF1J_10M_29'] 0 doesn't match 27.0. 437
# Sum of tissue weights from ['192_B6CASTF1J_10F_10', '192_B6CASTF1J_10F_11'] 0 doesn't match 282.0. 438
# Sum of tissue weights from ['193_B6CASTF1J_10M_27', '193_B6CASTF1J_10M_29'] 0 doesn't match 36.0. 439
# Sum of tissue weights from ['194_B6CASTF1J_10F_10', '194_B6CASTF1J_10F_11'] 0 doesn't match 316.0. 440
# Sum of tissue weights from ['195_B6CASTF1J_10M_27', '195_B6CASTF1J_10M_29'] 0 doesn't match 34.0. 441
# Sum of tissue weights from ['196_B6CASTF1J_10F_10', '196_B6CASTF1J_10F_11'] 0 doesn't match 285.0. 442
# Sum of tissue weights from ['197_B6CASTF1J_10M_27', '197_B6CASTF1J_10M_29'] 0 doesn't match 35.0. 443
# Sum of tissue weights from ['198_B6CASTF1J_10F_10', '198_B6CASTF1J_10F_11'] 0 doesn't match 315.0. 444
# Sum of tissue weights from ['207_B6PWKF1J_10M_27', '207_B6PWKF1J_10M_29'] 0 doesn't match 28.0. 445
# Sum of tissue weights from ['208_B6PWKF1J_10F_10', '208_B6PWKF1J_10F_11'] 0 doesn't match 171.0. 446
# Sum of tissue weights from ['213_B6PWKF1J_10M_27', '213_B6PWKF1J_10M_29'] 0 doesn't match 28.0. 447
# Sum of tissue weights from ['210_B6PWKF1J_10F_10', '210_B6PWKF1J_10F_11'] 0 doesn't match 166.0. 448
# Sum of tissue weights from ['215_B6PWKF1J_10M_27', '215_B6PWKF1J_10M_29'] 0 doesn't match 24.0. 449
# Sum of tissue weights from ['212_B6PWKF1J_10F_10', '212_B6PWKF1J_10F_11'] 0 doesn't match 245.0. 450
# Sum of tissue weights from ['217_B6PWKF1J_10M_27', '217_B6PWKF1J_10M_29'] 0 doesn't match 23.0. 451
# Sum of tissue weights from ['214_B6PWKF1J_10F_10', '214_B6PWKF1J_10F_11'] 0 doesn't match 178.0. 452
# Sum of tissue weights from ['223_B6WSBF1J_10M_27', '223_B6WSBF1J_10M_29'] 0 doesn't match 11.0. 453
# Sum of tissue weights from ['228_B6WSBF1J_10F_10', '228_B6WSBF1J_10F_11'] 0 doesn't match 168.0. 454
# Sum of tissue weights from ['225_B6WSBF1J_10M_27', '225_B6WSBF1J_10M_29'] 0 doesn't match 22.0. 455
# Sum of tissue weights from ['232_B6WSBF1J_10F_10', '232_B6WSBF1J_10F_11'] 0 doesn't match 246.0. 456
# Sum of tissue weights from ['227_B6WSBF1J_10M_27', '227_B6WSBF1J_10M_29'] 0 doesn't match 19.0. 457
# Sum of tissue weights from ['234_B6WSBF1J_10F_10', '234_B6WSBF1J_10F_11'] 0 doesn't match 213.0. 458
# Sum of tissue weights from ['229_B6WSBF1J_10M_27', '229_B6WSBF1J_10M_29'] 0 doesn't match 20.0. 459
# Sum of tissue weights from ['236_B6WSBF1J_10F_10', '236_B6WSBF1J_10F_11'] 0 doesn't match 170.0. 460
# Sum of tissue weights from ['239_TREM2R47HNSS_HO_10M_27', '239_TREM2R47HNSS_HO_10M_29'] 0 doesn't match 44.0. 461
# Sum of tissue weights from ['240_TREM2R47HNSS_HO_10F_10', '240_TREM2R47HNSS_HO_10F_11'] 0 doesn't match 334.0. 462
# Sum of tissue weights from ['241_TREM2R47HNSS_HO_10M_27', '241_TREM2R47HNSS_HO_10M_29'] 0 doesn't match 43.0. 463
# Sum of tissue weights from ['242_TREM2R47HNSS_HO_10F_10', '242_TREM2R47HNSS_HO_10F_11'] 0 doesn't match 365.0. 464
# Sum of tissue weights from ['243_TREM2R47HNSS_HO_10M_27', '243_TREM2R47HNSS_HO_10M_29'] 0 doesn't match 30.0. 465
# Sum of tissue weights from ['244_TREM2R47HNSS_HO_10F_10', '244_TREM2R47HNSS_HO_10F_11'] 0 doesn't match 341.0. 466
# Sum of tissue weights from ['245_TREM2R47HNSS_HO_10M_27', '245_TREM2R47HNSS_HO_10M_29'] 0 doesn't match 40.0. 467
# Sum of tissue weights from ['248_TREM2R47HNSS_HO_10F_10', '248_TREM2R47HNSS_HO_10F_11'] 0 doesn't match 370.0. 468
# Sum of tissue weights from ['127_B6AF1J_10M_08'] 0 doesn't match 15.0. 505
# Sum of tissue weights from ['128_B6AF1J_10F_08'] 0 doesn't match 13.0. 506
# Sum of tissue weights from ['129_B6AF1J_10M_08'] 0 doesn't match 17.0. 507
# Sum of tissue weights from ['130_B6AF1J_10F_08'] 0 doesn't match 14.0. 508
# Sum of tissue weights from ['131_B6AF1J_10M_08'] 0 doesn't match 19.0. 509
# Sum of tissue weights from ['132_B6AF1J_10F_08'] 0 doesn't match 13.0. 510
# Sum of tissue weights from ['133_B6AF1J_10M_08'] 0 doesn't match 12.0. 511
# Sum of tissue weights from ['134_B6AF1J_10F_08'] 0 doesn't match 23.0. 512
# Sum of tissue weights from ['143_B6129SF1J_10M_08'] 0 doesn't match 19.0. 513
# Sum of tissue weights from ['144_B6129SF1J_10F_08'] 0 doesn't match 14.0. 514
# Sum of tissue weights from ['145_B6129SF1J_10M_08'] 0 doesn't match 20.0. 515
# Sum of tissue weights from ['146_B6129SF1J_10F_08'] 0 doesn't match 18.0. 516
# Sum of tissue weights from ['147_B6129SF1J_10M_08'] 0 doesn't match 18.0. 517
# Sum of tissue weights from ['148_B6129SF1J_10F_08'] 0 doesn't match 19.0. 518
# Sum of tissue weights from ['149_B6129SF1J_10M_08'] 0 doesn't match 17.0. 519
# Sum of tissue weights from ['150_B6129SF1J_10F_08'] 0 doesn't match 16.0. 520
# Sum of tissue weights from ['159_B6NODF1J_10M_08'] 0 doesn't match 18.0. 521
# Sum of tissue weights from ['160_B6NODF1J_10F_08'] 0 doesn't match 21.0. 522
# Sum of tissue weights from ['161_B6NODF1J_10M_08'] 0 doesn't match 27.0. 523
# Sum of tissue weights from ['164_B6NODF1J_10F_08'] 0 doesn't match 16.0. 524
# Sum of tissue weights from ['165_B6NODF1J_10M_08'] 0 doesn't match 23.0. 525
# Sum of tissue weights from ['166_B6NODF1J_10F_08'] 0 doesn't match 14.0. 526
# Sum of tissue weights from ['167_B6NODF1J_10M_08'] 0 doesn't match 16.0. 527
# Sum of tissue weights from ['168_B6NODF1J_10F_08'] 0 doesn't match 18.0. 528
# Sum of tissue weights from ['175_B6NZOF1J_10M_08'] 0 doesn't match 15.0. 529
# Sum of tissue weights from ['176_B6NZOF1J_10F_08'] 0 doesn't match 13.0. 530
# Sum of tissue weights from ['177_B6NZOF1J_10M_08'] 0 doesn't match 14.0. 531
# Sum of tissue weights from ['178_B6NZOF1J_10F_08'] 0 doesn't match 16.0. 532
# Sum of tissue weights from ['181_B6NZOF1J_10M_08'] 0 doesn't match 18.0. 533
# Sum of tissue weights from ['180_B6NZOF1J_10F_08'] 0 doesn't match 17.0. 534
# Sum of tissue weights from ['183_B6NZOF1J_10M_08'] 0 doesn't match 17.0. 535
# Sum of tissue weights from ['182_B6NZOF1J_10F_08'] 0 doesn't match 13.0. 536
# Sum of tissue weights from ['191_B6CASTF1J_10M_08'] 0 doesn't match 19.0. 537
# Sum of tissue weights from ['192_B6CASTF1J_10F_08'] 0 doesn't match 19.0. 538
# Sum of tissue weights from ['193_B6CASTF1J_10M_08'] 0 doesn't match 14.0. 539
# Sum of tissue weights from ['194_B6CASTF1J_10F_08'] 0 doesn't match 16.0. 540
# Sum of tissue weights from ['195_B6CASTF1J_10M_08'] 0 doesn't match 20.0. 541
# Sum of tissue weights from ['196_B6CASTF1J_10F_08'] 0 doesn't match 16.0. 542
# Sum of tissue weights from ['197_B6CASTF1J_10M_08'] 0 doesn't match 21.0. 543
# Sum of tissue weights from ['198_B6CASTF1J_10F_08'] 0 doesn't match 19.0. 544
# Sum of tissue weights from ['207_B6PWKF1J_10M_08'] 0 doesn't match 24.0. 545
# Sum of tissue weights from ['208_B6PWKF1J_10F_08'] 0 doesn't match 13.0. 546
# Sum of tissue weights from ['213_B6PWKF1J_10M_08'] 0 doesn't match 19.0. 547
# Sum of tissue weights from ['210_B6PWKF1J_10F_08'] 0 doesn't match 20.0. 548
# Sum of tissue weights from ['215_B6PWKF1J_10M_08'] 0 doesn't match 17.0. 549
# Sum of tissue weights from ['212_B6PWKF1J_10F_08'] 0 doesn't match 43.0. 550
# Sum of tissue weights from ['217_B6PWKF1J_10M_08'] 0 doesn't match 17.0. 551
# Sum of tissue weights from ['214_B6PWKF1J_10F_08'] 0 doesn't match 15.0. 552
# Sum of tissue weights from ['223_B6WSBF1J_10M_08'] 0 doesn't match 13.0. 553
# Sum of tissue weights from ['228_B6WSBF1J_10F_08'] 0 doesn't match 17.0. 554
# Sum of tissue weights from ['225_B6WSBF1J_10M_08'] 0 doesn't match 20.0. 555
# Sum of tissue weights from ['232_B6WSBF1J_10F_08'] 0 doesn't match 23.0. 556
# Sum of tissue weights from ['227_B6WSBF1J_10M_08'] 0 doesn't match 24.0. 557
# Sum of tissue weights from ['234_B6WSBF1J_10F_08'] 0 doesn't match 21.0. 558
# Sum of tissue weights from ['229_B6WSBF1J_10M_08'] 0 doesn't match 12.0. 559
# Sum of tissue weights from ['236_B6WSBF1J_10F_08'] 0 doesn't match 23.0. 560
# Sum of tissue weights from ['239_TREM2R47HNSS_HO_10M_08'] 0 doesn't match 24.0. 561
# Sum of tissue weights from ['240_TREM2R47HNSS_HO_10F_08'] 0 doesn't match 15.0. 562
# Sum of tissue weights from ['241_TREM2R47HNSS_HO_10M_08'] 0 doesn't match 33.0. 563
# Sum of tissue weights from ['242_TREM2R47HNSS_HO_10F_08'] 0 doesn't match 20.0. 564
# Sum of tissue weights from ['243_TREM2R47HNSS_HO_10M_08'] 0 doesn't match 35.0. 565
# Sum of tissue weights from ['244_TREM2R47HNSS_HO_10F_08'] 0 doesn't match 20.0. 566
# Sum of tissue weights from ['245_TREM2R47HNSS_HO_10M_08'] 0 doesn't match 27.0. 567
# Sum of tissue weights from ['248_TREM2R47HNSS_HO_10F_08'] 0 doesn't match 21.0. 568
# Sum of tissue weights from ['127_B6AF1J_10M_31'] 0 doesn't match 301.0. 605
# Sum of tissue weights from ['128_B6AF1J_10F_31'] 0 doesn't match 431.0. 606
# Sum of tissue weights from ['129_B6AF1J_10M_31'] 0 doesn't match 287.0. 607
# Sum of tissue weights from ['130_B6AF1J_10F_31'] 0 doesn't match 390.0. 608
# Sum of tissue weights from ['131_B6AF1J_10M_31'] 0 doesn't match 266.0. 609
# Sum of tissue weights from ['132_B6AF1J_10F_31'] 0 doesn't match 381.0. 610
# Sum of tissue weights from ['133_B6AF1J_10M_31'] 0 doesn't match 277.0. 611
# Sum of tissue weights from ['134_B6AF1J_10F_31'] 0 doesn't match 401.0. 612
# Sum of tissue weights from ['143_B6129SF1J_10M_31'] 0 doesn't match 234.0. 613
# Sum of tissue weights from ['144_B6129SF1J_10F_31'] 0 doesn't match 465.0. 614
# Sum of tissue weights from ['145_B6129SF1J_10M_31'] 0 doesn't match 269.0. 615
# Sum of tissue weights from ['146_B6129SF1J_10F_31'] 0 doesn't match 435.0. 616
# Sum of tissue weights from ['147_B6129SF1J_10M_31'] 0 doesn't match 264.0. 617
# Sum of tissue weights from ['148_B6129SF1J_10F_31'] 0 doesn't match 464.0. 618
# Sum of tissue weights from ['149_B6129SF1J_10M_31'] 0 doesn't match 267.0. 619
# Sum of tissue weights from ['150_B6129SF1J_10F_31'] 0 doesn't match 439.0. 620
# Sum of tissue weights from ['159_B6NODF1J_10M_31'] 0 doesn't match 320.0. 621
# Sum of tissue weights from ['160_B6NODF1J_10F_31'] 0 doesn't match 323.0. 622
# Sum of tissue weights from ['161_B6NODF1J_10M_31'] 0 doesn't match 299.0. 623
# Sum of tissue weights from ['164_B6NODF1J_10F_31'] 0 doesn't match 240.0. 624
# Sum of tissue weights from ['165_B6NODF1J_10M_31'] 0 doesn't match 314.0. 625
# Sum of tissue weights from ['166_B6NODF1J_10F_31'] 0 doesn't match 382.0. 626
# Sum of tissue weights from ['167_B6NODF1J_10M_31'] 0 doesn't match 320.0. 627
# Sum of tissue weights from ['168_B6NODF1J_10F_31'] 0 doesn't match 396.0. 628
# Sum of tissue weights from ['175_B6NZOF1J_10M_31'] 0 doesn't match 231.0. 629
# Sum of tissue weights from ['176_B6NZOF1J_10F_31'] 0 doesn't match 291.0. 630
# Sum of tissue weights from ['177_B6NZOF1J_10M_31'] 0 doesn't match 234.0. 631
# Sum of tissue weights from ['178_B6NZOF1J_10F_31'] 0 doesn't match 246.0. 632
# Sum of tissue weights from ['181_B6NZOF1J_10M_31'] 0 doesn't match 225.0. 633
# Sum of tissue weights from ['180_B6NZOF1J_10F_31'] 0 doesn't match 271.0. 634
# Sum of tissue weights from ['183_B6NZOF1J_10M_31'] 0 doesn't match 240.0. 635
# Sum of tissue weights from ['182_B6NZOF1J_10F_31'] 0 doesn't match 326.0. 636
# Sum of tissue weights from ['191_B6CASTF1J_10M_31'] 0 doesn't match 267.0. 637
# Sum of tissue weights from ['192_B6CASTF1J_10F_31'] 0 doesn't match 400.0. 638
# Sum of tissue weights from ['193_B6CASTF1J_10M_31'] 0 doesn't match 316.0. 639
# Sum of tissue weights from ['194_B6CASTF1J_10F_31'] 0 doesn't match 415.0. 640
# Sum of tissue weights from ['195_B6CASTF1J_10M_31'] 0 doesn't match 276.0. 641
# Sum of tissue weights from ['196_B6CASTF1J_10F_31'] 0 doesn't match 409.0. 642
# Sum of tissue weights from ['197_B6CASTF1J_10M_31'] 0 doesn't match 310.0. 643
# Sum of tissue weights from ['198_B6CASTF1J_10F_31'] 0 doesn't match 410.0. 644
# Sum of tissue weights from ['207_B6PWKF1J_10M_31'] 0 doesn't match 178.0. 645
# Sum of tissue weights from ['208_B6PWKF1J_10F_31'] 0 doesn't match 230.0. 646
# Sum of tissue weights from ['213_B6PWKF1J_10M_31'] 0 doesn't match 172.0. 647
# Sum of tissue weights from ['210_B6PWKF1J_10F_31'] 0 doesn't match 239.0. 648
# Sum of tissue weights from ['215_B6PWKF1J_10M_31'] 0 doesn't match 190.0. 649
# Sum of tissue weights from ['212_B6PWKF1J_10F_31'] 0 doesn't match 286.0. 650
# Sum of tissue weights from ['217_B6PWKF1J_10M_31'] 0 doesn't match 189.0. 651
# Sum of tissue weights from ['214_B6PWKF1J_10F_31'] 0 doesn't match 242.0. 652
# Sum of tissue weights from ['223_B6WSBF1J_10M_31'] 0 doesn't match 226.0. 653
# Sum of tissue weights from ['228_B6WSBF1J_10F_31'] 0 doesn't match 331.0. 654
# Sum of tissue weights from ['225_B6WSBF1J_10M_31'] 0 doesn't match 258.0. 655
# Sum of tissue weights from ['232_B6WSBF1J_10F_31'] 0 doesn't match 357.0. 656
# Sum of tissue weights from ['227_B6WSBF1J_10M_31'] 0 doesn't match 233.0. 657
# Sum of tissue weights from ['234_B6WSBF1J_10F_31'] 0 doesn't match 325.0. 658
# Sum of tissue weights from ['229_B6WSBF1J_10M_31'] 0 doesn't match 218.0. 659
# Sum of tissue weights from ['236_B6WSBF1J_10F_31'] 0 doesn't match 302.0. 660
# Sum of tissue weights from ['239_TREM2R47HNSS_HO_10M_31'] 0 doesn't match 443.0. 661
# Sum of tissue weights from ['240_TREM2R47HNSS_HO_10F_31'] 0 doesn't match 612.0. 662
# Sum of tissue weights from ['241_TREM2R47HNSS_HO_10M_31'] 0 doesn't match 479.0. 663
# Sum of tissue weights from ['242_TREM2R47HNSS_HO_10F_31'] 0 doesn't match 622.0. 664
# Sum of tissue weights from ['243_TREM2R47HNSS_HO_10M_31'] 0 doesn't match 440.0. 665
# Sum of tissue weights from ['244_TREM2R47HNSS_HO_10F_31'] 0 doesn't match 616.0. 666
# Sum of tissue weights from ['245_TREM2R47HNSS_HO_10M_31'] 0 doesn't match 420.0. 667
# Sum of tissue weights from ['248_TREM2R47HNSS_HO_10F_31'] 0 doesn't match 602.0. 668
# Sum of tissue weights from ['127_B6AF1J_10M_33'] 0 doesn't match 226.0. 705
# Sum of tissue weights from ['128_B6AF1J_10F_33'] 0 doesn't match 336.0. 706
# Sum of tissue weights from ['129_B6AF1J_10M_33'] 0 doesn't match 277.0. 707
# Sum of tissue weights from ['130_B6AF1J_10F_33'] 0 doesn't match 353.0. 708
# Sum of tissue weights from ['131_B6AF1J_10M_33'] 0 doesn't match 248.0. 709
# Sum of tissue weights from ['132_B6AF1J_10F_33'] 0 doesn't match 330.0. 710
# Sum of tissue weights from ['133_B6AF1J_10M_33'] 0 doesn't match 253.0. 711
# Sum of tissue weights from ['134_B6AF1J_10F_33'] 0 doesn't match 357.0. 712
# Sum of tissue weights from ['143_B6129SF1J_10M_33'] 0 doesn't match 188.0. 713
# Sum of tissue weights from ['144_B6129SF1J_10F_33'] 0 doesn't match 289.0. 714
# Sum of tissue weights from ['146_B6129SF1J_10F_33'] 0 doesn't match 276.0. 716
# Sum of tissue weights from ['147_B6129SF1J_10M_33'] 0 doesn't match 228.0. 717
# Sum of tissue weights from ['148_B6129SF1J_10F_33'] 0 doesn't match 316.0. 718
# Sum of tissue weights from ['149_B6129SF1J_10M_33'] 0 doesn't match 192.0. 719
# Sum of tissue weights from ['150_B6129SF1J_10F_33'] 0 doesn't match 283.0. 720
# Sum of tissue weights from ['159_B6NODF1J_10M_33'] 0 doesn't match 252.0. 721
# Sum of tissue weights from ['160_B6NODF1J_10F_33'] 0 doesn't match 280.0. 722
# Sum of tissue weights from ['161_B6NODF1J_10M_33'] 0 doesn't match 222.0. 723
# Sum of tissue weights from ['164_B6NODF1J_10F_33'] 0 doesn't match 220.0. 724
# Sum of tissue weights from ['165_B6NODF1J_10M_33'] 0 doesn't match 235.0. 725
# Sum of tissue weights from ['166_B6NODF1J_10F_33'] 0 doesn't match 258.0. 726
# Sum of tissue weights from ['175_B6NZOF1J_10M_33'] 0 doesn't match 146.0. 729
# Sum of tissue weights from ['176_B6NZOF1J_10F_33'] 0 doesn't match 176.0. 730
# Sum of tissue weights from ['177_B6NZOF1J_10M_33'] 0 doesn't match 167.0. 731
# Sum of tissue weights from ['178_B6NZOF1J_10F_33'] 0 doesn't match 154.0. 732
# Sum of tissue weights from ['181_B6NZOF1J_10M_33'] 0 doesn't match 154.0. 733
# Sum of tissue weights from ['180_B6NZOF1J_10F_33'] 0 doesn't match 182.0. 734
# Sum of tissue weights from ['183_B6NZOF1J_10M_33'] 0 doesn't match 150.0. 735
# Sum of tissue weights from ['182_B6NZOF1J_10F_33'] 0 doesn't match 211.0. 736
# Sum of tissue weights from ['192_B6CASTF1J_10F_33'] 0 doesn't match 262.0. 738
# Sum of tissue weights from ['193_B6CASTF1J_10M_33'] 0 doesn't match 238.0. 739
# Sum of tissue weights from ['194_B6CASTF1J_10F_33'] 0 doesn't match 258.0. 740
# Sum of tissue weights from ['195_B6CASTF1J_10M_33'] 0 doesn't match 218.0. 741
# Sum of tissue weights from ['196_B6CASTF1J_10F_33'] 0 doesn't match 257.0. 742
# Sum of tissue weights from ['197_B6CASTF1J_10M_33'] 0 doesn't match 214.0. 743
# Sum of tissue weights from ['198_B6CASTF1J_10F_33'] 0 doesn't match 239.0. 744
# Sum of tissue weights from ['207_B6PWKF1J_10M_33'] 0 doesn't match 193.0. 745
# Sum of tissue weights from ['208_B6PWKF1J_10F_33'] 0 doesn't match 207.0. 746
# Sum of tissue weights from ['210_B6PWKF1J_10F_33'] 0 doesn't match 225.0. 748
# Sum of tissue weights from ['215_B6PWKF1J_10M_33'] 0 doesn't match 203.0. 749
# Sum of tissue weights from ['212_B6PWKF1J_10F_33'] 0 doesn't match 242.0. 750
# Sum of tissue weights from ['217_B6PWKF1J_10M_33'] 0 doesn't match 195.0. 751
# Sum of tissue weights from ['214_B6PWKF1J_10F_33'] 0 doesn't match 224.0. 752
# Sum of tissue weights from ['223_B6WSBF1J_10M_33'] 0 doesn't match 162.0. 753
# Sum of tissue weights from ['228_B6WSBF1J_10F_33'] 0 doesn't match 216.0. 754
# Sum of tissue weights from ['232_B6WSBF1J_10F_33'] 0 doesn't match 237.0. 756
# Sum of tissue weights from ['227_B6WSBF1J_10M_33'] 0 doesn't match 192.0. 757
# Sum of tissue weights from ['234_B6WSBF1J_10F_33'] 0 doesn't match 241.0. 758
# Sum of tissue weights from ['229_B6WSBF1J_10M_33'] 0 doesn't match 183.0. 759
# Sum of tissue weights from ['236_B6WSBF1J_10F_33'] 0 doesn't match 236.0. 760
# Sum of tissue weights from ['239_TREM2R47HNSS_HO_10M_33'] 0 doesn't match 270.0. 761
# Sum of tissue weights from ['240_TREM2R47HNSS_HO_10F_33'] 0 doesn't match 359.0. 762
# Sum of tissue weights from ['241_TREM2R47HNSS_HO_10M_33'] 0 doesn't match 298.0. 763
# Sum of tissue weights from ['242_TREM2R47HNSS_HO_10F_33'] 0 doesn't match 340.0. 764
# Sum of tissue weights from ['243_TREM2R47HNSS_HO_10M_33'] 0 doesn't match 268.0. 765
# Sum of tissue weights from ['244_TREM2R47HNSS_HO_10F_33'] 0 doesn't match 308.0. 766
# Sum of tissue weights from ['245_TREM2R47HNSS_HO_10M_33'] 0 doesn't match 286.0. 767
# Sum of tissue weights from ['248_TREM2R47HNSS_HO_10F_33'] 0 doesn't match 330.0. 768

# %%
# According to Liz this sheet isn't ready yet.
# load_samples_into_experiment(lizs_sheet_name, "CC Samples into experiment", header=1)

# %% [markdown]
# # Plate layout
#
# (the hard thing)

# %%
WellContent = namedtuple("well_content", ["genotype", "tissue_id"])


def get_genotype_from_tissue(tissue_id):
    assert pandas.notnull(tissue_id)

    fields = tissue_id.split("_")
    assert len(fields) == 4, f"Field label validation fail {tissue_id}, not enough fields {len(fields)}"

    return normalize_strain(fields[1])

assert get_genotype_from_tissue("016_B6J_10F_20") == "B6J"
assert get_genotype_from_tissue("046_NZOJ_10F_03") == "NZOJ"
assert get_genotype_from_tissue("198_B6CASTF1/J_10F_20") == "B6CASTF1J"



def validate_tissue_ids(contents, expected_genotypes):
    for expected, (row_index, row) in zip(expected_genotypes, contents.iterrows()):
        for cell in row:
            fields = cell.split("_")
            assert len(fields) == 4, f"Field label validation fail {cell}"
            # there's a few sample swaps, don't validate them.
            if expected == "Mixed":
                continue
            elif fields[1] not in ("092_CASTJ_10F_03"):
                assert fields[1] == expected, f"{fields[1]} failed to match {expected}"


def is_plate_name(name):
    return not pandas.isnull(name) and name.startswith("IGVF_")

def find_plate_start(sheet, offsets):
    block_headers = [
        "M","F","Mixed","B6J","NODJ","AJ","PWKJ","129S1J","CASTJ","WSBJ","NZOJ","B6CASTF1/J","B6PWKF1/J","B6WSBF1/J","B6NODF1/J"
    ]
    for plate_id_row in sheet[sheet[offsets["plate_label"]].apply(is_plate_name)].index:
        plate_name = normalize_plate_name(sheet.loc[plate_id_row, offsets["plate_label"]])
        for i in range(plate_id_row, plate_id_row + 4):
            cell = sheet.loc[i, offsets["well_start"]]
            if isinstance(cell, str) and (cell.startswith("Tissue") or cell in block_headers):
                yield (plate_name, i)
                
def get_plate_genotype(sheet, start, offsets):
    plate_tissues = []
    for cell in sheet.loc[start+2:start+9, offsets["tissue_label"]].tolist():
        if not pandas.isnull(cell):
            match = re.match("(B6J|NODJ|AJ|PWKJ|129S1J|CASTJ|WSBJ|NZOJ|Mixed)", cell, re.IGNORECASE)
            if match is not None:
                plate_tissues.append(match.group(0))
            else:
                print("Diffculty matching {} in {} {}".format(cell, start+2, start+9))
    
    return plate_tissues


def validate_plate_column_ids(plate_column_ids):
    expected_column_ids = set(range(1,13))
    for column_id in plate_column_ids:
        assert column_id in expected_column_ids, f"{column_id} {type(column_id)} not in expected_column_ids"
    
def validate_plate_row_ids(plate_row_labels):
    expected_row_labels = set(("A", "B", "C", "D", "E", "F", "G", "H"))
    for row_label in plate_row_labels:
        assert row_label in expected_row_labels, f"{row_label} not in expected labels"
    
def parse_single_well_block(sheet, plate_start, offsets):
    # column ids
    simple_plate_column_ids = sheet.loc[plate_start+1, offsets["well_range"]].tolist()
    validate_plate_column_ids(simple_plate_column_ids)

    plate_row_labels = sheet.loc[plate_start+2:plate_start+9, offsets["well_row_label"]].dropna().tolist()
    validate_plate_row_ids(plate_row_labels)

    contents = sheet.loc[plate_start+2:plate_start+len(plate_row_labels)+1, offsets["well_range"]].copy()
    contents.index = plate_row_labels
    contents.columns = simple_plate_column_ids
    contents = contents.dropna()

    genotypes = get_plate_genotype(sheet, plate_start, offsets)
    validate_tissue_ids(contents, genotypes)

    well_contents = {}
    for well_row, row in contents.iterrows():
        for well_column, tissue_cell in zip(simple_plate_column_ids, row):
            genotype = get_genotype_from_tissue(tissue_cell)
            well_contents[(well_row, str(well_column))] = [WellContent(genotype, tissue_cell)]

    return well_contents

def parse_multiplexed_well_block(sheet, start, expected_genotypes, offsets):
    well_re = re.compile("^[A-H]1?[\d]$")
    wells = sheet.loc[start+3, offsets["well_range"]].tolist()
    for cell in wells:
        if pandas.isnull(cell) or well_re.match(cell) is None:
            raise ValueError(f"well value {cell} in row {start+3} does not look correct")

    contents = sheet.loc[start+0:start+1, offsets["well_range"]]
    contents.columns = [(x[0], x[1:]) for x in wells]
    validate_tissue_ids(contents, expected_genotypes)
    contents.index = expected_genotypes

    well_contents = {}
    for expected_genotype, row in contents.dropna().iterrows():
        for well, tissue_id in row.iteritems():
            genotype = get_genotype_from_tissue(tissue_id)
            well_contents.setdefault(well, []).append(WellContent(genotype, tissue_id))

    return well_contents

def parse_plate(sheet):
    max_rows_from_plate_name_to_well_names = 4

    offsets = {
        "plate_label": 1,
        "tissue_label": 1,
        "well_row_label": 2,
        "well_start": 3,
        "well_range": slice(3, 10),
    }
    offsets_simple = offsets.copy()
    offsets_simple["well_range"] = slice(3, 14)

    for plate_name, plate_start in find_plate_start(sheet, offsets):
        if plate_name.endswith("XX"):
            return

        well_contents = {}
        genotypes = get_plate_genotype(sheet, plate_start, offsets)
        
        if plate_name in ("IGVF_B01", "IGVF_012", "IGVF_013", "IGVF_014"):
            well_contents.update(parse_single_well_block(sheet, plate_start, offsets_simple))
            complex_blocks = []        
        else:
            well_contents.update(parse_single_well_block(sheet, plate_start, offsets))

            complex_blocks = [
                (plate_start + 12, slice(0, 2)),
                (plate_start + 12 + 5, slice(2, 4)),
                (plate_start + 12 + 10, slice(4, 6)),
                (plate_start + 12 + 15, slice(6, 8)),
            ]

            for complex_start, genotype_slice in complex_blocks:
                expected_genotypes = genotypes[genotype_slice]
                well_contents.update(parse_multiplexed_well_block(sheet, complex_start, expected_genotypes, offsets))
        
        yield (plate_name, well_contents)
        
offsets = {
    "plate_label": 1,
    "tissue_label": 1,
    "well_row_label": 2,
    "well_start": 3,
    "well_range": slice(3, 14),
}

# %%
        
plate_layout = pandas.read_excel(
    lizs_sheet_name, 
    sheet_name="Plate setups",
    header=None,
)


for plate_name, plate_contents in parse_plate(plate_layout):
    print(plate_name, len(plate_contents))
# Out:
# IGVF_003 96
# IGVF_004 96
# IGVF_005 96
# IGVF_006 96
# IGVF_007 96
# IGVF_008 96
# IGVF_008B 96
# IGVF_B01 48
# IGVF_009 96
# IGVF_010 96
# IGVF_011 96
# IGVF_012 48
# IGVF_013 96
# IGVF_014 48

# %%
# half height 4 row plates
well_contents = parse_single_well_block(plate_layout, 257, offsets)
assert len(well_contents) == 48, f"{len(well_contents)}"

well_contents = parse_single_well_block(plate_layout, 395, offsets)
assert len(well_contents) == 48, f"{len(well_contents)}"

# Full length 8 row plate
well_contents = parse_single_well_block(plate_layout, 406, offsets)
assert len(well_contents) == 96, f"{len(well_contents)}"
#print(well_contents)

# %%
models.LibraryConstructionReagent.objects.all()
# Out:
# <QuerySet [<LibraryConstructionReagent: Parse WT Mega v2>, <LibraryConstructionReagent: Parse WT v2>]>

# %%
def guess_barcode_reagent_from_plate(plate_name):
    # Depend on a global to avoid hitting the database a bunch
    wt_mega_2_reagent = models.LibraryConstructionReagent.objects.get(name="wt-mega", version="v2")
    wt_regular_2_reagent = models.LibraryConstructionReagent.objects.get(name="wt", version="v2")    
    
    if plate_name in ("IGVF_B01", "IGVF_012"):
        reagent = wt_regular_2_reagent
    else:
        reagent = wt_mega_2_reagent

    return reagent

assert str(guess_barcode_reagent_from_plate("IGVF_003")) == "Parse WT Mega v2"
assert str(guess_barcode_reagent_from_plate("IGVF_012")) == "Parse WT v2"

def load_plates(plate_layout):
    # Validate tissue references:
    failed = False
    for plate_name, plate_contents in parse_plate(plate_layout):
        for well_id in plate_contents:
            well_contents = plate_contents[well_id]

            for well_fraction in well_contents:
                tissue_id = normalize_strain(well_fraction.tissue_id)
                try:
                    biosample = models.FixedSample.objects.get(name=tissue_id)
                except models.FixedSample.DoesNotExist:
                    print(f"Unable to find {tissue_id} on plate {plate_name}")
                    failed = True

    #assert not failed, "Resolve tissues"

    # populate database
    if models.SplitSeqWell.biosample.through.objects.count() > 0:
        truncate(models.SplitSeqWell.biosample.through)

    if models.SplitSeqWell.objects.count() > 0:
        truncate(models.SplitSeqWell)

    if models.SplitSeqPlate.objects.count() > 0:
        truncate(models.SplitSeqPlate)

    errors = 0
    plates_loaded = set()

    for plate_name, plate_contents in parse_plate(plate_layout):
        plates_loaded.add(plate_name)
        plate_record = models.SplitSeqPlate(
            name=plate_name,
            size=models.PlateSizeEnum.size_96,
            pool_location=None,
            date_performed=None,
        )
        plate_record.save()

        for well_id in plate_contents:
            well_contents = plate_contents[well_id]

            biosamples = []
            for well_content in well_contents:
                tissue_id = normalize_strain(well_content.tissue_id)
                try:
                    biosamples.append(models.FixedSample.objects.get(name=tissue_id))
                except models.FixedSample.DoesNotExist:
                    print(f"unable to find tissue {tissue_id} for {plate_name} {well_id}")
                    errors += 1


            reagent = guess_barcode_reagent_from_plate(plate_name)

            barcodes = models.LibraryBarcode.objects.filter(
                reagent=reagent,
                code="{}{}".format(well_id[0], well_id[1]),
            )

            well_record = models.SplitSeqWell(
                plate=plate_record,
                row=well_id[0],
                column=well_id[1],
            )
            well_record.save()
            well_record.biosample.set(biosamples)
            well_record.barcode.set(barcodes)
            well_record.save()

    assert not errors, "Check error messages"
    assert "IGVF_008B" in plates_loaded, "Remember to make copied IGVF_008B plate"
    assert "IGVF_012" in plates_loaded, "Still having trouble with IGVF_012"
    
load_plates(plate_layout)

# %%
[x for x in models.Tissue.objects.all() if x.name.startswith("191_B6CAST")]
# Out:
# [<Tissue: 191_B6CASTF1J_10M_01 Hypothalamus/Pituitary>,
#  <Tissue: 191_B6CASTF1J_10M_03 Cortex/Hippocampus left>,
#  <Tissue: 191_B6CASTF1J_10M_04 Cortex/Hippocampus right>,
#  <Tissue: 191_B6CASTF1J_10M_05 Liver>,
#  <Tissue: 191_B6CASTF1J_10M_06 Heart>,
#  <Tissue: 191_B6CASTF1J_10M_08 Adrenal>,
#  <Tissue: 191_B6CASTF1J_10M_19 Tail>,
#  <Tissue: 191_B6CASTF1J_10M_20 PBMC - WBC>,
#  <Tissue: 191_B6CASTF1J_10M_27 Testis left>,
#  <Tissue: 191_B6CASTF1J_10M_28 Testis right>,
#  <Tissue: 191_B6CASTF1J_10M_29 Epididymis left>,
#  <Tissue: 191_B6CASTF1J_10M_30 Epididymis right>,
#  <Tissue: 191_B6CASTF1J_10M_31 Kidney left>,
#  <Tissue: 191_B6CASTF1J_10M_32 Kidney right>,
#  <Tissue: 191_B6CASTF1J_10M_33 Gastrocnemius left>,
#  <Tissue: 191_B6CASTF1J_10M_34 Gastrocnemius right>]

# %% [markdown]
# # Submitted measurement sets

# %%
def load_submitted_measurement_sets():
    measurement_sets = {}

    for accession_prefix in submitted_sheets:
        for i, row in submitted_sheets[accession_prefix]["measurement_set"].iterrows():
            if not pandas.isnull(row["accession"]):
                aliases = row["aliases:array"].split(',')
                name = aliases[0].replace("ali-mortazavi:", "")

                try:
                    record = models.MeasurementSet.objects.get(name=name)
                except models.MeasurementSet.DoesNotExist:
                    record = models.MeasurementSet(
                        name=name,
                    )
                    record.save()

                    if accession_prefix == "igvftst":
                        see_also_template = "https://api.sandbox.igvf.org/measurment-sets/{}/"
                    elif accession_prefix == "igvf":
                        see_also_template = "https://api.data.igvf.org/measurement-sets/{}/"

                    accession = models.Accession(
                        accession_prefix=accession_prefix,
                        name=row["accession"],
                        uuid=row["uuid"],
                        see_also=see_also_template.format(row["accession"]),
                    )
                    accession.save()
                    record.accession.add(accession)
                    record.save()
                measurement_sets[name] = record
    print("loaded", len(measurement_sets), "measurement_sets")
    return measurement_sets

# %% [markdown]
# # Subpool
#
# ## Extract meaning from the Experiments tab

# %% [markdown]
# - number of nuclei per subpool (Experiment)
# - cDNA amp # PCR cycles (Experiment)
# - cDNA ng/ul in 25ul (experiment)
# - total cDNA ng (experiment)
# - Bioanalyzer cDNA ave bp length (expierment)
# - Sub library Index PCR # (experiment)
# - Sublibrary Index (experiment)
# - Sequence for SampleSheet (experiment)
# - library ng/ul (experiment)
# - Bioanalyzer library ave bp length (experiment)
# - Nextseq run number (experiment)
#
# - number of 67k aliquots  (experiment)
# - number of 8k aliquots (experiment)
#
# - QC # raw reads (1 mismatch) (experiment)

# %%
experiment = pandas.read_excel(
    lizs_sheet_name, 
    sheet_name="Experiment",
    header=0,
    index_col=None,
    #usecols=range(0, 49)
)
experiment
# Out:
#              Experiment          mice  Fixation Box Split-seq prep start date  \
# 0     IGVF_Splitseq_002    B6 (2F+2M)  IGVF_FIX_001                2022-08-24
# 1                   NaN  CAST (2F+2M)  IGVF_FIX_002                       NaT
# 2           Fixation V1           NaN           NaN                       NaT
# 3                 1M V1           NaN           NaN                       NaT
# 4                   NaN           NaN           NaN                       NaT
# ...                 ...           ...           ...                       ...
# 1009                NaN           NaN           NaN                       NaT
# 1010                NaN           NaN           NaN                       NaT
# 1011                NaN           NaN           NaN                       NaT
# 1012                NaN           NaN           NaN                       NaT
# 1013                NaN           NaN           NaN                       NaT
#
#      Submit Sublibrary [Barcoded Nuclei] (nuclei/uL)  \
# 0        No     002_4A                          4540
# 1        No     002_4B                           NaN
# 2        No    002_64A                           NaN
# 3        No    002_64B                           NaN
# 4        No    002_64C                           NaN
# ...     ...        ...                           ...
# 1009    NaN        NaN                           NaN
# 1010    NaN        NaN                           NaN
# 1011    NaN        NaN                           NaN
# 1012    NaN        NaN                           NaN
# 1013    NaN        NaN                           NaN
#
#       Barcoded Nuclei Vol. (uL) Total barcoded nuclei (1st 3 rounds)  \
# 0                         240.0                              1089600
# 1                           NaN                                  NaN
# 2                           NaN                        Target Nuclei
# 3                           NaN                              1018000
# 4                           NaN                        Excess Nuclei
# ...                         ...                                  ...
# 1009                        NaN                                  NaN
# 1010                        NaN                                  NaN
# 1011                        NaN                                  NaN
# 1012                        NaN                                  NaN
# 1013                        NaN                                  NaN
#
#       # of backup aliquots  ... Unnamed: 54  Unnamed: 55  Unnamed: 56  \
# 0                      3.0  ...         NaN          NaN          NaN
# 1                      NaN  ...         NaN          NaN          NaN
# 2                      NaN  ...         NaN          NaN          NaN
# 3                      NaN  ...         NaN          NaN          NaN
# 4                      NaN  ...         NaN          NaN          NaN
# ...                    ...  ...         ...          ...          ...
# 1009                   NaN  ...         NaN          NaN          NaN
# 1010                   NaN  ...         NaN          NaN          NaN
# 1011                   NaN  ...         NaN          NaN          NaN
# 1012                   NaN  ...         NaN          NaN          NaN
# 1013                   NaN  ...         NaN          NaN          NaN
#
#       Unnamed: 57 Unnamed: 58 Unnamed: 59 Unnamed: 60 Unnamed: 61  \
# 0             NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...
# 1009          NaN         NaN         NaN         NaN         NaN
# 1010          NaN         NaN         NaN         NaN         NaN
# 1011          NaN         NaN         NaN         NaN         NaN
# 1012          NaN         NaN         NaN         NaN         NaN
# 1013          NaN         NaN         NaN         NaN         NaN
#
#       Unnamed: 62  Unnamed: 63
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ...           ...          ...
# 1009          NaN          NaN
# 1010          NaN          NaN
# 1011          NaN          NaN
# 1012          NaN          NaN
# 1013          NaN          NaN
#
# [1014 rows x 64 columns]

# %%
experiment = pandas.read_excel(
    lizs_sheet_name, 
    sheet_name="Experiment",
    header=0,
    index_col=None,
    #usecols=range(0, 49)
).rename(columns={
    # Unnamed: 42 seems like an index or reference to the sample sheet?
    "Unnamed: 43": "Novaseq raw reads",
    "Unnamed: 44": "Novaseq1 L001",
    "Unnamed: 45": "Novaseq1 L002",
    "Unnamed: 46": "Novaseq1 L003",
    "Unnamed: 47": "Novaseq1 L004",
    "Unnamed: 48": "Novaseq2 L001",
    "Unnamed: 49": "Novaseq2 L002",
    "Unnamed: 50": "Novaseq2 L003",
    "Unnamed: 51": "Novaseq2 L004",
})

experiment
# Out:
#              Experiment          mice  Fixation Box Split-seq prep start date  \
# 0     IGVF_Splitseq_002    B6 (2F+2M)  IGVF_FIX_001                2022-08-24
# 1                   NaN  CAST (2F+2M)  IGVF_FIX_002                       NaT
# 2           Fixation V1           NaN           NaN                       NaT
# 3                 1M V1           NaN           NaN                       NaT
# 4                   NaN           NaN           NaN                       NaT
# ...                 ...           ...           ...                       ...
# 1009                NaN           NaN           NaN                       NaT
# 1010                NaN           NaN           NaN                       NaT
# 1011                NaN           NaN           NaN                       NaT
# 1012                NaN           NaN           NaN                       NaT
# 1013                NaN           NaN           NaN                       NaT
#
#      Submit Sublibrary [Barcoded Nuclei] (nuclei/uL)  \
# 0        No     002_4A                          4540
# 1        No     002_4B                           NaN
# 2        No    002_64A                           NaN
# 3        No    002_64B                           NaN
# 4        No    002_64C                           NaN
# ...     ...        ...                           ...
# 1009    NaN        NaN                           NaN
# 1010    NaN        NaN                           NaN
# 1011    NaN        NaN                           NaN
# 1012    NaN        NaN                           NaN
# 1013    NaN        NaN                           NaN
#
#       Barcoded Nuclei Vol. (uL) Total barcoded nuclei (1st 3 rounds)  \
# 0                         240.0                              1089600
# 1                           NaN                                  NaN
# 2                           NaN                        Target Nuclei
# 3                           NaN                              1018000
# 4                           NaN                        Excess Nuclei
# ...                         ...                                  ...
# 1009                        NaN                                  NaN
# 1010                        NaN                                  NaN
# 1011                        NaN                                  NaN
# 1012                        NaN                                  NaN
# 1013                        NaN                                  NaN
#
#       # of backup aliquots  ... Unnamed: 54  Unnamed: 55  Unnamed: 56  \
# 0                      3.0  ...         NaN          NaN          NaN
# 1                      NaN  ...         NaN          NaN          NaN
# 2                      NaN  ...         NaN          NaN          NaN
# 3                      NaN  ...         NaN          NaN          NaN
# 4                      NaN  ...         NaN          NaN          NaN
# ...                    ...  ...         ...          ...          ...
# 1009                   NaN  ...         NaN          NaN          NaN
# 1010                   NaN  ...         NaN          NaN          NaN
# 1011                   NaN  ...         NaN          NaN          NaN
# 1012                   NaN  ...         NaN          NaN          NaN
# 1013                   NaN  ...         NaN          NaN          NaN
#
#       Unnamed: 57 Unnamed: 58 Unnamed: 59 Unnamed: 60 Unnamed: 61  \
# 0             NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...
# 1009          NaN         NaN         NaN         NaN         NaN
# 1010          NaN         NaN         NaN         NaN         NaN
# 1011          NaN         NaN         NaN         NaN         NaN
# 1012          NaN         NaN         NaN         NaN         NaN
# 1013          NaN         NaN         NaN         NaN         NaN
#
#       Unnamed: 62  Unnamed: 63
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ...           ...          ...
# 1009          NaN          NaN
# 1010          NaN          NaN
# 1011          NaN          NaN
# 1012          NaN          NaN
# 1013          NaN          NaN
#
# [1014 rows x 64 columns]

# %%
def is_experiment_name(name):
    not_submittable = ["IGVF_Splitseq_EX"]
    return not pandas.isnull(name) and name.startswith("IGVF_Splitseq")

experiment[experiment["Experiment"].apply(is_experiment_name) & (pandas.notnull(experiment["mice"]))]
# Out:
#              Experiment                         mice  Fixation Box  \
# 0     IGVF_Splitseq_002                   B6 (2F+2M)  IGVF_FIX_001
# 17    IGVF_Splitseq_003           8 founders (4M+4F)  IGVF_FIX_003
# 34    IGVF_Splitseq_004           8 founders (4M+4F)  IGVF_FIX_005
# 51    IGVF_Splitseq_005           8 founders (4M+4F)  IGVF_FIX_010
# 68    IGVF_Splitseq_006           8 founders (4M+4F)  IGVF_FIX_006
# 87    IGVF_Splitseq_007           8 founders (4M+4F)  IGVF_FIX_006
# 105   IGVF_Splitseq_008           8 founders (4M+4F)  IGVF_FIX_008
# 117   IGVF_Splitseq_B01          CASTJ + B6J (2M+2F)           NaN
# 126  IGVF_Splitseq_008B           8 founders (4M+4F)  IGVF_FIX_008
# 137   IGVF_Splitseq_009           8 founders (4M+4F)  IGVF_FIX_004
# 153   IGVF_Splitseq_010           8 founders (4M+4F)  IGVF_FIX_011
# 169   IGVF_Splitseq_011           8 founders (4M+4F)  IGVF_FIX_012
# 185    IGVF_Splitseq_EX           8 founders (4M+4F)           NaN
# 196   IGVF_Splitseq_012                          B6J  IGVF_Repeats
# 208   IGVF_Splitseq_013  8 founders + 4 F1s (4M+4F)   IGVF_FIX_021
# 225   IGVF_Splitseq_014                          B6J  IGVF_FIX_021
# 235   IGVF_Splitseq_015                8 F1s (4M+4F)  IGVF_FIX_013
# 253   IGVF_Splitseq_016                8 F1s (4M+4F)  IGVF_FIX_015
# 271   IGVF_Splitseq_017                8 F1s (4M+4F)  IGVF_FIX_014
# 289   IGVF_Splitseq_018                8 F1s (4M+4F)  IGVF_FIX_012
# 307   IGVF_Splitseq_019                8 F1s (4M+4F)  IGVF_FIX_029
# 325   IGVF_Splitseq_020                8 F1s (4M+4F)  IGVF_FIX_016
# 343   IGVF_Splitseq_021                8 F1s (4M+4F)  IGVF_FIX_017
# 361   IGVF_Splitseq_022                8 F1s (4M+4F)  IGVF_FIX_031
#
#     Split-seq prep start date Submit Sublibrary [Barcoded Nuclei] (nuclei/uL)  \
# 0                  2022-08-24     No     002_4A                          4540
# 17                 2022-12-01     No     003_8A                          6860
# 34                 2022-12-15     No     004_8A                          2460
# 51                 2023-01-23     No     005_8A                          4675
# 68                 2023-02-10     No     006_8A                          3160
# 87                 2023-03-07     No     007_8A                          2810
# 105                2023-03-24     No     008_8A                          2600
# 117                2023-04-03    Yes    B01_13A                          4920
# 126                2023-04-19    Yes   008B_67A                          3330
# 137                2023-05-02    Yes    009_67A                          3370
# 153                       NaT    Yes    010_67A                          5440
# 169                       NaT    Yes    011_67A                          6620
# 185                       NaT    Yes    003_13A                           NaN
# 196                       NaT    Yes    012_13A                          3220
# 208                2023-09-08    Yes    013_13A                          4160
# 225                2023-09-25    Yes    014_13A                          1040
# 235                       NaT    NaN    015_13A                           NaN
# 253                       NaT    NaN    016_13A                           NaN
# 271                       NaT    NaN    017_13A                           NaN
# 289                       NaT    NaN    018_13A                           NaN
# 307                       NaT    NaN    019_13A                           NaN
# 325                       NaT    NaN    020_13A                           NaN
# 343                       NaT    NaN    021_13A                           NaN
# 361                       NaT    NaN    022_13A                           NaN
#
#      Barcoded Nuclei Vol. (uL) Total barcoded nuclei (1st 3 rounds)  \
# 0                        240.0                              1089600
# 17                       250.0                              1715000
# 34                       640.0                              1574400
# 51                       390.0                              1823250
# 68                       780.0                              2464800
# 87                       580.0                              1629800
# 105                      250.0                               650000
# 117                       83.6                               411312
# 126                      250.0                               832500
# 137                      285.0                               960450
# 153                      250.0                              1360000
# 169                      250.0                              1655000
# 185                        NaN                                  NaN
# 196                       81.0                               260820
# 208                      225.0                               936000
# 225                       97.5                               101400
# 235                      250.0                                  NaN
# 253                      250.0                                  NaN
# 271                      250.0                                  NaN
# 289                      250.0                                  NaN
# 307                      250.0                                  NaN
# 325                      250.0                                  NaN
# 343                      250.0                                  NaN
# 361                      250.0                                  NaN
#
#      # of backup aliquots  ... Unnamed: 54  Unnamed: 55  Unnamed: 56  \
# 0                     3.0  ...         NaN          NaN          NaN
# 17                    7.0  ...         NaN        Total         L001
# 34                    5.0  ...         NaN        Total         L001
# 51                    6.0  ...         NaN        Total         L001
# 68                    8.0  ...         NaN        Total         L001
# 87                    8.0  ...         NaN        Total         L001
# 105                   0.0  ...         NaN        Total         L001
# 117                  10.0  ...         NaN          NaN          NaN
# 126                   0.0  ...           2   1417529714    355914199
# 137                   0.0  ...           2   1474101220    177858630
# 153                   3.0  ...           2   1276835447    173224540
# 169                   7.0  ...           2   1316269124    173623468
# 185                   1.0  ...         NaN          NaN          NaN
# 196                  12.0  ...         NaN          NaN          NaN
# 208                   0.0  ...         NaN        Total         L001
# 225                   0.0  ...         NaN          NaN          NaN
# 235                   NaN  ...         NaN        Total         L001
# 253                   NaN  ...         NaN        Total         L001
# 271                   NaN  ...         NaN        Total         L001
# 289                   NaN  ...         NaN        Total         L001
# 307                   NaN  ...         NaN        Total         L001
# 325                   NaN  ...         NaN        Total         L001
# 343                   NaN  ...         NaN        Total         L001
# 361                   NaN  ...         NaN        Total         L001
#
#      Unnamed: 57 Unnamed: 58 Unnamed: 59 Unnamed: 60 Unnamed: 61  Unnamed: 62  \
# 0            NaN         NaN         NaN         NaN         NaN          NaN
# 17          L002        L003        L004        L001        L002         L003
# 34          L002        L003        L004        L001        L002         L003
# 51          L002        L003        L004        L001        L002         L003
# 68          L002        L003        L004        L001        L002         L003
# 87          L002        L003        L004        L001        L002         L003
# 105         L002        L003        L004         NaN         NaN          NaN
# 117          NaN         NaN         NaN         NaN         NaN          NaN
# 126    355917666   358863075   346834774         NaN         NaN          NaN
# 137    182128617   178436907   177628982   189105418   193500915    191649075
# 153    171233145   172829595   168517796   145490904   150435757    148667669
# 169    170663719   172876343   165573211   158569678   162211611    156551618
# 185          NaN         NaN         NaN         NaN         NaN          NaN
# 196          NaN         NaN         NaN         NaN         NaN          NaN
# 208         L002        L003        L004         NaN         NaN          NaN
# 225          NaN         NaN         NaN         NaN         NaN          NaN
# 235         L002        L003        L004        L001        L002         L003
# 253         L002        L003        L004        L001        L002         L003
# 271         L002        L003        L004        L001        L002         L003
# 289         L002        L003        L004        L001        L002         L003
# 307         L002        L003        L004        L001        L002         L003
# 325         L002        L003        L004        L001        L002         L003
# 343         L002        L003        L004        L001        L002         L003
# 361         L002        L003        L004        L001        L002         L003
#
#      Unnamed: 63
# 0            NaN
# 17          L004
# 34          L004
# 51          L004
# 68          L004
# 87          L004
# 105          NaN
# 117          NaN
# 126          NaN
# 137    183792676
# 153    146436041
# 169    156199476
# 185          NaN
# 196          NaN
# 208          NaN
# 225          NaN
# 235         L004
# 253         L004
# 271         L004
# 289         L004
# 307         L004
# 325         L004
# 343         L004
# 361         L004
#
# [24 rows x 64 columns]

# %%
def find_fixation_start(sheet):
    def is_experiment_name(name):
        not_submittable = ["IGVF_Splitseq_EX"]
        return not pandas.isnull(name) and name.startswith("IGVF_Splitseq") # and not name in not_submittable

    for fixation_id_row in sheet[sheet["Experiment"].apply(is_experiment_name) & (pandas.notnull(experiment["mice"]))].index:
        name = sheet.loc[fixation_id_row, "Experiment"]
        start = fixation_id_row

        stop = sheet.shape[0]
        for i, value in sheet.iloc[start:]["Sublibrary"].iteritems():
            if pandas.isnull(value):
                stop = i - 1
                break
        
        
        yield (name, start, stop)

for name, start, stop in find_fixation_start(experiment):
    print(name, start, stop)
# Out:
# IGVF_Splitseq_002 0 15
# IGVF_Splitseq_003 17 32
# IGVF_Splitseq_004 34 49
# IGVF_Splitseq_005 51 66
# IGVF_Splitseq_006 68 85
# IGVF_Splitseq_007 87 102
# IGVF_Splitseq_008 105 114
# IGVF_Splitseq_B01 117 124
# IGVF_Splitseq_008B 126 135
# IGVF_Splitseq_009 137 151
# IGVF_Splitseq_010 153 167
# IGVF_Splitseq_011 169 183
# IGVF_Splitseq_EX 185 192
# IGVF_Splitseq_012 196 203
# IGVF_Splitseq_013 208 222
# IGVF_Splitseq_014 225 232
# IGVF_Splitseq_015 235 250
# IGVF_Splitseq_016 253 268
# IGVF_Splitseq_017 271 286
# IGVF_Splitseq_018 289 304
# IGVF_Splitseq_019 307 322
# IGVF_Splitseq_020 325 340
# IGVF_Splitseq_021 343 358
# IGVF_Splitseq_022 361 376

# %%
def parse_selection_type(value):
    if value is None:
        return None
    elif value.lower() in ("normal", "no"):
        return models.SublibrarySelectionTypeEnum.no_selection
    elif value in ("capture", "EX"):
        return models.SublibrarySelectionTypeEnum.exome_capture
    else:
        raise ValueError(f"Unrecognized capture type {value}")
        
def parse_sample_type(value):
    if value is None:
        return None
    elif value.lower() in ("nuclei",):
        return models.SubcellularComponentEnum.nuclei
    elif value.lower() in ("cells",):
        return models.SubcellularComponentEnum.cellular
    else:
        raise ValueError(f"Unrecognized sample type {value}")


def parse_fixation(sheet, experiment_name, start, stop):
    block = sheet.loc[start:stop]

    experiment_name_fields = experiment_name.split("_")
    plate_name = f"{experiment_name_fields[0]}_{experiment_name_fields[-1]}"
    
    aliquots = {}
    for i, row in block.iterrows():
        count = row["# of backup aliquots"]
        size = row["Backup Aliquot Size"]
        if not (pandas.isnull(count) or pandas.isnull(size)):
            if isinstance(size, str) and size.endswith("k"):
                size = size[:-1]
            size = int(size) * 1000
            aliquots[size] = int(count)
    
    experiment = {
        "experiment_name": experiment_name,
        "plate_name": plate_name,
        "prep_date": block.loc[start, "Split-seq prep start date"],
        "unused_aliquots": aliquots,
        "subpool": [],
    }

    for i, row in block.iterrows():
        if not pandas.isnull(row["Sublibrary"]):
            if pandas.isnull(row["NovaSeq Sequencing date"]):
                novaseq_run_id = None
            else:
                novaseq_run_id = row["NovaSeq Sequencing date"].isoformat().split("T")[0]

            if pandas.isnull(row.get("Novaseq raw reads")):
                novaseq_raw_reads = None
                novaseq1_raw_reads = None
                novaseq2_raw_reads = None
            elif row["Novaseq raw reads"] == "Total":
                novaseq_raw_reads = None
                novaseq1_raw_reads = None
                novaseq2_raw_reads = None
            else:
                novaseq_raw_reads = int_or_none(row.get("Novaseq raw reads"))
                novaseq1_raw_reads = sum([int_or_none(row.get(x)) for x in["Novaseq1 L001", "Novaseq1 L002", "Novaseq1 L003", "Novaseq1 L004"]])
                novaseq2_raw_reads = sum([int_or_none(row.get(x)) for x in["Novaseq2 L001", "Novaseq2 L002", "Novaseq2 L003", "Novaseq2 L004"]])

            plate_name, subname = row["Sublibrary"].split("_")
            print(row["Sublibrary Type"], row["Sublibrary"])
            subpool = {
                "name": row["Sublibrary"],
                "plate_name": "IGVF_{}".format(plate_name),
                "subpool_subname": subname,
                "submit": row["Submit"],
                "nuclei": int_or_none(row["Nuclei / Sublibrary"]),
                "selection_type": parse_selection_type(row["Sublibrary Type"]),
                "subcellular_component": parse_sample_type(row["Sample Type"]),
                "cdna_pcr_rounds": row["cDNA Amp # PCR Cycles"],
                "cdna_ng_per_ul": row["[cDNA] (ng/uL)"],
                "cdna_volume": row["cDNA Vol. (uL)"],
                #total_cdna = cdna_ng_per_ul_in_25ul * 25
                "bioanalyzer_date": row["BA date"],
                "cdna_average_bp_length": int_or_none(row["cDNA Ave. Length (bp)"]),
                "index_pcr_no": int_or_none(row["Sub library Index PCR #"]),
                "index": str_or_none(row["Sublibrary Index"]),
                "i7_barcode": row["i7 Forward Sequence"],
                "i5_barcode": row["i5 Forward Sequence"],
                "library_ng_per_ul": float_or_none(row["[Library] (ng/ul)"]),
                "library_average_bp_length": float_or_none(row["Library Ave. Length (bp)"]),
                "nextseq_run_date": date_or_none(row["QC Sequencing date"]),
                "nextseq_run_id": str_or_none(int_or_none(row["Nextseq run #"])),
                "nextseq_run_raw_reads": int_or_none(row["QC # raw reads  (1 mismatch)"]),
                "novaseq_run_date": date_or_none(row["NovaSeq Sequencing date"]),
                "novaseq_run_id": novaseq_run_id,
                "novaseq_run_raw_reads": novaseq_raw_reads,
                "novaseq1_raw_reads": novaseq1_raw_reads,
                "novaseq2_raw_reads": novaseq2_raw_reads,
            }
            experiment["subpool"].append(subpool)
            #if not pandas.isnull(subpool["nuclei"]):
            #    nuclei = subpool["nuclei"]
            #    aliquots[nuclei] = aliquots.get(nuclei) + 1

    return experiment

#parse_fixation(experiment, "IGVF_Splitseq_003", 17, 32)
#parse_fixation(experiment, "IGVF_Splitseq_008", 108, 117)
#parse_fixation(experiment, "IGVF_Splitseq_B01", 124, 131)
#parse_fixation(experiment, "IGVF_Splitseq_008B", 133, 143)
parse_fixation(experiment, "IGVF_Splitseq_EX", 186, 197)
# Out:
# EX 004_13A
# EX 005_13A
# EX 007_13A
# EX 008B_13A
# EX 009_13A
# EX 010_13A
# EX 011_13A
# NO 012_13A
# NO 012_13B
# {'experiment_name': 'IGVF_Splitseq_EX',
#  'plate_name': 'IGVF_EX',
#  'prep_date': NaT,
#  'unused_aliquots': {13000: 12},
#  'subpool': [{'name': '004_13A',
#    'plate_name': 'IGVF_004',
#    'subpool_subname': '13A',
#    'submit': 'Yes',
#    'nuclei': 13000,
#    'selection_type': <SublibrarySelectionTypeEnum.exome_capture: 'EX'>,
#    'subcellular_component': <SubcellularComponentEnum.nuclei: 'N'>,
#    'cdna_pcr_rounds': '5 + 8',
#    'cdna_ng_per_ul': 23.8,
#    'cdna_volume': 25.0,
#    'bioanalyzer_date': NaT,
#    'cdna_average_bp_length': None,
#    'index_pcr_no': 12,
#    'index': 2,
#    'i7_barcode': 'ACTTGA',
#    'i5_barcode': nan,
#    'library_ng_per_ul': 24.4,
#    'library_average_bp_length': None,
#    'nextseq_run_date': datetime.date(2023, 5, 30),
#    'nextseq_run_id': 1070,
#    'nextseq_run_raw_reads': None,
#    'novaseq_run_date': None,
#    'novaseq_run_id': None,
#    'novaseq_run_raw_reads': None,
#    'novaseq1_raw_reads': None,
#    'novaseq2_raw_reads': None},
#   {'name': '005_13A',
#    'plate_name': 'IGVF_005',
#    'subpool_subname': '13A',
#    'submit': 'Yes',
#    'nuclei': 13000,
#    'selection_type': <SublibrarySelectionTypeEnum.exome_capture: 'EX'>,
#    'subcellular_component': <SubcellularComponentEnum.nuclei: 'N'>,
#    'cdna_pcr_rounds': '5 + 8',
#    'cdna_ng_per_ul': 52.0,
#    'cdna_volume': 25.0,
#    'bioanalyzer_date': NaT,
#    'cdna_average_bp_length': None,
#    'index_pcr_no': 12,
#    'index': 3,
#    'i7_barcode': 'GATCAG',
#    'i5_barcode': nan,
#    'library_ng_per_ul': 19.8,
#    'library_average_bp_length': None,
#    'nextseq_run_date': datetime.date(2023, 5, 30),
#    'nextseq_run_id': 1070,
#    'nextseq_run_raw_reads': None,
#    'novaseq_run_date': None,
#    'novaseq_run_id': None,
#    'novaseq_run_raw_reads': None,
#    'novaseq1_raw_reads': None,
#    'novaseq2_raw_reads': None},
#   {'name': '007_13A',
#    'plate_name': 'IGVF_007',
#    'subpool_subname': '13A',
#    'submit': 'Yes',
#    'nuclei': 13000,
#    'selection_type': <SublibrarySelectionTypeEnum.exome_capture: 'EX'>,
#    'subcellular_component': <SubcellularComponentEnum.nuclei: 'N'>,
#    'cdna_pcr_rounds': '5 + 8',
#    'cdna_ng_per_ul': 62.4,
#    'cdna_volume': 25.0,
#    'bioanalyzer_date': NaT,
#    'cdna_average_bp_length': None,
#    'index_pcr_no': 12,
#    'index': 4,
#    'i7_barcode': 'TAGCTT',
#    'i5_barcode': nan,
#    'library_ng_per_ul': 17.5,
#    'library_average_bp_length': None,
#    'nextseq_run_date': datetime.date(2023, 5, 30),
#    'nextseq_run_id': 1070,
#    'nextseq_run_raw_reads': None,
#    'novaseq_run_date': None,
#    'novaseq_run_id': None,
#    'novaseq_run_raw_reads': None,
#    'novaseq1_raw_reads': None,
#    'novaseq2_raw_reads': None},
#   {'name': '008B_13A',
#    'plate_name': 'IGVF_008B',
#    'subpool_subname': '13A',
#    'submit': 'Yes',
#    'nuclei': 13000,
#    'selection_type': <SublibrarySelectionTypeEnum.exome_capture: 'EX'>,
#    'subcellular_component': <SubcellularComponentEnum.nuclei: 'N'>,
#    'cdna_pcr_rounds': '5 + 8',
#    'cdna_ng_per_ul': 57.6,
#    'cdna_volume': 25.0,
#    'bioanalyzer_date': NaT,
#    'cdna_average_bp_length': None,
#    'index_pcr_no': 12,
#    'index': 5,
#    'i7_barcode': 'ATGTCA',
#    'i5_barcode': nan,
#    'library_ng_per_ul': 16.8,
#    'library_average_bp_length': None,
#    'nextseq_run_date': datetime.date(2023, 6, 2),
#    'nextseq_run_id': 1071,
#    'nextseq_run_raw_reads': None,
#    'novaseq_run_date': None,
#    'novaseq_run_id': None,
#    'novaseq_run_raw_reads': None,
#    'novaseq1_raw_reads': None,
#    'novaseq2_raw_reads': None},
#   {'name': '009_13A',
#    'plate_name': 'IGVF_009',
#    'subpool_subname': '13A',
#    'submit': 'Yes',
#    'nuclei': 13000,
#    'selection_type': <SublibrarySelectionTypeEnum.exome_capture: 'EX'>,
#    'subcellular_component': <SubcellularComponentEnum.nuclei: 'N'>,
#    'cdna_pcr_rounds': '5 + 8',
#    'cdna_ng_per_ul': 84.5,
#    'cdna_volume': 25.0,
#    'bioanalyzer_date': NaT,
#    'cdna_average_bp_length': None,
#    'index_pcr_no': 12,
#    'index': 6,
#    'i7_barcode': 'CTTGTA',
#    'i5_barcode': nan,
#    'library_ng_per_ul': 20.8,
#    'library_average_bp_length': None,
#    'nextseq_run_date': datetime.date(2023, 6, 2),
#    'nextseq_run_id': 1071,
#    'nextseq_run_raw_reads': None,
#    'novaseq_run_date': None,
#    'novaseq_run_id': None,
#    'novaseq_run_raw_reads': None,
#    'novaseq1_raw_reads': None,
#    'novaseq2_raw_reads': None},
#   {'name': '010_13A',
#    'plate_name': 'IGVF_010',
#    'subpool_subname': '13A',
#    'submit': 'Yes',
#    'nuclei': 13000,
#    'selection_type': <SublibrarySelectionTypeEnum.exome_capture: 'EX'>,
#    'subcellular_component': <SubcellularComponentEnum.nuclei: 'N'>,
#    'cdna_pcr_rounds': '5 + 8',
#    'cdna_ng_per_ul': 25.8,
#    'cdna_volume': 25.0,
#    'bioanalyzer_date': NaT,
#    'cdna_average_bp_length': None,
#    'index_pcr_no': 12,
#    'index': 7,
#    'i7_barcode': 'AGTCAA',
#    'i5_barcode': nan,
#    'library_ng_per_ul': 27.6,
#    'library_average_bp_length': None,
#    'nextseq_run_date': datetime.date(2023, 6, 2),
#    'nextseq_run_id': 1071,
#    'nextseq_run_raw_reads': None,
#    'novaseq_run_date': None,
#    'novaseq_run_id': None,
#    'novaseq_run_raw_reads': None,
#    'novaseq1_raw_reads': None,
#    'novaseq2_raw_reads': None},
#   {'name': '011_13A',
#    'plate_name': 'IGVF_011',
#    'subpool_subname': '13A',
#    'submit': 'Yes',
#    'nuclei': 13000,
#    'selection_type': <SublibrarySelectionTypeEnum.exome_capture: 'EX'>,
#    'subcellular_component': <SubcellularComponentEnum.nuclei: 'N'>,
#    'cdna_pcr_rounds': '5 + 8',
#    'cdna_ng_per_ul': 98.0,
#    'cdna_volume': 25.0,
#    'bioanalyzer_date': NaT,
#    'cdna_average_bp_length': None,
#    'index_pcr_no': 12,
#    'index': 8,
#    'i7_barcode': 'AGTTCC',
#    'i5_barcode': nan,
#    'library_ng_per_ul': 17.9,
#    'library_average_bp_length': None,
#    'nextseq_run_date': datetime.date(2023, 6, 2),
#    'nextseq_run_id': 1071,
#    'nextseq_run_raw_reads': None,
#    'novaseq_run_date': None,
#    'novaseq_run_id': None,
#    'novaseq_run_raw_reads': None,
#    'novaseq1_raw_reads': None,
#    'novaseq2_raw_reads': None},
#   {'name': '012_13A',
#    'plate_name': 'IGVF_012',
#    'subpool_subname': '13A',
#    'submit': 'Yes',
#    'nuclei': 13000,
#    'selection_type': <SublibrarySelectionTypeEnum.no_selection: 'NO'>,
#    'subcellular_component': <SubcellularComponentEnum.nuclei: 'N'>,
#    'cdna_pcr_rounds': '5 + 8',
#    'cdna_ng_per_ul': 72.1,
#    'cdna_volume': 20.0,
#    'bioanalyzer_date': Timestamp('2023-06-13 00:00:00'),
#    'cdna_average_bp_length': 1368,
#    'index_pcr_no': 11,
#    'index': 1,
#    'i7_barcode': 'CAGATC',
#    'i5_barcode': nan,
#    'library_ng_per_ul': 19.2,
#    'library_average_bp_length': 446.0,
#    'nextseq_run_date': datetime.date(2023, 6, 16),
#    'nextseq_run_id': 1072,
#    'nextseq_run_raw_reads': None,
#    'novaseq_run_date': None,
#    'novaseq_run_id': None,
#    'novaseq_run_raw_reads': None,
#    'novaseq1_raw_reads': None,
#    'novaseq2_raw_reads': None},
#   {'name': '012_13B',
#    'plate_name': 'IGVF_012',
#    'subpool_subname': '13B',
#    'submit': 'Yes',
#    'nuclei': 13000,
#    'selection_type': <SublibrarySelectionTypeEnum.no_selection: 'NO'>,
#    'subcellular_component': <SubcellularComponentEnum.nuclei: 'N'>,
#    'cdna_pcr_rounds': '5 + 8',
#    'cdna_ng_per_ul': 95.2,
#    'cdna_volume': 20.0,
#    'bioanalyzer_date': Timestamp('2023-06-13 00:00:00'),
#    'cdna_average_bp_length': 1458,
#    'index_pcr_no': 11,
#    'index': 2,
#    'i7_barcode': 'ACTTGA',
#    'i5_barcode': nan,
#    'library_ng_per_ul': 14.8,
#    'library_average_bp_length': 451.0,
#    'nextseq_run_date': datetime.date(2023, 6, 16),
#    'nextseq_run_id': 1072,
#    'nextseq_run_raw_reads': None,
#    'novaseq_run_date': None,
#    'novaseq_run_id': None,
#    'novaseq_run_raw_reads': None,
#    'novaseq1_raw_reads': None,
#    'novaseq2_raw_reads': None}]}

# %%
platforms = {x.name: x for x in models.Platform.objects.all()}
platforms
# Out:
# {'nextseq2000': <Platform: Nextseq 2000>,
#  'novaseq6000': <Platform: Novaseq 6000>,
#  'minion': <Platform: Oxford Nanopore MinION>,
#  'promethion': <Platform: Oxford Nanopore PromethION>,
#  'pacbio': <Platform: Pac Bio>}

# %%
class SubpoolName:
    def __init__(self, name=None):
        if isinstance(name, str):
            self._normalized = SubpoolName.subpool_name_to_numbers(name)
        elif isinstance(name, list):
            self._normalized = name
        elif name is None:
            self._normalized = None
        else:
            raise ValueError("Unrecognized type {} for {}".format(type(name), name))

    def __str__(self):
        if self._normalized is None:
            return "None"
        else:
            return SubpoolName.numbers_to_subpool_name(self._normalized)
        
    def __repr__(self):
        if self._normalized is None:
            return str("{}()".format(self.__class__.__name__))
        else:
            return str("{}('{}')".format(self.__class__.__name__, str(self)))
        
    def __eq__(self, cmp):
        if self._normalized is None and cmp is None:
            return True
        elif self._normalized is None and cmp._normalized is None:
            return True
        elif self._normalized is None or cmp._normalized is None:
            return False
        elif len(self._normalized) != len(cmp._normalized):
            return False
        else:
            for left, right in zip(self._normalized, cmp._normalized):
                if left != right:
                    return False
                
        return True
    
    def __lt__(self, cmp):
        if self._normalized is None and cmp is None:
            return False
        elif self._normalized is None and cmp._normalized is None:
            return False
        elif self._normalized is None:
            return True
        elif cmp is None or cmp._normalized is None:
            return False
        elif self._normalized[0] < cmp._normalized[0]:
            return True
        elif len(self._normalized) < len(cmp._normalized):
            return True
        elif len(self._normalized) > len(cmp._normalized):
            return False
        else:
            for left, right in zip(self._normalized, cmp._normalized):
                if left == right:
                    continue
                elif left < right:
                    return True
                else:
                    return False
                
        return False
                
    def __gt__(self, cmp):
        if self._normalized is None and cmp is None:
            return False
        elif self._normalized is None and cmp._normalized is None:
            return False
        elif cmp is None or cmp._normalized is None:
            return True
        elif self._normalized[0] > cmp._normalized[0]:
            return True
        elif len(self._normalized) < len(cmp._normalized):
            return False
        elif len(self._normalized) > len(cmp._normalized):
            return True
        else:
            for left, right in zip(self._normalized, cmp._normalized):
                if left == right:
                    continue
                elif left < right:
                    return False
                else:
                    return True
            
        return False
        
    @classmethod
    def subpool_name_to_numbers(cls, name):
        STATE_DIGITS = 1
        STATE_LETTERS = 2
        STATE_ERROR = -1

        digits = []
        letters = []
        state = STATE_DIGITS
        for char in name:
            if state == STATE_DIGITS:
                if char.isdigit():
                    digits.append(char)
                elif char.isalpha():
                    state = STATE_LETTERS
                    letters.append(char)
                else:
                    raise ValueError("Unrecognized symbol {} in {}".format(char, name))
            elif state == STATE_LETTERS:
                if char.isdigit():
                    raise ValueError("Unexpected digit {} in {}".format(char, name))
                elif char.isalpha():
                    letters.append(char)
                else:
                    raise ValueError("Unrecognized symbol {} in {}".format(char, name))

        result = [int("".join(digits))]
        for number in letters:
            if number < "A" or number > "Z":
                raise ValueError("out of bounds letter code in {}".format(name))
            else:
                result.append(ord(number) - ord("A"))

        return result

    @classmethod
    def numbers_to_subpool_name(cls, subpool_list):

        result = [str(subpool_list[0])]
        for char in subpool_list[1:]:
            result.append(chr(char + ord("A")))

        return "".join(result)

    def next_code(self):
        if self._normalized is None:
            return None

        carry = 0
        advancable = []
        for i, place in enumerate(reversed(self._normalized[1:])):
            if i == 0:
                place += 1
            else:
                place += carry
                carry = 0

            if place > 25:
                carry = 1
                place = 0

            advancable.append(place)

        if carry > 0:
            advancable.append(0)

        result = [self._normalized[0]]
        result.extend(reversed(advancable))
        
        return SubpoolName(result)

s = SubpoolName("8ACZ")
print(s)

decoded = SubpoolName.subpool_name_to_numbers("8ACZ") 
print("decoded", decoded)
encoded = SubpoolName.numbers_to_subpool_name(decoded)
print("encoded", encoded)

print(SubpoolName("8ACZ").next_code())



for pairs in [("8A", "8B"), ("8AA", "8Z"), ("8B", "8E"), ("8B", "8A"), ("8Z", "8AA"), ("67A", "67A"), ("8AA", "8AB")]:
    left = SubpoolName(pairs[0])
    right = SubpoolName(pairs[1])
    print(left, right, left < right, left == right, left > right)
    
print(max(SubpoolName("8A"), SubpoolName("8B")))
print(max(None, SubpoolName("8B")))
print(max(SubpoolName("8A"), None))
# Out:
# 8ACZ
# decoded [8, 0, 2, 25]
# encoded 8ACZ
# 8ADA
# 8A 8B True False False
# 8AA 8Z False False True
# 8B 8E True False False
# 8B 8A False False True
# 8Z 8AA True False False
# 67A 67A False True False
# 8AA 8AB True False False
# 8B
# 8B
# 8A

# %% [markdown]
# # load subpools, sequencing runs and subpools in sequencing run

# %%
def load_submitted_multiplexed_samples():
    multiplexed_samples = {}

    for accession_prefix in submitted_sheets:
        for i, row in submitted_sheets[accession_prefix]["multiplexed_sample"].iterrows():
            if not pandas.isnull(row["accession"]):
                aliases = row["aliases:array"].split(',')
                name = aliases[0].replace("ali-mortazavi:", "")
                if accession_prefix == "igvftst":
                    see_also_template = "https://api.sandbox.igvf.org/multiplexed-samples/{}/"
                elif accession_prefix == "igvf":
                    see_also_template = "https://api.data.igvf.org/multiplexed-samples/{}/"

                multiplexed_samples.setdefault(name, []).append({
                    "accession_prefix": accession_prefix,
                    "name": row["accession"],
                    "uuid": row["uuid"],
                    "see_also": see_also_template.format(row["accession"]),
                })
    print(len(multiplexed_samples))
    
    return multiplexed_samples

# %%
def load_split_seq_plates_as_dict():
    plates = {}
    for current_plate in models.SplitSeqPlate.objects.all():
        plates[current_plate.name] = current_plate
    return plates

# %%
load_split_seq_plates_as_dict()
# Out:
# {'IGVF_003': <SplitSeqPlate: IGVF_003>,
#  'IGVF_004': <SplitSeqPlate: IGVF_004>,
#  'IGVF_005': <SplitSeqPlate: IGVF_005>,
#  'IGVF_006': <SplitSeqPlate: IGVF_006>,
#  'IGVF_007': <SplitSeqPlate: IGVF_007>,
#  'IGVF_008': <SplitSeqPlate: IGVF_008>,
#  'IGVF_008B': <SplitSeqPlate: IGVF_008B>,
#  'IGVF_B01': <SplitSeqPlate: IGVF_B01>,
#  'IGVF_009': <SplitSeqPlate: IGVF_009>,
#  'IGVF_010': <SplitSeqPlate: IGVF_010>,
#  'IGVF_011': <SplitSeqPlate: IGVF_011>,
#  'IGVF_012': <SplitSeqPlate: IGVF_012>,
#  'IGVF_013': <SplitSeqPlate: IGVF_013>,
#  'IGVF_014': <SplitSeqPlate: IGVF_014>}

# %%
[vars(x) for x in models.LibraryBarcode.objects.filter(
    reagent=guess_barcode_reagent_from_plate("IGVF_004"),
    barcode_type=None,
    code="10",
)]
# Out:
# [{'_state': <django.db.models.base.ModelState at 0x7efdcf27ea00>,
#   'id': 202,
#   'reagent_id': 'wt-mega',
#   'name': '10',
#   'code': '10',
#   'i7_sequence': 'CCGTCC',
#   'i5_sequence': None,
#   'barcode_type': None,
#   'well_position': None}]

# %%
def load_experiments_return_submittable_subpools():
    compression=r"(?<compression>gz|bz2|xz|zstd)"
    nanopore_library_name_re_template = r"igvf(?P<run>[\d]+)_(?P<library_id>{library_name})_.*_(?P<fragment>[\d]+)\.fastq\.{compression}"
    nextseq_library_name_re_template = r"(?P<run>[\d]+)_(?P<library_id>{library_name})_(?P<read_id>[RI][\d])\.fastq\.{compression}"
    nextseq_library_index_re_template = r"Sublibrary_(?P<library_id>{library_index})_S(?P<sample_id>[\d]+)_(?P<lane_id>L[\d]+)_(?P<read_id>[RI][\d])_(?P<fragment>[\d]+)\.fastq\.{compression}"
    novaseq_library_index_re_template = r"Sublibrary_(?P<library_id>{library_index})_S(?P<sample_id>[\d]+)_(?P<lane_id>L[\d]+)_(?P<read_id>[RI][\d])_(?P<fragment>[\d]+)\.fastq\.{compression}"

    multiplexed_samples = load_submitted_multiplexed_samples()
    split_seq_plates = load_split_seq_plates_as_dict()

    failed_plates = {"IGVF_006",}
    failed = False
    submittable_subpools = {}
    for experiment_name, experiment_start, experiment_stop in find_fixation_start(experiment):
        fixation = parse_fixation(experiment, experiment_name, experiment_start, experiment_stop)

        if fixation["plate_name"] in failed_plates:
            print(f"Skipping failed plate {plate_name}")
            continue

        last_subpools = {}

        reagent = guess_barcode_reagent_from_plate(fixation["plate_name"])

        for line_offset, subpool in enumerate(fixation["subpool"]):
            if subpool["plate_name"] not in split_seq_plates:
                print("Unable to find plate for {}".format(subpool["plate_name"]))
                continue

            try:
                barcodes = models.LibraryBarcode.objects.filter(
                    reagent=reagent, 
                    barcode_type=None, 
                    code=subpool["index"])
            except models.LibraryBarcode.DoesNotExist:
                print(f"Unable to find barcode {subpool['index']}")
                
            if len(barcodes) == 0:
                print(f"Unable to find barcodes with {reagent} None {subpool['index']}")

            # validate i7 barcodes
            library_i7_barcodes_sequence = {b.i7_sequence for b in barcodes if pandas.notnull(b.i7_sequence)}
            if not pandas.isnull(subpool["i7_barcode"]):
                i7_expected_sequence = set(subpool["i7_barcode"].split(","))
            else:
                i7_expected_sequence = set()
            if library_i7_barcodes_sequence != i7_expected_sequence:
                print(f"{subpool['name']} Database lookup of {subpool['index']} i7_barcodes {library_i7_barcodes_sequence} doesn't match human entry {i7_expected_sequence}")
                print(reagent, subpool["index"], barcodes)
                failed = True
                continue

            # validate i5 barcodes
            library_i5_barcodes_sequence = {b.i5_sequence for b in barcodes if pandas.notnull(b.i5_sequence)}
            if len(library_i5_barcodes_sequence) > 0:
                if not pandas.isnull(subpool["i5_barcode"]):
                    i5_expected_sequence = set(subpool["i5_barcode"].split(","))
                else:
                    i5_expected_sequence = set()
                if library_i5_barcodes_sequence != i5_expected_sequence:
                    print(f"{subpool['name']} Database lookup of i5_barcodes {library_i5_barcodes_sequence} doesn't match human entry {i5_expected_sequence}")
                    failed = True
                    continue

            plate = split_seq_plates[subpool["plate_name"]]
            subpool_prefix = subpool["name"].split("_")[0]
            last_subpools[subpool["nuclei"]] = max(
                last_subpools.get(subpool["nuclei"]), 
                SubpoolName(subpool["subpool_subname"]))

            record = models.Subpool(
                name=subpool["name"],
                plate=plate,
                nuclei=subpool["nuclei"],
                selection_type=subpool["selection_type"],
                cdna_pcr_rounds=subpool["cdna_pcr_rounds"],
                cdna_ng_per_ul=float_or_none(subpool["cdna_ng_per_ul"]),
                cdna_volume=float_or_none(subpool["cdna_volume"]),
                bioanalyzer_date=date_or_none(subpool["bioanalyzer_date"]),
                cdna_average_bp_length=int_or_none(subpool["cdna_average_bp_length"]),
                index_pcr_number=int_or_none(subpool["index_pcr_no"]),
                index=str_or_none(subpool["index"]),
                library_ng_per_ul=float_or_none(subpool["library_ng_per_ul"]),
                library_average_bp_length=int_or_none(subpool["library_average_bp_length"]),
            )
            record.save()
            record.barcode.set(barcodes)
            record.save()

            if pandas.notnull(subpool["submit"]):
                submittable_subpools[subpool["name"]] = subpool["submit"]

            name = "subpool_{}".format(subpool["name"].lower())
            if name in multiplexed_samples:
                for accession_row in multiplexed_samples[name]:
                    if pandas.notnull(accession_row["name"]):
                        print(name, record.name, multiplexed_samples[name])
                        accession = models.Accession(**accession_row)
                        accession.save()
                        record.accession.add(accession)
                        record.save()            

        for nuclei in fixation["unused_aliquots"]:
            if nuclei in last_subpools:
                subpool_name = last_subpools[nuclei]
                for i in range(fixation["unused_aliquots"][nuclei]):
                    subpool_name = subpool_name.next_code()

                    record = models.Subpool(
                        name="{}_{}".format(subpool_prefix, subpool_name),
                        plate=plate,
                        nuclei=nuclei,
                    )
                    print(record.name)
                    record.save()
            else:
                print("No unused aliquots {} {}".format(nuclei, last_subpools))

    assert not failed
    return submittable_subpools
    
submittable_subpools = load_experiments_return_submittable_subpools()
# Out:
# 171
# NO 002_4A
# NO 002_4B
# NO 002_64A
# NO 002_64B
# NO 002_64C
# NO 002_64D
# NO 002_64E
# NO 002_64F
# NO 002_64G
# NO 002_64H
# NO 002_64I
# NO 002_64J
# NO 002_64K
# NO 002_64L
# NO 002_64M
# NO 002_64N
# Unable to find plate for IGVF_002
# Unable to find plate for IGVF_002
# Unable to find plate for IGVF_002
# Unable to find plate for IGVF_002
# Unable to find plate for IGVF_002
# Unable to find plate for IGVF_002
# Unable to find plate for IGVF_002
# Unable to find plate for IGVF_002
# Unable to find plate for IGVF_002
# Unable to find plate for IGVF_002
# Unable to find plate for IGVF_002
# Unable to find plate for IGVF_002
# Unable to find plate for IGVF_002
# Unable to find plate for IGVF_002
# Unable to find plate for IGVF_002
# Unable to find plate for IGVF_002
# No unused aliquots 67000 {}
# NO 003_8A
# NO 003_67A
# NO 003_67B
# NO 003_67C
# NO 003_67D
# NO 003_67E
# NO 003_67F
# NO 003_67G
# NO 003_67H
# NO 003_67I
# NO 003_67J
# NO 003_67K
# NO 003_67L
# NO 003_67M
# NO 003_67N
# NO 003_67O
# 003_67P
# 003_67Q
# 003_67R
# 003_67S
# 003_67T
# 003_67U
# 003_67V
# 003_8B
# 003_8C
# NO 004_8A
# NO 004_67A
# NO 004_67B
# NO 004_67C
# NO 004_67D
# NO 004_67E
# NO 004_67F
# NO 004_67G
# NO 004_67H
# NO 004_67I
# NO 004_67J
# NO 004_67K
# NO 004_67L
# NO 004_67M
# NO 004_67N
# NO 004_67O
# 004_67P
# 004_67Q
# 004_67R
# 004_67S
# 004_67T
# 004_8B
# 004_8C
# NO 005_8A
# NO 005_67A
# NO 005_67B
# NO 005_67C
# NO 005_67D
# NO 005_67E
# NO 005_67F
# NO 005_67G
# NO 005_67H
# NO 005_67I
# NO 005_67J
# NO 005_67K
# NO 005_67L
# NO 005_67M
# NO 005_67N
# NO 005_67O
# 005_67P
# 005_67Q
# 005_67R
# 005_67S
# 005_67T
# 005_67U
# 005_8B
# 005_8C
# 005_8D
# 005_8E
# 005_8F
# 005_8G
# 005_8H
# NO 006_8A
# NO 006_67A
# NO 006_67B
# NO 006_67C
# NO 006_67D
# NO 006_67E
# NO 006_67F
# NO 006_67G
# NO 006_67H
# NO 006_67I
# NO 006_67J
# NO 006_67K
# NO 006_67L
# NO 006_67M
# NO 006_67N
# NO 006_67O
# NO 006_67P
# NO 006_67Q
# Skipping failed plate IGVF_014
# NO 007_8A
# NO 007_67A
# NO 007_67B
# NO 007_67C
# NO 007_67D
# NO 007_67E
# NO 007_67F
# NO 007_67G
# NO 007_67H
# NO 007_67I
# NO 007_67J
# NO 007_67K
# NO 007_67L
# NO 007_67M
# NO 007_67N
# NO 007_67O
# 007_67P
# 007_67Q
# 007_67R
# 007_67S
# 007_67T
# 007_67U
# 007_67V
# 007_67W
# 007_8B
# 007_8C
# 007_8D
# 007_8E
# 007_8F
# 007_8G
# 007_8H
# 007_8I
# NO 008_8A
# NO 008_67A
# NO 008_67B
# NO 008_67C
# NO 008_67D
# NO 008_67E
# NO 008_67F
# NO 008_67G
# NO 008_67H
# NO 008_67I
# NO B01_13A
# NO B01_13B
# NO B01_13C
# NO B01_13D
# NO B01_13E
# NO B01_13F
# EX B01_13G
# NO B01_13H
# subpool_b01_13a B01_13A [{'accession_prefix': 'igvftst', 'name': 'TSTSM35366348', 'uuid': '77a93b75-f44a-4aa5-937b-a6788051bc18', 'see_also': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM35366348/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1676SYRC', 'uuid': 'efad3fdd-f466-4c59-94e0-8791e2bfaa93', 'see_also': 'https://api.data.igvf.org/multiplexed-samples/IGVFSM1676SYRC/'}]
# subpool_b01_13a B01_13A [{'accession_prefix': 'igvftst', 'name': 'TSTSM35366348', 'uuid': '77a93b75-f44a-4aa5-937b-a6788051bc18', 'see_also': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM35366348/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1676SYRC', 'uuid': 'efad3fdd-f466-4c59-94e0-8791e2bfaa93', 'see_also': 'https://api.data.igvf.org/multiplexed-samples/IGVFSM1676SYRC/'}]
# subpool_b01_13b B01_13B [{'accession_prefix': 'igvftst', 'name': 'TSTSM99018100', 'uuid': '6cac6a8b-7750-4df6-92cf-fae41082813d', 'see_also': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM99018100/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1955RVUC', 'uuid': 'f45edb75-5e28-4578-a2d5-395546f64b2a', 'see_also': 'https://api.data.igvf.org/multiplexed-samples/IGVFSM1955RVUC/'}]
# subpool_b01_13b B01_13B [{'accession_prefix': 'igvftst', 'name': 'TSTSM99018100', 'uuid': '6cac6a8b-7750-4df6-92cf-fae41082813d', 'see_also': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM99018100/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM1955RVUC', 'uuid': 'f45edb75-5e28-4578-a2d5-395546f64b2a', 'see_also': 'https://api.data.igvf.org/multiplexed-samples/IGVFSM1955RVUC/'}]
# subpool_b01_13c B01_13C [{'accession_prefix': 'igvftst', 'name': 'TSTSM36900951', 'uuid': '01858fa2-3c3d-476a-8d81-e82a0612c0e8', 'see_also': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM36900951/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8093RPKR', 'uuid': '33b1fa8c-53ac-4db9-81e2-df137881c434', 'see_also': 'https://api.data.igvf.org/multiplexed-samples/IGVFSM8093RPKR/'}]
# subpool_b01_13c B01_13C [{'accession_prefix': 'igvftst', 'name': 'TSTSM36900951', 'uuid': '01858fa2-3c3d-476a-8d81-e82a0612c0e8', 'see_also': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM36900951/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8093RPKR', 'uuid': '33b1fa8c-53ac-4db9-81e2-df137881c434', 'see_also': 'https://api.data.igvf.org/multiplexed-samples/IGVFSM8093RPKR/'}]
# subpool_b01_13d B01_13D [{'accession_prefix': 'igvftst', 'name': 'TSTSM27245068', 'uuid': 'b69b021b-aa90-41cf-8d1f-cfc59c726b20', 'see_also': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM27245068/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9603DIDI', 'uuid': 'abb7e2a6-c08b-4a15-88fe-94c5c38a3400', 'see_also': 'https://api.data.igvf.org/multiplexed-samples/IGVFSM9603DIDI/'}]
# subpool_b01_13d B01_13D [{'accession_prefix': 'igvftst', 'name': 'TSTSM27245068', 'uuid': 'b69b021b-aa90-41cf-8d1f-cfc59c726b20', 'see_also': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM27245068/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM9603DIDI', 'uuid': 'abb7e2a6-c08b-4a15-88fe-94c5c38a3400', 'see_also': 'https://api.data.igvf.org/multiplexed-samples/IGVFSM9603DIDI/'}]
# subpool_b01_13e B01_13E [{'accession_prefix': 'igvftst', 'name': 'TSTSM90710268', 'uuid': '8d44590d-bcb5-46f9-8c87-ea375db12ea9', 'see_also': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM90710268/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6958ESMJ', 'uuid': '92fcc1a8-9170-4a7c-90f8-5ec339a987d1', 'see_also': 'https://api.data.igvf.org/multiplexed-samples/IGVFSM6958ESMJ/'}]
# subpool_b01_13e B01_13E [{'accession_prefix': 'igvftst', 'name': 'TSTSM90710268', 'uuid': '8d44590d-bcb5-46f9-8c87-ea375db12ea9', 'see_also': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM90710268/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6958ESMJ', 'uuid': '92fcc1a8-9170-4a7c-90f8-5ec339a987d1', 'see_also': 'https://api.data.igvf.org/multiplexed-samples/IGVFSM6958ESMJ/'}]
# subpool_b01_13f B01_13F [{'accession_prefix': 'igvftst', 'name': 'TSTSM57985101', 'uuid': '2f34272a-6603-41e0-9820-cf2dd432244b', 'see_also': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM57985101/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6546CQJB', 'uuid': 'b2e62292-5163-4a73-9861-23a535a97dac', 'see_also': 'https://api.data.igvf.org/multiplexed-samples/IGVFSM6546CQJB/'}]
# subpool_b01_13f B01_13F [{'accession_prefix': 'igvftst', 'name': 'TSTSM57985101', 'uuid': '2f34272a-6603-41e0-9820-cf2dd432244b', 'see_also': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM57985101/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM6546CQJB', 'uuid': 'b2e62292-5163-4a73-9861-23a535a97dac', 'see_also': 'https://api.data.igvf.org/multiplexed-samples/IGVFSM6546CQJB/'}]
# subpool_b01_13g B01_13G [{'accession_prefix': 'igvftst', 'name': 'TSTSM10953505', 'uuid': 'b0e63479-2caf-4aac-9c98-2ff823f92c74', 'see_also': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM10953505/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8722YQAW', 'uuid': '00179685-55cf-4dc1-a00a-3f5fb9133288', 'see_also': 'https://api.data.igvf.org/multiplexed-samples/IGVFSM8722YQAW/'}]
# subpool_b01_13g B01_13G [{'accession_prefix': 'igvftst', 'name': 'TSTSM10953505', 'uuid': 'b0e63479-2caf-4aac-9c98-2ff823f92c74', 'see_also': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM10953505/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM8722YQAW', 'uuid': '00179685-55cf-4dc1-a00a-3f5fb9133288', 'see_also': 'https://api.data.igvf.org/multiplexed-samples/IGVFSM8722YQAW/'}]
# subpool_b01_13h B01_13H [{'accession_prefix': 'igvftst', 'name': 'TSTSM89995437', 'uuid': '5484bec6-4b0e-4488-b3b1-fd4def0022df', 'see_also': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM89995437/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2294BOOU', 'uuid': 'f25eb07b-ed33-496f-a8d7-83814b4b642f', 'see_also': 'https://api.data.igvf.org/multiplexed-samples/IGVFSM2294BOOU/'}]
# subpool_b01_13h B01_13H [{'accession_prefix': 'igvftst', 'name': 'TSTSM89995437', 'uuid': '5484bec6-4b0e-4488-b3b1-fd4def0022df', 'see_also': 'https://api.sandbox.igvf.org/multiplexed-samples/TSTSM89995437/'}, {'accession_prefix': 'igvf', 'name': 'IGVFSM2294BOOU', 'uuid': 'f25eb07b-ed33-496f-a8d7-83814b4b642f', 'see_also': 'https://api.data.igvf.org/multiplexed-samples/IGVFSM2294BOOU/'}]
# B01_13I
# B01_13J
# B01_13K
# B01_13L
# B01_13M
# B01_13N
# B01_13O
# B01_13P
# B01_13Q
# B01_13R
# NO 008B_67A
# NO 008B_67B
# NO 008B_67C
# NO 008B_67D
# NO 008B_67E
# NO 008B_67F
# NO 008B_67G
# NO 008B_67H
# NO 008B_67I
# NO 008B_67J
# No unused aliquots 13000 {67000: SubpoolName('67J')}
# NO 009_67A
# NO 009_67B
# NO 009_67C
# NO 009_67D
# NO 009_67E
# NO 009_67F
# NO 009_67G
# NO 009_67H
# NO 009_67I
# NO 009_67J
# NO 009_67K
# NO 009_67L
# NO 009_67M
# NO 009_67N
# NO 009_67O
# No unused aliquots 13000 {67000: SubpoolName('67O')}
# NO 010_67A
# NO 010_67B
# NO 010_67C
# NO 010_67D
# NO 010_67E
# NO 010_67F
# NO 010_67G
# NO 010_67H
# NO 010_67I
# NO 010_67J
# NO 010_67K
# NO 010_67L
# NO 010_67M
# NO 010_67N
# NO 010_67O
# 010_67P
# 010_67Q
# 010_67R
# No unused aliquots 13000 {67000: SubpoolName('67O')}
# NO 011_67A
# NO 011_67B
# NO 011_67C
# NO 011_67D
# NO 011_67E
# NO 011_67F
# NO 011_67G
# NO 011_67H
# NO 011_67I
# NO 011_67J
# NO 011_67K
# NO 011_67L
# NO 011_67M
# NO 011_67N
# NO 011_67O
# 011_67P
# 011_67Q
# 011_67R
# 011_67S
# 011_67T
# 011_67U
# 011_67V
# No unused aliquots 13000 {67000: SubpoolName('67O')}
# EX 003_13A
# EX 004_13A
# EX 005_13A
# EX 007_13A
# EX 008B_13A
# EX 009_13A
# EX 010_13A
# EX 011_13A
# 011_13B
# 011_13C
# NO 012_13A
# NO 012_13B
# NO 012_13C
# NO 012_13D
# NO 012_13E
# NO 012_13F
# NO 012_13G
# NO 012_13H
# 012_13I
# 012_13J
# 012_13K
# 012_13L
# 012_13M
# 012_13N
# 012_13O
# 012_13P
# 012_13Q
# 012_13R
# 012_13S
# 012_13T
# EX 013_13A
# NO 013_67A
# NO 013_67B
# NO 013_67C
# NO 013_67D
# NO 013_67E
# NO 013_67F
# NO 013_67G
# NO 013_67H
# NO 013_67I
# NO 013_67J
# NO 013_67K
# NO 013_67L
# NO 013_67M
# NO 013_67N
# NO 014_13A
# NO 014_13B
# NO 014_13C
# NO 014_13D
# NO 014_13E
# NO 014_13F
# NO 014_13G
# NO 014_13H
# EX 015_13A
# NO 015_67A
# NO 015_67B
# NO 015_67C
# NO 015_67D
# NO 015_67E
# NO 015_67F
# NO 015_67G
# NO 015_67H
# NO 015_67I
# NO 015_67J
# NO 015_67K
# NO 015_67L
# NO 015_67M
# NO 015_67N
# NO 015_67O
# Unable to find plate for IGVF_015
# Unable to find plate for IGVF_015
# Unable to find plate for IGVF_015
# Unable to find plate for IGVF_015
# Unable to find plate for IGVF_015
# Unable to find plate for IGVF_015
# Unable to find plate for IGVF_015
# Unable to find plate for IGVF_015
# Unable to find plate for IGVF_015
# Unable to find plate for IGVF_015
# Unable to find plate for IGVF_015
# Unable to find plate for IGVF_015
# Unable to find plate for IGVF_015
# Unable to find plate for IGVF_015
# Unable to find plate for IGVF_015
# Unable to find plate for IGVF_015
# EX 016_13A
# NO 016_67A
# NO 016_67B
# NO 016_67C
# NO 016_67D
# NO 016_67E
# NO 016_67F
# NO 016_67G
# NO 016_67H
# NO 016_67I
# NO 016_67J
# NO 016_67K
# NO 016_67L
# NO 016_67M
# NO 016_67N
# NO 016_67O
# Unable to find plate for IGVF_016
# Unable to find plate for IGVF_016
# Unable to find plate for IGVF_016
# Unable to find plate for IGVF_016
# Unable to find plate for IGVF_016
# Unable to find plate for IGVF_016
# Unable to find plate for IGVF_016
# Unable to find plate for IGVF_016
# Unable to find plate for IGVF_016
# Unable to find plate for IGVF_016
# Unable to find plate for IGVF_016
# Unable to find plate for IGVF_016
# Unable to find plate for IGVF_016
# Unable to find plate for IGVF_016
# Unable to find plate for IGVF_016
# Unable to find plate for IGVF_016
# EX 017_13A
# NO 017_67A
# NO 017_67B
# NO 017_67C
# NO 017_67D
# NO 017_67E
# NO 017_67F
# NO 017_67G
# NO 017_67H
# NO 017_67I
# NO 017_67J
# NO 017_67K
# NO 017_67L
# NO 017_67M
# NO 017_67N
# NO 017_67O
# Unable to find plate for IGVF_017
# Unable to find plate for IGVF_017
# Unable to find plate for IGVF_017
# Unable to find plate for IGVF_017
# Unable to find plate for IGVF_017
# Unable to find plate for IGVF_017
# Unable to find plate for IGVF_017
# Unable to find plate for IGVF_017
# Unable to find plate for IGVF_017
# Unable to find plate for IGVF_017
# Unable to find plate for IGVF_017
# Unable to find plate for IGVF_017
# Unable to find plate for IGVF_017
# Unable to find plate for IGVF_017
# Unable to find plate for IGVF_017
# Unable to find plate for IGVF_017
# EX 018_13A
# NO 018_67A
# NO 018_67B
# NO 018_67C
# NO 018_67D
# NO 018_67E
# NO 018_67F
# NO 018_67G
# NO 018_67H
# NO 018_67I
# NO 018_67J
# NO 018_67K
# NO 018_67L
# NO 018_67M
# NO 018_67N
# NO 018_67O
# Unable to find plate for IGVF_018
# Unable to find plate for IGVF_018
# Unable to find plate for IGVF_018
# Unable to find plate for IGVF_018
# Unable to find plate for IGVF_018
# Unable to find plate for IGVF_018
# Unable to find plate for IGVF_018
# Unable to find plate for IGVF_018
# Unable to find plate for IGVF_018
# Unable to find plate for IGVF_018
# Unable to find plate for IGVF_018
# Unable to find plate for IGVF_018
# Unable to find plate for IGVF_018
# Unable to find plate for IGVF_018
# Unable to find plate for IGVF_018
# Unable to find plate for IGVF_018
# EX 019_13A
# NO 019_67A
# NO 019_67B
# NO 019_67C
# NO 019_67D
# NO 019_67E
# NO 019_67F
# NO 019_67G
# NO 019_67H
# NO 019_67I
# NO 019_67J
# NO 019_67K
# NO 019_67L
# NO 019_67M
# NO 019_67N
# NO 019_67O
# Unable to find plate for IGVF_019
# Unable to find plate for IGVF_019
# Unable to find plate for IGVF_019
# Unable to find plate for IGVF_019
# Unable to find plate for IGVF_019
# Unable to find plate for IGVF_019
# Unable to find plate for IGVF_019
# Unable to find plate for IGVF_019
# Unable to find plate for IGVF_019
# Unable to find plate for IGVF_019
# Unable to find plate for IGVF_019
# Unable to find plate for IGVF_019
# Unable to find plate for IGVF_019
# Unable to find plate for IGVF_019
# Unable to find plate for IGVF_019
# Unable to find plate for IGVF_019
# EX 020_13A
# NO 020_67A
# NO 020_67B
# NO 020_67C
# NO 020_67D
# NO 020_67E
# NO 020_67F
# NO 020_67G
# NO 020_67H
# NO 020_67I
# NO 020_67J
# NO 020_67K
# NO 020_67L
# NO 020_67M
# NO 020_67N
# NO 020_67O
# Unable to find plate for IGVF_020
# Unable to find plate for IGVF_020
# Unable to find plate for IGVF_020
# Unable to find plate for IGVF_020
# Unable to find plate for IGVF_020
# Unable to find plate for IGVF_020
# Unable to find plate for IGVF_020
# Unable to find plate for IGVF_020
# Unable to find plate for IGVF_020
# Unable to find plate for IGVF_020
# Unable to find plate for IGVF_020
# Unable to find plate for IGVF_020
# Unable to find plate for IGVF_020
# Unable to find plate for IGVF_020
# Unable to find plate for IGVF_020
# Unable to find plate for IGVF_020
# EX 021_13A
# NO 021_67A
# NO 021_67B
# NO 021_67C
# NO 021_67D
# NO 021_67E
# NO 021_67F
# NO 021_67G
# NO 021_67H
# NO 021_67I
# NO 021_67J
# NO 021_67K
# NO 021_67L
# NO 021_67M
# NO 021_67N
# NO 021_67O
# Unable to find plate for IGVF_021
# Unable to find plate for IGVF_021
# Unable to find plate for IGVF_021
# Unable to find plate for IGVF_021
# Unable to find plate for IGVF_021
# Unable to find plate for IGVF_021
# Unable to find plate for IGVF_021
# Unable to find plate for IGVF_021
# Unable to find plate for IGVF_021
# Unable to find plate for IGVF_021
# Unable to find plate for IGVF_021
# Unable to find plate for IGVF_021
# Unable to find plate for IGVF_021
# Unable to find plate for IGVF_021
# Unable to find plate for IGVF_021
# Unable to find plate for IGVF_021
# EX 022_13A
# NO 022_67A
# NO 022_67B
# NO 022_67C
# NO 022_67D
# NO 022_67E
# NO 022_67F
# NO 022_67G
# NO 022_67H
# NO 022_67I
# NO 022_67J
# NO 022_67K
# NO 022_67L
# NO 022_67M
# NO 022_67N
# NO 022_67O
# Unable to find plate for IGVF_022
# Unable to find plate for IGVF_022
# Unable to find plate for IGVF_022
# Unable to find plate for IGVF_022
# Unable to find plate for IGVF_022
# Unable to find plate for IGVF_022
# Unable to find plate for IGVF_022
# Unable to find plate for IGVF_022
# Unable to find plate for IGVF_022
# Unable to find plate for IGVF_022
# Unable to find plate for IGVF_022
# Unable to find plate for IGVF_022
# Unable to find plate for IGVF_022
# Unable to find plate for IGVF_022
# Unable to find plate for IGVF_022
# Unable to find plate for IGVF_022

# %%
models.LibraryBarcode.objects.get(i7_sequence="TAATCGAC")
# Out:
# <LibraryBarcode: UDI_Plate_WT_20 UDI20 TAATCGAC+TAATCGAC>

# %%
# Old creating runs from the sample sheet

#    expected_names = {
#        "IGVF_Splitseq_003": {
#            "nanopore": nanopore_library_name_re_template,
#            "nextseq": nextseq_library_name_re_template,
#            "novaseq": novaseq_library_index_re_template,
#        },
#        "IGVF_Splitseq_004": {
#            "nanopore": nanopore_library_name_re_template,
#            "nextseq": nextseq_library_name_re_template,
#            "novaseq": novaseq_library_index_re_template,
#        },
#        "IGVF_Splitseq_005": {
#            "nanopore": nanopore_library_name_re_template,
#            "nextseq": nextseq_library_index_re_template,
#            "novaseq": novaseq_library_index_re_template,
#        },
#        "IGVF_Splitseq_006": {
#            "nanopore": nanopore_library_name_re_template,
#            "nextseq": nextseq_library_index_re_template,
#            "novaseq": novaseq_library_index_re_template,
#        },
#
#    }
#
#    nanopore_runs = {
#        "IGVF_Splitseq_003": {
#            "name": "2023-01-03-8A",
#            "run_date": datetime.datetime(2023,1,3),
#            "raw_reads": 87784162,
#        }
#    }

#        if experiment_name in nanopore_runs and subpool["nuclei"] == 8000:
#            measurement = get_or_create_sequencing_run(
#                # nanopore_runs[experiment_name]["name"]
#                name="{}/{}".format(plate.name.lower(), "nanopore"),
#                run_date=nanopore_runs[experiment_name]["run_date"],
#                platform=platforms["nanopore"],
#                plate=plate,
#            )
#            
#            pattern = expected_names[experiment_name]["nanopore"].format(
#                library_name=subpool["subpool_subname"],
#                library_index=line_offset+1,
#                compression=compression,
#            )
#            
#            run = models.SubpoolInRun(
#                subpool=record,
#                sequencing_run=measurement,
#                raw_reads=nanopore_runs[experiment_name]["raw_reads"],
#                status=models.RunStatus.PASS,
#            )
#            run.save()            
#
#        if subpool["nextseq_run_date"] is not None:
#            measurement = get_or_create_sequencing_run(
#                #sublibrary["nextseq_run_id"]
#                name="{}/{}".format(plate.name.lower(), "nextseq"),
#                run_date=subpool["nextseq_run_date"],
#                platform=platforms["nextseq"],
#                plate=plate,
#            )
#
#            pattern = expected_names[experiment_name]["nextseq"].format(
#                library_name=subpool["subpool_subname"],
#                library_index=line_offset+1,
#                compression=compression,
#            )            
#            
#            run = models.SubpoolInRun(
#                subpool=record,
#                sequencing_run=measurement,
#                raw_reads=subpool["nextseq_run_raw_reads"],
#                status=models.RunStatus.PASS,
#            )
#            run.save()
#            
#        if subpool["novaseq_run_date"] is not None:
#            for i, nova_raw_reads in enumerate([subpool["novaseq1_raw_reads"], subpool["novaseq2_raw_reads"]]):
#                #nova_run_name = "{}-{}".format(sublibrary["novaseq_run_id"], i+1)
#                nova_run_name = "{}/{}".format(plate.name.lower(), "nova{}".format(i+1))
#                measurement = get_or_create_sequencing_run(
#                    name=nova_run_name,
#                    run_date=subpool["novaseq_run_date"],
#                    platform=platforms["novaseq"],
#                    plate=plate,
#                )
#
#                pattern = expected_names[experiment_name]["novaseq"].format(
#                    library_name=subpool["subpool_subname"],
#                    library_index=line_offset+1,
#                    compression=compression,
#                )
#
#                run = models.SubpoolInRun(
#                    subpool=record,
#                    sequencing_run=measurement,
#                    raw_reads=nova_raw_reads,
#                    status=models.RunStatus.PASS,                    
#                )
#                run.save()

# %%
def load_fastq_csv():
    fastqs = pandas.read_csv(
        "fastq_metadata.tsv", sep="\t",
        dtype={
            "sample_id": str,
            "read_id": str,
            "fragment": str,
            "sequencer_run": str,
            "lane": str,
        }).sort_values(["experiment", "subpool_name", "index_id", "lane", "read"])
    return fastqs

fastqs = load_fastq_csv()
fastqs.head()
# Out:
#     experiment    family                               filename  \
# 378   igvf_003  illumina  igvf_003/nextseq2/003_13A_R1.fastq.gz
# 377   igvf_003  illumina  igvf_003/nextseq2/003_13A_R2.fastq.gz
# 13    igvf_003  illumina   igvf_003/nextseq/003_67A_R1.fastq.gz
# 12    igvf_003  illumina   igvf_003/nextseq/003_67A_R2.fastq.gz
# 14    igvf_003  illumina   igvf_003/nextseq/003_67B_R1.fastq.gz
#
#                                md5sum         size       ctime plate_id  \
# 378  57e977fdfe32850db83ee5f7addb7165  17707636592  2023-10-02      003
# 377  148c181e7d81e4aa15611fb2086d5971  10322410034  2023-10-02      003
# 13   35350d53cf858267d294bce69e475c83  48483277280  2023-09-08      003
# 12   00c68ff0f9e0217d422c57e8948d4bb4  32327542019  2023-09-08      003
# 14   79db765143bb23e14c613c9e1339e9f7  44182320136  2023-09-08      003
#
#     subpool_name fragment compression sequencer sequencer_run flowcell_id  \
# 378          13A      NaN          gz   VH00582             6   AAC3V7HHV
# 377          13A      NaN          gz   VH00582             6   AAC3V7HHV
# 13           67A      NaN          gz   VH00582             1   AAATMGFHV
# 12           67A      NaN          gz   VH00582             1   AAATMGFHV
# 14           67B      NaN          gz   VH00582             1   AAATMGFHV
#
#      nuclei read barcode index_id sample_id lane exome_capture
# 378      13   R1  CAGATC        1       NaN  NaN            EX
# 377      13   R2  CAGATC        1       NaN  NaN            EX
# 13       67   R1  ACTTGA        2       NaN  NaN           NaN
# 12       67   R2  ACTTGA        2       NaN  NaN           NaN
# 14       67   R1  GATCAG        3       NaN  NaN           NaN

# %%
def fastq_metadata_row_to_subpool_name(row):
    if pandas.isnull(row.subpool_name):
        return None
    else:
        return "{}_{}".format(row.plate_id, row.subpool_name)

def get_subpool_from_fastq_row(row):
    plate_name = normalize_plate_name(row.experiment)
    subpool_name = fastq_metadata_row_to_subpool_name(row)

    query = {
        "plate__name": plate_name,
    }
    
    if pandas.notnull(subpool_name):
        query["name"] = subpool_name
    if pandas.notnull(row.index_id):
        query["index"] = str_or_none(row.index_id)
    
    # these are labeled as having X nuclei but actually have fewer nuclei. 
    # Not that you can tell that from the filename
    nuclei_dont_match = {"013_67N", "014_13H"}
    if pandas.notnull(row.nuclei) and subpool_name not in nuclei_dont_match:
        query["nuclei"] = int(row.nuclei)*1000
    if pandas.notnull(row.exome_capture):
        query["selection_type"] = row.exome_capture

    subpools = models.Subpool.objects.filter(**query)
    
    if len(subpools) == 0:
        print("Nothing found for {} {}".format(query, row.filename))
    elif len(subpools) > 1:
        print("Multiple hits for {}: {} {}".format(query, subpools, row.filename))
    else:
        return subpools[0]

from Bio.Seq import Seq
def check_fastq_barcode_is_equal(i7_sequence, i5_sequence, barcode):
    if pandas.isnull(i5_sequence):
        return i7_sequence == barcode
    
    sequences = barcode.split("+")
    if len(sequences) != 2:
        print("Warning: database says dual index, file says single index: {} {} {}".format(i7_sequence, i5_sequence, barcode))
        return False

    i7, i5 = sequences
    # barcodes in the fastq file are reverse complimented.
    i5 = Seq(i5).reverse_complement()
    return i7_sequence == i7 and i5_sequence == i5
    
assert check_fastq_barcode_is_equal("ACTTGA", None, "ACTTGA")
assert not check_fastq_barcode_is_equal("ACTTGA", None, "CTTGTA")
assert check_fastq_barcode_is_equal("GTGAAACT", "AGTCTGTA", "GTGAAACT+TACAGACT")
assert not check_fastq_barcode_is_equal("GTGAAACT", "AGTCTGTA", "ACTTGATC+TTTGGGTG")
assert not check_fastq_barcode_is_equal("GTGAAACT", "AGTCTGTA", "CTTGTA")
print("Finish check_fastq_barcode_is_equal test assertions")

def test_subpool_lookup(fastqs):
    for i, row in fastqs.iterrows():
        subpool = get_subpool_from_fastq_row(row)
        if subpool is None:
            continue
        barcodes = subpool.barcode.filter(barcode_type=None)
        if barcodes.count() != 1:
            print("Barcode count wrong {}".format(barcode))

        barcode = barcodes[0]
        if not check_fastq_barcode_is_equal(barcode.i7_sequence, barcode.i5_sequence, row["barcode"]):
            print(f"Barcode mismatch {subpool.plate_name()} {subpool.index} {barcode.i7_sequence} {barcode.i5_sequence} {row.barcode} {row.filename}")

test_subpool_lookup(fastqs)
# Out:
# Warning: database says dual index, file says single index: GTGAAACT AGTCTGTA CTTGTA
# Finish check_fastq_barcode_is_equal test assertions
# Barcode mismatch IGVF_003 1 CAGATC None nan igvf_003/nanopore/igvf003_8A_lig-ss_11.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC None nan igvf_003/nanopore/igvf003_8A_lig-ss_4.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC None nan igvf_003/nanopore/igvf003_8A_lig-ss_7.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC None nan igvf_003/nanopore/igvf003_8A_lig-ss_6.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC None nan igvf_003/nanopore/igvf003_8A_lig-ss_8.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC None nan igvf_003/nanopore/igvf003_8A_lig-ss_5.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC None nan igvf_003/nanopore/igvf003_8A_lig-ss_1.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC None nan igvf_003/nanopore/igvf003_8A_lig-ss_2.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC None nan igvf_003/nanopore/igvf003_8A_lig-ss_10.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC None nan igvf_003/nanopore/igvf003_8A_lig-ss_9.fastq.gz
# Barcode mismatch IGVF_003 1 CAGATC None nan igvf_003/nanopore/igvf003_8A_lig-ss_3.fastq.gz

# %%
[(x.index, x.nuclei, x.selection_type) for x in models.Subpool.objects.filter(plate__name="IGVF_013")]
# Out:
# [('UDI01', 13000, 'EX'),
#  ('UDI02', 67000, 'NO'),
#  ('UDI03', 67000, 'NO'),
#  ('UDI04', 67000, 'NO'),
#  ('UDI05', 67000, 'NO'),
#  ('UDI06', 67000, 'NO'),
#  ('UDI07', 67000, 'NO'),
#  ('UDI08', 67000, 'NO'),
#  ('UDI09', 67000, 'NO'),
#  ('UDI10', 67000, 'NO'),
#  ('UDI11', 67000, 'NO'),
#  ('UDI12', 67000, 'NO'),
#  ('UDI13', 67000, 'NO'),
#  ('UDI14', 67000, 'NO'),
#  ('UDI15', 48256, 'NO')]

# %% [markdown]
# Load information about previously submitted records

# %%
submitted_sequence_file = {}

for accession_prefix in submitted_sheets:
    for i, row in submitted_sheets[accession_prefix]["sequence_file"].iterrows():
        if not pandas.isnull(row["accession"]):
            if accession_prefix == "igvftst":
                see_also_template = "https://api.sandbox.igvf.org/sequence-files/{}/"
            elif accession_prefix == "igvf":
                see_also_template = "https://api.data.igvf.org/sequence-files/{}/"
            
            if pandas.notnull(row["accession"]):
                submitted_sequence_file.setdefault(row["submitted_file_name"], []).append({
                    "accession_prefix": accession_prefix,
                    "name": row["accession"],
                    "uuid": row["uuid"],
                    "see_also": see_also_template.format(row["accession"]),
                })
        
print("loaded {} submitted sequence_file records".format(len(submitted_sequence_file)))
# Out:
# loaded 2132 submitted sequence_file records

# %%
submitted_sheets.keys()
# Out:
# dict_keys(['igvftst', 'igvf'])

# %%
def built_in_cache(a, b, cache={}):
    cache.setdefault(a, b)
    print(cache)
    
built_in_cache('a', 1)
built_in_cache('b', 3)
built_in_cache('c', 4)
built_in_cache('a', 2)
# Out:
# {'a': 1}
# {'a': 1, 'b': 3}
# {'a': 1, 'b': 3, 'c': 4}
# {'a': 1, 'b': 3, 'c': 4}

# %%
sequencing_experiments = {}
sequencing_subpools = {}

# %%
def get_or_create_sequencing_run(name, run_date, platform, plate, accessions=None):
    if name in sequencing_experiments:
        return sequencing_experiments[name]
    
    try:
        sequencing_run = models.SequencingRun.objects.get(name=name)
    except models.SequencingRun.DoesNotExist:
        sequencing_run = models.SequencingRun(
            name=name,
            run_date=run_date,
            platform=platform,
            plate=plate,
            stranded=models.StrandedEnum.REVERSE,
        )
        sequencing_run.save()
        if accessions is not None:
            sequencing_run.accession.set(accessions)
            sequencing_run.save
        
    sequencing_experiments[name] = sequencing_run
    return sequencing_run

def get_or_create_subpool_in_run(subpool, sequencing_run, status, raw_reads=None, measurement_set=None):
    try:
        subpool_in_run = models.SubpoolInRun.objects.get(subpool=subpool, sequencing_run=sequencing_run)
    except models.SubpoolInRun.DoesNotExist:
        subpool_in_run = models.SubpoolInRun(
            subpool=subpool, 
            sequencing_run=sequencing_run,
            raw_reads=None,
            status=status,
            measurement_set=measurement_set,
        )
        subpool_in_run.save()
        
    sequencing_subpools[name] = subpool_in_run
    return subpool_in_run


def lane_or_none(value):
    if pandas.isnull(value):
        return None
    elif isinstance(value, float):
        return int(value)
    elif value.startswith("L"):
        return int(value[1:])
    else:
        return int(value)

def load_fastqs(submittable_subpools):
    fastqs = load_fastq_csv()
    measurement_sets = load_submitted_measurement_sets()

    for i, row in fastqs.iterrows():
        #plate_name = normalize_plate_name(row.experiment)
        #subpool_name = "{}_{}".format(row.plate_id, row.subpool_name)
        #index_id = int(row.index_id)
        fastq_relative = Path(row.filename)
        sequencing_run_name = str(Path(fastq_relative.parts[0])/fastq_relative.parts[1])
        sequencer = row.get("sequencer")
        run_date = row["ctime"]
        md5sum = row["md5sum"]

        #if row["read_id"] in ('I1',):
        #    continue

        subpool = get_subpool_from_fastq_row(row)

        if subpool is None:
            print("Unable to import {row.filename}")
            continue

        current_plate = subpool.plate

        platform = {
            "A00850": models.Platform.objects.get(display_name="Novaseq 6000"),
            "VH00582": models.Platform.objects.get(display_name="Nextseq 2000"),
            "minion": models.Platform.objects.get(name="minion"),
            "promethion": models.Platform.objects.get(name="promethion"),
        }[sequencer]

        subpool_status = {
            "Yes": models.RunStatusEnum.PASS,
            "No": models.RunStatusEnum.FAILED,
            None: models.RunStatusEnum.FAILED,
        }[submittable_subpools.get(subpool.name)]

        sequencing_run = get_or_create_sequencing_run(sequencing_run_name, run_date, platform, current_plate, accessions=None)
        subpool_run = get_or_create_subpool_in_run(subpool=subpool, sequencing_run=sequencing_run, status=subpool_status)

        for accession_prefix in ["igvftst", "igvf"]:
            file_set_name = None
            submitted_md5s = submitted_sheets[accession_prefix]["sequence_file"].set_index("md5sum")
            if row.md5sum in submitted_md5s.index:
                file_set_alias = submitted_md5s.loc[row.md5sum]["file_set"]
                file_set_name = file_set_alias.split(":")[1]

        if file_set_name is None:
            pass
        elif file_set_name not in measurement_sets:
            # skip if there hasn't been a submitted measurement_set
            pass
        elif subpool_run.measurement_set is None:
            subpool_run.measurement_set = measurement_sets[file_set_name]
            subpool_run.save()
            print(f"updating {subpool_run} measurement set to {measurement_sets[file_set_name]}")
        else:
            assert subpool_run.measurement_set.name == file_set_name, f"SubpoolInRun measurement_set mismatch {subpool_run.measurement_set.name} {file_set_name}"


        subpool_file = models.SubpoolInRunFile(
            sequencing_run=sequencing_run,
            subpool_run=subpool_run,
            md5sum=md5sum,
            filename=str(fastq_relative),
            flowcell_id=row["flowcell_id"],
        )
        if not pandas.isnull(row["lane"]):
            subpool_file.lane = lane_or_none(row["lane"])
        if not pandas.isnull(row["read"]):
            subpool_file.read = row["read"]
        subpool_file.save()

        for accession_info in submitted_sequence_file.get(str(fastq_relative), []):
            if pandas.notnull(accession_info["name"]):
                accession = models.Accession(
                    accession_prefix=accession_info["accession_prefix"],
                    name=accession_info["name"],
                    uuid=accession_info["uuid"],
                    see_also=accession_info["see_also"],
                )
                accession.save()                
                subpool_file.accession.add(accession)
                subpool_file.save()

load_fastqs(submittable_subpools)

print("total plates", models.SplitSeqPlate.objects.count())
print("total sequencing runs", models.SequencingRun.objects.count())
print("total subpools", models.Subpool.objects.count())
print("total subpool in run", models.SubpoolInRun.objects.count())
print("total subpool in run files", models.SubpoolInRunFile.objects.count())
# Out:
# loaded 173 measurement_sets
# updating 003_13A igvf_003/nextseq2 measurement set to 003_13A_illumina
# updating 003_67A igvf_003/nextseq measurement set to 003_67A_illumina
# updating 003_67B igvf_003/nextseq measurement set to 003_67B_illumina
# updating 003_67I igvf_003/nova1 measurement set to 003_67I_illumina
# updating 003_67I igvf_003/nova2 measurement set to 003_67I_illumina
# updating 003_67J igvf_003/nova1 measurement set to 003_67J_illumina
# updating 003_67J igvf_003/nova2 measurement set to 003_67J_illumina
# updating 003_67K igvf_003/nova1 measurement set to 003_67K_illumina
# updating 003_67K igvf_003/nova2 measurement set to 003_67K_illumina
# updating 003_67L igvf_003/nova1 measurement set to 003_67L_illumina
# updating 003_67L igvf_003/nova2 measurement set to 003_67L_illumina
# updating 003_67M igvf_003/nova1 measurement set to 003_67M_illumina
# updating 003_67M igvf_003/nova2 measurement set to 003_67M_illumina
# updating 003_67N igvf_003/nova1 measurement set to 003_67N_illumina
# updating 003_67N igvf_003/nova2 measurement set to 003_67N_illumina
# updating 003_67O igvf_003/nova1 measurement set to 003_67O_illumina
# updating 003_67O igvf_003/nova2 measurement set to 003_67O_illumina
# updating 003_67A igvf_003/nova1 measurement set to 003_67A_illumina
# updating 003_67A igvf_003/nova2 measurement set to 003_67A_illumina
# updating 003_67B igvf_003/nova1 measurement set to 003_67B_illumina
# updating 003_67B igvf_003/nova2 measurement set to 003_67B_illumina
# updating 003_67C igvf_003/nova1 measurement set to 003_67C_illumina
# updating 003_67C igvf_003/nova2 measurement set to 003_67C_illumina
# updating 003_67D igvf_003/nova1 measurement set to 003_67D_illumina
# updating 003_67D igvf_003/nova2 measurement set to 003_67D_illumina
# updating 003_67E igvf_003/nova1 measurement set to 003_67E_illumina
# updating 003_67E igvf_003/nova2 measurement set to 003_67E_illumina
# updating 003_67F igvf_003/nova1 measurement set to 003_67F_illumina
# updating 003_67F igvf_003/nova2 measurement set to 003_67F_illumina
# updating 003_67G igvf_003/nova1 measurement set to 003_67G_illumina
# updating 003_67G igvf_003/nova2 measurement set to 003_67G_illumina
# updating 003_67H igvf_003/nova1 measurement set to 003_67H_illumina
# updating 003_67H igvf_003/nova2 measurement set to 003_67H_illumina
# updating 004_13A igvf_004/nextseq2 measurement set to 004_13A_illumina
# updating 004_67A igvf_004/nextseq measurement set to 004_67A_illumina
# updating 004_67B igvf_004/nextseq measurement set to 004_67B_illumina
# updating 004_67I igvf_004/nova1 measurement set to 004_67I_illumina
# updating 004_67I igvf_004/nova2 measurement set to 004_67I_illumina
# updating 004_67J igvf_004/nova1 measurement set to 004_67J_illumina
# updating 004_67J igvf_004/nova2 measurement set to 004_67J_illumina
# updating 004_67K igvf_004/nova1 measurement set to 004_67K_illumina
# updating 004_67K igvf_004/nova2 measurement set to 004_67K_illumina
# updating 004_67L igvf_004/nova1 measurement set to 004_67L_illumina
# updating 004_67L igvf_004/nova2 measurement set to 004_67L_illumina
# updating 004_67M igvf_004/nova1 measurement set to 004_67M_illumina
# updating 004_67M igvf_004/nova2 measurement set to 004_67M_illumina
# updating 004_67N igvf_004/nova1 measurement set to 004_67N_illumina
# updating 004_67N igvf_004/nova2 measurement set to 004_67N_illumina
# updating 004_67O igvf_004/nova1 measurement set to 004_67O_illumina
# updating 004_67O igvf_004/nova2 measurement set to 004_67O_illumina
# updating 004_67A igvf_004/nova1 measurement set to 004_67A_illumina
# updating 004_67A igvf_004/nova2 measurement set to 004_67A_illumina
# updating 004_67B igvf_004/nova1 measurement set to 004_67B_illumina
# updating 004_67B igvf_004/nova2 measurement set to 004_67B_illumina
# updating 004_67C igvf_004/nova1 measurement set to 004_67C_illumina
# updating 004_67C igvf_004/nova2 measurement set to 004_67C_illumina
# updating 004_67D igvf_004/nova1 measurement set to 004_67D_illumina
# updating 004_67D igvf_004/nova2 measurement set to 004_67D_illumina
# updating 004_67E igvf_004/nova1 measurement set to 004_67E_illumina
# updating 004_67E igvf_004/nova2 measurement set to 004_67E_illumina
# updating 004_67F igvf_004/nova1 measurement set to 004_67F_illumina
# updating 004_67F igvf_004/nova2 measurement set to 004_67F_illumina
# updating 004_67G igvf_004/nova1 measurement set to 004_67G_illumina
# updating 004_67G igvf_004/nova2 measurement set to 004_67G_illumina
# updating 004_67H igvf_004/nova1 measurement set to 004_67H_illumina
# updating 004_67H igvf_004/nova2 measurement set to 004_67H_illumina
# updating 005_13A igvf_005/nextseq2 measurement set to 005_13A_illumina
# updating 005_67I igvf_005/nova1 measurement set to 005_67I_illumina
# updating 005_67I igvf_005/nova2 measurement set to 005_67I_illumina
# updating 005_67J igvf_005/nova1 measurement set to 005_67J_illumina
# updating 005_67J igvf_005/nova2 measurement set to 005_67J_illumina
# updating 005_67K igvf_005/nova1 measurement set to 005_67K_illumina
# updating 005_67K igvf_005/nova2 measurement set to 005_67K_illumina
# updating 005_67L igvf_005/nova1 measurement set to 005_67L_illumina
# updating 005_67L igvf_005/nova2 measurement set to 005_67L_illumina
# updating 005_67M igvf_005/nova1 measurement set to 005_67M_illumina
# updating 005_67M igvf_005/nova2 measurement set to 005_67M_illumina
# updating 005_67N igvf_005/nova1 measurement set to 005_67N_illumina
# updating 005_67N igvf_005/nova2 measurement set to 005_67N_illumina
# updating 005_67O igvf_005/nova1 measurement set to 005_67O_illumina
# updating 005_67O igvf_005/nova2 measurement set to 005_67O_illumina
# updating 005_67A igvf_005/nova1 measurement set to 005_67A_illumina
# updating 005_67A igvf_005/nova2 measurement set to 005_67A_illumina
# updating 005_67B igvf_005/nova1 measurement set to 005_67B_illumina
# updating 005_67B igvf_005/nova2 measurement set to 005_67B_illumina
# updating 005_67C igvf_005/nova1 measurement set to 005_67C_illumina
# updating 005_67C igvf_005/nova2 measurement set to 005_67C_illumina
# updating 005_67D igvf_005/nova1 measurement set to 005_67D_illumina
# updating 005_67D igvf_005/nova2 measurement set to 005_67D_illumina
# updating 005_67E igvf_005/nova1 measurement set to 005_67E_illumina
# updating 005_67E igvf_005/nova2 measurement set to 005_67E_illumina
# updating 005_67F igvf_005/nova1 measurement set to 005_67F_illumina
# updating 005_67F igvf_005/nova2 measurement set to 005_67F_illumina
# updating 005_67G igvf_005/nova1 measurement set to 005_67G_illumina
# updating 005_67G igvf_005/nova2 measurement set to 005_67G_illumina
# updating 005_67H igvf_005/nova1 measurement set to 005_67H_illumina
# updating 005_67H igvf_005/nova2 measurement set to 005_67H_illumina
# updating 007_13A igvf_007/nextseq2 measurement set to 007_13A_illumina
# updating 007_67I igvf_007/nova1 measurement set to 007_67I_illumina
# updating 007_67I igvf_007/nova2 measurement set to 007_67I_illumina
# updating 007_67J igvf_007/nova1 measurement set to 007_67J_illumina
# updating 007_67J igvf_007/nova2 measurement set to 007_67J_illumina
# updating 007_67K igvf_007/nova1 measurement set to 007_67K_illumina
# updating 007_67K igvf_007/nova2 measurement set to 007_67K_illumina
# updating 007_67L igvf_007/nova1 measurement set to 007_67L_illumina
# updating 007_67L igvf_007/nova2 measurement set to 007_67L_illumina
# updating 007_67M igvf_007/nova1 measurement set to 007_67M_illumina
# updating 007_67M igvf_007/nova2 measurement set to 007_67M_illumina
# updating 007_67N igvf_007/nova1 measurement set to 007_67N_illumina
# updating 007_67N igvf_007/nova2 measurement set to 007_67N_illumina
# updating 007_67O igvf_007/nova1 measurement set to 007_67O_illumina
# updating 007_67O igvf_007/nova2 measurement set to 007_67O_illumina
# updating 007_67A igvf_007/nova1 measurement set to 007_67A_illumina
# updating 007_67A igvf_007/nova2 measurement set to 007_67A_illumina
# updating 007_67B igvf_007/nova1 measurement set to 007_67B_illumina
# updating 007_67B igvf_007/nova2 measurement set to 007_67B_illumina
# updating 007_67C igvf_007/nova1 measurement set to 007_67C_illumina
# updating 007_67C igvf_007/nova2 measurement set to 007_67C_illumina
# updating 007_67D igvf_007/nova1 measurement set to 007_67D_illumina
# updating 007_67D igvf_007/nova2 measurement set to 007_67D_illumina
# updating 007_67E igvf_007/nova1 measurement set to 007_67E_illumina
# updating 007_67E igvf_007/nova2 measurement set to 007_67E_illumina
# updating 007_67F igvf_007/nova1 measurement set to 007_67F_illumina
# updating 007_67F igvf_007/nova2 measurement set to 007_67F_illumina
# updating 007_67G igvf_007/nova1 measurement set to 007_67G_illumina
# updating 007_67G igvf_007/nova2 measurement set to 007_67G_illumina
# updating 007_67H igvf_007/nova1 measurement set to 007_67H_illumina
# updating 007_67H igvf_007/nova2 measurement set to 007_67H_illumina
# updating 008_67C igvf_008/nextseq measurement set to 008_67C_illumina
# updating 008_67G igvf_008/nextseq measurement set to 008_67G_illumina
# updating 008_67I igvf_008/nova1 measurement set to 008_67I_illumina
# updating 008_67A igvf_008/nova1 measurement set to 008_67A_illumina
# updating 008_67B igvf_008/nova1 measurement set to 008_67B_illumina
# updating 008_67C igvf_008/nova1 measurement set to 008_67C_illumina
# updating 008_67D igvf_008/nova1 measurement set to 008_67D_illumina
# updating 008_67E igvf_008/nova1 measurement set to 008_67E_illumina
# updating 008_67F igvf_008/nova1 measurement set to 008_67F_illumina
# updating 008_67G igvf_008/nova1 measurement set to 008_67G_illumina
# updating 008_67H igvf_008/nova1 measurement set to 008_67H_illumina
# updating 008B_13A igvf_008b/nextseq2 measurement set to 008B_13A_illumina
# updating 008B_67G igvf_008b/nextseq measurement set to 008B_67G_illumina
# updating 008B_67I igvf_008b/nextseq measurement set to 008B_67I_illumina
# updating 008B_67I igvf_008b/nova1 measurement set to 008B_67I_illumina
# updating 008B_67J igvf_008b/nova1 measurement set to 008B_67J_illumina
# updating 008B_67A igvf_008b/nova1 measurement set to 008B_67A_illumina
# updating 008B_67B igvf_008b/nova1 measurement set to 008B_67B_illumina
# updating 008B_67C igvf_008b/nova1 measurement set to 008B_67C_illumina
# updating 008B_67D igvf_008b/nova1 measurement set to 008B_67D_illumina
# updating 008B_67E igvf_008b/nova1 measurement set to 008B_67E_illumina
# updating 008B_67F igvf_008b/nova1 measurement set to 008B_67F_illumina
# updating 008B_67G igvf_008b/nova1 measurement set to 008B_67G_illumina
# updating 008B_67H igvf_008b/nova1 measurement set to 008B_67H_illumina
# updating 009_13A igvf_009/nextseq2 measurement set to 009_13A_illumina
# updating 009_67A igvf_009/nextseq measurement set to 009_67A_illumina
# updating 009_67O igvf_009/nextseq measurement set to 009_67O_illumina
# updating 009_67I igvf_009/nova1 measurement set to 009_67I_illumina
# updating 009_67I igvf_009/nova2 measurement set to 009_67I_illumina
# updating 009_67J igvf_009/nova1 measurement set to 009_67J_illumina
# updating 009_67J igvf_009/nova2 measurement set to 009_67J_illumina
# updating 009_67K igvf_009/nova1 measurement set to 009_67K_illumina
# updating 009_67K igvf_009/nova2 measurement set to 009_67K_illumina
# updating 009_67L igvf_009/nova1 measurement set to 009_67L_illumina
# updating 009_67L igvf_009/nova2 measurement set to 009_67L_illumina
# updating 009_67M igvf_009/nova1 measurement set to 009_67M_illumina
# updating 009_67M igvf_009/nova2 measurement set to 009_67M_illumina
# updating 009_67N igvf_009/nova1 measurement set to 009_67N_illumina
# updating 009_67N igvf_009/nova2 measurement set to 009_67N_illumina
# updating 009_67O igvf_009/nova1 measurement set to 009_67O_illumina
# updating 009_67O igvf_009/nova2 measurement set to 009_67O_illumina
# updating 009_67A igvf_009/nova1 measurement set to 009_67A_illumina
# updating 009_67A igvf_009/nova2 measurement set to 009_67A_illumina
# updating 009_67B igvf_009/nova1 measurement set to 009_67B_illumina
# updating 009_67B igvf_009/nova2 measurement set to 009_67B_illumina
# updating 009_67C igvf_009/nova1 measurement set to 009_67C_illumina
# updating 009_67C igvf_009/nova2 measurement set to 009_67C_illumina
# updating 009_67D igvf_009/nova1 measurement set to 009_67D_illumina
# updating 009_67D igvf_009/nova2 measurement set to 009_67D_illumina
# updating 009_67E igvf_009/nova1 measurement set to 009_67E_illumina
# updating 009_67E igvf_009/nova2 measurement set to 009_67E_illumina
# updating 009_67F igvf_009/nova1 measurement set to 009_67F_illumina
# updating 009_67F igvf_009/nova2 measurement set to 009_67F_illumina
# updating 009_67G igvf_009/nova1 measurement set to 009_67G_illumina
# updating 009_67G igvf_009/nova2 measurement set to 009_67G_illumina
# updating 009_67H igvf_009/nova1 measurement set to 009_67H_illumina
# updating 009_67H igvf_009/nova2 measurement set to 009_67H_illumina
# updating 010_13A igvf_010/nextseq2 measurement set to 010_13A_illumina
# updating 010_67D igvf_010/nextseq measurement set to 010_67D_illumina
# updating 010_67O igvf_010/nextseq measurement set to 010_67O_illumina
# updating 010_67I igvf_010/nova1 measurement set to 010_67I_illumina
# updating 010_67I igvf_010/nova2 measurement set to 010_67I_illumina
# updating 010_67J igvf_010/nova1 measurement set to 010_67J_illumina
# updating 010_67J igvf_010/nova2 measurement set to 010_67J_illumina
# updating 010_67K igvf_010/nova1 measurement set to 010_67K_illumina
# updating 010_67K igvf_010/nova2 measurement set to 010_67K_illumina
# updating 010_67L igvf_010/nova1 measurement set to 010_67L_illumina
# updating 010_67L igvf_010/nova2 measurement set to 010_67L_illumina
# updating 010_67M igvf_010/nova1 measurement set to 010_67M_illumina
# updating 010_67M igvf_010/nova2 measurement set to 010_67M_illumina
# updating 010_67N igvf_010/nova1 measurement set to 010_67N_illumina
# updating 010_67N igvf_010/nova2 measurement set to 010_67N_illumina
# updating 010_67O igvf_010/nova1 measurement set to 010_67O_illumina
# updating 010_67O igvf_010/nova2 measurement set to 010_67O_illumina
# updating 010_67A igvf_010/nova1 measurement set to 010_67A_illumina
# updating 010_67A igvf_010/nova2 measurement set to 010_67A_illumina
# updating 010_67B igvf_010/nova1 measurement set to 010_67B_illumina
# updating 010_67B igvf_010/nova2 measurement set to 010_67B_illumina
# updating 010_67C igvf_010/nova1 measurement set to 010_67C_illumina
# updating 010_67C igvf_010/nova2 measurement set to 010_67C_illumina
# updating 010_67D igvf_010/nova1 measurement set to 010_67D_illumina
# updating 010_67D igvf_010/nova2 measurement set to 010_67D_illumina
# updating 010_67E igvf_010/nova1 measurement set to 010_67E_illumina
# updating 010_67E igvf_010/nova2 measurement set to 010_67E_illumina
# updating 010_67F igvf_010/nova1 measurement set to 010_67F_illumina
# updating 010_67F igvf_010/nova2 measurement set to 010_67F_illumina
# updating 010_67G igvf_010/nova1 measurement set to 010_67G_illumina
# updating 010_67G igvf_010/nova2 measurement set to 010_67G_illumina
# updating 010_67H igvf_010/nova1 measurement set to 010_67H_illumina
# updating 010_67H igvf_010/nova2 measurement set to 010_67H_illumina
# updating 011_13A igvf_011/nextseq2 measurement set to 011_13A_illumina
# updating 011_67M igvf_011/nextseq measurement set to 011_67M_illumina
# updating 011_67O igvf_011/nextseq measurement set to 011_67O_illumina
# updating 011_67I igvf_011/nova1 measurement set to 011_67I_illumina
# updating 011_67I igvf_011/nova2 measurement set to 011_67I_illumina
# updating 011_67J igvf_011/nova1 measurement set to 011_67J_illumina
# updating 011_67J igvf_011/nova2 measurement set to 011_67J_illumina
# updating 011_67K igvf_011/nova1 measurement set to 011_67K_illumina
# updating 011_67K igvf_011/nova2 measurement set to 011_67K_illumina
# updating 011_67L igvf_011/nova1 measurement set to 011_67L_illumina
# updating 011_67L igvf_011/nova2 measurement set to 011_67L_illumina
# updating 011_67M igvf_011/nova1 measurement set to 011_67M_illumina
# updating 011_67M igvf_011/nova2 measurement set to 011_67M_illumina
# updating 011_67N igvf_011/nova1 measurement set to 011_67N_illumina
# updating 011_67N igvf_011/nova2 measurement set to 011_67N_illumina
# updating 011_67O igvf_011/nova1 measurement set to 011_67O_illumina
# updating 011_67O igvf_011/nova2 measurement set to 011_67O_illumina
# updating 011_67A igvf_011/nova1 measurement set to 011_67A_illumina
# updating 011_67A igvf_011/nova2 measurement set to 011_67A_illumina
# updating 011_67B igvf_011/nova1 measurement set to 011_67B_illumina
# updating 011_67B igvf_011/nova2 measurement set to 011_67B_illumina
# updating 011_67C igvf_011/nova1 measurement set to 011_67C_illumina
# updating 011_67C igvf_011/nova2 measurement set to 011_67C_illumina
# updating 011_67D igvf_011/nova1 measurement set to 011_67D_illumina
# updating 011_67D igvf_011/nova2 measurement set to 011_67D_illumina
# updating 011_67E igvf_011/nova1 measurement set to 011_67E_illumina
# updating 011_67E igvf_011/nova2 measurement set to 011_67E_illumina
# updating 011_67F igvf_011/nova1 measurement set to 011_67F_illumina
# updating 011_67F igvf_011/nova2 measurement set to 011_67F_illumina
# updating 011_67G igvf_011/nova1 measurement set to 011_67G_illumina
# updating 011_67G igvf_011/nova2 measurement set to 011_67G_illumina
# updating 011_67H igvf_011/nova1 measurement set to 011_67H_illumina
# updating 011_67H igvf_011/nova2 measurement set to 011_67H_illumina
# updating 012_13A igvf_012/nextseq measurement set to 012_13A_illumina
# updating 012_13B igvf_012/nextseq measurement set to 012_13B_illumina
# updating 012_13C igvf_012/nextseq measurement set to 012_13C_illumina
# updating 012_13D igvf_012/nextseq measurement set to 012_13D_illumina
# updating 012_13E igvf_012/nextseq measurement set to 012_13E_illumina
# updating 012_13F igvf_012/nextseq measurement set to 012_13F_illumina
# updating 012_13G igvf_012/nextseq measurement set to 012_13G_illumina
# updating 012_13H igvf_012/nextseq measurement set to 012_13H_illumina
# updating 013_13A igvf_013/nextseq measurement set to 013_13A_illumina
# updating 013_67A igvf_013/nova1 measurement set to 013_67A_illumina
# updating 013_67B igvf_013/nova1 measurement set to 013_67B_illumina
# updating 013_67C igvf_013/nova1 measurement set to 013_67C_illumina
# updating 013_67D igvf_013/nova1 measurement set to 013_67D_illumina
# updating 013_67E igvf_013/nova1 measurement set to 013_67E_illumina
# updating 013_67F igvf_013/nova1 measurement set to 013_67F_illumina
# updating 013_67G igvf_013/nova1 measurement set to 013_67G_illumina
# updating 013_67H igvf_013/nova1 measurement set to 013_67H_illumina
# updating 013_67H igvf_013/nextseq measurement set to 013_67H_illumina
# updating 013_67I igvf_013/nova1 measurement set to 013_67I_illumina
# updating 013_67J igvf_013/nova1 measurement set to 013_67J_illumina
# updating 013_67J igvf_013/nextseq measurement set to 013_67J_illumina
# updating 013_67K igvf_013/nova1 measurement set to 013_67K_illumina
# updating 013_67L igvf_013/nova1 measurement set to 013_67L_illumina
# updating 013_67M igvf_013/nova1 measurement set to 013_67M_illumina
# updating 013_67N igvf_013/nova1 measurement set to 013_67N_illumina
# updating 014_13A igvf_014/nextseq measurement set to 014_13A_illumina
# updating 014_13B igvf_014/nextseq measurement set to 014_13B_illumina
# updating 014_13C igvf_014/nextseq measurement set to 014_13C_illumina
# updating 014_13D igvf_014/nextseq measurement set to 014_13D_illumina
# updating 014_13E igvf_014/nextseq measurement set to 014_13E_illumina
# updating 014_13F igvf_014/nextseq measurement set to 014_13F_illumina
# updating 014_13G igvf_014/nextseq measurement set to 014_13G_illumina
# updating 014_13H igvf_014/nextseq measurement set to 014_13H_illumina
# updating B01_13A igvf_b01/next2 measurement set to B01_13A_illumina
# updating B01_13A igvf_b01/next1 measurement set to B01_13A_illumina
# updating B01_13B igvf_b01/next2 measurement set to B01_13B_illumina
# updating B01_13B igvf_b01/next1 measurement set to B01_13B_illumina
# updating B01_13C igvf_b01/next2 measurement set to B01_13C_illumina
# updating B01_13C igvf_b01/next1 measurement set to B01_13C_illumina
# updating B01_13D igvf_b01/next2 measurement set to B01_13D_illumina
# updating B01_13D igvf_b01/next1 measurement set to B01_13D_illumina
# updating B01_13E igvf_b01/next2 measurement set to B01_13E_illumina
# updating B01_13E igvf_b01/next1 measurement set to B01_13E_illumina
# updating B01_13F igvf_b01/next2 measurement set to B01_13F_illumina
# updating B01_13F igvf_b01/next1 measurement set to B01_13F_illumina
# updating B01_13G igvf_b01/next2 measurement set to B01_13G_illumina
# updating B01_13G igvf_b01/next1 measurement set to B01_13G_illumina
# updating B01_13H igvf_b01/next2 measurement set to B01_13H_illumina
# updating B01_13H igvf_b01/next1 measurement set to B01_13H_illumina
# total plates 14
# total sequencing runs 38
# total subpools 255
# total subpool in run 304
# total subpool in run files 3119

# %%
for q in models.Subpool.objects.filter(plate__name="IGVF_014", index="UDI24"):
    print(q.name, q.index, q.nuclei, q.selection_type)
# Out:
# 014_13H UDI24 10400 NO

# %%
[(x.name, x.index, x.selection_type) for x in models.Subpool.objects.filter(plate__name="IGVF_013")]
# Out:
# [('013_13A', 'UDI01', 'EX'),
#  ('013_67A', 'UDI02', 'NO'),
#  ('013_67B', 'UDI03', 'NO'),
#  ('013_67C', 'UDI04', 'NO'),
#  ('013_67D', 'UDI05', 'NO'),
#  ('013_67E', 'UDI06', 'NO'),
#  ('013_67F', 'UDI07', 'NO'),
#  ('013_67G', 'UDI08', 'NO'),
#  ('013_67H', 'UDI09', 'NO'),
#  ('013_67I', 'UDI10', 'NO'),
#  ('013_67J', 'UDI11', 'NO'),
#  ('013_67K', 'UDI12', 'NO'),
#  ('013_67L', 'UDI13', 'NO'),
#  ('013_67M', 'UDI14', 'NO'),
#  ('013_67N', 'UDI15', 'NO')]

# %%
def print_subpool_submission_status(fastqs):
    for i, row in fastqs.iterrows():
        plate_name = normalize_plate_name(row.experiment)
        index_id = row.index_id
        fastq_relative = Path(row.filename)
        sequencing_run_name = str(Path(fastq_relative.parts[0])/fastq_relative.parts[1])
        sequencer = row.get("sequencer")
        run_date = row["ctime"]
        md5sum = row["md5sum"]

        #if row["read_id"] in ('I1',):
        #    continue

        subpool = get_subpool_from_fastq_row(row)
        current_plate = subpool.plate

        platform = {
            "A00850": models.Platform.objects.get(display_name="Novaseq 6000"),
            "VH00582": models.Platform.objects.get(display_name="Nextseq 2000"),
            "minion": models.Platform.objects.get(name="minion"),
            "promethion": models.Platform.objects.get(name="promethion"),
        }[sequencer]

        subpool_status = {
            "Yes": models.RunStatus.PASS,
            "No": models.RunStatus.FAILED,
            None: models.RunStatus.FAILED,
        }[submittable_subpools.get(subpool.name)]

        #sequencing_run = get_or_create_sequencing_run(sequencing_run_name, run_date, platform, current_plate, accessions=None)
        #subpool_run = get_or_create_subpool_in_run(subpool=subpool, sequencing_run=sequencing_run, status=subpool_status)
        print(row.filename, row.index_id, sequencing_run_name, run_date, subpool, subpool_status)

#print_subpool_submission_status(fastqs)

# %%
md5counts = Counter(fastqs["md5sum"])
dupmd5s = set()
for md5sum in md5counts:
    if md5counts[md5sum] > 1:
        dupmd5s.add(md5sum)
        
dupfiles = fastqs[fastqs["md5sum"].isin(dupmd5s)].sort_values(["experiment", "md5sum", "filename"])
print(dupfiles.shape)
dupfiles
# Out:
# (0, 20)
# Empty DataFrame
# Columns: [experiment, family, filename, md5sum, size, ctime, plate_id, subpool_name, fragment, compression, sequencer, sequencer_run, flowcell_id, nuclei, read, barcode, index_id, sample_id, lane, exome_capture]
# Index: []

# %%
print(dupfiles.to_csv(index=False))
# Out:
# experiment,family,filename,md5sum,size,ctime,plate_id,subpool_name,fragment,compression,sequencer,sequencer_run,flowcell_id,nuclei,read,barcode,index_id,sample_id,lane,exome_capture

# %%
models.SexEnum.choices
# Out:
# [('M', 'male'), ('F', 'female'), ('U', 'unknown'), ('O', 'other')]

# %%
# In case of interrupted upload

if 0:
    EC = str(Path("~/proj/encoded_client").expanduser())
    if EC not in sys.path:
        sys.path.append(EC)

    from encoded_client.encoded import ENCODED

    server = ENCODED("api.data.igvf.org")

    submitted_tissues = load_submitted_tissues()
    for tissue_id in submitted_tissues:
        for record in submitted_tissues[tissue_id]:
            if pandas.isnull(record["uuid"] ):
                tissue = server.get_json(record["see_also"])
                print("{}\t{}".format(record["name"], tissue["uuid"]))

# %%
models.SubpoolInRunFile.objects.get(md5sum="2a5a07155767a2f541cfb20e7d0636e0")
# Out:
# <SubpoolInRunFile: igvf_b01/next2/B01_13H_R2.fastq.gz>
